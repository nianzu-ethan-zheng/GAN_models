# %%
# Standard library
import tensorflow as tf
import numpy as np
import _pickle as pickle
import os, sys
# Packages
from model import build_graph,config

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
from aae_dim_reduction import Operation
import dataset
from process import Process
import sampler
import plot as plt

# %%
def main(run_load_from_file=False):
    # load MNIST images
    images, labels = dataset.load_train_images()

    # config
    opt = Operation()
    opt.check_dir(config.ckpt_dir, is_restart=False)
    opt.check_dir(config.log_dir, is_restart=True)

    # setting
    max_epoch = 510
    num_trains_per_epoch = 500
    batch_size_l = 100
    batch_size_u = 100

    # create semi-supervised split
    num_validation_data = 10000
    num_labeled_data = 1000
    num_types_of_label = 10
    training_images_l, training_labels_l, training_images_u, validation_images, validation_labels = dataset.create_semisupervised(
        images, labels, num_validation_data, num_labeled_data, num_types_of_label)

    # training
    with tf.device(config.device):
        h = build_graph()

    sess_config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
    sess_config.gpu_options.allow_growth = True
    sess_config.gpu_options.per_process_gpu_memory_fraction = 0.9
    saver = tf.train.Saver(max_to_keep=2)

    with tf.Session(config=sess_config) as sess:
        '''
         Load from checkpoint or start a new session

        '''
        if run_load_from_file:
            saver.restore(sess, tf.train.latest_checkpoint(config.ckpt_dir))
            training_epoch_loss, _ = pickle.load(open(config.ckpt_dir + '/pickle.pkl', 'rb'))
        else:
            sess.run(tf.global_variables_initializer())
            training_epoch_loss = []

        # Recording loss per epoch
        process = Process()
        for epoch in range(max_epoch):
            process.start_epoch(epoch, max_epoch)

            '''
            Learning rate generator

            '''
            learning_rate = opt.ladder_learning_rate(epoch + len(training_epoch_loss))

            # Recording loss per iteration
            training_loss_set = []
            sum_loss_reconstruction = 0
            sum_loss_supervised = 0
            sum_loss_discrminator = 0
            sum_loss_generator = 0
            sum_loss_cluster_head = 0

            process_iteration = Process()
            for i in range(num_trains_per_epoch):
                process_iteration.start_epoch(i, num_trains_per_epoch)

                # sample from data distribution
                images_l, label_onehot_l, label_id_l = dataset.sample_labeled_data(training_images_l, training_labels_l,
                                                                                   batch_size_l)
                images_u = dataset.sample_unlabeled_data(training_images_u, batch_size_u)

                if epoch ==0:
                    for j in range(5):
                        starting_labels, ending_labels = dataset.cluster_create_dataset(config.ndim_y)
                        _, loss_transform = sess.run([h.opt_t, h.loss_t], feed_dict={
                            h.g_s: starting_labels,
                            h.g_e: ending_labels,
                            h.lr: learning_rate
                        })
                # reconstruction_phase
                _, loss_reconstruction = sess.run([h.opt_r, h.loss_r], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                z_true_u = sampler.gaussian(batch_size_u, config.ndim_z, mean=0, var=1)
                y_true_u = sampler.onehot_categorical(batch_size_u, config.ndim_y)
                # adversarial phase for discriminator
                _, loss_discriminator_y = sess.run([h.opt_dy, h.loss_dy], feed_dict={
                    h.x: images_u,
                    h.y: y_true_u,
                    h.lr: learning_rate
                })

                _, loss_discriminator_z = sess.run([h.opt_dz, h.loss_dz], feed_dict={
                    h.x: images_u,
                    h.z: z_true_u,
                    h.lr: learning_rate
                })

                loss_discriminator = loss_discriminator_y + loss_discriminator_z

                # adversarial phase for generator
                _, loss_generator_y, loss_generator_z = sess.run([h.opt_e, h.loss_gy, h.loss_gz], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                loss_generator = loss_generator_y + loss_generator_z

                # supervised phase
                _, loss_generator_supervised = sess.run([h.opt_ey, h.loss_ey], feed_dict={
                    h.x: images_l,
                    h.y_s: label_id_l,
                    h.lr: learning_rate
                })

                # additional cost function that penalizes the euclidean between of every two of cluster
                

                training_loss_set.append([
                    loss_reconstruction,
                    loss_discriminator,
                    loss_discriminator_y,
                    loss_discriminator_z,
                    loss_generator,
                    loss_generator_z,
                    loss_generator_y,
                    loss_generator_supervised,
                    loss_transform
                ])

                sum_loss_reconstruction += loss_reconstruction
                sum_loss_discrminator += loss_discriminator
                sum_loss_generator += loss_generator
                sum_loss_supervised += loss_generator_supervised
                sum_loss_cluster_head += loss_transform

                if i % 1000 == 0:
                    process_iteration.show_table_2d(i, num_trains_per_epoch, {
                        'reconstruction': sum_loss_reconstruction / (i + 1),
                        'discriminator': sum_loss_discrminator / (i + 1),
                        'generator': sum_loss_generator / (i + 1),
                        'supervise': sum_loss_supervised / (i + 1),
                        'cluster_head':sum_loss_cluster_head / (i + 1)
                    })
            # In end of epoch, summary the loss
            average_training_loss_per_epoch = np.mean(np.array(training_loss_set), axis=0)

            # validation phase
            images_v_segments = np.split(validation_images, num_validation_data // 1000)
            labels_v_segments = np.split(validation_labels, num_validation_data // 1000)
            sum_accuracy = 0
            for images_v, labels_v in zip(images_v_segments, labels_v_segments):
                y_v = sess.run(h.y_r, feed_dict={h.x: images_v})
                accuracy = opt.compute_accuracy(y_v, labels_v)
                sum_accuracy += accuracy
            validation_accuracy = sum_accuracy / len(images_v_segments)

            # append validation accuracy to the training loss
            average_loss_per_epoch = np.append(average_training_loss_per_epoch, validation_accuracy)
            training_epoch_loss.append(average_loss_per_epoch)
            loss_name_per_epoch = [
                'reconstruction',
                'discriminator',
                'discriminator_y',
                'discriminator_z',
                'generator',
                'generator_z',
                'generator_y',
                'supervised',
                'transform',
                'validation_accuracy'
            ]

            if epoch % 1 == 0:
                process.show_bar(epoch, max_epoch, {
                    'loss_r': average_loss_per_epoch[0],
                    'loss_d': average_loss_per_epoch[1],
                    'loss_g': average_loss_per_epoch[4],
                    'loss_v': average_loss_per_epoch[9],
                })

                plt.tile_images(sess.run(h.x_, feed_dict={h.x: images_u}),
                                dir=config.log_dir,
                                filename='x_rec_epoch_{}'.format(str(epoch).zfill(3)))

            if epoch % 10 == 0:
                saver.save(sess, os.path.join(config.ckpt_dir, 'model_ckptpoint'), global_step=epoch)
                pickle.dump((training_epoch_loss, loss_name_per_epoch), open(config.ckpt_dir + '/pickle.pkl', 'wb'))
                plt.plot_double_scale_trend(config.ckpt_dir)

# %%
if __name__ == '__main__':
    tf.reset_default_graph()
    main(run_load_from_file=False)
# Out:
# Iteration:  0(500 in total)	 Time left:00:05:22
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#    -45.13227    |     2.77243     |     1.37039     |    362.27551    |     2.29804
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  0/510[...................................................................................................]--02:48:49-- - loss_d: 2.75264 -  - loss_g: 1.39905 -  - loss_r: 91.95889 -  - loss_v: 0.90470 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.79350     |     1.35655     |    81.46384     |     0.02607
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  1/510[...................................................................................................]--02:11:01-- - loss_d: 2.76770 -  - loss_g: 1.39673 -  - loss_r: 76.33472 -  - loss_v: 0.90850 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.71652     |     1.39058     |    69.80592     |     0.00455
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  2/510[...................................................................................................]--02:11:23-- - loss_d: 2.77058 -  - loss_g: 1.39243 -  - loss_r: 73.22192 -  - loss_v: 0.91500 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77863     |     1.35219     |    69.41328     |     0.00563
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  3/510[...................................................................................................]--02:10:46-- - loss_d: 2.77126 -  - loss_g: 1.39032 -  - loss_r: 71.12289 -  - loss_v: 0.91880 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.73129     |     1.42010     |    66.37573     |     0.00034
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  4/510[...................................................................................................]--02:11:13-- - loss_d: 2.77200 -  - loss_g: 1.39039 -  - loss_r: 70.03924 -  - loss_v: 0.92530 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.78408     |     1.44304     |    72.75742     |     0.00081
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  5/510[...................................................................................................]--02:16:37-- - loss_d: 2.77052 -  - loss_g: 1.38871 -  - loss_r: 69.48249 -  - loss_v: 0.91600 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.79624     |     1.39544     |    69.27935     |     0.00011
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  6/510[=>.................................................................................................]--02:16:53-- - loss_d: 2.77249 -  - loss_g: 1.38846 -  - loss_r: 68.38770 -  - loss_v: 0.91760 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77250     |     1.40356     |    65.57388     |     0.00049
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  7/510[=>.................................................................................................]--02:16:10-- - loss_d: 2.77305 -  - loss_g: 1.38864 -  - loss_r: 68.07129 -  - loss_v: 0.92550 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.74652     |     1.39498     |    67.26524     |     0.00003
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  8/510[=>.................................................................................................]--02:15:14-- - loss_d: 2.77221 -  - loss_g: 1.38728 -  - loss_r: 67.60464 -  - loss_v: 0.92240 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76865     |     1.40571     |    65.65427     |     0.00002
# ---------------------------------------------------------------------------------------
#
#
# Epoch:  9/510[=>.................................................................................................]--02:14:25-- - loss_d: 2.77211 -  - loss_g: 1.38772 -  - loss_r: 67.17896 -  - loss_v: 0.92130 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.79706     |     1.36624     |    72.26928     |     0.00002
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 10/510[=>.................................................................................................]--02:14:32-- - loss_d: 2.77225 -  - loss_g: 1.38745 -  - loss_r: 67.07242 -  - loss_v: 0.90980 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77947     |     1.36904     |    64.65474     |     0.00002
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 11/510[==>................................................................................................]--02:14:47-- - loss_d: 2.77301 -  - loss_g: 1.38762 -  - loss_r: 66.75626 -  - loss_v: 0.91700 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76538     |     1.39522     |    69.75294     |     0.00006
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 12/510[==>................................................................................................]--02:14:55-- - loss_d: 2.77253 -  - loss_g: 1.38732 -  - loss_r: 66.29244 -  - loss_v: 0.92400 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77116     |     1.40783     |    66.06954     |     0.00023
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 13/510[==>................................................................................................]--02:13:29-- - loss_d: 2.77248 -  - loss_g: 1.38807 -  - loss_r: 66.38889 -  - loss_v: 0.91980 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76526     |     1.39892     |    72.72182     |     0.00015
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 14/510[==>................................................................................................]--02:15:29-- - loss_d: 2.77252 -  - loss_g: 1.38770 -  - loss_r: 65.94893 -  - loss_v: 0.91040 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76855     |     1.37889     |    61.83226     |     0.00009
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 15/510[==>................................................................................................]--02:12:38-- - loss_d: 2.77378 -  - loss_g: 1.38618 -  - loss_r: 65.77610 -  - loss_v: 0.91260 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76550     |     1.38793     |    77.90723     |     0.00001
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 16/510[===>...............................................................................................]--02:13:35-- - loss_d: 2.77282 -  - loss_g: 1.38726 -  - loss_r: 65.39000 -  - loss_v: 0.91560 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.78365     |     1.37400     |    67.87720     |     0.00007
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 17/510[===>...............................................................................................]--02:12:55-- - loss_d: 2.77312 -  - loss_g: 1.38767 -  - loss_r: 65.83453 -  - loss_v: 0.91780 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.78224     |     1.38922     |    63.75055     |     0.00002
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 18/510[===>...............................................................................................]--02:12:36-- - loss_d: 2.77342 -  - loss_g: 1.38723 -  - loss_r: 65.18946 -  - loss_v: 0.92300 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77929     |     1.39330     |    65.93600     |     0.00004
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 19/510[===>...............................................................................................]--02:13:55-- - loss_d: 2.77298 -  - loss_g: 1.38713 -  - loss_r: 64.83588 -  - loss_v: 0.91970 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76437     |     1.38282     |    65.26154     |     0.00025
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 20/510[===>...............................................................................................]--02:11:53-- - loss_d: 2.77309 -  - loss_g: 1.38657 -  - loss_r: 64.80833 -  - loss_v: 0.91620 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77235     |     1.40536     |    62.95964     |     0.00033
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 21/510[====>..............................................................................................]--02:11:35-- - loss_d: 2.77290 -  - loss_g: 1.38667 -  - loss_r: 64.95348 -  - loss_v: 0.92150 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77833     |     1.38319     |    77.53872     |     0.00001
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 22/510[====>..............................................................................................]--02:11:32-- - loss_d: 2.77306 -  - loss_g: 1.38647 -  - loss_r: 64.96268 -  - loss_v: 0.91420 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76867     |     1.38826     |    64.98164     |     0.00017
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 23/510[====>..............................................................................................]--02:10:01-- - loss_d: 2.77318 -  - loss_g: 1.38670 -  - loss_r: 64.72650 -  - loss_v: 0.92400 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77396     |     1.38869     |    60.15949     |     0.00008
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 24/510[====>..............................................................................................]--02:12:09-- - loss_d: 2.77298 -  - loss_g: 1.38629 -  - loss_r: 64.29788 -  - loss_v: 0.91850 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77594     |     1.38681     |    63.87886     |     0.00001
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 25/510[====>..............................................................................................]--02:09:29-- - loss_d: 2.77292 -  - loss_g: 1.38638 -  - loss_r: 63.27170 -  - loss_v: 0.91280 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77091     |     1.38048     |    62.60283     |     0.00018
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 26/510[=====>.............................................................................................]--02:09:27-- - loss_d: 2.77304 -  - loss_g: 1.38642 -  - loss_r: 63.61398 -  - loss_v: 0.91190 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77317     |     1.39095     |    59.83725     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 27/510[=====>.............................................................................................]--02:09:18-- - loss_d: 2.77285 -  - loss_g: 1.38593 -  - loss_r: 63.38321 -  - loss_v: 0.91400 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77125     |     1.38756     |    69.20522     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 28/510[=====>.............................................................................................]--02:10:01-- - loss_d: 2.77254 -  - loss_g: 1.38636 -  - loss_r: 63.11930 -  - loss_v: 0.91440 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77078     |     1.38881     |    65.68703     |     0.00003
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 29/510[=====>.............................................................................................]--02:10:17-- - loss_d: 2.77263 -  - loss_g: 1.38596 -  - loss_r: 63.38023 -  - loss_v: 0.91490 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77630     |     1.38590     |    66.81960     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 30/510[=====>.............................................................................................]--02:09:42-- - loss_d: 2.77252 -  - loss_g: 1.38688 -  - loss_r: 63.39737 -  - loss_v: 0.91570 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77522     |     1.38837     |    64.29131     |     0.00002
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 31/510[======>............................................................................................]--02:10:10-- - loss_d: 2.77276 -  - loss_g: 1.38647 -  - loss_r: 63.07864 -  - loss_v: 0.91670 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77240     |     1.38413     |    73.65313     |     0.00001
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 32/510[======>............................................................................................]--02:08:47-- - loss_d: 2.77275 -  - loss_g: 1.38639 -  - loss_r: 63.15343 -  - loss_v: 0.91470 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77306     |     1.38496     |    57.71019     |     0.00001
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 33/510[======>............................................................................................]--02:09:16-- - loss_d: 2.77281 -  - loss_g: 1.38633 -  - loss_r: 62.92844 -  - loss_v: 0.91340 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77438     |     1.39211     |    71.09079     |     0.00001
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 34/510[======>............................................................................................]--02:07:41-- - loss_d: 2.77273 -  - loss_g: 1.38628 -  - loss_r: 63.02248 -  - loss_v: 0.91700 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77362     |     1.38275     |    63.38906     |     0.00001
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 35/510[======>............................................................................................]--02:07:55-- - loss_d: 2.77271 -  - loss_g: 1.38663 -  - loss_r: 62.99678 -  - loss_v: 0.92150 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77308     |     1.38368     |    59.70020     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 36/510[=======>...........................................................................................]--02:07:35-- - loss_d: 2.77264 -  - loss_g: 1.38652 -  - loss_r: 62.97044 -  - loss_v: 0.92170 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77306     |     1.38556     |    61.14532     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 37/510[=======>...........................................................................................]--02:07:46-- - loss_d: 2.77251 -  - loss_g: 1.38557 -  - loss_r: 62.73255 -  - loss_v: 0.91920 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77059     |     1.38706     |    60.14801     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 38/510[=======>...........................................................................................]--02:07:38-- - loss_d: 2.77247 -  - loss_g: 1.38608 -  - loss_r: 62.87448 -  - loss_v: 0.91970 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77425     |     1.38631     |    68.35149     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 39/510[=======>...........................................................................................]--02:07:03-- - loss_d: 2.77263 -  - loss_g: 1.38588 -  - loss_r: 63.24903 -  - loss_v: 0.91890 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77101     |     1.38437     |    66.62867     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 40/510[=======>...........................................................................................]--02:06:58-- - loss_d: 2.77261 -  - loss_g: 1.38699 -  - loss_r: 62.79185 -  - loss_v: 0.92290 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77223     |     1.38534     |    63.30941     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 41/510[========>..........................................................................................]--02:06:48-- - loss_d: 2.77258 -  - loss_g: 1.38619 -  - loss_r: 62.42739 -  - loss_v: 0.92210 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77249     |     1.38453     |    59.31205     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 42/510[========>..........................................................................................]--02:07:52-- - loss_d: 2.77259 -  - loss_g: 1.38594 -  - loss_r: 62.26113 -  - loss_v: 0.92160 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77316     |     1.38552     |    60.45326     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 43/510[========>..........................................................................................]--02:06:37-- - loss_d: 2.77258 -  - loss_g: 1.38596 -  - loss_r: 62.89079 -  - loss_v: 0.91920 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77645     |     1.38381     |    67.29313     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 44/510[========>..........................................................................................]--02:05:06-- - loss_d: 2.77258 -  - loss_g: 1.38636 -  - loss_r: 62.67495 -  - loss_v: 0.92230 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77182     |     1.38627     |    66.41699     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 45/510[========>..........................................................................................]--02:05:13-- - loss_d: 2.77257 -  - loss_g: 1.38577 -  - loss_r: 62.67467 -  - loss_v: 0.92520 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77172     |     1.38404     |    61.36367     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 46/510[=========>.........................................................................................]--02:04:49-- - loss_d: 2.77261 -  - loss_g: 1.38594 -  - loss_r: 62.47011 -  - loss_v: 0.92530 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77262     |     1.38997     |    65.17164     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 47/510[=========>.........................................................................................]--02:04:22-- - loss_d: 2.77252 -  - loss_g: 1.38659 -  - loss_r: 62.77212 -  - loss_v: 0.92520 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77242     |     1.38853     |    61.86106     |     0.00004
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 48/510[=========>.........................................................................................]--02:04:01-- - loss_d: 2.77258 -  - loss_g: 1.38636 -  - loss_r: 62.64746 -  - loss_v: 0.92440 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77565     |     1.38649     |    62.32479     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 49/510[=========>.........................................................................................]--02:03:34-- - loss_d: 2.77254 -  - loss_g: 1.38613 -  - loss_r: 62.48987 -  - loss_v: 0.92480 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77196     |     1.38483     |    59.40721     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 50/510[=========>.........................................................................................]--02:02:38-- - loss_d: 2.77252 -  - loss_g: 1.38615 -  - loss_r: 62.76134 -  - loss_v: 0.92350 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77420     |     1.38520     |    61.22736     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 51/510[=========>.........................................................................................]--02:03:17-- - loss_d: 2.77253 -  - loss_g: 1.38689 -  - loss_r: 62.69332 -  - loss_v: 0.92370 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77567     |     1.38441     |    68.00622     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 52/510[==========>........................................................................................]--02:02:23-- - loss_d: 2.77256 -  - loss_g: 1.38617 -  - loss_r: 62.56543 -  - loss_v: 0.92480 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77652     |     1.38316     |    61.55689     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 53/510[==========>........................................................................................]--02:03:12-- - loss_d: 2.77247 -  - loss_g: 1.38664 -  - loss_r: 62.80185 -  - loss_v: 0.92600 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76984     |     1.38469     |    62.97628     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 54/510[==========>........................................................................................]--02:02:52-- - loss_d: 2.77258 -  - loss_g: 1.38605 -  - loss_r: 62.40641 -  - loss_v: 0.92350 -
#
# Iteration:  0(500 in total)	 Time left:00:00:25
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77518     |     1.38723     |    57.64430     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 55/510[==========>........................................................................................]--02:03:17-- - loss_d: 2.77269 -  - loss_g: 1.38691 -  - loss_r: 62.55629 -  - loss_v: 0.92450 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77468     |     1.38245     |    63.64482     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 56/510[==========>........................................................................................]--02:02:01-- - loss_d: 2.77261 -  - loss_g: 1.38606 -  - loss_r: 62.55275 -  - loss_v: 0.92330 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77319     |     1.38477     |    65.11459     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 57/510[===========>.......................................................................................]--02:02:28-- - loss_d: 2.77262 -  - loss_g: 1.38652 -  - loss_r: 62.60541 -  - loss_v: 0.92180 -
#
# Iteration:  0(500 in total)	 Time left:00:00:25
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77495     |     1.39083     |    58.47365     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 58/510[===========>.......................................................................................]--02:01:23-- - loss_d: 2.77244 -  - loss_g: 1.38638 -  - loss_r: 62.58017 -  - loss_v: 0.92310 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77347     |     1.38474     |    59.05855     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 59/510[===========>.......................................................................................]--02:02:00-- - loss_d: 2.77254 -  - loss_g: 1.38686 -  - loss_r: 62.50782 -  - loss_v: 0.92530 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77435     |     1.38841     |    67.79855     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 60/510[===========>.......................................................................................]--02:01:07-- - loss_d: 2.77253 -  - loss_g: 1.38645 -  - loss_r: 62.68093 -  - loss_v: 0.92360 -
#
# Iteration:  0(500 in total)	 Time left:00:00:25
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77101     |     1.38455     |    63.53574     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 61/510[===========>.......................................................................................]--02:01:21-- - loss_d: 2.77244 -  - loss_g: 1.38654 -  - loss_r: 62.23554 -  - loss_v: 0.92410 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77060     |     1.39009     |    62.97812     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 62/510[============>......................................................................................]--02:00:14-- - loss_d: 2.77242 -  - loss_g: 1.38623 -  - loss_r: 62.65860 -  - loss_v: 0.92330 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77109     |     1.38976     |    59.79986     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 63/510[============>......................................................................................]--02:00:48-- - loss_d: 2.77267 -  - loss_g: 1.38653 -  - loss_r: 62.56393 -  - loss_v: 0.92230 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77347     |     1.38560     |    58.88738     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 64/510[============>......................................................................................]--02:00:16-- - loss_d: 2.77275 -  - loss_g: 1.38595 -  - loss_r: 62.60334 -  - loss_v: 0.92460 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77159     |     1.38252     |    58.20840     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 65/510[============>......................................................................................]--01:59:39-- - loss_d: 2.77264 -  - loss_g: 1.38619 -  - loss_r: 62.56148 -  - loss_v: 0.92530 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77241     |     1.38719     |    65.87016     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 66/510[============>......................................................................................]--01:59:58-- - loss_d: 2.77270 -  - loss_g: 1.38630 -  - loss_r: 62.14804 -  - loss_v: 0.92500 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77574     |     1.38442     |    66.18404     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch: 67/510[=============>.....................................................................................]--01:59:18-- - loss_d: 2.77246 -  - loss_g: 1.38556 -  - loss_r: 62.48661 -  - loss_v: 0.92550 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
# ...
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77285     |     1.38175     |    57.90611     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:487/510[===============================================================================================>...]--00:05:58-- - loss_d: 2.77263 -  - loss_g: 1.38644 -  - loss_r: 59.23554 -  - loss_v: 0.91830 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77477     |     1.38564     |    53.35758     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:488/510[===============================================================================================>...]--00:05:41-- - loss_d: 2.77257 -  - loss_g: 1.38687 -  - loss_r: 59.24247 -  - loss_v: 0.92050 -
#
# Iteration:  0(500 in total)	 Time left:00:00:29
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77362     |     1.38951     |    57.37109     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:489/510[===============================================================================================>...]--00:05:25-- - loss_d: 2.77263 -  - loss_g: 1.38627 -  - loss_r: 59.27728 -  - loss_v: 0.92190 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77088     |     1.38628     |    55.52879     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:490/510[================================================================================================>..]--00:05:06-- - loss_d: 2.77276 -  - loss_g: 1.38678 -  - loss_r: 59.11658 -  - loss_v: 0.92230 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76154     |     1.38674     |    61.29977     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:491/510[================================================================================================>..]--00:04:54-- - loss_d: 2.77268 -  - loss_g: 1.38671 -  - loss_r: 59.31926 -  - loss_v: 0.92410 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76903     |     1.38833     |    58.96523     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:492/510[================================================================================================>..]--00:04:35-- - loss_d: 2.77230 -  - loss_g: 1.38579 -  - loss_r: 59.17176 -  - loss_v: 0.92540 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77429     |     1.38691     |    61.25868     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:493/510[================================================================================================>..]--00:04:17-- - loss_d: 2.77245 -  - loss_g: 1.38595 -  - loss_r: 59.08071 -  - loss_v: 0.92290 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76772     |     1.38842     |    62.80258     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:494/510[================================================================================================>..]--00:04:03-- - loss_d: 2.77276 -  - loss_g: 1.38647 -  - loss_r: 58.99827 -  - loss_v: 0.92470 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77983     |     1.39389     |    55.80246     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:495/510[=================================================================================================>.]--00:03:46-- - loss_d: 2.77237 -  - loss_g: 1.38643 -  - loss_r: 59.05579 -  - loss_v: 0.92050 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77448     |     1.38370     |    52.95305     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:496/510[=================================================================================================>.]--00:03:29-- - loss_d: 2.77279 -  - loss_g: 1.38673 -  - loss_r: 58.74217 -  - loss_v: 0.92180 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77299     |     1.38880     |    59.15615     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:497/510[=================================================================================================>.]--00:03:13-- - loss_d: 2.77258 -  - loss_g: 1.38665 -  - loss_r: 59.24337 -  - loss_v: 0.92090 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77587     |     1.38630     |    56.91476     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:498/510[=================================================================================================>.]--00:02:58-- - loss_d: 2.77245 -  - loss_g: 1.38585 -  - loss_r: 58.96611 -  - loss_v: 0.92000 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76523     |     1.38351     |    57.26085     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:499/510[=================================================================================================>.]--00:02:42-- - loss_d: 2.77278 -  - loss_g: 1.38620 -  - loss_r: 58.93926 -  - loss_v: 0.92370 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77387     |     1.39168     |    61.27068     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:500/510[==================================================================================================>]--00:02:25-- - loss_d: 2.77260 -  - loss_g: 1.38649 -  - loss_r: 59.03392 -  - loss_v: 0.92390 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77446     |     1.38767     |    58.94328     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:501/510[==================================================================================================>]--00:02:11-- - loss_d: 2.77274 -  - loss_g: 1.38686 -  - loss_r: 58.74191 -  - loss_v: 0.92430 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77476     |     1.39059     |    57.72389     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:502/510[==================================================================================================>]--00:01:53-- - loss_d: 2.77261 -  - loss_g: 1.38641 -  - loss_r: 58.65124 -  - loss_v: 0.92490 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77662     |     1.38663     |    55.67149     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:503/510[==================================================================================================>]--00:01:36-- - loss_d: 2.77281 -  - loss_g: 1.38680 -  - loss_r: 58.82739 -  - loss_v: 0.92460 -
#
# Iteration:  0(500 in total)	 Time left:00:00:29
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77368     |     1.38761     |    56.53365     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:504/510[==================================================================================================>]--00:01:21-- - loss_d: 2.77244 -  - loss_g: 1.38650 -  - loss_r: 58.70703 -  - loss_v: 0.92500 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.76649     |     1.38723     |    59.08246     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:505/510[===================================================================================================]--00:01:04-- - loss_d: 2.77252 -  - loss_g: 1.38634 -  - loss_r: 58.75845 -  - loss_v: 0.92610 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77231     |     1.38315     |    55.55180     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:506/510[===================================================================================================]--00:00:48-- - loss_d: 2.77254 -  - loss_g: 1.38684 -  - loss_r: 58.66685 -  - loss_v: 0.92580 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77342     |     1.39038     |    57.43776     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:507/510[===================================================================================================]--00:00:32-- - loss_d: 2.77239 -  - loss_g: 1.38617 -  - loss_r: 58.52077 -  - loss_v: 0.92550 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77542     |     1.38846     |    62.26823     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:508/510[===================================================================================================]--00:00:16-- - loss_d: 2.77262 -  - loss_g: 1.38667 -  - loss_r: 58.90602 -  - loss_v: 0.92570 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ---------------------------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction  |    supervise
# ---------------------------------------------------------------------------------------
#   -455.62500    |     2.77699     |     1.38097     |    60.31949     |     0.00000
# ---------------------------------------------------------------------------------------
#
#
# Epoch:509/510[===================================================================================================]-418817:57:18-- - loss_d: 2.77250 -  - loss_g: 1.38682 -  - loss_r: 58.66753 -  - loss_v: 0.92510 -
