# %%
# Standard library
import tensorflow as tf
import numpy as np
import _pickle as pickle
import os, sys
# Packages
from model import build_graph, config

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
from aae_classification import Operation
import dataset
from process import Process
import sampler
import plot as plt

# %%
def main(run_load_from_file=False):
    # load MNIST images
    images, labels = dataset.load_train_images()

    # config
    opt = Operation()
    opt.check_dir(config.ckpt_dir, is_restart=False)
    opt.check_dir(config.log_dir, is_restart=True)

    # setting
    max_epoch = 440
    num_trains_per_epoch = 500
    batch_size_l = 100
    batch_size_u = 100

    # create semi-supervised split
    num_validation_data = 10000
    num_labeled_data = 100
    num_types_of_label = 10
    training_images_l, training_labels_l, training_images_u, validation_images, validation_labels = dataset.create_semisupervised(
        images, labels, num_validation_data, num_labeled_data, num_types_of_label)

    # training
    with tf.device(config.device):
        h = build_graph()

    sess_config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
    sess_config.gpu_options.allow_growth = True
    sess_config.gpu_options.per_process_gpu_memory_fraction = 0.9
    saver = tf.train.Saver(max_to_keep=2)

    with tf.Session(config=sess_config) as sess:
        '''
         Load from checkpoint or start a new session

        '''
        if run_load_from_file:
            saver.restore(sess, tf.train.latest_checkpoint(config.ckpt_dir))
            training_epoch_loss,_ = pickle.load(open(config.ckpt_dir + '/pickle.pkl', 'rb'))
        else:
            sess.run(tf.global_variables_initializer())
            training_epoch_loss = []

        # Recording loss per epoch
        process = Process()
        for epoch in range(max_epoch):
            process.start_epoch(epoch, max_epoch)

            '''
            Learning rate generator

            '''
            learning_rate = opt.ladder_learning_rate(epoch + len(training_epoch_loss))

            # Recording loss per iteration
            training_loss_set =[]
            sum_loss_reconstruction = 0
            sum_loss_supervised = 0
            sum_loss_discrminator = 0
            sum_loss_generator = 0

            process_iteration = Process()
            for i in range(num_trains_per_epoch):
                process_iteration.start_epoch(i, num_trains_per_epoch)

                # sample from data distribution
                images_l, label_onehot_l, label_id_l = dataset.sample_labeled_data(training_images_l, training_labels_l,
                                                                                   batch_size_l)
                images_u = dataset.sample_unlabeled_data(training_images_u, batch_size_u)

                # reconstruction_phase
                _, loss_reconstruction = sess.run([h.opt_r, h.loss_r], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                z_true_u = sampler.gaussian(batch_size_u, config.ndim_z, mean=0, var=1)
                y_true_u = sampler.onehot_categorical(batch_size_u, config.ndim_y)
                # adversarial phase for discriminator
                _, loss_discriminator_y = sess.run([h.opt_dy, h.loss_dy], feed_dict={
                    h.x: images_u,
                    h.y: y_true_u,
                    h.lr: learning_rate
                })

                _, loss_discriminator_z = sess.run([h.opt_dz, h.loss_dz], feed_dict={
                    h.x: images_u,
                    h.z: z_true_u,
                    h.lr: learning_rate
                })

                loss_discriminator = loss_discriminator_y + loss_discriminator_z

                # adversarial phase for generator
                _, loss_generator_y, loss_generator_z = sess.run([h.opt_e, h.loss_gy, h.loss_gz], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                loss_generator = loss_generator_y + loss_generator_z

                # supervised phase
                _, loss_generator_supervised = sess.run([h.opt_ey, h.loss_ey], feed_dict={
                    h.x: images_l,
                    h.y_s: label_id_l,
                    h.lr: learning_rate
                })

                training_loss_set.append([
                    loss_reconstruction,
                    loss_discriminator,
                    loss_discriminator_y,
                    loss_discriminator_z,
                    loss_generator,
                    loss_generator_z,
                    loss_generator_y,
                    loss_generator_supervised
                ])

                sum_loss_reconstruction += loss_reconstruction / batch_size_u
                sum_loss_discrminator += loss_discriminator
                sum_loss_generator += loss_generator
                sum_loss_supervised += loss_generator_supervised

                if i % 1000 == 0:
                    process_iteration.show_table_2d(i, num_trains_per_epoch, {
                        'reconstruction': sum_loss_reconstruction / (i + 1),
                        'discriminator': sum_loss_discrminator / (i + 1),
                        'generator': sum_loss_generator / (i + 1),
                        'supervise': sum_loss_supervised / (i + 1)
                    })
            # In end of epoch, summary the loss
            average_training_loss_per_epoch = np.mean(np.array(training_loss_set), axis=0).flatten()

            # validation phase
            images_v_segments = np.split(validation_images, num_validation_data // 1000)
            labels_v_segments = np.split(validation_labels, num_validation_data // 1000)
            sum_accuracy = 0
            for images_v, labels_v in zip(images_v_segments, labels_v_segments):
                y_v = sess.run(h.y_r, feed_dict={h.x: images_v})
                prediction = np.argmax(y_v, 1)
                equality = np.equal(prediction, labels_v)
                accuracy = np.mean(equality.astype(np.float32))
                sum_accuracy += accuracy
            validation_accuracy = sum_accuracy / len(images_v_segments)

            # append validation accuracy to the training loss
            average_loss_per_epoch = np.append(average_training_loss_per_epoch, validation_accuracy)
            training_epoch_loss.append(average_loss_per_epoch)
            loss_name_per_epoch = [
                'reconstruction',
                'discriminator',
                'discriminator_y',
                'discriminator_z',
                'generator',
                'generator_z',
                'generator_y',
                'supervised',
                'validation_accuracy'
            ]

            if epoch % 1 == 0:
                process.show_bar(epoch, max_epoch, {
                    'loss_r': average_loss_per_epoch[0],
                    'loss_d': average_loss_per_epoch[1],
                    'loss_g': average_loss_per_epoch[4],
                    'loss_v': average_loss_per_epoch[8]
                })

                plt.tile_images(sess.run(h.x_, feed_dict={h.x: images_u}),
                                dir=config.log_dir,
                                filename='x_rec_epoch_{}'.format(str(epoch).zfill(3)))

            if epoch % 10 == 0:
                saver.save(sess, os.path.join(config.ckpt_dir, 'model_ckptpoint'), global_step=epoch)
                pickle.dump((training_epoch_loss, loss_name_per_epoch), open(config.ckpt_dir + '/pickle.pkl', 'wb'))
                plt.plot_double_scale_trend(config.ckpt_dir)

# %%
if __name__ == '__main__':
    tf.reset_default_graph()
    main(run_load_from_file=True)
# Out:
# Iteration:  0(500 in total)	 Time left:00:05:04
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79890     |     1.43785     |     3.73047     |     2.30540
# ----------------------------------------------------------------------
#
#
# Epoch:  0/440[...................................................................................................]--02:32:37-- - loss_d: 2.71879 -  - loss_g: 1.43284 -  - loss_r: 53.58974 -  - loss_v: 0.88390 -
#
# Iteration:  0(500 in total)	 Time left:00:00:30
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.74259     |     1.43099     |     0.36102     |     0.00093
# ----------------------------------------------------------------------
#
#
# Epoch:  1/440[...................................................................................................]--02:23:57-- - loss_d: 2.74114 -  - loss_g: 1.42714 -  - loss_r: 31.57451 -  - loss_v: 0.89910 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77127     |     1.40632     |     0.33381     |     0.00047
# ----------------------------------------------------------------------
#
#
# Epoch:  2/440[...................................................................................................]--02:25:11-- - loss_d: 2.74305 -  - loss_g: 1.42305 -  - loss_r: 28.17119 -  - loss_v: 0.91390 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.69177     |     1.43934     |     0.28463     |     0.00023
# ----------------------------------------------------------------------
#
#
# Epoch:  3/440[...................................................................................................]--02:31:35-- - loss_d: 2.74648 -  - loss_g: 1.41928 -  - loss_r: 26.07241 -  - loss_v: 0.92260 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.68356     |     1.44827     |     0.25916     |     0.00016
# ----------------------------------------------------------------------
#
#
# Epoch:  4/440[...................................................................................................]--02:32:52-- - loss_d: 2.74470 -  - loss_g: 1.41877 -  - loss_r: 24.85811 -  - loss_v: 0.92570 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77861     |     1.31129     |     0.24833     |     0.00011
# ----------------------------------------------------------------------
#
#
# Epoch:  5/440[=>.................................................................................................]--02:28:22-- - loss_d: 2.75395 -  - loss_g: 1.41561 -  - loss_r: 23.96201 -  - loss_v: 0.92750 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.74386     |     1.45670     |     0.24083     |     0.00008
# ----------------------------------------------------------------------
#
#
# Epoch:  6/440[=>.................................................................................................]--02:27:24-- - loss_d: 2.75603 -  - loss_g: 1.41093 -  - loss_r: 23.32063 -  - loss_v: 0.93050 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76715     |     1.38209     |     0.22281     |     0.00006
# ----------------------------------------------------------------------
#
#
# Epoch:  7/440[=>.................................................................................................]--02:28:20-- - loss_d: 2.75798 -  - loss_g: 1.41250 -  - loss_r: 22.62961 -  - loss_v: 0.93550 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72413     |     1.42696     |     0.22464     |     0.00006
# ----------------------------------------------------------------------
#
#
# Epoch:  8/440[=>.................................................................................................]--02:27:04-- - loss_d: 2.75655 -  - loss_g: 1.41408 -  - loss_r: 22.13185 -  - loss_v: 0.93400 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76950     |     1.44748     |     0.22512     |     0.00005
# ----------------------------------------------------------------------
#
#
# Epoch:  9/440[==>................................................................................................]--02:31:33-- - loss_d: 2.75676 -  - loss_g: 1.41253 -  - loss_r: 21.87179 -  - loss_v: 0.93740 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77762     |     1.32475     |     0.22264     |     0.00003
# ----------------------------------------------------------------------
#
#
# Epoch: 10/440[==>................................................................................................]--02:28:03-- - loss_d: 2.75733 -  - loss_g: 1.40625 -  - loss_r: 21.38764 -  - loss_v: 0.93590 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.74647     |     1.43567     |     0.21322     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch: 11/440[==>................................................................................................]--02:29:02-- - loss_d: 2.75815 -  - loss_g: 1.41251 -  - loss_r: 21.07737 -  - loss_v: 0.93960 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79200     |     1.41480     |     0.20895     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch: 12/440[==>................................................................................................]--02:33:07-- - loss_d: 2.75943 -  - loss_g: 1.41386 -  - loss_r: 20.66894 -  - loss_v: 0.93690 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.85018     |     1.34059     |     0.19884     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch: 13/440[==>................................................................................................]--02:28:05-- - loss_d: 2.76043 -  - loss_g: 1.41011 -  - loss_r: 20.51808 -  - loss_v: 0.93900 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.74903     |     1.44771     |     0.19075     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 14/440[===>...............................................................................................]--02:26:43-- - loss_d: 2.76123 -  - loss_g: 1.40896 -  - loss_r: 20.26601 -  - loss_v: 0.94670 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.58610     |     1.41223     |     0.18520     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 15/440[===>...............................................................................................]--02:23:28-- - loss_d: 2.76234 -  - loss_g: 1.40655 -  - loss_r: 20.10292 -  - loss_v: 0.94430 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79989     |     1.35203     |     0.21599     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 16/440[===>...............................................................................................]--02:26:54-- - loss_d: 2.76715 -  - loss_g: 1.40524 -  - loss_r: 19.92258 -  - loss_v: 0.94240 -
#
# Iteration:  0(500 in total)	 Time left:00:00:27
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.74343     |     1.42482     |     0.20201     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 17/440[===>...............................................................................................]--02:24:44-- - loss_d: 2.76365 -  - loss_g: 1.40565 -  - loss_r: 19.79592 -  - loss_v: 0.94200 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.82710     |     1.48501     |     0.20473     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 18/440[====>..............................................................................................]--02:23:40-- - loss_d: 2.76401 -  - loss_g: 1.40796 -  - loss_r: 19.60283 -  - loss_v: 0.94470 -
#
# Iteration:  0(500 in total)	 Time left:00:00:27
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.80804     |     1.40287     |     0.24108     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 19/440[====>..............................................................................................]--02:23:50-- - loss_d: 2.76408 -  - loss_g: 1.40398 -  - loss_r: 19.55613 -  - loss_v: 0.94890 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76773     |     1.41836     |     0.20752     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 20/440[====>..............................................................................................]--02:22:33-- - loss_d: 2.76538 -  - loss_g: 1.40382 -  - loss_r: 19.13490 -  - loss_v: 0.94400 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.82612     |     1.47363     |     0.18733     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 21/440[====>..............................................................................................]--02:24:53-- - loss_d: 2.76678 -  - loss_g: 1.40546 -  - loss_r: 19.11028 -  - loss_v: 0.94670 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76086     |     1.40958     |     0.18303     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 22/440[====>..............................................................................................]--02:25:39-- - loss_d: 2.76755 -  - loss_g: 1.40383 -  - loss_r: 19.01113 -  - loss_v: 0.94810 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77893     |     1.44458     |     0.18198     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 23/440[=====>.............................................................................................]--02:22:48-- - loss_d: 2.76641 -  - loss_g: 1.40338 -  - loss_r: 18.85133 -  - loss_v: 0.94860 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72421     |     1.36431     |     0.18465     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 24/440[=====>.............................................................................................]--02:21:57-- - loss_d: 2.76500 -  - loss_g: 1.40360 -  - loss_r: 18.74607 -  - loss_v: 0.94760 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72513     |     1.42843     |     0.20903     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 25/440[=====>.............................................................................................]--02:14:59-- - loss_d: 2.76572 -  - loss_g: 1.39713 -  - loss_r: 17.52914 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72838     |     1.37370     |     0.17383     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 26/440[=====>.............................................................................................]--02:16:23-- - loss_d: 2.76491 -  - loss_g: 1.39770 -  - loss_r: 17.22314 -  - loss_v: 0.94970 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76257     |     1.38306     |     0.17643     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 27/440[======>............................................................................................]--02:14:30-- - loss_d: 2.76464 -  - loss_g: 1.39781 -  - loss_r: 17.11150 -  - loss_v: 0.95020 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73078     |     1.38724     |     0.16746     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 28/440[======>............................................................................................]--02:15:01-- - loss_d: 2.76022 -  - loss_g: 1.39674 -  - loss_r: 17.01230 -  - loss_v: 0.94890 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.86091     |     1.42098     |     0.17699     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 29/440[======>............................................................................................]--02:16:30-- - loss_d: 2.75851 -  - loss_g: 1.39642 -  - loss_r: 17.00490 -  - loss_v: 0.94950 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77843     |     1.43821     |     0.17389     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 30/440[======>............................................................................................]--02:13:48-- - loss_d: 2.76185 -  - loss_g: 1.39257 -  - loss_r: 16.81746 -  - loss_v: 0.94890 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73885     |     1.43904     |     0.17322     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 31/440[=======>...........................................................................................]--02:14:33-- - loss_d: 2.76126 -  - loss_g: 1.39883 -  - loss_r: 16.90468 -  - loss_v: 0.94990 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76691     |     1.35028     |     0.14799     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 32/440[=======>...........................................................................................]--02:19:07-- - loss_d: 2.76215 -  - loss_g: 1.39659 -  - loss_r: 16.82997 -  - loss_v: 0.95040 -
#
# Iteration:  0(500 in total)	 Time left:00:00:38
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77602     |     1.43197     |     0.17848     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 33/440[=======>...........................................................................................]--02:18:37-- - loss_d: 2.76044 -  - loss_g: 1.39731 -  - loss_r: 16.77748 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.70282     |     1.32349     |     0.16281     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 34/440[=======>...........................................................................................]--02:19:22-- - loss_d: 2.76123 -  - loss_g: 1.39616 -  - loss_r: 16.71670 -  - loss_v: 0.94990 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.82648     |     1.43068     |     0.16569     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 35/440[=======>...........................................................................................]--02:22:13-- - loss_d: 2.75909 -  - loss_g: 1.39785 -  - loss_r: 16.69840 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.84735     |     1.33800     |     0.16493     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 36/440[========>..........................................................................................]--02:22:00-- - loss_d: 2.75830 -  - loss_g: 1.40103 -  - loss_r: 16.68144 -  - loss_v: 0.94900 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.71682     |     1.39464     |     0.18633     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 37/440[========>..........................................................................................]--02:17:26-- - loss_d: 2.76009 -  - loss_g: 1.40035 -  - loss_r: 16.59969 -  - loss_v: 0.94870 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.74791     |     1.45527     |     0.16998     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 38/440[========>..........................................................................................]--02:18:17-- - loss_d: 2.75751 -  - loss_g: 1.39488 -  - loss_r: 16.58205 -  - loss_v: 0.94760 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79139     |     1.36715     |     0.17287     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 39/440[========>..........................................................................................]--02:17:24-- - loss_d: 2.76037 -  - loss_g: 1.39823 -  - loss_r: 16.59401 -  - loss_v: 0.94960 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.65019     |     1.37846     |     0.15668     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 40/440[=========>.........................................................................................]--02:16:31-- - loss_d: 2.75866 -  - loss_g: 1.39785 -  - loss_r: 16.49905 -  - loss_v: 0.94780 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72303     |     1.41019     |     0.16706     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 41/440[=========>.........................................................................................]--02:15:31-- - loss_d: 2.75913 -  - loss_g: 1.39833 -  - loss_r: 16.52948 -  - loss_v: 0.94920 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79195     |     1.39664     |     0.15494     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 42/440[=========>.........................................................................................]--02:16:49-- - loss_d: 2.75630 -  - loss_g: 1.40122 -  - loss_r: 16.38279 -  - loss_v: 0.95000 -
#
# Iteration:  0(500 in total)	 Time left:00:00:27
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75819     |     1.37249     |     0.15675     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 43/440[=========>.........................................................................................]--02:21:59-- - loss_d: 2.76045 -  - loss_g: 1.39963 -  - loss_r: 16.53148 -  - loss_v: 0.94950 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.68106     |     1.33880     |     0.16792     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 44/440[=========>.........................................................................................]--02:15:40-- - loss_d: 2.75729 -  - loss_g: 1.40005 -  - loss_r: 16.45033 -  - loss_v: 0.94920 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76220     |     1.37669     |     0.16402     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 45/440[==========>........................................................................................]--02:23:30-- - loss_d: 2.75776 -  - loss_g: 1.40267 -  - loss_r: 16.48284 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73458     |     1.34978     |     0.16852     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 46/440[==========>........................................................................................]--02:13:32-- - loss_d: 2.75867 -  - loss_g: 1.39764 -  - loss_r: 16.33757 -  - loss_v: 0.94940 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78041     |     1.42504     |     0.16405     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 47/440[==========>........................................................................................]--02:07:54-- - loss_d: 2.75688 -  - loss_g: 1.40025 -  - loss_r: 16.23479 -  - loss_v: 0.95030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72029     |     1.41022     |     0.15920     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 48/440[==========>........................................................................................]--02:14:24-- - loss_d: 2.74978 -  - loss_g: 1.40173 -  - loss_r: 16.35950 -  - loss_v: 0.94970 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.65174     |     1.41755     |     0.18156     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 49/440[===========>.......................................................................................]--02:14:39-- - loss_d: 2.75611 -  - loss_g: 1.39918 -  - loss_r: 16.29296 -  - loss_v: 0.94960 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.82531     |     1.43148     |     0.14679     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 50/440[===========>.......................................................................................]--02:15:18-- - loss_d: 2.75907 -  - loss_g: 1.40045 -  - loss_r: 16.39508 -  - loss_v: 0.95030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:28
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.68198     |     1.40623     |     0.16819     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 51/440[===========>.......................................................................................]--02:13:03-- - loss_d: 2.75300 -  - loss_g: 1.39932 -  - loss_r: 16.30956 -  - loss_v: 0.95030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.69058     |     1.38606     |     0.15671     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 52/440[===========>.......................................................................................]--02:12:20-- - loss_d: 2.75784 -  - loss_g: 1.39969 -  - loss_r: 16.37152 -  - loss_v: 0.95000 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77945     |     1.36449     |     0.16839     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 53/440[============>......................................................................................]--02:12:08-- - loss_d: 2.75902 -  - loss_g: 1.40013 -  - loss_r: 16.20440 -  - loss_v: 0.94950 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75831     |     1.39143     |     0.15568     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 54/440[============>......................................................................................]--02:10:40-- - loss_d: 2.75854 -  - loss_g: 1.40176 -  - loss_r: 16.11255 -  - loss_v: 0.94940 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.81342     |     1.39673     |     0.18334     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 55/440[============>......................................................................................]--02:17:03-- - loss_d: 2.75481 -  - loss_g: 1.40196 -  - loss_r: 16.25550 -  - loss_v: 0.95000 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.80775     |     1.40164     |     0.17180     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 56/440[============>......................................................................................]--02:10:58-- - loss_d: 2.76300 -  - loss_g: 1.39540 -  - loss_r: 16.20216 -  - loss_v: 0.94990 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73333     |     1.40879     |     0.19317     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 57/440[============>......................................................................................]--02:10:43-- - loss_d: 2.75356 -  - loss_g: 1.39863 -  - loss_r: 16.22764 -  - loss_v: 0.94930 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75957     |     1.38968     |     0.15903     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 58/440[=============>.....................................................................................]--02:10:15-- - loss_d: 2.75989 -  - loss_g: 1.39983 -  - loss_r: 16.22879 -  - loss_v: 0.94940 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73691     |     1.37836     |     0.16827     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 59/440[=============>.....................................................................................]--02:12:25-- - loss_d: 2.75866 -  - loss_g: 1.40306 -  - loss_r: 16.15800 -  - loss_v: 0.95040 -
#
# Iteration:  0(500 in total)	 Time left:00:00:31
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.84598     |     1.34138     |     0.16696     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 60/440[=============>.....................................................................................]--02:12:35-- - loss_d: 2.75863 -  - loss_g: 1.40236 -  - loss_r: 16.20012 -  - loss_v: 0.95030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76061     |     1.36496     |     0.16882     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 61/440[=============>.....................................................................................]--02:09:31-- - loss_d: 2.75813 -  - loss_g: 1.40277 -  - loss_r: 16.10919 -  - loss_v: 0.94980 -
#
# Iteration:  0(500 in total)	 Time left:00:00:27
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.63711     |     1.41194     |     0.15250     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 62/440[==============>....................................................................................]--02:09:49-- - loss_d: 2.75907 -  - loss_g: 1.39738 -  - loss_r: 16.14852 -  - loss_v: 0.94930 -
#
# Iteration:  0(500 in total)	 Time left:00:00:25
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75545     |     1.39932     |     0.14690     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 63/440[==============>....................................................................................]--02:10:03-- - loss_d: 2.75640 -  - loss_g: 1.40012 -  - loss_r: 16.18642 -  - loss_v: 0.95000 -
#
# Iteration:  0(500 in total)	 Time left:00:00:27
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79702     |     1.38818     |     0.15043     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 64/440[==============>....................................................................................]--02:09:25-- - loss_d: 2.75966 -  - loss_g: 1.40299 -  - loss_r: 16.10911 -  - loss_v: 0.95080 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.82606     |     1.34427     |     0.14782     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 65/440[==============>....................................................................................]--02:09:04-- - loss_d: 2.76106 -  - loss_g: 1.39771 -  - loss_r: 16.12631 -  - loss_v: 0.95060 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72247     |     1.41670     |     0.16269     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 66/440[==============>....................................................................................]--02:06:08-- - loss_d: 2.75894 -  - loss_g: 1.40157 -  - loss_r: 16.11483 -  - loss_v: 0.95040 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75777     |     1.35420     |     0.16003     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 67/440[===============>...................................................................................]--02:06:50-- - loss_d: 2.75791 -  - loss_g: 1.40082 -  - loss_r: 15.97428 -  - loss_v: 0.94990 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.69308     |     1.47599     |     0.15070     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 68/440[===============>...................................................................................]--02:08:45-- - loss_d: 2.75530 -  - loss_g: 1.40158 -  - loss_r: 15.96100 -  - loss_v: 0.94920 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76433     |     1.38110     |     0.14404     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 69/440[===============>...................................................................................]--02:09:29-- - loss_d: 2.76310 -  - loss_g: 1.40009 -  - loss_r: 15.96805 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.67939     |     1.47806     |     0.14806     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 70/440[===============>...................................................................................]--02:07:57-- - loss_d: 2.76126 -  - loss_g: 1.39841 -  - loss_r: 16.03468 -  - loss_v: 0.94950 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.80129     |     1.37561     |     0.15197     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 71/440[================>..................................................................................]--02:04:56-- - loss_d: 2.76267 -  - loss_g: 1.40140 -  - loss_r: 15.96768 -  - loss_v: 0.94820 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79407     |     1.37970     |     0.15810     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 72/440[================>..................................................................................]--02:06:20-- - loss_d: 2.75623 -  - loss_g: 1.40237 -  - loss_r: 15.93540 -  - loss_v: 0.94960 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.83098     |     1.37514     |     0.15995     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 73/440[================>..................................................................................]--02:05:02-- - loss_d: 2.75944 -  - loss_g: 1.39804 -  - loss_r: 15.92849 -  - loss_v: 0.95030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76327     |     1.45283     |     0.16565     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 74/440[================>..................................................................................]--02:07:15-- - loss_d: 2.76408 -  - loss_g: 1.40055 -  - loss_r: 15.93824 -  - loss_v: 0.94980 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.80931     |     1.38593     |     0.16354     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 75/440[=================>.................................................................................]--02:06:23-- - loss_d: 2.75713 -  - loss_g: 1.39924 -  - loss_r: 15.83008 -  - loss_v: 0.95110 -
#
# Iteration:  0(500 in total)	 Time left:00:00:25
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.84277     |     1.34046     |     0.16296     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 76/440[=================>.................................................................................]--02:04:04-- - loss_d: 2.75975 -  - loss_g: 1.40066 -  - loss_r: 15.88000 -  - loss_v: 0.94990 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73244     |     1.43970     |     0.16777     |     0.00000
# ----------------------------------------------------------------------
#
#
# ...
#
# Iteration:  0(500 in total)	 Time left:00:00:35
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.72257     |     1.35988     |     0.15151     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:121/440[===========================>.......................................................................]--01:46:34-- - loss_d: 2.75808 -  - loss_g: 1.39957 -  - loss_r: 15.26255 -  - loss_v: 0.95000 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.70300     |     1.39233     |     0.15913     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:122/440[===========================>.......................................................................]--01:46:34-- - loss_d: 2.75885 -  - loss_g: 1.40349 -  - loss_r: 15.36307 -  - loss_v: 0.94990 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73292     |     1.44768     |     0.15354     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:123/440[===========================>.......................................................................]--01:48:41-- - loss_d: 2.75831 -  - loss_g: 1.39788 -  - loss_r: 15.26841 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.85522     |     1.39894     |     0.15701     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:124/440[============================>......................................................................]--01:47:07-- - loss_d: 2.75825 -  - loss_g: 1.39964 -  - loss_r: 15.25145 -  - loss_v: 0.95040 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.69894     |     1.39326     |     0.15398     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:125/440[============================>......................................................................]--01:46:33-- - loss_d: 2.76085 -  - loss_g: 1.40107 -  - loss_r: 15.25575 -  - loss_v: 0.95060 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.68262     |     1.36458     |     0.14472     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:126/440[============================>......................................................................]--01:47:30-- - loss_d: 2.76097 -  - loss_g: 1.39741 -  - loss_r: 15.24810 -  - loss_v: 0.95020 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76938     |     1.38486     |     0.13834     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:127/440[============================>......................................................................]--01:45:30-- - loss_d: 2.76128 -  - loss_g: 1.40213 -  - loss_r: 15.25949 -  - loss_v: 0.95020 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.83186     |     1.36515     |     0.16605     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:128/440[=============================>.....................................................................]--01:46:38-- - loss_d: 2.76103 -  - loss_g: 1.39826 -  - loss_r: 15.21053 -  - loss_v: 0.94990 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78869     |     1.40438     |     0.15635     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:129/440[=============================>.....................................................................]--01:44:47-- - loss_d: 2.75750 -  - loss_g: 1.40459 -  - loss_r: 15.21537 -  - loss_v: 0.95080 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78799     |     1.39041     |     0.16859     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:130/440[=============================>.....................................................................]--01:45:34-- - loss_d: 2.75922 -  - loss_g: 1.40056 -  - loss_r: 15.20203 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.70582     |     1.40706     |     0.17029     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:131/440[=============================>.....................................................................]--01:45:52-- - loss_d: 2.75741 -  - loss_g: 1.39964 -  - loss_r: 15.15598 -  - loss_v: 0.95100 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75856     |     1.36267     |     0.12883     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:132/440[=============================>.....................................................................]--01:44:32-- - loss_d: 2.75821 -  - loss_g: 1.39818 -  - loss_r: 15.21033 -  - loss_v: 0.94980 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73536     |     1.39916     |     0.16729     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:133/440[==============================>....................................................................]--01:45:38-- - loss_d: 2.76131 -  - loss_g: 1.40123 -  - loss_r: 15.10255 -  - loss_v: 0.94960 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76430     |     1.38797     |     0.15814     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:134/440[==============================>....................................................................]--01:44:13-- - loss_d: 2.75906 -  - loss_g: 1.40056 -  - loss_r: 15.11363 -  - loss_v: 0.94950 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73703     |     1.42386     |     0.15059     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:135/440[==============================>....................................................................]--01:43:53-- - loss_d: 2.76199 -  - loss_g: 1.39900 -  - loss_r: 15.12460 -  - loss_v: 0.95050 -
#
# Iteration:  0(500 in total)	 Time left:00:00:28
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.74682     |     1.37458     |     0.13292     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:136/440[==============================>....................................................................]--01:44:15-- - loss_d: 2.75699 -  - loss_g: 1.40175 -  - loss_r: 15.02525 -  - loss_v: 0.95030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.73568     |     1.48143     |     0.14420     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:137/440[===============================>...................................................................]--01:42:58-- - loss_d: 2.75973 -  - loss_g: 1.40285 -  - loss_r: 15.11580 -  - loss_v: 0.95030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.68638     |     1.39430     |     0.14982     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:138/440[===============================>...................................................................]--01:43:14-- - loss_d: 2.75538 -  - loss_g: 1.40260 -  - loss_r: 15.09562 -  - loss_v: 0.95010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.81431     |     1.38204     |     0.13649     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:139/440[===============================>...................................................................]--01:42:26-- - loss_d: 2.76083 -  - loss_g: 1.39636 -  - loss_r: 15.10934 -  - loss_v: 0.95020 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.70546     |     1.35495     |     0.13321     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:140/440[===============================>...................................................................]--01:42:11-- - loss_d: 2.76145 -  - loss_g: 1.39987 -  - loss_r: 15.04087 -  - loss_v: 0.95050 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.68438     |     1.40409     |     0.13333     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:141/440[================================>..................................................................]--01:43:18-- - loss_d: 2.75715 -  - loss_g: 1.40311 -  - loss_r: 15.03411 -  - loss_v: 0.95080 -
#
# Iteration:  0(500 in total)	 Time left:00:00:27
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.66984     |     1.46607     |     0.16056     |     0.00000
# ----------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f4c655d17e7e> in <module>()
#       1 if __name__ == '__main__':
#       2     tf.reset_default_graph()
# ----> 3     main(run_load_from_file=False)
#
# <ipython-input-2-6ca7843b1876> in main(run_load_from_file)
#      87                     h.x: images_u,
#      88                     h.z: z_true_u,
# ---> 89                     h.lr: learning_rate
#      90                 })
#      91
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
