# %%
# Standard library
import tensorflow as tf
import numpy as np
import _pickle as pickle
import os, sys
# Packages
from model import build_graph

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
from aae_dim_reduction import Operation, Config
import dataset
from process import Process
import sampler
import plot as plt

# %%
def main(run_load_from_file=False):
    # load MNIST images
    images, labels = dataset.load_train_images()

    # config
    opt = Operation()
    config = Config()
    opt.check_dir(config.ckpt_dir, is_restart=False)
    opt.check_dir(config.log_dir, is_restart=True)

    # setting
    max_epoch = 510
    num_trains_per_epoch = 500
    batch_size_l = 100
    batch_size_u = 100

    # create semi-supervised split
    num_validation_data = 10000
    num_labeled_data = 1000
    num_types_of_label = 10
    training_images_l, training_labels_l, training_images_u, validation_images, validation_labels = dataset.create_semisupervised(
        images, labels, num_validation_data, num_labeled_data, num_types_of_label)

    # training
    with tf.device(config.device):
        h = build_graph()

    sess_config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
    sess_config.gpu_options.allow_growth = True
    sess_config.gpu_options.per_process_gpu_memory_fraction = 0.9
    saver = tf.train.Saver(max_to_keep=2)

    with tf.Session(config=sess_config) as sess:
        '''
         Load from checkpoint or start a new session

        '''
        if run_load_from_file:
            saver.restore(sess, tf.train.latest_checkpoint(config.ckpt_dir))
            training_epoch_loss, _ = pickle.load(open(config.ckpt_dir + '/pickle.pkl', 'rb'))
        else:
            sess.run(tf.global_variables_initializer())
            training_epoch_loss = []

        # Recording loss per epoch
        process = Process()
        for epoch in range(max_epoch):
            process.start_epoch(epoch, max_epoch)

            '''
            Learning rate generator

            '''
            learning_rate = opt.ladder_learning_rate(epoch + len(training_epoch_loss))

            # Recording loss per iteration
            training_loss_set = []
            sum_loss_reconstruction = 0
            sum_loss_supervised = 0
            sum_loss_discrminator = 0
            sum_loss_generator = 0

            process_iteration = Process()
            for i in range(num_trains_per_epoch):
                process_iteration.start_epoch(i, num_trains_per_epoch)

                # sample from data distribution
                images_l, label_onehot_l, label_id_l = dataset.sample_labeled_data(training_images_l, training_labels_l,
                                                                                   batch_size_l)
                images_u = dataset.sample_unlabeled_data(training_images_u, batch_size_u)

                # reconstruction_phase
                _, loss_reconstruction = sess.run([h.opt_r, h.loss_r], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                z_true_u = sampler.gaussian(batch_size_u, config.ndim_z, mean=0, var=1)
                y_true_u = sampler.onehot_categorical(batch_size_u, config.ndim_y)
                # adversarial phase for discriminator
                _, loss_discriminator_y = sess.run([h.opt_dy, h.loss_dy], feed_dict={
                    h.x: images_u,
                    h.y: y_true_u,
                    h.lr: learning_rate
                })

                _, loss_discriminator_z = sess.run([h.opt_dz, h.loss_dz], feed_dict={
                    h.x: images_u,
                    h.z: z_true_u,
                    h.lr: learning_rate
                })

                loss_discriminator = loss_discriminator_y + loss_discriminator_z

                # adversarial phase for generator
                _, loss_generator_y, loss_generator_z = sess.run([h.opt_e, h.loss_gy, h.loss_gz], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                loss_generator = loss_generator_y + loss_generator_z

                # supervised phase
                _, loss_generator_supervised = sess.run([h.opt_ey, h.loss_ey], feed_dict={
                    h.x: images_l,
                    h.y_s: label_id_l,
                    h.lr: learning_rate
                })

                training_loss_set.append([
                    loss_reconstruction,
                    loss_discriminator,
                    loss_discriminator_y,
                    loss_discriminator_z,
                    loss_generator,
                    loss_generator_z,
                    loss_generator_y,
                    loss_generator_supervised,
                ])

                sum_loss_reconstruction += loss_reconstruction
                sum_loss_discrminator += loss_discriminator
                sum_loss_generator += loss_generator
                sum_loss_supervised += loss_generator_supervised

                if i % 1000 == 0:
                    process_iteration.show_table_2d(i, num_trains_per_epoch, {
                        'reconstruction': sum_loss_reconstruction / (i + 1),
                        'discriminator': sum_loss_discrminator / (i + 1),
                        'generator': sum_loss_generator / (i + 1),
                        'supervise': sum_loss_supervised / (i + 1),
                    })
            # In end of epoch, summary the loss
            average_training_loss_per_epoch = np.mean(np.array(training_loss_set), axis=0)

            # validation phase
            images_v_segments = np.split(validation_images, num_validation_data // 1000)
            labels_v_segments = np.split(validation_labels, num_validation_data // 1000)
            sum_accuracy = 0
            for images_v, labels_v in zip(images_v_segments, labels_v_segments):
                y_v = sess.run(h.y_r, feed_dict={h.x: images_v})
                accuracy = opt.compute_accuracy(y_v, labels_v)
                sum_accuracy += accuracy
            validation_accuracy = sum_accuracy / len(images_v_segments)

            # append validation accuracy to the training loss
            average_loss_per_epoch = np.append(average_training_loss_per_epoch, validation_accuracy)
            training_epoch_loss.append(average_loss_per_epoch)
            loss_name_per_epoch = [
                'reconstruction',
                'discriminator',
                'discriminator_y',
                'discriminator_z',
                'generator',
                'generator_z',
                'generator_y',
                'supervised',
                'validation_accuracy'
            ]

            if epoch % 1 == 0:
                process.show_bar(epoch, max_epoch, {
                    'loss_r': average_loss_per_epoch[0],
                    'loss_d': average_loss_per_epoch[1],
                    'loss_g': average_loss_per_epoch[4],
                    'loss_v': average_loss_per_epoch[8],
                })

                plt.tile_images(sess.run(h.x_, feed_dict={h.x: images_u}),
                                dir=config.log_dir,
                                filename='x_rec_epoch_{}'.format(str(epoch).zfill(3)))

            if epoch % 10 == 0:
                saver.save(sess, os.path.join(config.ckpt_dir, 'model_ckptpoint'), global_step=epoch)
                pickle.dump((training_epoch_loss, loss_name_per_epoch), open(config.ckpt_dir + '/pickle.pkl', 'wb'))
                plt.plot_double_scale_trend(config.ckpt_dir)

# %%
if __name__ == '__main__':
    tf.reset_default_graph()
    main(run_load_from_file=True)
# Out:
# INFO:tensorflow:Restoring parameters from ./ckpt_dir\model_ckptpoint-470
#
# Iteration:  0(500 in total)	 Time left:00:05:31
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76802     |     1.39285     |    58.09893     |     2.53010
# ----------------------------------------------------------------------
#
#
# Epoch:  0/510[...................................................................................................]--02:18:46-- - loss_d: 2.77203 -  - loss_g: 1.38620 -  - loss_r: 60.98676 -  - loss_v: 0.93800 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76901     |     1.37415     |    60.83890     |     0.00014
# ----------------------------------------------------------------------
#
#
# Epoch:  1/510[...................................................................................................]--02:11:46-- - loss_d: 2.77193 -  - loss_g: 1.38611 -  - loss_r: 60.82959 -  - loss_v: 0.93900 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78196     |     1.39481     |    62.91802     |     0.00483
# ----------------------------------------------------------------------
#
#
# Epoch:  2/510[...................................................................................................]--02:20:38-- - loss_d: 2.77216 -  - loss_g: 1.38615 -  - loss_r: 60.67152 -  - loss_v: 0.93920 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77087     |     1.38095     |    60.39351     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:  3/510[...................................................................................................]--02:13:56-- - loss_d: 2.77204 -  - loss_g: 1.38694 -  - loss_r: 61.01943 -  - loss_v: 0.93850 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78026     |     1.38086     |    55.95839     |     0.00058
# ----------------------------------------------------------------------
#
#
# Epoch:  4/510[...................................................................................................]--02:13:49-- - loss_d: 2.77254 -  - loss_g: 1.38641 -  - loss_r: 60.73976 -  - loss_v: 0.93820 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76643     |     1.38037     |    60.15377     |     0.00234
# ----------------------------------------------------------------------
#
#
# Epoch:  5/510[...................................................................................................]--02:17:18-- - loss_d: 2.77227 -  - loss_g: 1.38684 -  - loss_r: 60.39308 -  - loss_v: 0.93760 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76882     |     1.39120     |    64.07561     |     0.00010
# ----------------------------------------------------------------------
#
#
# Epoch:  6/510[=>.................................................................................................]--02:13:54-- - loss_d: 2.77130 -  - loss_g: 1.38631 -  - loss_r: 60.76807 -  - loss_v: 0.93670 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76829     |     1.39544     |    63.96766     |     0.00294
# ----------------------------------------------------------------------
#
#
# Epoch:  7/510[=>.................................................................................................]--02:13:14-- - loss_d: 2.77201 -  - loss_g: 1.38654 -  - loss_r: 60.78155 -  - loss_v: 0.93670 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77191     |     1.38587     |    56.80065     |     0.00006
# ----------------------------------------------------------------------
#
#
# Epoch:  8/510[=>.................................................................................................]--02:12:13-- - loss_d: 2.77237 -  - loss_g: 1.38635 -  - loss_r: 60.58823 -  - loss_v: 0.93720 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77853     |     1.37531     |    58.75033     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch:  9/510[=>.................................................................................................]--02:13:50-- - loss_d: 2.77204 -  - loss_g: 1.38691 -  - loss_r: 61.07151 -  - loss_v: 0.93600 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77916     |     1.38115     |    59.48680     |     0.00008
# ----------------------------------------------------------------------
#
#
# Epoch: 10/510[=>.................................................................................................]--02:13:59-- - loss_d: 2.77258 -  - loss_g: 1.38641 -  - loss_r: 60.80979 -  - loss_v: 0.93780 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77717     |     1.38716     |    58.06283     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch: 11/510[==>................................................................................................]--02:10:28-- - loss_d: 2.77172 -  - loss_g: 1.38581 -  - loss_r: 60.49078 -  - loss_v: 0.93760 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77963     |     1.37340     |    58.06791     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch: 12/510[==>................................................................................................]--02:12:47-- - loss_d: 2.77156 -  - loss_g: 1.38667 -  - loss_r: 60.32488 -  - loss_v: 0.93680 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78031     |     1.38761     |    53.24385     |     0.02767
# ----------------------------------------------------------------------
#
#
# Epoch: 13/510[==>................................................................................................]--02:26:31-- - loss_d: 2.77200 -  - loss_g: 1.38606 -  - loss_r: 60.58589 -  - loss_v: 0.93430 -
#
# Iteration:  0(500 in total)	 Time left:00:00:25
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76731     |     1.38401     |    67.54485     |     0.00010
# ----------------------------------------------------------------------
#
#
# Epoch: 14/510[==>................................................................................................]--02:11:37-- - loss_d: 2.77197 -  - loss_g: 1.38613 -  - loss_r: 60.49817 -  - loss_v: 0.93620 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78543     |     1.39366     |    57.91295     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 15/510[==>................................................................................................]--02:10:13-- - loss_d: 2.77225 -  - loss_g: 1.38705 -  - loss_r: 60.63891 -  - loss_v: 0.93390 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77719     |     1.38665     |    55.44290     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 16/510[===>...............................................................................................]--02:11:25-- - loss_d: 2.77258 -  - loss_g: 1.38607 -  - loss_r: 60.41911 -  - loss_v: 0.93310 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76184     |     1.39431     |    61.84762     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 17/510[===>...............................................................................................]--02:09:56-- - loss_d: 2.77219 -  - loss_g: 1.38675 -  - loss_r: 60.77607 -  - loss_v: 0.93350 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77394     |     1.38579     |    59.22652     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 18/510[===>...............................................................................................]--02:11:13-- - loss_d: 2.77187 -  - loss_g: 1.38598 -  - loss_r: 60.64053 -  - loss_v: 0.93270 -
#
# Iteration:  0(500 in total)	 Time left:00:00:28
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76999     |     1.38190     |    61.93777     |     0.00042
# ----------------------------------------------------------------------
#
#
# Epoch: 19/510[===>...............................................................................................]--02:10:47-- - loss_d: 2.77196 -  - loss_g: 1.38651 -  - loss_r: 60.53888 -  - loss_v: 0.93310 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77419     |     1.38496     |    61.63742     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 20/510[===>...............................................................................................]--02:11:53-- - loss_d: 2.77229 -  - loss_g: 1.38625 -  - loss_r: 60.57808 -  - loss_v: 0.93370 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76749     |     1.40498     |    57.27204     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 21/510[====>..............................................................................................]--02:14:52-- - loss_d: 2.77213 -  - loss_g: 1.38604 -  - loss_r: 60.78686 -  - loss_v: 0.93160 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77986     |     1.39337     |    63.02798     |     0.00003
# ----------------------------------------------------------------------
#
#
# Epoch: 22/510[====>..............................................................................................]--02:20:30-- - loss_d: 2.77269 -  - loss_g: 1.38651 -  - loss_r: 60.47157 -  - loss_v: 0.93080 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.79437     |     1.37615     |    68.42361     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 23/510[====>..............................................................................................]--02:17:09-- - loss_d: 2.77220 -  - loss_g: 1.38657 -  - loss_r: 60.44300 -  - loss_v: 0.93080 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78643     |     1.39968     |    58.53195     |     0.00005
# ----------------------------------------------------------------------
#
#
# Epoch: 24/510[====>..............................................................................................]--02:16:24-- - loss_d: 2.77259 -  - loss_g: 1.38720 -  - loss_r: 60.71035 -  - loss_v: 0.93030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77323     |     1.38139     |    59.61166     |     0.00003
# ----------------------------------------------------------------------
#
#
# Epoch: 25/510[====>..............................................................................................]--02:13:48-- - loss_d: 2.77232 -  - loss_g: 1.38619 -  - loss_r: 60.68242 -  - loss_v: 0.93290 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77489     |     1.38926     |    64.35162     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 26/510[=====>.............................................................................................]--02:15:24-- - loss_d: 2.77256 -  - loss_g: 1.38696 -  - loss_r: 60.83395 -  - loss_v: 0.93030 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77847     |     1.38986     |    58.32903     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 27/510[=====>.............................................................................................]--02:16:04-- - loss_d: 2.77263 -  - loss_g: 1.38595 -  - loss_r: 60.69061 -  - loss_v: 0.93160 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76539     |     1.38321     |    57.65469     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 28/510[=====>.............................................................................................]--02:14:27-- - loss_d: 2.77211 -  - loss_g: 1.38723 -  - loss_r: 60.54373 -  - loss_v: 0.92870 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77863     |     1.39010     |    71.20005     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch: 29/510[=====>.............................................................................................]--02:14:57-- - loss_d: 2.77230 -  - loss_g: 1.38695 -  - loss_r: 60.65390 -  - loss_v: 0.92900 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78052     |     1.39714     |    62.36028     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 30/510[=====>.............................................................................................]--02:13:35-- - loss_d: 2.77148 -  - loss_g: 1.38594 -  - loss_r: 60.65278 -  - loss_v: 0.92730 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77815     |     1.37547     |    59.85456     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 31/510[======>............................................................................................]--02:13:15-- - loss_d: 2.77259 -  - loss_g: 1.38693 -  - loss_r: 60.51642 -  - loss_v: 0.92890 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75422     |     1.38159     |    55.82305     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 32/510[======>............................................................................................]--02:12:22-- - loss_d: 2.77249 -  - loss_g: 1.38616 -  - loss_r: 60.81958 -  - loss_v: 0.92930 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76480     |     1.40264     |    66.11771     |     0.00290
# ----------------------------------------------------------------------
#
#
# Epoch: 33/510[======>............................................................................................]--02:11:59-- - loss_d: 2.77251 -  - loss_g: 1.38736 -  - loss_r: 60.46850 -  - loss_v: 0.93010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78342     |     1.37720     |    55.05729     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 34/510[======>............................................................................................]--02:11:15-- - loss_d: 2.77281 -  - loss_g: 1.38625 -  - loss_r: 60.49020 -  - loss_v: 0.92900 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77059     |     1.39742     |    66.24344     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 35/510[======>............................................................................................]--02:11:39-- - loss_d: 2.77238 -  - loss_g: 1.38652 -  - loss_r: 60.35785 -  - loss_v: 0.92650 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77313     |     1.38996     |    57.26591     |     0.01910
# ----------------------------------------------------------------------
#
#
# Epoch: 36/510[=======>...........................................................................................]--02:12:30-- - loss_d: 2.77300 -  - loss_g: 1.38622 -  - loss_r: 60.54625 -  - loss_v: 0.92640 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76288     |     1.38722     |    63.83393     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 37/510[=======>...........................................................................................]--02:11:02-- - loss_d: 2.77271 -  - loss_g: 1.38664 -  - loss_r: 60.57652 -  - loss_v: 0.92640 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78733     |     1.38904     |    59.25727     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 38/510[=======>...........................................................................................]--02:12:25-- - loss_d: 2.77235 -  - loss_g: 1.38725 -  - loss_r: 60.53619 -  - loss_v: 0.92740 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77444     |     1.39709     |    58.93981     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 39/510[=======>...........................................................................................]--02:10:00-- - loss_d: 2.77320 -  - loss_g: 1.38591 -  - loss_r: 60.70489 -  - loss_v: 0.92690 -
#
# Iteration:  0(500 in total)	 Time left:00:00:33
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77659     |     1.38016     |    62.13169     |     0.00003
# ----------------------------------------------------------------------
#
#
# Epoch: 40/510[=======>...........................................................................................]--02:09:28-- - loss_d: 2.77255 -  - loss_g: 1.38551 -  - loss_r: 60.74185 -  - loss_v: 0.92810 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77630     |     1.38483     |    60.31996     |     0.00004
# ----------------------------------------------------------------------
#
#
# Epoch: 41/510[========>..........................................................................................]--02:08:42-- - loss_d: 2.77180 -  - loss_g: 1.38606 -  - loss_r: 60.36118 -  - loss_v: 0.92820 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75708     |     1.38109     |    61.09583     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 42/510[========>..........................................................................................]--02:08:55-- - loss_d: 2.77231 -  - loss_g: 1.38659 -  - loss_r: 60.73801 -  - loss_v: 0.92680 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78389     |     1.38683     |    61.90022     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch: 43/510[========>..........................................................................................]--02:13:34-- - loss_d: 2.77271 -  - loss_g: 1.38683 -  - loss_r: 60.48389 -  - loss_v: 0.92680 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77858     |     1.38605     |    66.91354     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 44/510[========>..........................................................................................]--02:10:18-- - loss_d: 2.77208 -  - loss_g: 1.38616 -  - loss_r: 60.14335 -  - loss_v: 0.92800 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78380     |     1.38513     |    57.11948     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 45/510[========>..........................................................................................]--02:09:56-- - loss_d: 2.77232 -  - loss_g: 1.38591 -  - loss_r: 60.59190 -  - loss_v: 0.92730 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76409     |     1.37841     |    57.99730     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 46/510[=========>.........................................................................................]--02:09:22-- - loss_d: 2.77251 -  - loss_g: 1.38654 -  - loss_r: 60.50309 -  - loss_v: 0.92660 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75503     |     1.38720     |    60.03219     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 47/510[=========>.........................................................................................]--02:09:22-- - loss_d: 2.77249 -  - loss_g: 1.38602 -  - loss_r: 60.27587 -  - loss_v: 0.92890 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78304     |     1.38759     |    62.13430     |     0.00164
# ----------------------------------------------------------------------
#
#
# Epoch: 48/510[=========>.........................................................................................]--02:08:23-- - loss_d: 2.77293 -  - loss_g: 1.38566 -  - loss_r: 60.42185 -  - loss_v: 0.92820 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77722     |     1.38571     |    60.83103     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 49/510[=========>.........................................................................................]--02:07:54-- - loss_d: 2.77274 -  - loss_g: 1.38662 -  - loss_r: 60.58055 -  - loss_v: 0.92620 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77633     |     1.38786     |    57.12517     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 50/510[=========>.........................................................................................]--02:16:22-- - loss_d: 2.77276 -  - loss_g: 1.38582 -  - loss_r: 60.44632 -  - loss_v: 0.92870 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76665     |     1.38496     |    61.07816     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 51/510[=========>.........................................................................................]--02:08:10-- - loss_d: 2.77208 -  - loss_g: 1.38712 -  - loss_r: 60.27879 -  - loss_v: 0.92830 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78864     |     1.39722     |    57.20625     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 52/510[==========>........................................................................................]--02:08:30-- - loss_d: 2.77257 -  - loss_g: 1.38620 -  - loss_r: 60.17729 -  - loss_v: 0.93140 -
#
# Iteration:  0(500 in total)	 Time left:00:00:26
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77131     |     1.38612     |    62.05362     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 53/510[==========>........................................................................................]--02:08:23-- - loss_d: 2.77240 -  - loss_g: 1.38595 -  - loss_r: 60.52994 -  - loss_v: 0.93020 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77534     |     1.38854     |    61.07599     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 54/510[==========>........................................................................................]--02:06:39-- - loss_d: 2.77285 -  - loss_g: 1.38647 -  - loss_r: 60.67612 -  - loss_v: 0.93170 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77837     |     1.38832     |    61.20056     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 55/510[==========>........................................................................................]--02:06:21-- - loss_d: 2.77244 -  - loss_g: 1.38633 -  - loss_r: 60.50517 -  - loss_v: 0.93220 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77655     |     1.38086     |    60.18674     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 56/510[==========>........................................................................................]--02:09:57-- - loss_d: 2.77207 -  - loss_g: 1.38631 -  - loss_r: 60.38195 -  - loss_v: 0.92850 -
#
# Iteration:  0(500 in total)	 Time left:00:00:24
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77388     |     1.38356     |    66.34293     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 57/510[===========>.......................................................................................]--02:05:10-- - loss_d: 2.77315 -  - loss_g: 1.38645 -  - loss_r: 60.59875 -  - loss_v: 0.93080 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76410     |     1.38701     |    56.97996     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 58/510[===========>.......................................................................................]--02:05:19-- - loss_d: 2.77231 -  - loss_g: 1.38553 -  - loss_r: 60.19583 -  - loss_v: 0.93220 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77357     |     1.38633     |    67.15652     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 59/510[===========>.......................................................................................]--02:05:15-- - loss_d: 2.77228 -  - loss_g: 1.38676 -  - loss_r: 60.43769 -  - loss_v: 0.93460 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76346     |     1.39301     |    57.15080     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 60/510[===========>.......................................................................................]--02:05:27-- - loss_d: 2.77223 -  - loss_g: 1.38521 -  - loss_r: 60.32963 -  - loss_v: 0.92960 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77703     |     1.39740     |    60.36780     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 61/510[===========>.......................................................................................]--02:02:18-- - loss_d: 2.77302 -  - loss_g: 1.38675 -  - loss_r: 60.22243 -  - loss_v: 0.93120 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76267     |     1.38184     |    58.91010     |     0.00001
# ----------------------------------------------------------------------
#
#
# Epoch: 62/510[============>......................................................................................]--02:03:59-- - loss_d: 2.77255 -  - loss_g: 1.38618 -  - loss_r: 60.27598 -  - loss_v: 0.93380 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75713     |     1.38377     |    59.18204     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 63/510[============>......................................................................................]--02:05:54-- - loss_d: 2.77257 -  - loss_g: 1.38774 -  - loss_r: 60.38587 -  - loss_v: 0.93210 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76794     |     1.38861     |    60.43608     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 64/510[============>......................................................................................]--02:03:23-- - loss_d: 2.77234 -  - loss_g: 1.38602 -  - loss_r: 60.25097 -  - loss_v: 0.92770 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76909     |     1.38767     |    60.11814     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 65/510[============>......................................................................................]--02:09:09-- - loss_d: 2.77225 -  - loss_g: 1.38722 -  - loss_r: 60.33821 -  - loss_v: 0.93320 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75721     |     1.39211     |    64.68037     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 66/510[============>......................................................................................]--02:02:38-- - loss_d: 2.77269 -  - loss_g: 1.38693 -  - loss_r: 60.27599 -  - loss_v: 0.92960 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78235     |     1.37808     |    60.13071     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 67/510[=============>.....................................................................................]--02:10:23-- - loss_d: 2.77228 -  - loss_g: 1.38733 -  - loss_r: 60.10489 -  - loss_v: 0.92850 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78509     |     1.39099     |    60.42260     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 68/510[=============>.....................................................................................]--02:01:21-- - loss_d: 2.77251 -  - loss_g: 1.38606 -  - loss_r: 60.03693 -  - loss_v: 0.92800 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76798     |     1.38164     |    57.98340     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 69/510[=============>.....................................................................................]--02:00:09-- - loss_d: 2.77231 -  - loss_g: 1.38677 -  - loss_r: 60.25175 -  - loss_v: 0.92810 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75719     |     1.40316     |    58.81123     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 70/510[=============>.....................................................................................]--01:59:17-- - loss_d: 2.77220 -  - loss_g: 1.38573 -  - loss_r: 60.56271 -  - loss_v: 0.92650 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77339     |     1.38355     |    59.55199     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 71/510[=============>.....................................................................................]--02:00:31-- - loss_d: 2.77298 -  - loss_g: 1.38667 -  - loss_r: 60.23151 -  - loss_v: 0.92670 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76098     |     1.38605     |    64.36157     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 72/510[==============>....................................................................................]--01:58:36-- - loss_d: 2.77251 -  - loss_g: 1.38692 -  - loss_r: 60.37904 -  - loss_v: 0.92910 -
#
# Iteration:  0(500 in total)	 Time left:00:00:22
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77713     |     1.37753     |    62.51411     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 73/510[==============>....................................................................................]--02:06:04-- - loss_d: 2.77257 -  - loss_g: 1.38665 -  - loss_r: 60.27409 -  - loss_v: 0.92920 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77467     |     1.38984     |    57.91760     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 74/510[==============>....................................................................................]--02:00:48-- - loss_d: 2.77219 -  - loss_g: 1.38584 -  - loss_r: 60.05392 -  - loss_v: 0.93010 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76933     |     1.39127     |    63.76213     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 75/510[==============>....................................................................................]--02:00:50-- - loss_d: 2.77233 -  - loss_g: 1.38584 -  - loss_r: 60.30414 -  - loss_v: 0.92940 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77686     |     1.39072     |    57.39074     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch: 76/510[==============>....................................................................................]--02:01:43-- - loss_d: 2.77275 -  - loss_g: 1.38638 -  - loss_r: 60.26785 -  - loss_v: 0.92650 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77456     |     1.38484     |    61.80562     |     0.00000
# ----------------------------------------------------------------------
#
#
# ...
# ----------------------------------------------------------------------
#
#
# Epoch:168/510[================================>..................................................................]--01:34:55-- - loss_d: 2.77187 -  - loss_g: 1.38516 -  - loss_r: 60.02664 -  - loss_v: 0.92770 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76963     |     1.37855     |    52.08173     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:169/510[=================================>.................................................................]--01:37:58-- - loss_d: 2.77214 -  - loss_g: 1.38616 -  - loss_r: 59.87440 -  - loss_v: 0.92890 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76021     |     1.38860     |    58.11366     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:170/510[=================================>.................................................................]--01:34:19-- - loss_d: 2.77280 -  - loss_g: 1.38665 -  - loss_r: 59.92308 -  - loss_v: 0.92760 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78376     |     1.38230     |    59.85691     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:171/510[=================================>.................................................................]--01:33:54-- - loss_d: 2.77257 -  - loss_g: 1.38636 -  - loss_r: 59.81530 -  - loss_v: 0.92880 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77265     |     1.37660     |    54.31561     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:172/510[=================================>.................................................................]--01:38:14-- - loss_d: 2.77241 -  - loss_g: 1.38665 -  - loss_r: 59.57147 -  - loss_v: 0.92690 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77058     |     1.38200     |    59.33518     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:173/510[=================================>.................................................................]--01:36:25-- - loss_d: 2.77251 -  - loss_g: 1.38591 -  - loss_r: 59.35613 -  - loss_v: 0.92700 -
#
# Iteration:  0(500 in total)	 Time left:00:00:20
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77309     |     1.39512     |    57.62457     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:174/510[==================================>................................................................]--01:37:49-- - loss_d: 2.77224 -  - loss_g: 1.38666 -  - loss_r: 59.47334 -  - loss_v: 0.92630 -
#
# Iteration:  0(500 in total)	 Time left:00:00:21
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78492     |     1.38909     |    60.88900     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:175/510[==================================>................................................................]--01:33:50-- - loss_d: 2.77213 -  - loss_g: 1.38617 -  - loss_r: 59.66446 -  - loss_v: 0.92470 -
#
# Iteration:  0(500 in total)	 Time left:00:00:19
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77612     |     1.38485     |    60.07228     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:176/510[==================================>................................................................]--01:36:37-- - loss_d: 2.77266 -  - loss_g: 1.38641 -  - loss_r: 59.54812 -  - loss_v: 0.92910 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77205     |     1.38169     |    55.97565     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:177/510[==================================>................................................................]--01:33:31-- - loss_d: 2.77231 -  - loss_g: 1.38625 -  - loss_r: 59.67445 -  - loss_v: 0.92480 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77515     |     1.39123     |    59.09125     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:178/510[==================================>................................................................]--01:32:23-- - loss_d: 2.77262 -  - loss_g: 1.38621 -  - loss_r: 59.30239 -  - loss_v: 0.92750 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.75875     |     1.38600     |    54.40775     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:179/510[===================================>...............................................................]--01:32:31-- - loss_d: 2.77268 -  - loss_g: 1.38657 -  - loss_r: 59.52760 -  - loss_v: 0.92660 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76577     |     1.38733     |    59.03686     |     0.00002
# ----------------------------------------------------------------------
#
#
# Epoch:180/510[===================================>...............................................................]--01:35:37-- - loss_d: 2.77238 -  - loss_g: 1.38631 -  - loss_r: 59.42998 -  - loss_v: 0.92860 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.76990     |     1.38884     |    57.24220     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:181/510[===================================>...............................................................]--01:33:37-- - loss_d: 2.77232 -  - loss_g: 1.38628 -  - loss_r: 59.58194 -  - loss_v: 0.92910 -
#
# Iteration:  0(500 in total)	 Time left:00:00:28
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77004     |     1.38868     |    64.80354     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:182/510[===================================>...............................................................]--01:31:29-- - loss_d: 2.77299 -  - loss_g: 1.38671 -  - loss_r: 59.37399 -  - loss_v: 0.92570 -
#
# Iteration:  0(500 in total)	 Time left:00:00:17
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78073     |     1.39101     |    67.57343     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:183/510[===================================>...............................................................]--01:31:07-- - loss_d: 2.77316 -  - loss_g: 1.38638 -  - loss_r: 59.41777 -  - loss_v: 0.92900 -
#
# Iteration:  0(500 in total)	 Time left:00:00:18
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.77275     |     1.38668     |    56.03636     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:184/510[====================================>..............................................................]--01:32:05-- - loss_d: 2.77243 -  - loss_g: 1.38631 -  - loss_r: 59.34542 -  - loss_v: 0.92700 -
#
# Iteration:  0(500 in total)	 Time left:00:00:32
# ----------------------------------------------------------------------
#  discriminator  |    generator    | reconstruction  |    supervise
# ----------------------------------------------------------------------
#     2.78104     |     1.37967     |    58.55078     |     0.00000
# ----------------------------------------------------------------------
#
#
# Epoch:185/510[====================================>..............................................................]--01:32:20-- - loss_d: 2.77269 -  - loss_g: 1.38666 -  - loss_r: 59.68855 -  - loss_v: 0.92760 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a33309ac0e05> in <module>()
#       1 if __name__ == '__main__':
#       2     tf.reset_default_graph()
# ----> 3     main(run_load_from_file=True)
#
# <ipython-input-2-5ee698356554> in main(run_load_from_file)
#     169                 plt.tile_images(sess.run(h.x_, feed_dict={h.x: images_u}),
#     170                                 dir=config.log_dir,
# --> 171                                 filename='x_rec_epoch_{}'.format(str(epoch).zfill(3)))
#     172
#     173             if epoch % 10 == 0:
#
# C:\Users\CYD\Desktop\AAE_advanced\plot.py in tile_images(image_batch, image_width, image_height, dir, filename)
#      11         raise Exception('please provide a path ')
#      12
# ---> 13     pylab.clf()
#      14     fig = pylab.gcf()
#      15     fig.set_size_inches(16.0, 16.0)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in clf()
#     671     Clear the current figure.
#     672     """
# --> 673     gcf().clf()
#     674
#     675
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\figure.py in clf(self, keep_observers)
#    1065
#    1066         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 1067             ax.cla()
#    1068             self.delaxes(ax)         # removes ax from self._axstack
#    1069
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#     979         yaxis_visible = self.yaxis.get_visible()
#     980
# --> 981         self.xaxis.cla()
#     982         self.yaxis.cla()
#     983         for name, spine in six.iteritems(self.spines):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axis.py in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     773
#     774         self.majorTicks.extend([self._get_tick(major=True)])
# --> 775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#     777         self._lastNumMinorTicks = 1
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick2line(self)
#     432                           markersize=self._size,
#     433                           markeredgewidth=self._width,
# --> 434                           zorder=self._zorder)
#     435
#     436         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     423         self.set_markeredgewidth(markeredgewidth)
#     424
# --> 425         self.set_fillstyle(fillstyle)
#     426
#     427         self.verticalOffset = None
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\lines.py in set_fillstyle(self, fs)
#     553         ACCEPTS: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#     554         """
# --> 555         self._marker.set_fillstyle(fs)
#     556         self.stale = True
#     557
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\markers.py in set_fillstyle(self, fillstyle)
#     235                              % ' '.join(self.fillstyles))
#     236         self._fillstyle = fillstyle
# --> 237         self._recache()
#     238
#     239     def get_joinstyle(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     206         self._capstyle = 'butt'
#     207         self._filled = True
# --> 208         self._marker_function()
#     209
#     210     if six.PY3:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickup(self)
#     714
#     715     def _set_tickup(self):
# --> 716         self._transform = Affine2D().scale(1.0, 1.0)
#     717         self._snap_threshold = 1.0
#     718         self._filled = False
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1986             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]],
#    1987             np.float_)
# -> 1988         self._mtx = np.dot(scale_mtx, self._mtx)
#    1989         self.invalidate()
#    1990         return self
#
# KeyboardInterrupt:
