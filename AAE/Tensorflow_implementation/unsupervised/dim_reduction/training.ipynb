# %%
# Standard library
import tensorflow as tf
import numpy as np
import _pickle as pickle
import os, sys
# Packages
from model import build_graph

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
from aae_dim_reduction import Operation, Config
import dataset
from process import Process
import sampler
import plot as plt

# %%
def main(run_load_from_file=False):
    # load MNIST images
    images, labels = dataset.load_train_images()

    # config
    opt = Operation()
    config = Config()
    opt.check_dir(config.ckpt_dir, is_restart=False)
    opt.check_dir(config.log_dir, is_restart=True)

    # setting
    max_epoch = 510
    num_trains_per_epoch = 500
    batch_size_l = 100
    batch_size_u = 100

    # training
    with tf.device(config.device):
        h = build_graph()

    sess_config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
    sess_config.gpu_options.allow_growth = True
    sess_config.gpu_options.per_process_gpu_memory_fraction = 0.9
    saver = tf.train.Saver(max_to_keep=2)

    with tf.Session(config=sess_config) as sess:
        '''
         Load from checkpoint or start a new session

        '''
        if run_load_from_file:
            saver.restore(sess, tf.train.latest_checkpoint(config.ckpt_dir))
            training_epoch_loss, _ = pickle.load(open(config.ckpt_dir + '/pickle.pkl', 'rb'))
        else:
            sess.run(tf.global_variables_initializer())
            training_epoch_loss = []

        # Recording loss per epoch
        process = Process()
        for epoch in range(max_epoch):
            process.start_epoch(epoch, max_epoch)

            '''
            Learning rate generator

            '''
            learning_rate = opt.ladder_learning_rate(epoch + len(training_epoch_loss))

            # Recording loss per iteration
            training_loss_set = []
            sum_loss_reconstruction = 0
            sum_loss_discrminator = 0
            sum_loss_generator = 0
            sum_loss_cluster_head = 0

            process_iteration = Process()
            for i in range(num_trains_per_epoch):
                process_iteration.start_epoch(i, num_trains_per_epoch)

                # sample from data distribution
                images_u = dataset.sample_unlabeled_data(images, batch_size_u)

                # additional cost function that penalizes the euclidean between of every two of cluster
                if epoch ==0:
                    for j in range(10):
                        starting_labels, ending_labels = dataset.cluster_create_dataset(config.ndim_y)
                        _, loss_transform = sess.run([h.opt_t, h.loss_t], feed_dict={
                            h.g_s: starting_labels,
                            h.g_e: ending_labels,
                            h.lr: learning_rate
                        })

                # reconstruction_phase
                _, loss_reconstruction = sess.run([h.opt_r, h.loss_r], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                z_true_u = sampler.gaussian(batch_size_u, config.ndim_z, mean=0, var=1)
                y_true_u = sampler.onehot_categorical(batch_size_u, config.ndim_y)
                # adversarial phase for discriminator
                _, loss_discriminator_y = sess.run([h.opt_dy, h.loss_dy], feed_dict={
                    h.x: images_u,
                    h.y: y_true_u,
                    h.lr: learning_rate
                })

                _, loss_discriminator_z = sess.run([h.opt_dz, h.loss_dz], feed_dict={
                    h.x: images_u,
                    h.z: z_true_u,
                    h.lr: learning_rate
                })

                loss_discriminator = loss_discriminator_y + loss_discriminator_z

                # adversarial phase for generator
                _, loss_generator_y, loss_generator_z = sess.run([h.opt_e, h.loss_gy, h.loss_gz], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                loss_generator = loss_generator_y + loss_generator_z


                training_loss_set.append([
                    loss_reconstruction,
                    loss_discriminator,
                    loss_discriminator_y,
                    loss_discriminator_z,
                    loss_generator,
                    loss_generator_z,
                    loss_generator_y,
                    loss_transform
                ])

                sum_loss_reconstruction += loss_reconstruction
                sum_loss_discrminator += loss_discriminator
                sum_loss_generator += loss_generator
                sum_loss_cluster_head += loss_transform

                if i % 1000 == 0:
                    process_iteration.show_table_2d(i, num_trains_per_epoch, {
                        'reconstruction': sum_loss_reconstruction / (i + 1),
                        'discriminator': sum_loss_discrminator / (i + 1),
                        'generator': sum_loss_generator / (i + 1),
                        'cluster_head':sum_loss_cluster_head / (i + 1)
                    })
            # In end of epoch, summary the loss
            average_training_loss_per_epoch = np.mean(np.array(training_loss_set), axis=0)

            training_epoch_loss.append(average_training_loss_per_epoch)
            loss_name_per_epoch = [
                'reconstruction',
                'discriminator',
                'discriminator_y',
                'discriminator_z',
                'generator',
                'generator_z',
                'generator_y',
                'transform',
            ]

            if epoch % 1 == 0:
                process.show_bar(epoch, max_epoch, {
                    'loss_r': average_training_loss_per_epoch[0],
                    'loss_d': average_training_loss_per_epoch[1],
                    'loss_g': average_training_loss_per_epoch[4],
                })

                plt.tile_images(sess.run(h.x_, feed_dict={h.x: images_u}),
                                dir=config.log_dir,
                                filename='x_rec_epoch_{}'.format(str(epoch).zfill(3)))

            if epoch % 10 == 0:
                saver.save(sess, os.path.join(config.ckpt_dir, 'model_ckptpoint'), global_step=epoch)
                pickle.dump((training_epoch_loss, loss_name_per_epoch), open(config.ckpt_dir + '/pickle.pkl', 'wb'))
                plt.plot_double_scale_trend(config.ckpt_dir)

# %%
if __name__ == '__main__':
    tf.reset_default_graph()
    main(run_load_from_file=False)
# Out:
# Iteration:  0(500 in total)	 Time left:00:05:03
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -465.01074    |     2.77257     |     1.37144     |    363.06082
# ----------------------------------------------------------------------
#
#
# Epoch:  0/510[...................................................................................................]--03:37:16-- - loss_d: 2.41895 -  - loss_g: 1.70933 -  - loss_r: 87.23355 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.12513     |     1.84136     |    75.37714
# ----------------------------------------------------------------------
#
#
# Epoch:  1/510[...................................................................................................]--02:06:10-- - loss_d: 2.26960 -  - loss_g: 1.96066 -  - loss_r: 77.47324 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.36666     |     1.83788     |    73.31773
# ----------------------------------------------------------------------
#
#
# Epoch:  2/510[...................................................................................................]--02:10:12-- - loss_d: 2.32608 -  - loss_g: 1.99374 -  - loss_r: 74.32588 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.41656     |     2.12785     |    68.54269
# ----------------------------------------------------------------------
#
#
# Epoch:  3/510[...................................................................................................]--02:06:13-- - loss_d: 2.31865 -  - loss_g: 2.08809 -  - loss_r: 72.15121 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.58478     |     2.07518     |    71.48615
# ----------------------------------------------------------------------
#
#
# Epoch:  4/510[...................................................................................................]--02:11:42-- - loss_d: 2.66720 -  - loss_g: 1.57028 -  - loss_r: 71.12180 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.62197     |     1.60705     |    75.65108
# ----------------------------------------------------------------------
#
#
# Epoch:  5/510[...................................................................................................]--02:14:11-- - loss_d: 2.70125 -  - loss_g: 1.55095 -  - loss_r: 70.03379 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.58649     |     1.44244     |    66.63042
# ----------------------------------------------------------------------
#
#
# Epoch:  6/510[=>.................................................................................................]--02:14:04-- - loss_d: 2.71316 -  - loss_g: 1.50147 -  - loss_r: 69.24506 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.92016     |     1.31394     |    79.06051
# ----------------------------------------------------------------------
#
#
# Epoch:  7/510[=>.................................................................................................]--02:11:24-- - loss_d: 2.72758 -  - loss_g: 1.49910 -  - loss_r: 68.73860 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.87276     |     1.32600     |    71.31248
# ----------------------------------------------------------------------
#
#
# Epoch:  8/510[=>.................................................................................................]--02:10:43-- - loss_d: 2.73983 -  - loss_g: 1.47541 -  - loss_r: 68.17965 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.45295     |     1.24646     |    71.23970
# ----------------------------------------------------------------------
#
#
# Epoch:  9/510[=>.................................................................................................]--02:11:00-- - loss_d: 2.72659 -  - loss_g: 1.45758 -  - loss_r: 67.89525 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.68319     |     1.58508     |    67.82592
# ----------------------------------------------------------------------
#
#
# Epoch: 10/510[=>.................................................................................................]--02:11:07-- - loss_d: 2.74510 -  - loss_g: 1.46103 -  - loss_r: 67.76332 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.82124     |     1.42828     |    64.91606
# ----------------------------------------------------------------------
#
#
# Epoch: 11/510[==>................................................................................................]--02:11:24-- - loss_d: 2.75500 -  - loss_g: 1.44539 -  - loss_r: 67.59106 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.81540     |     1.31095     |    69.97643
# ----------------------------------------------------------------------
#
#
# Epoch: 12/510[==>................................................................................................]--02:11:29-- - loss_d: 2.74785 -  - loss_g: 1.45864 -  - loss_r: 67.50391 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.77499     |     1.54441     |    68.46439
# ----------------------------------------------------------------------
#
#
# Epoch: 13/510[==>................................................................................................]--02:12:38-- - loss_d: 2.74014 -  - loss_g: 1.44448 -  - loss_r: 67.21306 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.69111     |     1.48874     |    74.69267
# ----------------------------------------------------------------------
#
#
# Epoch: 14/510[==>................................................................................................]--02:12:49-- - loss_d: 2.76094 -  - loss_g: 1.43459 -  - loss_r: 66.99288 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.77196     |     1.27295     |    68.35037
# ----------------------------------------------------------------------
#
#
# Epoch: 15/510[==>................................................................................................]--02:09:42-- - loss_d: 2.75607 -  - loss_g: 1.43076 -  - loss_r: 66.95171 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.48952     |     1.51998     |    64.83166
# ----------------------------------------------------------------------
#
#
# Epoch: 16/510[===>...............................................................................................]--02:09:13-- - loss_d: 2.74848 -  - loss_g: 1.43396 -  - loss_r: 66.73168 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.72891     |     1.31307     |    62.59479
# ----------------------------------------------------------------------
#
#
# Epoch: 17/510[===>...............................................................................................]--02:10:46-- - loss_d: 2.75138 -  - loss_g: 1.41897 -  - loss_r: 66.45136 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.75313     |     1.43253     |    66.26574
# ----------------------------------------------------------------------
#
#
# Epoch: 18/510[===>...............................................................................................]--02:10:18-- - loss_d: 2.77091 -  - loss_g: 1.42588 -  - loss_r: 66.46995 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.76083     |     1.35585     |    70.58973
# ----------------------------------------------------------------------
#
#
# Epoch: 19/510[===>...............................................................................................]--02:11:16-- - loss_d: 2.77158 -  - loss_g: 1.41897 -  - loss_r: 66.02445 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.81027     |     1.28316     |    64.42337
# ----------------------------------------------------------------------
#
#
# Epoch: 20/510[===>...............................................................................................]--02:08:32-- - loss_d: 2.76786 -  - loss_g: 1.41669 -  - loss_r: 66.02871 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.93014     |     1.48300     |    62.88018
# ----------------------------------------------------------------------
#
#
# Epoch: 21/510[====>..............................................................................................]--02:08:04-- - loss_d: 2.76732 -  - loss_g: 1.40830 -  - loss_r: 65.91280 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.77462     |     1.36444     |    63.54190
# ----------------------------------------------------------------------
#
#
# Epoch: 22/510[====>..............................................................................................]--02:10:57-- - loss_d: 2.76854 -  - loss_g: 1.40930 -  - loss_r: 65.83333 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.91339     |     1.38578     |    66.28201
# ----------------------------------------------------------------------
#
#
# Epoch: 23/510[====>..............................................................................................]--02:09:08-- - loss_d: 2.76568 -  - loss_g: 1.40557 -  - loss_r: 66.17630 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.82646     |     1.37658     |    69.72232
# ----------------------------------------------------------------------
#
#
# Epoch: 24/510[====>..............................................................................................]--02:09:14-- - loss_d: 2.77530 -  - loss_g: 1.41125 -  - loss_r: 65.68660 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.70367     |     1.42888     |    64.18002
# ----------------------------------------------------------------------
#
#
# Epoch: 25/510[====>..............................................................................................]--02:08:28-- - loss_d: 2.76539 -  - loss_g: 1.39360 -  - loss_r: 64.92921 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.74642     |     1.35357     |    60.82499
# ----------------------------------------------------------------------
#
#
# Epoch: 26/510[=====>.............................................................................................]--02:07:05-- - loss_d: 2.77020 -  - loss_g: 1.39856 -  - loss_r: 64.43206 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.64740     |     1.46781     |    73.15881
# ----------------------------------------------------------------------
#
#
# Epoch: 27/510[=====>.............................................................................................]--02:10:21-- - loss_d: 2.76056 -  - loss_g: 1.39751 -  - loss_r: 64.76347 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.81259     |     1.40656     |    61.03892
# ----------------------------------------------------------------------
#
#
# Epoch: 28/510[=====>.............................................................................................]--02:06:29-- - loss_d: 2.76485 -  - loss_g: 1.40842 -  - loss_r: 64.46730 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.78467     |     1.43700     |    62.70921
# ----------------------------------------------------------------------
#
#
# Epoch: 29/510[=====>.............................................................................................]--02:07:09-- - loss_d: 2.75773 -  - loss_g: 1.39712 -  - loss_r: 64.26492 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.89191     |     1.32570     |    64.08109
# ----------------------------------------------------------------------
#
#
# Epoch: 30/510[=====>.............................................................................................]--02:05:36-- - loss_d: 2.76190 -  - loss_g: 1.40171 -  - loss_r: 64.27062 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.76832     |     1.34633     |    64.94241
# ----------------------------------------------------------------------
#
#
# Epoch: 31/510[======>............................................................................................]--02:03:47-- - loss_d: 2.75436 -  - loss_g: 1.39883 -  - loss_r: 64.46914 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.76609     |     1.49576     |    67.32312
# ----------------------------------------------------------------------
#
#
# Epoch: 32/510[======>............................................................................................]--02:06:38-- - loss_d: 2.75869 -  - loss_g: 1.40255 -  - loss_r: 64.23563 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.72843     |     1.35016     |    65.71443
# ----------------------------------------------------------------------
#
#
# Epoch: 33/510[======>............................................................................................]--02:05:29-- - loss_d: 2.76324 -  - loss_g: 1.40652 -  - loss_r: 64.50508 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.76746     |     1.45245     |    64.72693
# ----------------------------------------------------------------------
#
#
# Epoch: 34/510[======>............................................................................................]--02:04:52-- - loss_d: 2.77009 -  - loss_g: 1.40124 -  - loss_r: 64.21595 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.77747     |     1.44856     |    68.67067
# ----------------------------------------------------------------------
#
#
# Epoch: 35/510[======>............................................................................................]--02:07:46-- - loss_d: 2.75366 -  - loss_g: 1.39761 -  - loss_r: 64.38365 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.87963     |     1.39954     |    63.23119
# ----------------------------------------------------------------------
#
#
# Epoch: 36/510[=======>...........................................................................................]--02:00:33-- - loss_d: 2.75911 -  - loss_g: 1.40267 -  - loss_r: 64.22261 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.80908     |     1.43345     |    64.23264
# ----------------------------------------------------------------------
#
#
# Epoch: 37/510[=======>...........................................................................................]--01:57:35-- - loss_d: 2.75751 -  - loss_g: 1.40640 -  - loss_r: 63.95247 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.71134     |     1.36216     |    64.84850
# ----------------------------------------------------------------------
#
#
# Epoch: 38/510[=======>...........................................................................................]--01:58:11-- - loss_d: 2.74814 -  - loss_g: 1.39935 -  - loss_r: 64.27138 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.84057     |     1.36301     |    60.37202
# ----------------------------------------------------------------------
#
#
# Epoch: 39/510[=======>...........................................................................................]--01:58:10-- - loss_d: 2.74649 -  - loss_g: 1.40503 -  - loss_r: 63.95568 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.85984     |     1.31330     |    66.05968
# ----------------------------------------------------------------------
#
#
# Epoch: 40/510[=======>...........................................................................................]--01:59:50-- - loss_d: 2.75435 -  - loss_g: 1.40558 -  - loss_r: 63.84563 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.73185     |     1.50144     |    64.33664
# ----------------------------------------------------------------------
#
#
# Epoch: 41/510[========>..........................................................................................]--01:58:58-- - loss_d: 2.75437 -  - loss_g: 1.40493 -  - loss_r: 64.09507 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.78938     |     1.31518     |    65.49578
# ----------------------------------------------------------------------
#
#
# Epoch: 42/510[========>..........................................................................................]--01:56:00-- - loss_d: 2.75927 -  - loss_g: 1.40277 -  - loss_r: 63.81107 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.73801     |     1.53600     |    68.77998
# ----------------------------------------------------------------------
#
#
# Epoch: 43/510[========>..........................................................................................]--02:00:01-- - loss_d: 2.75728 -  - loss_g: 1.40367 -  - loss_r: 63.88225 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.75809     |     1.49517     |    60.40071
# ----------------------------------------------------------------------
#
#
# Epoch: 44/510[========>..........................................................................................]--02:02:55-- - loss_d: 2.75728 -  - loss_g: 1.40605 -  - loss_r: 63.82159 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.84288     |     1.32630     |    67.90118
# ----------------------------------------------------------------------
#
#
# Epoch: 45/510[========>..........................................................................................]--02:02:05-- - loss_d: 2.75771 -  - loss_g: 1.41011 -  - loss_r: 63.91946 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.73189     |     1.36456     |    65.20673
# ----------------------------------------------------------------------
#
#
# Epoch: 46/510[=========>.........................................................................................]--02:02:29-- - loss_d: 2.74869 -  - loss_g: 1.40426 -  - loss_r: 63.89038 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.80398     |     1.31215     |    61.04342
# ----------------------------------------------------------------------
#
#
# Epoch: 47/510[=========>.........................................................................................]--02:00:04-- - loss_d: 2.75812 -  - loss_g: 1.40117 -  - loss_r: 63.89919 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.75770     |     1.30840     |    62.22605
# ----------------------------------------------------------------------
#
#
# Epoch: 48/510[=========>.........................................................................................]--02:00:47-- - loss_d: 2.76149 -  - loss_g: 1.40287 -  - loss_r: 63.74687 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.86092     |     1.33746     |    62.30799
# ----------------------------------------------------------------------
#
#
# Epoch: 49/510[=========>.........................................................................................]--02:01:36-- - loss_d: 2.75758 -  - loss_g: 1.40226 -  - loss_r: 64.33909 -
#
# Iteration:  0(500 in total)	 Time left:00:00:16
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.81724     |     1.41734     |    66.59110
# ----------------------------------------------------------------------
#
#
# Epoch: 50/510[=========>.........................................................................................]--02:01:03-- - loss_d: 2.75304 -  - loss_g: 1.41175 -  - loss_r: 63.69448 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.50503     |     1.30271     |    60.72820
# ----------------------------------------------------------------------
#
#
# Epoch: 51/510[=========>.........................................................................................]--02:01:55-- - loss_d: 2.74662 -  - loss_g: 1.41251 -  - loss_r: 64.00495 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.90697     |     1.50271     |    63.18425
# ----------------------------------------------------------------------
#
#
# Epoch: 52/510[==========>........................................................................................]--01:59:37-- - loss_d: 2.75023 -  - loss_g: 1.40677 -  - loss_r: 63.73003 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.80584     |     1.25832     |    66.57021
# ----------------------------------------------------------------------
#
#
# Epoch: 53/510[==========>........................................................................................]--01:57:33-- - loss_d: 2.75488 -  - loss_g: 1.41669 -  - loss_r: 63.89519 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.61730     |     1.51260     |    67.75707
# ----------------------------------------------------------------------
#
#
# Epoch: 54/510[==========>........................................................................................]--01:58:06-- - loss_d: 2.75024 -  - loss_g: 1.40864 -  - loss_r: 63.43462 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.81521     |     1.41548     |    66.65247
# ----------------------------------------------------------------------
#
#
# Epoch: 55/510[==========>........................................................................................]--01:58:38-- - loss_d: 2.76649 -  - loss_g: 1.40294 -  - loss_r: 63.88601 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.74533     |     1.34226     |    65.06165
# ----------------------------------------------------------------------
#
#
# Epoch: 56/510[==========>........................................................................................]--01:57:20-- - loss_d: 2.75640 -  - loss_g: 1.39634 -  - loss_r: 63.58212 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.94020     |     1.53131     |    67.54233
# ----------------------------------------------------------------------
#
#
# Epoch: 57/510[===========>.......................................................................................]--01:59:44-- - loss_d: 2.74990 -  - loss_g: 1.41167 -  - loss_r: 63.87191 -
#
# Iteration:  0(500 in total)	 Time left:00:00:31
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.70023     |     1.41686     |    65.05688
# ----------------------------------------------------------------------
#
#
# Epoch: 58/510[===========>.......................................................................................]--02:00:01-- - loss_d: 2.75231 -  - loss_g: 1.40337 -  - loss_r: 63.73002 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.75916     |     1.43106     |    62.87473
# ----------------------------------------------------------------------
#
#
# Epoch: 59/510[===========>.......................................................................................]--01:56:21-- - loss_d: 2.74446 -  - loss_g: 1.41383 -  - loss_r: 63.80137 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.69047     |     1.53083     |    63.41833
# ----------------------------------------------------------------------
#
#
# Epoch: 60/510[===========>.......................................................................................]--01:56:21-- - loss_d: 2.75182 -  - loss_g: 1.41210 -  - loss_r: 63.70931 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.65469     |     1.61865     |    66.59892
# ----------------------------------------------------------------------
#
#
# Epoch: 61/510[===========>.......................................................................................]--01:59:37-- - loss_d: 2.75673 -  - loss_g: 1.40611 -  - loss_r: 63.88004 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.61648     |     1.38159     |    59.19942
# ----------------------------------------------------------------------
#
#
# Epoch: 62/510[============>......................................................................................]--01:54:45-- - loss_d: 2.76665 -  - loss_g: 1.40523 -  - loss_r: 63.57999 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.59237     |     1.43139     |    63.66827
# ----------------------------------------------------------------------
#
#
# Epoch: 63/510[============>......................................................................................]--01:53:47-- - loss_d: 2.75899 -  - loss_g: 1.39891 -  - loss_r: 63.69763 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.80651     |     1.34437     |    65.46601
# ----------------------------------------------------------------------
#
#
# Epoch: 64/510[============>......................................................................................]--01:57:35-- - loss_d: 2.75181 -  - loss_g: 1.40115 -  - loss_r: 63.56775 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.71258     |     1.52384     |    61.90266
# ----------------------------------------------------------------------
#
#
# Epoch: 65/510[============>......................................................................................]--01:56:51-- - loss_d: 2.75420 -  - loss_g: 1.40919 -  - loss_r: 63.49678 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.98774     |     1.38757     |    57.39547
# ----------------------------------------------------------------------
#
#
# Epoch: 66/510[============>......................................................................................]--01:54:58-- - loss_d: 2.74869 -  - loss_g: 1.41789 -  - loss_r: 63.49851 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.64901     |     1.39219     |    68.79027
# ----------------------------------------------------------------------
#
#
# Epoch: 67/510[=============>.....................................................................................]--01:55:30-- - loss_d: 2.75411 -  - loss_g: 1.41088 -  - loss_r: 63.71595 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.76379     |     1.61548     |    70.43579
# ----------------------------------------------------------------------
#
#
# Epoch: 68/510[=============>.....................................................................................]--01:54:08-- - loss_d: 2.75226 -  - loss_g: 1.40740 -  - loss_r: 63.65541 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.79099     |     1.47371     |    66.23897
# ----------------------------------------------------------------------
#
#
# Epoch: 69/510[=============>.....................................................................................]--01:54:08-- - loss_d: 2.75093 -  - loss_g: 1.40653 -  - loss_r: 63.73037 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.72344     |     1.27731     |    63.01392
# ----------------------------------------------------------------------
#
#
# Epoch: 70/510[=============>.....................................................................................]--01:54:33-- - loss_d: 2.74873 -  - loss_g: 1.40962 -  - loss_r: 63.52021 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.73788     |     1.27060     |    59.09510
# ----------------------------------------------------------------------
#
#
# Epoch: 71/510[=============>.....................................................................................]--01:53:51-- - loss_d: 2.75839 -  - loss_g: 1.41125 -  - loss_r: 63.44758 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.76732     |     1.39592     |    59.52496
# ----------------------------------------------------------------------
#
#
# Epoch: 72/510[==============>....................................................................................]--01:54:37-- - loss_d: 2.74291 -  - loss_g: 1.40806 -  - loss_r: 63.67752 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.81525     |     1.44063     |    61.88607
# ----------------------------------------------------------------------
#
#
# Epoch: 73/510[==============>....................................................................................]--01:53:46-- - loss_d: 2.75671 -  - loss_g: 1.42293 -  - loss_r: 63.26979 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.78365     |     1.50029     |    60.83172
# ----------------------------------------------------------------------
#
#
# Epoch: 74/510[==============>....................................................................................]--01:52:16-- - loss_d: 2.75391 -  - loss_g: 1.41804 -  - loss_r: 63.48055 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.61548     |     1.28959     |    62.08356
# ----------------------------------------------------------------------
#
#
# Epoch: 75/510[==============>....................................................................................]--01:52:37-- - loss_d: 2.74657 -  - loss_g: 1.41245 -  - loss_r: 63.63793 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.75905     |     1.48117     |    58.57671
# ----------------------------------------------------------------------
#
#
# Epoch: 76/510[==============>....................................................................................]--01:53:48-- - loss_d: 2.74417 -  - loss_g: 1.40510 -  - loss_r: 63.35363 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     3.03937     |     1.40356     |    68.32610
# ----------------------------------------------------------------------
#
#
# Epoch: 77/510[===============>...................................................................................]--01:51:43-- - loss_d: 2.76041 -  - loss_g: 1.42437 -  - loss_r: 63.85323 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     3.08139     |     1.52165     |    61.15891
# ----------------------------------------------------------------------
#
#
# Epoch: 78/510[===============>...................................................................................]--01:49:53-- - loss_d: 2.75306 -  - loss_g: 1.42117 -  - loss_r: 63.22188 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.66498     |     1.39064     |    58.49168
# ----------------------------------------------------------------------
#
#
# Epoch: 79/510[===============>...................................................................................]--01:51:57-- - loss_d: 2.75429 -  - loss_g: 1.40998 -  - loss_r: 63.18962 -
#
# Iteration:  0(500 in total)	 Time left:00:00:31
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.55184     |     1.35092     |    67.80096
# ----------------------------------------------------------------------
#
#
# Epoch: 80/510[===============>...................................................................................]--01:53:05-- - loss_d: 2.74243 -  - loss_g: 1.41131 -  - loss_r: 63.33221 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.68573     |     1.32419     |    67.74007
# ----------------------------------------------------------------------
#
#
# Epoch: 81/510[===============>...................................................................................]--01:51:58-- - loss_d: 2.75048 -  - loss_g: 1.39812 -  - loss_r: 63.26609 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.62558     |     1.26468     |    63.79178
# ----------------------------------------------------------------------
#
#
# Epoch: 82/510[================>..................................................................................]--01:52:24-- - loss_d: 2.75337 -  - loss_g: 1.41566 -  - loss_r: 63.38940 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.71140     |     1.56353     |    62.27040
# ----------------------------------------------------------------------
#
#
# Epoch: 83/510[================>..................................................................................]--01:51:04-- - loss_d: 2.75473 -  - loss_g: 1.42305 -  - loss_r: 63.20263 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.78406     |     1.36838     |    62.48173
# ----------------------------------------------------------------------
#
#
# Epoch: 84/510[================>..................................................................................]--01:51:14-- - loss_d: 2.74925 -  - loss_g: 1.41558 -  - loss_r: 63.25332 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.79211     |     1.40747     |    70.73640
# ----------------------------------------------------------------------
#
#
# Epoch: 85/510[================>..................................................................................]--01:51:43-- - loss_d: 2.74468 -  - loss_g: 1.41686 -  - loss_r: 63.15102 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.59815     |     1.44830     |    64.38452
# ----------------------------------------------------------------------
#
#
# Epoch: 86/510[================>..................................................................................]--01:49:09-- - loss_d: 2.75638 -  - loss_g: 1.41709 -  - loss_r: 63.35286 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.52444     |     1.51388     |    65.95704
# ----------------------------------------------------------------------
#
#
# Epoch: 87/510[=================>.................................................................................]--01:52:26-- - loss_d: 2.74415 -  - loss_g: 1.40870 -  - loss_r: 63.31708 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.75729     |     1.37124     |    62.70145
# ----------------------------------------------------------------------
#
#
# Epoch: 88/510[=================>.................................................................................]--01:51:40-- - loss_d: 2.75107 -  - loss_g: 1.40882 -  - loss_r: 63.44391 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.56223     |     1.43538     |    65.09307
# ----------------------------------------------------------------------
#
#
# Epoch: 89/510[=================>.................................................................................]--01:49:56-- - loss_d: 2.74623 -  - loss_g: 1.41429 -  - loss_r: 63.11851 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.76950     |     1.39989     |    58.24027
# ----------------------------------------------------------------------
#
#
# Epoch: 90/510[=================>.................................................................................]--01:51:36-- - loss_d: 2.76100 -  - loss_g: 1.40927 -  - loss_r: 63.27151 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     3.00920     |     1.25639     |    56.38756
# ----------------------------------------------------------------------
#
#
# Epoch: 91/510[=================>.................................................................................]--01:49:38-- - loss_d: 2.75242 -  - loss_g: 1.40271 -  - loss_r: 63.49275 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.78460     |     1.25851     |    63.25221
# ----------------------------------------------------------------------
#
#
# Epoch: 92/510[==================>................................................................................]--01:48:23-- - loss_d: 2.76441 -  - loss_g: 1.41027 -  - loss_r: 63.07101 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.85121     |     1.54282     |    55.41727
# ----------------------------------------------------------------------
#
#
# Epoch: 93/510[==================>................................................................................]--01:45:50-- - loss_d: 2.76629 -  - loss_g: 1.41795 -  - loss_r: 63.42543 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.92169     |     1.23602     |    55.88701
# ----------------------------------------------------------------------
#
#
# Epoch: 94/510[==================>................................................................................]--01:51:19-- - loss_d: 2.74576 -  - loss_g: 1.40941 -  - loss_r: 63.23482 -
#
# Iteration:  0(500 in total)	 Time left:00:00:23
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.81776     |     1.45560     |    71.83447
# ----------------------------------------------------------------------
#
#
# Epoch: 95/510[==================>................................................................................]--01:49:10-- - loss_d: 2.74723 -  - loss_g: 1.41043 -  - loss_r: 63.22590 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# ----------------------------------------------------------------------
#  cluster_head   |  discriminator  |    generator    | reconstruction
# ----------------------------------------------------------------------
#   -1923.75000   |     2.65524     |     1.52137     |    65.41867
# ----------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f4c655d17e7e> in <module>()
#       1 if __name__ == '__main__':
#       2     tf.reset_default_graph()
# ----> 3     main(run_load_from_file=False)
#
# <ipython-input-2-34a97f2eeae0> in main(run_load_from_file)
#      89                     h.x: images_u,
#      90                     h.z: z_true_u,
# ---> 91                     h.lr: learning_rate
#      92                 })
#      93
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
