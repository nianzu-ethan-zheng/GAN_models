# %%
# Standard library
import tensorflow as tf
import numpy as np
import _pickle as pickle
import os, sys
# Packages
from model import build_graph, config

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
from aae import Operation
import dataset
from process import Process
import sampler
import plot as plt

# %%
def main(run_load_from_file=False):
    # load MNIST images
    images, labels = dataset.load_test_images()

    # config
    opt = Operation()
    opt.check_dir(config.ckpt_dir, is_restart=False)
    opt.check_dir(config.log_dir, is_restart=True)

    max_epoch = 2010
    num_trains_per_epoch = 500
    batch_size_u = 100

    # training
    with tf.device(config.device):
        h = build_graph()

    sess_config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
    sess_config.gpu_options.allow_growth = True
    sess_config.gpu_options.per_process_gpu_memory_fraction = 0.9
    saver = tf.train.Saver(max_to_keep=2)

    with tf.Session(config=sess_config) as sess:
        '''
         Load from checkpoint or start a new session

        '''
        if run_load_from_file:
            saver.restore(sess, tf.train.latest_checkpoint(config.ckpt_dir))
            training_epoch_loss, _ = pickle.load(open(config.ckpt_dir + '/pickle.pkl', 'rb'))
        else:
            sess.run(tf.global_variables_initializer())
            training_epoch_loss = []

        # Recording loss per epoch
        process = Process()
        for epoch in range(max_epoch):
            process.start_epoch(epoch, max_epoch)

            '''
            Learning rate generator

            '''
            learning_rate = 0.0001

            # Recording loss per iteration
            sum_loss_reconstruction = 0
            sum_loss_discrminator = 0
            sum_loss_generator = 0
            process_iteration = Process()
            for i in range(num_trains_per_epoch):
                process_iteration.start_epoch(i, num_trains_per_epoch)
                # Inputs
                '''
                _l -> labeled
                _u -> unlabeled

                '''
                images_u = dataset.sample_unlabeled_data(images, batch_size_u)
                num_types_of_label = config.num_types_of_label

                # z_true_u = sampler.swiss_roll(batch_size_u, config.ndim_z, num_types_of_label)
                z_true_u = sampler.gaussian_mixture(batch_size_u, config.ndim_z, num_types_of_label)
                # z_true_u = sampler.gaussian(batch_size_u, config.ndim_z, var=1)
                # z_true_u = sampler.uniform(batch_size_u, config.ndim_z,minv=-1, maxv=1)
                # z_true_u = sampler.uniform_desk(batch_size_u, config.ndim_z, radius=1)

                # reconstruction_phase
                _, loss_reconstruction = sess.run([h.opt_r, h.loss_r], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                # adversarial phase for discriminator
                _, loss_discriminator_u = sess.run([h.opt_d, h.loss_d], feed_dict={
                    h.x: images_u,
                    h.z: z_true_u,
                    h.lr: learning_rate
                })

                # adversarial phase for generator
                _, loss_generator_u = sess.run([h.opt_e, h.loss_e], feed_dict={
                    h.x: images_u,
                    h.lr: learning_rate
                })

                sum_loss_reconstruction += loss_reconstruction
                sum_loss_discrminator += loss_discriminator_u
                sum_loss_generator += loss_generator_u

                if i % 1000 == 0:
                    process_iteration.show_table_2d(i, num_trains_per_epoch, {
                        'reconstruction': sum_loss_reconstruction / (i + 1),
                        'discriminator': sum_loss_discrminator / (i + 1),
                        'generator': sum_loss_generator / (i + 1),
                    })

            average_loss_per_epoch = [
                sum_loss_reconstruction / num_trains_per_epoch,
                sum_loss_discrminator / num_trains_per_epoch,
                sum_loss_generator / num_trains_per_epoch,
            ]
            training_epoch_loss.append(average_loss_per_epoch)
            training_loss_name = [
                'reconstruction',
                'discriminator',
                'generator'
            ]

            if epoch % 1 == 0:
                process.show_bar(epoch, max_epoch, {
                    'loss_r': average_loss_per_epoch[0],
                    'loss_d': average_loss_per_epoch[1],
                    'loss_g': average_loss_per_epoch[2]
                })

                plt.scatter_labeled_z(sess.run(h.z_r, feed_dict={h.x: images[:1000]}), [int(var) for var in labels[:1000]],
                                      dir=config.log_dir,
                                      filename='z_representation-{}'.format(epoch))

            if epoch % 10 == 0:
                saver.save(sess, os.path.join(config.ckpt_dir, 'model_ckptpoint'), global_step=epoch)
                pickle.dump((training_epoch_loss, training_loss_name), open(config.ckpt_dir + '/pickle.pkl', 'wb'))

# %%
if __name__ == '__main__':
    main(run_load_from_file=False)
# Out:
# Iteration:  0(500 in total)	 Time left:00:01:56
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.38627     |     0.69273     |    362.66174
# -----------------------------------------------------
#
#
# Epoch:   0/2010[...................................................................................................]--04:28:44-- - loss_d: 1.37281 -  - loss_g: 0.74756 -  - loss_r: 123.81360 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.42806     |     0.65585     |    100.85782
# -----------------------------------------------------
#
#
# Epoch:   1/2010[...................................................................................................]--04:16:57-- - loss_d: 1.39120 -  - loss_g: 0.69226 -  - loss_r: 98.72575 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.38490     |     0.68392     |    92.40023
# -----------------------------------------------------
#
#
# Epoch:   2/2010[...................................................................................................]--04:15:45-- - loss_d: 1.39030 -  - loss_g: 0.68682 -  - loss_r: 96.27983 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.46473     |     0.70029     |    100.49797
# -----------------------------------------------------
#
#
# Epoch:   3/2010[...................................................................................................]--04:13:41-- - loss_d: 1.38360 -  - loss_g: 0.69671 -  - loss_r: 92.97222 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.36347     |     0.69702     |    90.32539
# -----------------------------------------------------
#
#
# Epoch:   4/2010[...................................................................................................]--04:19:48-- - loss_d: 1.38465 -  - loss_g: 0.69161 -  - loss_r: 86.27643 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.38380     |     0.69954     |    85.53673
# -----------------------------------------------------
#
#
# Epoch:   5/2010[...................................................................................................]--04:24:10-- - loss_d: 1.38440 -  - loss_g: 0.69530 -  - loss_r: 83.75740 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.37199     |     0.67908     |    82.22176
# -----------------------------------------------------
#
#
# Epoch:   6/2010[...................................................................................................]--04:24:59-- - loss_d: 1.38555 -  - loss_g: 0.69424 -  - loss_r: 80.70176 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.39244     |     0.68106     |    80.11514
# -----------------------------------------------------
#
#
# Epoch:   7/2010[...................................................................................................]--04:26:03-- - loss_d: 1.38542 -  - loss_g: 0.69604 -  - loss_r: 78.85554 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.37381     |     0.71340     |    81.70401
# -----------------------------------------------------
#
#
# Epoch:   8/2010[...................................................................................................]--04:27:29-- - loss_d: 1.38451 -  - loss_g: 0.70060 -  - loss_r: 77.35512 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.36854     |     0.70076     |    78.03756
# -----------------------------------------------------
#
#
# Epoch:   9/2010[...................................................................................................]--04:31:00-- - loss_d: 1.38508 -  - loss_g: 0.69800 -  - loss_r: 76.43140 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.37866     |     0.70425     |    67.87445
# -----------------------------------------------------
#
#
# Epoch:  10/2010[...................................................................................................]--04:30:49-- - loss_d: 1.38133 -  - loss_g: 0.70239 -  - loss_r: 74.65943 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.38934     |     0.67020     |    77.13354
# -----------------------------------------------------
#
#
# Epoch:  11/2010[...................................................................................................]--04:29:33-- - loss_d: 1.37678 -  - loss_g: 0.70231 -  - loss_r: 74.05067 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.36604     |     0.67958     |    69.10204
# -----------------------------------------------------
#
#
# Epoch:  12/2010[...................................................................................................]--04:24:03-- - loss_d: 1.37125 -  - loss_g: 0.70269 -  - loss_r: 73.00316 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.36292     |     0.68988     |    73.30795
# -----------------------------------------------------
#
#
# Epoch:  13/2010[...................................................................................................]--04:25:47-- - loss_d: 1.36112 -  - loss_g: 0.70758 -  - loss_r: 72.01659 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.35924     |     0.70359     |    66.47500
# -----------------------------------------------------
#
#
# Epoch:  14/2010[...................................................................................................]--04:24:17-- - loss_d: 1.35274 -  - loss_g: 0.71673 -  - loss_r: 71.21545 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.34730     |     0.74023     |    72.69862
# -----------------------------------------------------
#
#
# Epoch:  15/2010[...................................................................................................]--04:27:21-- - loss_d: 1.34344 -  - loss_g: 0.72388 -  - loss_r: 70.42892 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.31847     |     0.71938     |    70.58331
# -----------------------------------------------------
#
#
# Epoch:  16/2010[...................................................................................................]--04:27:09-- - loss_d: 1.33201 -  - loss_g: 0.73520 -  - loss_r: 69.86248 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.32578     |     0.73403     |    70.15193
# -----------------------------------------------------
#
#
# Epoch:  17/2010[...................................................................................................]--04:26:54-- - loss_d: 1.32186 -  - loss_g: 0.74285 -  - loss_r: 68.96641 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.32896     |     0.78164     |    65.98874
# -----------------------------------------------------
#
#
# Epoch:  18/2010[...................................................................................................]--04:28:44-- - loss_d: 1.30991 -  - loss_g: 0.75630 -  - loss_r: 68.52600 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.26949     |     0.77629     |    68.46590
# -----------------------------------------------------
#
#
# Epoch:  19/2010[...................................................................................................]--04:26:00-- - loss_d: 1.29508 -  - loss_g: 0.77098 -  - loss_r: 68.20251 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.28035     |     0.76250     |    62.14233
# -----------------------------------------------------
#
#
# Epoch:  20/2010[...................................................................................................]--04:21:39-- - loss_d: 1.28425 -  - loss_g: 0.78667 -  - loss_r: 67.80001 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.29010     |     0.79972     |    71.51985
# -----------------------------------------------------
#
#
# Epoch:  21/2010[=>.................................................................................................]--04:19:50-- - loss_d: 1.27323 -  - loss_g: 0.79931 -  - loss_r: 67.35570 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.31591     |     0.75748     |    68.82907
# -----------------------------------------------------
#
#
# Epoch:  22/2010[=>.................................................................................................]--04:22:02-- - loss_d: 1.26187 -  - loss_g: 0.81662 -  - loss_r: 66.98103 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.23936     |     0.87937     |    62.17719
# -----------------------------------------------------
#
#
# Epoch:  23/2010[=>.................................................................................................]--04:24:25-- - loss_d: 1.25242 -  - loss_g: 0.83213 -  - loss_r: 67.21204 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.23381     |     0.80529     |    71.06201
# -----------------------------------------------------
#
#
# Epoch:  24/2010[=>.................................................................................................]--04:27:35-- - loss_d: 1.24173 -  - loss_g: 0.85083 -  - loss_r: 66.86539 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.26819     |     0.87943     |    67.51050
# -----------------------------------------------------
#
#
# Epoch:  25/2010[=>.................................................................................................]--04:27:25-- - loss_d: 1.22989 -  - loss_g: 0.86895 -  - loss_r: 66.49202 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.18863     |     0.90473     |    63.93699
# -----------------------------------------------------
#
#
# Epoch:  26/2010[=>.................................................................................................]--04:26:47-- - loss_d: 1.21479 -  - loss_g: 0.89380 -  - loss_r: 66.60329 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.22747     |     0.89565     |    69.19940
# -----------------------------------------------------
#
#
# Epoch:  27/2010[=>.................................................................................................]--04:27:31-- - loss_d: 1.20191 -  - loss_g: 0.91348 -  - loss_r: 66.80735 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.15305     |     1.00369     |    66.46403
# -----------------------------------------------------
#
#
# Epoch:  28/2010[=>.................................................................................................]--04:25:55-- - loss_d: 1.20567 -  - loss_g: 0.92352 -  - loss_r: 66.35310 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.23764     |     0.85712     |    68.40289
# -----------------------------------------------------
#
#
# Epoch:  29/2010[=>.................................................................................................]--04:26:09-- - loss_d: 1.19106 -  - loss_g: 0.94111 -  - loss_r: 66.57886 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.16001     |     1.00197     |    69.18966
# -----------------------------------------------------
#
#
# Epoch:  30/2010[=>.................................................................................................]--04:21:05-- - loss_d: 1.19624 -  - loss_g: 0.95068 -  - loss_r: 66.66930 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.20450     |     0.99304     |    66.48812
# -----------------------------------------------------
#
#
# Epoch:  31/2010[=>.................................................................................................]--04:18:49-- - loss_d: 1.18370 -  - loss_g: 0.97459 -  - loss_r: 66.22020 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.20698     |     0.94813     |    65.26936
# -----------------------------------------------------
#
#
# Epoch:  32/2010[=>.................................................................................................]--04:18:05-- - loss_d: 1.17560 -  - loss_g: 0.99297 -  - loss_r: 66.75931 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.17161     |     0.95757     |    64.88628
# -----------------------------------------------------
#
#
# Epoch:  33/2010[=>.................................................................................................]--04:20:37-- - loss_d: 1.17303 -  - loss_g: 1.00362 -  - loss_r: 66.15653 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.18586     |     0.96445     |    67.08345
# -----------------------------------------------------
#
#
# Epoch:  34/2010[=>.................................................................................................]--04:26:10-- - loss_d: 1.16135 -  - loss_g: 1.02681 -  - loss_r: 66.39622 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.13424     |     1.11684     |    64.73994
# -----------------------------------------------------
#
#
# Epoch:  35/2010[=>.................................................................................................]--04:24:08-- - loss_d: 1.15911 -  - loss_g: 1.04395 -  - loss_r: 66.61706 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.15946     |     0.94845     |    65.71487
# -----------------------------------------------------
#
#
# Epoch:  36/2010[=>.................................................................................................]--04:16:30-- - loss_d: 1.14842 -  - loss_g: 1.06490 -  - loss_r: 66.55397 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.11840     |     1.06290     |    70.52231
# -----------------------------------------------------
#
#
# Epoch:  37/2010[=>.................................................................................................]--04:18:29-- - loss_d: 1.13236 -  - loss_g: 1.09455 -  - loss_r: 66.99113 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.08515     |     1.22046     |    62.23942
# -----------------------------------------------------
#
#
# Epoch:  38/2010[=>.................................................................................................]--04:20:01-- - loss_d: 1.12834 -  - loss_g: 1.11376 -  - loss_r: 67.03636 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.09416     |     1.12256     |    69.64540
# -----------------------------------------------------
#
#
# Epoch:  39/2010[=>.................................................................................................]--04:19:09-- - loss_d: 1.04094 -  - loss_g: 1.26836 -  - loss_r: 70.80523 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.76067     |     1.92999     |    81.19920
# -----------------------------------------------------
#
#
# Epoch:  40/2010[=>.................................................................................................]--04:19:17-- - loss_d: 0.79388 -  - loss_g: 1.76678 -  - loss_r: 83.86555 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.94579     |     1.52668     |    83.43409
# -----------------------------------------------------
#
#
# Epoch:  41/2010[==>................................................................................................]--04:19:15-- - loss_d: 0.78031 -  - loss_g: 1.86604 -  - loss_r: 82.55139 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.85117     |     1.71024     |    80.46828
# -----------------------------------------------------
#
#
# Epoch:  42/2010[==>................................................................................................]--04:23:33-- - loss_d: 0.77044 -  - loss_g: 1.90112 -  - loss_r: 81.25287 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.70847     |     1.99074     |    81.90582
# -----------------------------------------------------
#
#
# Epoch:  43/2010[==>................................................................................................]--04:16:35-- - loss_d: 0.75908 -  - loss_g: 1.98778 -  - loss_r: 79.68873 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.83985     |     1.84981     |    79.37863
# -----------------------------------------------------
#
#
# Epoch:  44/2010[==>................................................................................................]--04:18:01-- - loss_d: 0.75206 -  - loss_g: 2.08771 -  - loss_r: 82.53339 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.75901     |     1.87144     |    80.10649
# -----------------------------------------------------
#
#
# Epoch:  45/2010[==>................................................................................................]--04:17:47-- - loss_d: 0.73153 -  - loss_g: 2.15766 -  - loss_r: 80.31704 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.67975     |     2.04993     |    81.05006
# -----------------------------------------------------
#
#
# Epoch:  46/2010[==>................................................................................................]--04:22:16-- - loss_d: 0.72385 -  - loss_g: 2.19602 -  - loss_r: 80.08616 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.73062     |     1.92019     |    85.01913
# -----------------------------------------------------
#
#
# Epoch:  47/2010[==>................................................................................................]--04:14:36-- - loss_d: 0.72493 -  - loss_g: 2.16198 -  - loss_r: 79.56919 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.85988     |     2.10850     |    77.75040
# -----------------------------------------------------
#
#
# Epoch:  48/2010[==>................................................................................................]--04:17:35-- - loss_d: 0.72426 -  - loss_g: 2.12588 -  - loss_r: 79.27976 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.68812     |     1.98734     |    78.21432
# -----------------------------------------------------
#
#
# Epoch:  49/2010[==>................................................................................................]--04:21:07-- - loss_d: 0.71924 -  - loss_g: 2.15422 -  - loss_r: 78.21383 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.80532     |     2.26834     |    77.44872
# -----------------------------------------------------
#
#
# Epoch:  50/2010[==>................................................................................................]--04:23:39-- - loss_d: 0.73656 -  - loss_g: 2.07444 -  - loss_r: 77.83933 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.83895     |     1.98297     |    77.40073
# -----------------------------------------------------
#
#
# Epoch:  51/2010[==>................................................................................................]--04:17:56-- - loss_d: 0.75494 -  - loss_g: 2.02876 -  - loss_r: 76.89740 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.66479     |     2.19696     |    75.95071
# -----------------------------------------------------
#
#
# Epoch:  52/2010[==>................................................................................................]--04:21:08-- - loss_d: 0.75271 -  - loss_g: 2.03931 -  - loss_r: 77.35278 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.76870     |     2.14796     |    77.63412
# -----------------------------------------------------
#
#
# Epoch:  53/2010[==>................................................................................................]--04:21:29-- - loss_d: 0.75043 -  - loss_g: 2.08067 -  - loss_r: 78.51687 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.68662     |     2.07599     |    81.12415
# -----------------------------------------------------
#
#
# Epoch:  54/2010[==>................................................................................................]--04:15:19-- - loss_d: 0.75369 -  - loss_g: 2.11282 -  - loss_r: 78.10475 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.69098     |     2.34042     |    83.68504
# -----------------------------------------------------
#
#
# Epoch:  55/2010[==>................................................................................................]--04:19:04-- - loss_d: 0.75155 -  - loss_g: 2.16105 -  - loss_r: 78.28367 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.73905     |     1.78777     |    79.07063
# -----------------------------------------------------
#
#
# Epoch:  56/2010[==>................................................................................................]--04:19:08-- - loss_d: 0.77398 -  - loss_g: 2.07682 -  - loss_r: 75.82038 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.80658     |     2.02857     |    79.17036
# -----------------------------------------------------
#
#
# Epoch:  57/2010[==>................................................................................................]--04:18:32-- - loss_d: 0.76842 -  - loss_g: 2.04388 -  - loss_r: 75.64349 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.73580     |     2.24677     |    79.26034
# -----------------------------------------------------
#
#
# Epoch:  58/2010[==>................................................................................................]--04:17:08-- - loss_d: 0.77316 -  - loss_g: 2.03097 -  - loss_r: 76.79787 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.75825     |     2.21988     |    83.02248
# -----------------------------------------------------
#
#
# Epoch:  59/2010[==>................................................................................................]--04:13:15-- - loss_d: 0.76197 -  - loss_g: 2.04921 -  - loss_r: 76.19933 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.71949     |     2.17266     |    79.53104
# -----------------------------------------------------
#
#
# Epoch:  60/2010[==>................................................................................................]--04:15:40-- - loss_d: 0.75512 -  - loss_g: 2.03264 -  - loss_r: 77.06980 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.64083     |     2.45063     |    73.86200
# -----------------------------------------------------
#
#
# Epoch:  61/2010[===>...............................................................................................]--04:15:13-- - loss_d: 0.75511 -  - loss_g: 2.07028 -  - loss_r: 81.42585 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.64891     |     2.21470     |    89.64371
# -----------------------------------------------------
#
#
# Epoch:  62/2010[===>...............................................................................................]--04:22:31-- - loss_d: 0.76060 -  - loss_g: 2.19252 -  - loss_r: 81.87805 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.86719     |     1.81972     |    80.61958
# -----------------------------------------------------
#
#
# Epoch:  63/2010[===>...............................................................................................]--04:16:24-- - loss_d: 0.74750 -  - loss_g: 2.20383 -  - loss_r: 79.78080 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.65335     |     2.17477     |    89.00999
# -----------------------------------------------------
#
#
# Epoch:  64/2010[===>...............................................................................................]--04:16:05-- - loss_d: 0.76592 -  - loss_g: 2.18645 -  - loss_r: 78.42187 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.80380     |     2.26902     |    75.28108
# -----------------------------------------------------
#
#
# Epoch:  65/2010[===>...............................................................................................]--04:14:45-- - loss_d: 0.76866 -  - loss_g: 2.14936 -  - loss_r: 77.34779 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.79520     |     2.04242     |    80.30858
# -----------------------------------------------------
#
#
# Epoch:  66/2010[===>...............................................................................................]--04:15:08-- - loss_d: 0.75920 -  - loss_g: 2.13656 -  - loss_r: 78.02420 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.84581     |     2.30799     |    85.41341
# -----------------------------------------------------
#
#
# Epoch:  67/2010[===>...............................................................................................]--04:19:19-- - loss_d: 0.80288 -  - loss_g: 2.09294 -  - loss_r: 80.88245 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.93737     |     2.12770     |    75.72357
# -----------------------------------------------------
#
#
# Epoch:  68/2010[===>...............................................................................................]--04:22:41-- - loss_d: 0.85969 -  - loss_g: 2.06035 -  - loss_r: 88.14227 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.93621     |     2.07275     |    92.91028
# -----------------------------------------------------
#
#
# Epoch:  69/2010[===>...............................................................................................]--04:14:57-- - loss_d: 0.85212 -  - loss_g: 1.87603 -  - loss_r: 88.77809 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.81437     |     1.67091     |    85.56081
# -----------------------------------------------------
#
#
# Epoch:  70/2010[===>...............................................................................................]--04:21:45-- - loss_d: 0.81036 -  - loss_g: 1.82848 -  - loss_r: 91.79835 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.74458     |     2.00786     |    90.80254
# -----------------------------------------------------
#
#
# Epoch:  71/2010[===>...............................................................................................]--04:16:35-- - loss_d: 0.78101 -  - loss_g: 1.88252 -  - loss_r: 93.88528 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.64282     |     1.85598     |    93.23129
# -----------------------------------------------------
#
#
# Epoch:  72/2010[===>...............................................................................................]--04:17:27-- - loss_d: 0.76163 -  - loss_g: 1.91607 -  - loss_r: 95.11769 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.79731     |     2.01528     |    100.83662
# -----------------------------------------------------
#
#
# Epoch:  73/2010[===>...............................................................................................]--04:13:04-- - loss_d: 0.72941 -  - loss_g: 1.93910 -  - loss_r: 96.01946 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.60279     |     1.85192     |    103.49548
# -----------------------------------------------------
#
#
# Epoch:  74/2010[===>...............................................................................................]--04:13:23-- - loss_d: 0.74142 -  - loss_g: 1.94276 -  - loss_r: 97.33355 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.77069     |     1.87007     |    94.49411
# -----------------------------------------------------
#
#
# Epoch:  75/2010[===>...............................................................................................]--04:14:47-- - loss_d: 0.69042 -  - loss_g: 2.15623 -  - loss_r: 102.06662 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.79765     |     2.55261     |    101.02043
# -----------------------------------------------------
#
#
# Epoch:  76/2010[===>...............................................................................................]--04:16:08-- - loss_d: 0.68559 -  - loss_g: 2.09284 -  - loss_r: 101.91249 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.70104     |     2.14375     |    108.76089
# -----------------------------------------------------
#
#
# Epoch:  77/2010[===>...............................................................................................]--04:16:00-- - loss_d: 0.63118 -  - loss_g: 2.25441 -  - loss_r: 104.62546 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.63733     |     2.63283     |    104.22913
# -----------------------------------------------------
#
#
# Epoch:  78/2010[===>...............................................................................................]--04:25:59-- - loss_d: 0.59577 -  - loss_g: 2.37897 -  - loss_r: 105.78136 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.47225     |     2.32694     |    106.62754
# -----------------------------------------------------
#
#
# Epoch:  79/2010[===>...............................................................................................]--04:12:59-- - loss_d: 0.59371 -  - loss_g: 2.40217 -  - loss_r: 105.75167 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.47745     |     2.33778     |    105.57351
# -----------------------------------------------------
#
#
# Epoch:  80/2010[===>...............................................................................................]--04:16:36-- - loss_d: 0.59309 -  - loss_g: 2.40386 -  - loss_r: 105.83242 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.63739     |     2.29350     |    108.15379
# -----------------------------------------------------
#
#
# Epoch:  81/2010[====>..............................................................................................]--04:20:56-- - loss_d: 0.59511 -  - loss_g: 2.41215 -  - loss_r: 105.77208 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.57420     |     2.39726     |    106.70735
# -----------------------------------------------------
#
#
# Epoch:  82/2010[====>..............................................................................................]--04:16:07-- - loss_d: 0.59364 -  - loss_g: 2.41689 -  - loss_r: 105.79318 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.71594     |     2.50602     |    104.82302
# -----------------------------------------------------
#
#
# Epoch:  83/2010[====>..............................................................................................]--04:12:43-- - loss_d: 0.58382 -  - loss_g: 2.43914 -  - loss_r: 105.55954 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.59452     |     2.69696     |    105.94005
# -----------------------------------------------------
#
#
# Epoch:  84/2010[====>..............................................................................................]--04:12:54-- - loss_d: 0.58114 -  - loss_g: 2.46075 -  - loss_r: 105.55102 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.57837     |     2.55816     |    104.35485
# -----------------------------------------------------
#
#
# Epoch:  85/2010[====>..............................................................................................]--04:11:42-- - loss_d: 0.58521 -  - loss_g: 2.45541 -  - loss_r: 105.84459 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.47779     |     2.41587     |    111.72080
# -----------------------------------------------------
#
#
# Epoch:  86/2010[====>..............................................................................................]--04:23:49-- - loss_d: 0.57699 -  - loss_g: 2.48703 -  - loss_r: 105.68182 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.57224     |     2.34469     |    107.36354
# -----------------------------------------------------
#
#
# Epoch:  87/2010[====>..............................................................................................]--04:13:37-- - loss_d: 0.58257 -  - loss_g: 2.47681 -  - loss_r: 105.62011 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.46235     |     2.53890     |    101.73734
# -----------------------------------------------------
#
#
# Epoch:  88/2010[====>..............................................................................................]--04:15:28-- - loss_d: 0.57977 -  - loss_g: 2.49162 -  - loss_r: 105.59682 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.53756     |     2.63000     |    105.48199
# -----------------------------------------------------
#
#
# Epoch:  89/2010[====>..............................................................................................]--04:19:00-- - loss_d: 0.57712 -  - loss_g: 2.50776 -  - loss_r: 105.82024 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.51109     |     2.34528     |    103.09119
# -----------------------------------------------------
#
#
# Epoch:  90/2010[====>..............................................................................................]--04:12:03-- - loss_d: 0.57319 -  - loss_g: 2.50498 -  - loss_r: 105.97308 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.64401     |     2.66123     |    105.06556
# -----------------------------------------------------
#
#
# Epoch:  91/2010[====>..............................................................................................]--04:16:44-- - loss_d: 0.56988 -  - loss_g: 2.53857 -  - loss_r: 105.66306 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.60156     |     2.72642     |    102.62399
# -----------------------------------------------------
#
#
# Epoch:  92/2010[====>..............................................................................................]--04:15:25-- - loss_d: 0.56492 -  - loss_g: 2.53640 -  - loss_r: 105.85619 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.58599     |     2.89803     |    107.63597
# -----------------------------------------------------
#
#
# Epoch:  93/2010[====>..............................................................................................]--04:11:16-- - loss_d: 0.55755 -  - loss_g: 2.56919 -  - loss_r: 105.51891 -
#
# ...
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.65451     |     2.67114     |    105.17267
# -----------------------------------------------------
#
#
# Epoch: 105/2010[=====>.............................................................................................]--04:22:14-- - loss_d: 0.52722 -  - loss_g: 2.65727 -  - loss_r: 105.81727 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.54568     |     2.68318     |    105.37489
# -----------------------------------------------------
#
#
# Epoch: 106/2010[=====>.............................................................................................]--04:12:06-- - loss_d: 0.52919 -  - loss_g: 2.64919 -  - loss_r: 105.91581 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.63229     |     2.66726     |    105.52480
# -----------------------------------------------------
#
#
# Epoch: 107/2010[=====>.............................................................................................]--04:08:10-- - loss_d: 0.52406 -  - loss_g: 2.65838 -  - loss_r: 105.74298 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.42341     |     2.83231     |    108.53737
# -----------------------------------------------------
#
#
# Epoch: 108/2010[=====>.............................................................................................]--04:16:06-- - loss_d: 0.52178 -  - loss_g: 2.66178 -  - loss_r: 105.52373 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.49425     |     2.75456     |    105.41719
# -----------------------------------------------------
#
#
# Epoch: 109/2010[=====>.............................................................................................]--04:13:41-- - loss_d: 0.51707 -  - loss_g: 2.66288 -  - loss_r: 105.71042 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.51218     |     2.73466     |    105.62341
# -----------------------------------------------------
#
#
# Epoch: 110/2010[=====>.............................................................................................]--04:06:51-- - loss_d: 0.52024 -  - loss_g: 2.68485 -  - loss_r: 105.57493 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.46728     |     2.74064     |    110.50282
# -----------------------------------------------------
#
#
# Epoch: 111/2010[=====>.............................................................................................]--04:14:22-- - loss_d: 0.52022 -  - loss_g: 2.68267 -  - loss_r: 105.70948 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.46646     |     2.97439     |    107.44918
# -----------------------------------------------------
#
#
# Epoch: 112/2010[=====>.............................................................................................]--04:13:13-- - loss_d: 0.50603 -  - loss_g: 2.69037 -  - loss_r: 105.71336 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.46781     |     2.63699     |    104.39703
# -----------------------------------------------------
#
#
# Epoch: 113/2010[=====>.............................................................................................]--04:18:08-- - loss_d: 0.51037 -  - loss_g: 2.71825 -  - loss_r: 105.72663 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.43151     |     2.67822     |    108.91980
# -----------------------------------------------------
#
#
# Epoch: 114/2010[=====>.............................................................................................]--04:12:00-- - loss_d: 0.50639 -  - loss_g: 2.69475 -  - loss_r: 105.87526 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.52102     |     2.78616     |    107.19088
# -----------------------------------------------------
#
#
# Epoch: 115/2010[=====>.............................................................................................]--04:13:56-- - loss_d: 0.50985 -  - loss_g: 2.69383 -  - loss_r: 105.70200 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.42623     |     2.39570     |    103.90466
# -----------------------------------------------------
#
#
# Epoch: 116/2010[=====>.............................................................................................]--04:15:52-- - loss_d: 0.50784 -  - loss_g: 2.69125 -  - loss_r: 105.63613 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.49400     |     2.97253     |    103.61874
# -----------------------------------------------------
#
#
# Epoch: 117/2010[=====>.............................................................................................]--04:11:14-- - loss_d: 0.50673 -  - loss_g: 2.72080 -  - loss_r: 105.73677 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.55585     |     2.63257     |    105.24822
# -----------------------------------------------------
#
#
# Epoch: 118/2010[=====>.............................................................................................]--04:09:05-- - loss_d: 0.50381 -  - loss_g: 2.71667 -  - loss_r: 105.74674 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.52441     |     2.99305     |    107.61857
# -----------------------------------------------------
#
#
# Epoch: 119/2010[=====>.............................................................................................]--04:14:52-- - loss_d: 0.50295 -  - loss_g: 2.70477 -  - loss_r: 105.97614 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.48216     |     3.02403     |    109.06176
# -----------------------------------------------------
#
#
# Epoch: 120/2010[=====>.............................................................................................]--04:18:17-- - loss_d: 0.50606 -  - loss_g: 2.72159 -  - loss_r: 105.59308 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.59163     |     2.74569     |    103.42796
# -----------------------------------------------------
#
#
# Epoch: 121/2010[======>............................................................................................]--04:11:54-- - loss_d: 0.49647 -  - loss_g: 2.71074 -  - loss_r: 105.66341 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.56352     |     2.67877     |    105.55634
# -----------------------------------------------------
#
#
# Epoch: 122/2010[======>............................................................................................]--04:09:39-- - loss_d: 0.49703 -  - loss_g: 2.72621 -  - loss_r: 105.83219 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.48069     |     2.92329     |    105.30382
# -----------------------------------------------------
#
#
# Epoch: 123/2010[======>............................................................................................]--04:08:28-- - loss_d: 0.49442 -  - loss_g: 2.71774 -  - loss_r: 105.70813 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.40839     |     2.82637     |    104.36609
# -----------------------------------------------------
#
#
# Epoch: 124/2010[======>............................................................................................]--04:12:58-- - loss_d: 0.49792 -  - loss_g: 2.73575 -  - loss_r: 105.75462 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.52126     |     2.75103     |    110.85786
# -----------------------------------------------------
#
#
# Epoch: 125/2010[======>............................................................................................]--04:12:24-- - loss_d: 0.48960 -  - loss_g: 2.74299 -  - loss_r: 105.87796 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.36179     |     2.51973     |    106.52473
# -----------------------------------------------------
#
#
# Epoch: 126/2010[======>............................................................................................]--04:13:09-- - loss_d: 0.48769 -  - loss_g: 2.76644 -  - loss_r: 105.59130 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.44275     |     2.60505     |    108.07471
# -----------------------------------------------------
#
#
# Epoch: 127/2010[======>............................................................................................]--03:59:14-- - loss_d: 0.49519 -  - loss_g: 2.73121 -  - loss_r: 105.64531 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.45588     |     2.65207     |    105.24751
# -----------------------------------------------------
#
#
# Epoch: 128/2010[======>............................................................................................]--04:07:32-- - loss_d: 0.49461 -  - loss_g: 2.75995 -  - loss_r: 105.73094 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.52199     |     2.85688     |    110.56624
# -----------------------------------------------------
#
#
# Epoch: 129/2010[======>............................................................................................]--04:17:31-- - loss_d: 0.48998 -  - loss_g: 2.76004 -  - loss_r: 105.73066 -
#
# Iteration:  0(500 in total)	 Time left:00:00:03
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.53741     |     2.89818     |    107.31702
# -----------------------------------------------------
#
#
# Epoch: 130/2010[======>............................................................................................]--04:14:58-- - loss_d: 0.48450 -  - loss_g: 2.78030 -  - loss_r: 105.61410 -
#
# Iteration:  0(500 in total)	 Time left:00:00:15
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.49889     |     2.62110     |    106.29680
# -----------------------------------------------------
#
#
# Epoch: 131/2010[======>............................................................................................]--04:10:28-- - loss_d: 0.49328 -  - loss_g: 2.74619 -  - loss_r: 105.82224 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.46432     |     2.86138     |    111.64664
# -----------------------------------------------------
#
#
# Epoch: 132/2010[======>............................................................................................]--04:07:36-- - loss_d: 0.48491 -  - loss_g: 2.76078 -  - loss_r: 105.60544 -
#
# Iteration:  0(500 in total)	 Time left:00:00:07
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.49296     |     2.76822     |    103.61949
# -----------------------------------------------------
#
#
# Epoch: 133/2010[======>............................................................................................]--04:09:58-- - loss_d: 0.48387 -  - loss_g: 2.76208 -  - loss_r: 105.43025 -
#
# Iteration:  0(500 in total)	 Time left:00:00:06
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     0.44715     |     2.80119     |    111.08533
# -----------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ae7402f14524> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     main(run_load_from_file=False)
#
# <ipython-input-2-6f080b29305a> in main(run_load_from_file)
#      57
#      58                 '''
# ---> 59                 images_u = dataset.sample_unlabeled_data(images, batch_size_u)
#      60                 num_types_of_label = config.num_types_of_label
#      61
#
# C:\Users\CYD\Desktop\AAE_advanced\dataset.py in sample_unlabeled_data(images, batch_size, ndim_x)
#     144
#     145 def sample_unlabeled_data(images, batch_size, ndim_x=28 ** 2):
# --> 146     image_batch = np.zeros((batch_size, ndim_x), dtype=np.float32)
#     147     indices = np.random.choice(np.arange(len(images), dtype=np.int32), size=batch_size, replace=False)
#     148     for j in range(batch_size):
#
# KeyboardInterrupt:

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
import plot
hist_value, hist_head = plot.load_pickle_to_data('./ckpt_dir')
for loss_name in ['reconstruction']:
    plot.plot_loss_trace(hist_value[loss_name], loss_name, config.ckpt_dir)

plot.plot_adversarial_trace(hist_value['discriminator'], hist_value['generator'], 'z', config.ckpt_dir)
