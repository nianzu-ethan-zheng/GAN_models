# %%
# Standard library
import tensorflow as tf
import _pickle as pickle
import os, sys
# Packages
from model import build_graph, config

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))
from aae import Operation
import dataset
from process import Process
import sampler
import plot as plt

# %%
def main(run_load_from_file=False):
    # load MNIST images
    images, labels = dataset.load_test_images()

    # config
    opt = Operation()
    opt.check_dir(config.ckpt_dir, is_restart=False)
    opt.check_dir(config.log_dir, is_restart=True)

    max_epoch = 510
    num_trains_per_epoch = 500
    batch_size_u = 100

    # training
    with tf.device(config.device):
        h = build_graph()

    sess_config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
    sess_config.gpu_options.allow_growth = True
    sess_config.gpu_options.per_process_gpu_memory_fraction = 0.9
    saver = tf.train.Saver(max_to_keep=2)

    with tf.Session(config=sess_config) as sess:
        '''
         Load from checkpoint or start a new session

        '''
        if run_load_from_file:
            saver.restore(sess, tf.train.latest_checkpoint(config.ckpt_dir))
            training_epoch_loss, _ = pickle.load(open(config.ckpt_dir + '/pickle.pkl', 'rb'))
        else:
            sess.run(tf.global_variables_initializer())
            training_epoch_loss = []

        # Recording loss per epoch
        process = Process()
        for epoch in range(max_epoch):
            process.start_epoch(epoch, max_epoch)

            '''
            Learning rate generator

            '''
            learning_rate = 0.0001

            # Recording loss per iteration
            sum_loss_reconstruction = 0
            sum_loss_discrminator = 0
            sum_loss_generator = 0
            process_iteration = Process()
            for i in range(num_trains_per_epoch):
                process_iteration.start_epoch(i, num_trains_per_epoch)
                # Inputs
                '''
                _l -> labeled
                _u -> unlabeled

                '''
                images_u = dataset.sample_unlabeled_data(images, batch_size_u)
                if config.distribution_sampler == 'swiss_roll':
                    z_true_u = sampler.swiss_roll(batch_size_u,
                                                  config.ndim_z,
                                                  config.num_types_of_label
                                                  )
                elif config.distribution_sampler == 'gaussian_mixture':
                    z_true_u = sampler.gaussian_mixture(batch_size_u,
                                                        config.ndim_z,
                                                        config.num_types_of_label
                                                        )
                elif config.distribution_sampler == 'uniform_desk':
                    z_true_u = sampler.uniform_desk(batch_size_u,
                                                    config.ndim_z,
                                                    radius=2
                                                    )
                elif config.distribution_sampler == 'gaussian':
                    z_true_u = sampler.gaussian(batch_size_u,
                                                config.ndim_z,
                                                var=1
                                                )
                elif config.distribution_sampler == 'uniform':
                    z_true_u = sampler.uniform(batch_size_u,
                                               config.ndim_z,
                                               minv=-1,
                                               maxv=1
                                               )
                z_prior = sampler.gaussian(batch_size_u,
                                           config.ndim_noise
                                           )

                # reconstruction_phase
                _, loss_reconstruction = sess.run([h.opt_r, h.loss_r], feed_dict={
                    h.x: images_u,
                    h.z_prior: z_prior,
                    h.lr: learning_rate
                })

                # adversarial phase for discriminator
                _, loss_discriminator_u = sess.run([h.opt_d, h.loss_d], feed_dict={
                    h.x: images_u,
                    h.z_prior: z_prior,
                    h.z: z_true_u,
                    h.lr: learning_rate
                })

                # adversarial phase for generator
                _, loss_generator_u = sess.run([h.opt_e, h.loss_e], feed_dict={
                    h.x: images_u,
                    h.z_prior: z_prior,
                    h.lr: learning_rate
                })

                sum_loss_reconstruction += loss_reconstruction
                sum_loss_discrminator += loss_discriminator_u
                sum_loss_generator += loss_generator_u

                if i % 1000 == 0:
                    process_iteration.show_table_2d(i, num_trains_per_epoch, {
                        'reconstruction': sum_loss_reconstruction / (i + 1),
                        'discriminator': sum_loss_discrminator / (i + 1),
                        'generator': sum_loss_generator / (i + 1),
                    })

            average_loss_per_epoch = [
                sum_loss_reconstruction / num_trains_per_epoch,
                sum_loss_discrminator / num_trains_per_epoch,
                sum_loss_generator / num_trains_per_epoch,
            ]
            training_epoch_loss.append(average_loss_per_epoch)
            training_loss_name = [
                'reconstruction',
                'discriminator',
                'generator'
            ]

            if epoch % 1 == 0:
                process.show_bar(epoch, max_epoch, {
                    'loss_r': average_loss_per_epoch[0],
                    'loss_d': average_loss_per_epoch[1],
                    'loss_g': average_loss_per_epoch[2]
                })
                plt.scatter_labeled_z(sess.run(h.z_r, feed_dict={h.x: images[:1000], h.z_prior: sampler.gaussian(1000, config.ndim_noise)}), [int(var) for var in labels[:1000]],
                                      dir=config.log_dir,
                                      filename='z_representation-{}'.format(epoch))

            if epoch % 10 == 0:
                saver.save(sess, os.path.join(config.ckpt_dir, 'model_ckptpoint'), global_step=epoch)
                pickle.dump((training_epoch_loss, training_loss_name), open(config.ckpt_dir + '/pickle.pkl', 'wb'))

# %%
if __name__ == '__main__':
    main(run_load_from_file=True)
# Out:
# INFO:tensorflow:Restoring parameters from ./ckpt_dir\model_ckptpoint-50
#
# Iteration:  0(500 in total)	 Time left:00:04:27
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.38601     |     0.72466     |    74.24077
# -----------------------------------------------------
#
#
# Epoch:  0/510[...................................................................................................]--01:18:56-- - loss_d: 1.39037 -  - loss_g: 0.69622 -  - loss_r: 75.82151 -
#
# Iteration:  0(500 in total)	 Time left:00:00:09
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.39168     |     0.72035     |    72.57016
# -----------------------------------------------------
#
#
# Epoch:  1/510[...................................................................................................]--01:13:49-- - loss_d: 1.39067 -  - loss_g: 0.69576 -  - loss_r: 76.23794 -
#
# Iteration:  0(500 in total)	 Time left:00:00:09
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.39445     |     0.71549     |    76.70184
# -----------------------------------------------------
#
#
# Epoch:  2/510[...................................................................................................]--01:13:59-- - loss_d: 1.39019 -  - loss_g: 0.69576 -  - loss_r: 76.53858 -
#
# Iteration:  0(500 in total)	 Time left:00:00:09
# -----------------------------------------------------
#  discriminator  |    generator    | reconstruction
# -----------------------------------------------------
#     1.38772     |     0.72834     |    76.80414
# -----------------------------------------------------
#
#
# Epoch:  3/510[...................................................................................................]--01:14:36-- - loss_d: 1.39050 -  - loss_g: 0.69580 -  - loss_r: 75.81374 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f020385ff83c> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     main(run_load_from_file=True)
#
# <ipython-input-2-8248fd2dc8fe> in main(run_load_from_file)
#     141                 plt.scatter_labeled_z(sess.run(h.z_r, feed_dict={h.x: images[:1000], h.z_prior: sampler.gaussian(1000, config.ndim_noise)}), [int(var) for var in labels[:1000]],
#     142                                       dir=config.log_dir,
# --> 143                                       filename='z_representation-{}'.format(epoch))
#     144
#     145             if epoch % 10 == 0:
#
# C:\Users\CYD\Desktop\AAE_advanced\plot.py in scatter_labeled_z(z_batch, label_batch, dir, filename)
#      46     for n in range(z_batch.shape[0]):
#      47         pylab.scatter(z_batch[n, 0], z_batch[n, 1], c=colors[int(label_batch[n])], s=40, marker='o',
# ---> 48                       edgecolors='none')
#      49
#      50     def count(label_batch):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4015             marker_obj = marker
#    4016         else:
# -> 4017             marker_obj = mmarkers.MarkerStyle(marker)
#    4018
#    4019         path = marker_obj.get_path().transformed(
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     270
#     271         self._marker = marker
# --> 272         self._recache()
#     273
#     274     def get_path(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     206         self._capstyle = 'butt'
#     207         self._filled = True
# --> 208         self._marker_function()
#     209
#     210     if six.PY3:
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_circle(self, reduction)
#     367
#     368     def _set_circle(self, reduction=1.0):
# --> 369         self._transform = Affine2D().scale(0.5 * reduction)
#     370         self._snap_threshold = np.inf
#     371         fs = self.get_fillstyle()
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1986             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]],
#    1987             np.float_)
# -> 1988         self._mtx = np.dot(scale_mtx, self._mtx)
#    1989         self.invalidate()
#    1990         return self
#
# KeyboardInterrupt:
