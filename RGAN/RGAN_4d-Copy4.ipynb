# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly

import os
import shutil
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from collections import defaultdict
import _pickle as pickle

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110

# Define salient variable
cat_list = [] # Each entry in this list defines a categorical variable for specific size
cont_num = 1 # the number of continous variables

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1

# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/RGAN/Experient_10'

log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
xmid,ymid = (xmin+xmax)/2,(ymin+ymax)/2
x,y = (x - xmid)*2/( xmax - xmin ),(y - ymid)*2/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)
y= y.reshape(-1,cont_num)

## split the dataset
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.20,random_state=0)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 1024, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = ly.fully_connected(train, 256*172, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = tf.reshape(train,(-1,256,172,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[1,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv( x ,c ,cat_list =cat_list ,cont_num =cont_num,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img = ly.conv2d(x,num_outputs=size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
        
        
        img_out = ly.conv2d(img,num_outputs= size*8 ,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        c = tf.tile(c,[1,int(img_dim/4)])
        c = tf.reshape(c,(batch_size,1,int(img_dim/4),1))
        img = tf.concat((c,img_out),axis=1)
        
        img = ly.conv2d(img ,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        
        # fully_connected
        disc_img = ly.flatten(img)
        disc_img = ly.fully_connected(disc_img,1024,activation_fn=lrelu)
        disc = ly.fully_connected(disc_img,1,activation_fn=None)
        
        # Here we difine the unique layers used for the q_network, the number of outputs 
        q_img = ly.conv2d(img_out,num_outputs= size*8,kernel_size=[10,1],stride=[1,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        q_img = ly.flatten(q_img)
        q_img = ly.fully_connected(q_img,1024,activation_fn=lrelu,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format})
        
        q_cat_outs = []
        if len(cat_list)>0:
            for idx,var in enumerate(cat_list):
                q_outA = ly.fully_connected(q_img,var, activation_fn=tf.nn.softmax)
                q_cat_outs.append(q_outA)
        
        q_cont_outs = []
        if cont_num>0:
            q_cont_outs = ly.fully_connected(q_img,cont_num,activation_fn = tf.nn.tanh)
    
    return disc, q_cat_outs, q_cont_outs

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # Real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[None,channel,img_dim,1])
    real_label = tf.placeholder(dtype = tf.float32,shape = [None,cont_num])
    # Noise ;Continous variable, and rand variable to provide some variance
    z_cont = tf.placeholder(dtype = tf.float32,shape =[None,cont_num])
    z_rand = tf.placeholder(dtype =tf.float32,shape =[None,z_dim])
    # Categorical variable
    if len(cat_list)>0:
        z_cat = tf.placeholder(dtype = tf.int32, shape=[None,len(cat_list)])
        cat_var = tf.split(z_cat , len(cat_list),axis=1)

        cat_z =[]
        for idx ,depth in enumerate(cat_list):
            cat_temp = tf.one_hot(tf.reshape(cat_var[idx],[-1]), depth)
            cat_z.append(cat_temp)
    else:
        z_cat = tf.placeholder(dtype =tf.float32,shape =[None,10])
        cat_z = [z_cat]
    # Conbine all of the variable
    z = cat_z[:]
    z.append(z_cont)
    z.append(z_rand)
    z = tf.concat( z,axis=1)
    
    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    disc_real,cat_real,cont_real = discriminator(real_data,real_label)
    disc_fake,cat_fake,cont_fake = discriminator(gen,cont_real, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
    
    # Combine losses for each of categorical variables
    if len(cat_list)>0:
        cat_losses_f =[]
        tiny = 1e-10
        for idx,var in enumerate(cat_z):
            cat_loss_f = -tf.reduce_sum(var *tf.log(cat_fake[idx]+tiny),reduction_indices=1)
            cat_losses_f.append(cat_loss_f)
            # cat_losses_r 
    else:
        cat_losses_f=cat_losses_r = tf.constant(0.0)
    # Combine losses for each of continous variables
    # MSE
    if cont_num>0:
        cont_loss_f = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_fake-z_cont),reduction_indices=1))
        cont_loss_r = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_real- real_label),reduction_indices=1))
    else:
        cont_loss_f = cont_loss_r = tf.constant(0.0)
    
    # Loss balance parameter
    alpha = 1
    q_cont_loss = cont_loss_r + alpha* cont_loss_f
    q_cat_loss = tf.constant(0.0)
    q_loss = tf.add(q_cont_loss,q_cat_loss)
    
    # Total variation loss
    tv_loss = tf.nn.l2_loss(gen[:,:,1:,:]-gen[:,:,:img_dim-1,:])/batch_size
    
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss + 0.001 *cont_loss_f + 0.000 * tv_loss
    loss_dis = d_loss
    loss_qnt = cont_loss_r
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    if is_test:
        return gen,z_rand,z_cont,z_cat,cont_real,cont_loss_r,real_data,real_label
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')
    theta_c = theta_d[10:]
    theta_d = theta_d[:10]

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    counter_q = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_q = optimize(loss =loss_qnt ,variables=theta_c ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_image(specs ,size,i =100,image_path = rgan_dir):
    _,ax = plt.subplots(size[0],size[1],sharex = True,sharey = True)
    for i in range(size[0]):
        for j in range(size[1]):
            ax[i][j].plot(np.arange(specs.shape[1]),specs[i*10+j] ,'-*')
    
    plt.savefig(image_path+'/'+str(i).zfill(4)+'.png')
    plt.close()

# %%
def save_spectrum(gen, i,spec_size = 10,is_show=False):
    if gen.shape[0]<spec_size:
        spec_size = gen.shape[0]

    gen = gen[:spec_size]
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,spec_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, spec_size))
    # convert data to ideal format 
    def cv_proc(x):
        x = xmid + x*(xmax-xmin)/2
        return x
        
    spec = cv_proc(gen.reshape(spec_size,img_dim))
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')    
    plt.legend([np.array_str(var) for var in np.arange(spec_size)])
    if intv ==0:
        plt.ylim([-0.5,scale])
    else:
        plt.ylim([-0.5,scale*spec_size*intv])
    
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_rgan(max_iters = 1000):
    # build graph
    with tf.device(device):
        opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,\
        loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss = build_graph()
        
    saver = tf.train.Saver()

    def next_feed_dict(iter, shuffled = True,is_test =False):
        
        # feed image and label,train set if is_test=False
        # otherwise test set
        def generate_index(input,iter,shuffled =shuffled):
            input_number = input.shape[0]
            if shuffled:
                idx = np.random.randint(input_number,size=(batch_size,))
            else:
                bat_num = int(input_number/batch_size)
                par = int(iter % bat_num)
                idx = np.arange(input_number)[par * batch_size:(par+1)*batch_size]
            return idx
        
        if is_test:
            idx = generate_index(x_test,iter)
            feed_img,feed_label = x_test[idx],y_test[idx]
        else:
            idx = generate_index(x_train,iter)
            feed_img,feed_label = x_train[idx],y_train[idx]
        
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
        if len(cat_list)>0:
            batch_z_cat  = np.random.randint(0,10,[batch_size,len(cat_list)])
        else:
            batch_z_cat = np.random.normal(0,0.3,[batch_size,10]).astype(np.float32)
        
        batch_z_cont = np.random.uniform(-1,1,[batch_size,cont_num])     
        
        feed_dict = {real_data:feed_img, 
                     z_rand : batch_z_rand,
                     z_cat  : batch_z_cat,
                     z_cont : batch_z_cont,
                     real_label:feed_label }
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        
        # use two dict-like container to record of history data
        # for analysising the result
        history = defaultdict(list)
        
        for i in range(max_iters):
            
            start_time = time.time()
            ## Training Phase
            feed_dict = next_feed_dict(i)
            
            _,dLoss = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,gLoss,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            _,qLoss,qCont,qCat = sess.run([opt_q, loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['train_loss'].append([dLoss,gLoss,qLoss,qCont,qCat])
            
            ## Testing Phase
            feed_dict = next_feed_dict(i,is_test=True)
        
            dLoss_ = sess.run(loss_dis,feed_dict = feed_dict)
            gLoss_ = sess.run(loss_gen,feed_dict = feed_dict)
            qLoss_ ,qCont_ ,qCat_ = sess.run([loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['test_loss'].append([dLoss_ ,gLoss_ ,qLoss_ ,qCont_ ,qCat_])
            if i % 100 == 0:
                elapse = time.time() - start_time
                time_left = (max_iters-i-1)* elapse
                print('\nIteration: {:0>5d}({:0.2%}) of {} \t Time left:{:02d}:{:02d}:{:02d}'.format(i,i/max_iters,max_iters,\
                     int(time_left/3600),int(time_left%3600/60),int(time_left%60)))
                
                print('{0:<8s} | {1:<15s} | {2:<15s} | {3:<15s} | {4:<15s} | {5:<15s}'\
                    .format('Loss','generator','discriminator','Q network','Q_continous','Q_categorical'))
                print('-' * 98)
                row_fmt = '{0:<8s} | {1:<15.3f} | {2:<15.3f} | {3:<15.3f} | {4:<15.3f} | {5:<15.3f}'
                print(row_fmt.format('train',*history['train_loss'][-1]))
                print(row_fmt.format('test' ,*history['test_loss'][-1]))
                save_spectrum(spec, i)
                
        

            if i %1000 ==0:
                saver.save(sess, os.path.join(ckpt_dir,'model_checkpoint'),global_step=i)
            
        pickle.dump(history,open(rgan_dir+'/rgan_pickle.pkl','wb'))

# %%
tf.reset_default_graph()
max_iters = 20000
train_rgan(max_iters =max_iters)
# Out:
# Iteration: 00000(0.00%) of 20000 	 Time left:06:21:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.089          | 0.995           | 0.109           | 0.418           | 0.000
# test     | -1.513          | 1.020           | 0.311           | 0.923           | 0.000
#
# Iteration: 00100(0.50%) of 20000 	 Time left:01:12:25
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -496.863        | 254.745         | 0.331           | 1.011           | 0.000
# test     | -524.197        | 213.561         | 0.344           | 1.018           | 0.000
#
# Iteration: 00200(1.00%) of 20000 	 Time left:01:06:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -792.906        | 404.035         | 0.244           | 0.816           | 0.000
# test     | -841.362        | 398.725         | 0.267           | 0.886           | 0.000
#
# Iteration: 00300(1.50%) of 20000 	 Time left:01:08:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -631.395        | 262.080         | 0.106           | 0.697           | 0.000
# test     | -678.581        | 226.083         | 0.095           | 0.422           | 0.000
#
# Iteration: 00400(2.00%) of 20000 	 Time left:01:11:20
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.350         | -181.283        | 0.053           | 0.317           | 0.000
# test     | -13.321         | -181.642        | 0.073           | 0.295           | 0.000
#
# Iteration: 00500(2.50%) of 20000 	 Time left:01:05:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -114.068        | -114.751        | 0.039           | 0.314           | 0.000
# test     | -137.425        | -116.889        | 0.049           | 0.271           | 0.000
#
# Iteration: 00600(3.00%) of 20000 	 Time left:01:10:01
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -129.819        | -129.108        | 0.076           | 0.206           | 0.000
# test     | -119.129        | -146.394        | 0.126           | 0.461           | 0.000
#
# Iteration: 00700(3.50%) of 20000 	 Time left:01:05:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.189           | -174.257        | 0.036           | 0.595           | 0.000
# test     | -12.348         | -175.360        | 0.041           | 0.462           | 0.000
#
# Iteration: 00800(4.00%) of 20000 	 Time left:01:04:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.239          | 136.216         | 0.055           | 0.206           | 0.000
# test     | -7.744          | 135.029         | 0.052           | 0.320           | 0.000
#
# Iteration: 00900(4.50%) of 20000 	 Time left:01:04:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.531           | 84.326          | 0.034           | 0.209           | 0.000
# test     | 0.267           | 82.931          | 0.037           | 0.236           | 0.000
#
# Iteration: 01000(5.00%) of 20000 	 Time left:01:05:28
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.050          | 70.643          | 0.015           | 0.303           | 0.000
# test     | -9.584          | 70.030          | 0.022           | 0.232           | 0.000
#
# Iteration: 01100(5.50%) of 20000 	 Time left:01:03:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.253         | 60.283          | 0.050           | 0.238           | 0.000
# test     | -12.344         | 59.337          | 0.056           | 0.254           | 0.000
#
# Iteration: 01200(6.00%) of 20000 	 Time left:01:05:25
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.200         | -188.232        | 0.033           | 0.200           | 0.000
# test     | -12.743         | -190.799        | 0.026           | 0.200           | 0.000
#
# Iteration: 01300(6.50%) of 20000 	 Time left:01:03:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -52.563         | 21.197          | 0.025           | 0.227           | 0.000
# test     | -69.324         | 12.900          | 0.044           | 0.221           | 0.000
#
# Iteration: 01400(7.00%) of 20000 	 Time left:01:04:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.297         | 140.615         | 0.038           | 0.187           | 0.000
# test     | -15.610         | 139.966         | 0.116           | 0.442           | 0.000
#
# Iteration: 01500(7.50%) of 20000 	 Time left:01:03:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -16.002         | 133.563         | 0.038           | 0.254           | 0.000
# test     | -16.488         | 133.306         | 0.052           | 0.269           | 0.000
#
# Iteration: 01600(8.00%) of 20000 	 Time left:01:02:11
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.385         | 94.373          | 0.020           | 0.200           | 0.000
# test     | -14.158         | 93.268          | 0.039           | 0.247           | 0.000
#
# Iteration: 01700(8.50%) of 20000 	 Time left:01:04:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.323          | 39.591          | 0.072           | 0.335           | 0.000
# test     | -4.996          | 39.216          | 0.098           | 0.374           | 0.000
#
# Iteration: 01800(9.00%) of 20000 	 Time left:01:02:43
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.123          | 77.730          | 0.019           | 0.203           | 0.000
# test     | -2.070          | 76.350          | 0.020           | 0.198           | 0.000
#
# Iteration: 01900(9.50%) of 20000 	 Time left:01:01:10
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -16.832         | 69.695          | 0.029           | 0.253           | 0.000
# test     | -17.241         | 68.690          | 0.025           | 0.188           | 0.000
#
# Iteration: 02000(10.00%) of 20000 	 Time left:01:01:26
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.546          | 155.684         | 0.030           | 0.179           | 0.000
# test     | -1.284          | 155.137         | 0.061           | 0.190           | 0.000
#
# Iteration: 02100(10.50%) of 20000 	 Time left:01:01:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.970         | -164.366        | 0.025           | 0.191           | 0.000
# test     | -20.826         | -165.945        | 0.033           | 0.232           | 0.000
#
# Iteration: 02200(11.00%) of 20000 	 Time left:00:59:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.451         | -118.305        | 0.014           | 0.106           | 0.000
# test     | -16.113         | -126.550        | 0.043           | 0.217           | 0.000
#
# Iteration: 02300(11.50%) of 20000 	 Time left:00:59:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -38.601         | 84.970          | 0.026           | 0.401           | 0.000
# test     | -44.327         | 76.096          | 0.027           | 0.481           | 0.000
#
# Iteration: 02400(12.00%) of 20000 	 Time left:01:04:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -29.067         | 69.502          | 0.050           | 0.224           | 0.000
# test     | -21.515         | 70.466          | 0.039           | 0.268           | 0.000
#
# Iteration: 02500(12.50%) of 20000 	 Time left:01:03:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -34.066         | 180.876         | 0.019           | 0.188           | 0.000
# test     | -35.432         | 177.494         | 0.035           | 0.334           | 0.000
#
# Iteration: 02600(13.00%) of 20000 	 Time left:01:07:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -23.590         | 87.719          | 0.035           | 0.358           | 0.000
# test     | -23.347         | 85.836          | 0.048           | 0.264           | 0.000
#
# Iteration: 02700(13.50%) of 20000 	 Time left:00:58:28
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.518         | 71.895          | 0.018           | 0.199           | 0.000
# test     | -19.904         | 71.048          | 0.049           | 0.231           | 0.000
#
# Iteration: 02800(14.00%) of 20000 	 Time left:01:02:36
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.614           | 108.350         | 0.023           | 0.302           | 0.000
# test     | 0.062           | 108.006         | 0.028           | 0.225           | 0.000
#
# Iteration: 02900(14.50%) of 20000 	 Time left:00:57:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.991          | 112.818         | 0.012           | 0.231           | 0.000
# test     | -2.465          | 112.831         | 0.037           | 0.236           | 0.000
#
# Iteration: 03000(15.00%) of 20000 	 Time left:01:01:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.309          | 135.184         | 0.014           | 0.266           | 0.000
# test     | -4.686          | 134.644         | 0.076           | 0.263           | 0.000
#
# Iteration: 03100(15.50%) of 20000 	 Time left:01:01:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.408          | 138.697         | 0.022           | 0.229           | 0.000
# test     | -5.953          | 138.616         | 0.048           | 0.335           | 0.000
#
# Iteration: 03200(16.00%) of 20000 	 Time left:01:01:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.494          | 110.825         | 0.014           | 0.157           | 0.000
# test     | -1.706          | 109.705         | 0.021           | 0.180           | 0.000
#
# Iteration: 03300(16.50%) of 20000 	 Time left:01:00:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.255          | 49.694          | 0.010           | 0.196           | 0.000
# test     | -8.891          | 49.044          | 0.067           | 0.193           | 0.000
#
# Iteration: 03400(17.00%) of 20000 	 Time left:01:00:25
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -45.602         | 150.080         | 0.024           | 0.184           | 0.000
# test     | -46.436         | 145.780         | 0.057           | 0.220           | 0.000
#
# Iteration: 03500(17.50%) of 20000 	 Time left:00:55:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.917           | 137.675         | 0.019           | 0.164           | 0.000
# test     | 2.674           | 136.338         | 0.046           | 0.219           | 0.000
#
# Iteration: 03600(18.00%) of 20000 	 Time left:00:59:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.547          | 108.514         | 0.013           | 0.217           | 0.000
# test     | -3.539          | 107.607         | 0.049           | 0.263           | 0.000
#
# Iteration: 03700(18.50%) of 20000 	 Time left:00:59:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -53.030         | 129.725         | 0.021           | 0.221           | 0.000
# test     | -62.166         | 126.571         | 0.041           | 0.253           | 0.000
#
# Iteration: 03800(19.00%) of 20000 	 Time left:00:54:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.695          | 159.181         | 0.021           | 0.424           | 0.000
# test     | 0.877           | 155.401         | 0.045           | 0.417           | 0.000
#
# Iteration: 03900(19.50%) of 20000 	 Time left:00:54:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.062         | -153.725        | 0.027           | 0.246           | 0.000
# test     | -8.553          | -186.370        | 0.028           | 0.189           | 0.000
#
# Iteration: 04000(20.00%) of 20000 	 Time left:00:54:04
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.540          | 228.916         | 0.023           | 0.199           | 0.000
# test     | -14.032         | 228.291         | 0.035           | 0.179           | 0.000
#
# Iteration: 04100(20.50%) of 20000 	 Time left:00:55:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -23.757         | -236.826        | 0.018           | 0.206           | 0.000
# test     | -37.634         | -236.570        | 0.046           | 0.193           | 0.000
#
# Iteration: 04200(21.00%) of 20000 	 Time left:00:53:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -29.381         | 3.005           | 0.024           | 0.153           | 0.000
# test     | -35.790         | 2.229           | 0.046           | 0.270           | 0.000
#
# Iteration: 04300(21.50%) of 20000 	 Time left:00:53:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -43.731         | 111.083         | 0.032           | 0.323           | 0.000
# test     | -64.986         | 109.004         | 0.026           | 0.192           | 0.000
#
# Iteration: 04400(22.00%) of 20000 	 Time left:00:56:46
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -119.454        | 14.204          | 0.029           | 0.658           | 0.000
# test     | -113.793        | 1.977           | 0.018           | 0.528           | 0.000
#
# Iteration: 04500(22.50%) of 20000 	 Time left:00:56:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -52.871         | -180.613        | 0.011           | 0.238           | 0.000
# test     | -59.362         | -181.577        | 0.039           | 0.309           | 0.000
#
# Iteration: 04600(23.00%) of 20000 	 Time left:00:52:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -292.003        | 156.855         | 0.024           | 0.303           | 0.000
# test     | -332.127        | 133.028         | 0.042           | 0.385           | 0.000
#
# Iteration: 04700(23.50%) of 20000 	 Time left:00:51:42
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -258.033        | 157.355         | 0.023           | 0.236           | 0.000
# test     | -356.293        | 103.673         | 0.025           | 0.366           | 0.000
#
# Iteration: 04800(24.00%) of 20000 	 Time left:00:55:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -346.202        | 61.118          | 0.015           | 0.282           | 0.000
# test     | -341.036        | 15.733          | 0.029           | 0.264           | 0.000
#
# Iteration: 04900(24.50%) of 20000 	 Time left:00:54:57
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -174.377        | -71.346         | 0.028           | 0.442           | 0.000
# test     | -151.060        | -83.125         | 0.029           | 0.531           | 0.000
#
# Iteration: 05000(25.00%) of 20000 	 Time left:00:54:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -26.739         | 247.620         | 0.022           | 0.237           | 0.000
# test     | -27.215         | 242.989         | 0.037           | 0.233           | 0.000
#
# Iteration: 05100(25.50%) of 20000 	 Time left:00:54:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.431          | 27.010          | 0.028           | 0.207           | 0.000
# test     | -9.112          | 26.722          | 0.014           | 0.224           | 0.000
#
# Iteration: 05200(26.00%) of 20000 	 Time left:00:50:01
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 13.775          | -29.948         | 0.039           | 0.239           | 0.000
# test     | 2.736           | -28.938         | 0.029           | 0.245           | 0.000
#
# Iteration: 05300(26.50%) of 20000 	 Time left:00:53:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.918         | 5.976           | 0.024           | 0.291           | 0.000
# test     | -17.857         | 5.434           | 0.029           | 0.189           | 0.000
#
# Iteration: 05400(27.00%) of 20000 	 Time left:00:49:20
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.001          | -65.364         | 0.025           | 0.225           | 0.000
# test     | -5.785          | -67.790         | 0.023           | 0.208           | 0.000
#
# Iteration: 05500(27.50%) of 20000 	 Time left:00:49:00
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.258         | 189.732         | 0.012           | 0.173           | 0.000
# test     | -16.772         | 190.288         | 0.055           | 0.205           | 0.000
#
# Iteration: 05600(28.00%) of 20000 	 Time left:00:48:40
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -59.571         | 178.767         | 0.030           | 0.121           | 0.000
# test     | -89.607         | 179.192         | 0.026           | 0.203           | 0.000
#
# Iteration: 05700(28.50%) of 20000 	 Time left:00:48:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -27.691         | 4.140           | 0.013           | 0.222           | 0.000
# test     | -30.859         | 2.998           | 0.025           | 0.196           | 0.000
#
# Iteration: 05800(29.00%) of 20000 	 Time left:00:51:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.342           | 149.260         | 0.026           | 0.311           | 0.000
# test     | 3.573           | 147.841         | 0.043           | 0.271           | 0.000
#
# Iteration: 05900(29.50%) of 20000 	 Time left:00:47:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.376          | 95.853          | 0.011           | 0.308           | 0.000
# test     | -6.173          | 96.364          | 0.026           | 0.342           | 0.000
#
# Iteration: 06000(30.00%) of 20000 	 Time left:00:54:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.931         | 110.699         | 0.024           | 0.194           | 0.000
# test     | -5.452          | 107.467         | 0.019           | 0.221           | 0.000
#
# Iteration: 06100(30.50%) of 20000 	 Time left:00:50:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -20.896         | 62.672          | 0.015           | 0.203           | 0.000
# test     | -18.073         | 59.159          | 0.053           | 0.226           | 0.000
#
# Iteration: 06200(31.00%) of 20000 	 Time left:00:50:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -68.162         | 111.928         | 0.026           | 0.261           | 0.000
# test     | -91.578         | 110.927         | 0.028           | 0.278           | 0.000
#
# Iteration: 06300(31.50%) of 20000 	 Time left:00:46:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.966          | -175.034        | 0.007           | 0.249           | 0.000
# test     | -5.904          | -177.239        | 0.027           | 0.248           | 0.000
#
# Iteration: 06400(32.00%) of 20000 	 Time left:00:49:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -45.975         | -48.280         | 0.020           | 0.293           | 0.000
# test     | -50.969         | -48.702         | 0.029           | 0.223           | 0.000
#
# Iteration: 06500(32.50%) of 20000 	 Time left:00:49:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -186.430        | 95.780          | 0.013           | 0.287           | 0.000
# test     | -202.651        | 79.409          | 0.035           | 0.239           | 0.000
#
# Iteration: 06600(33.00%) of 20000 	 Time left:00:48:46
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -42.751         | -102.114        | 0.017           | 0.464           | 0.000
# test     | -46.007         | -102.376        | 0.048           | 0.269           | 0.000
#
# Iteration: 06700(33.50%) of 20000 	 Time left:00:44:57
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 10.005          | 39.765          | 0.006           | 0.296           | 0.000
# test     | 5.806           | 39.243          | 0.013           | 0.188           | 0.000
#
# Iteration: 06800(34.00%) of 20000 	 Time left:00:44:36
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -113.229        | 156.958         | 0.022           | 0.241           | 0.000
# test     | -123.368        | 154.839         | 0.043           | 0.254           | 0.000
#
# Iteration: 06900(34.50%) of 20000 	 Time left:00:47:40
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -35.788         | -77.021         | 0.011           | 0.252           | 0.000
# test     | -52.233         | -69.360         | 0.026           | 0.297           | 0.000
#
# Iteration: 07000(35.00%) of 20000 	 Time left:00:43:56
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.152         | -110.561        | 0.015           | 0.411           | 0.000
# test     | -22.911         | -115.108        | 0.023           | 0.333           | 0.000
#
# Iteration: 07100(35.50%) of 20000 	 Time left:00:43:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.115         | -188.992        | 0.012           | 0.235           | 0.000
# test     | -18.003         | -189.682        | 0.053           | 0.272           | 0.000
#
# Iteration: 07200(36.00%) of 20000 	 Time left:00:43:15
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.133         | 103.784         | 0.012           | 0.163           | 0.000
# test     | -15.849         | 102.614         | 0.024           | 0.193           | 0.000
#
# Iteration: 07300(36.50%) of 20000 	 Time left:00:42:55
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -54.711         | 64.794          | 0.017           | 0.225           | 0.000
# test     | -58.528         | 62.784          | 0.023           | 0.269           | 0.000
#
# Iteration: 07400(37.00%) of 20000 	 Time left:00:45:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -54.501         | 35.723          | 0.015           | 0.530           | 0.000
# test     | -57.555         | 33.473          | 0.021           | 0.431           | 0.000
#
# Iteration: 07500(37.50%) of 20000 	 Time left:00:45:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -197.146        | 72.045          | 0.015           | 0.243           | 0.000
# test     | -214.893        | 56.815          | 0.017           | 0.185           | 0.000
#
# Iteration: 07600(38.00%) of 20000 	 Time left:00:41:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 14.477          | 159.870         | 0.024           | 0.159           | 0.000
# test     | 13.221          | 159.330         | 0.038           | 0.252           | 0.000
#
# Iteration: 07700(38.50%) of 20000 	 Time left:00:41:34
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.635         | 72.927          | 0.033           | 0.241           | 0.000
# test     | -10.901         | 69.668          | 0.049           | 0.252           | 0.000
#
# Iteration: 07800(39.00%) of 20000 	 Time left:00:44:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.333          | 89.793          | 0.016           | 0.168           | 0.000
# test     | -6.716          | 89.587          | 0.025           | 0.249           | 0.000
#
# Iteration: 07900(39.50%) of 20000 	 Time left:00:40:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.801          | 47.366          | 0.011           | 0.253           | 0.000
# test     | -7.358          | 47.792          | 0.025           | 0.188           | 0.000
#
# Iteration: 08000(40.00%) of 20000 	 Time left:00:40:33
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.754         | 92.414          | 0.030           | 0.197           | 0.000
# test     | -7.241          | 87.650          | 0.038           | 0.192           | 0.000
#
# Iteration: 08100(40.50%) of 20000 	 Time left:00:40:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.052          | 235.177         | 0.016           | 0.212           | 0.000
# test     | -13.358         | 234.438         | 0.023           | 0.199           | 0.000
#
# Iteration: 08200(41.00%) of 20000 	 Time left:00:42:56
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -57.856         | -34.630         | 0.014           | 0.346           | 0.000
# test     | -38.055         | -59.619         | 0.025           | 0.350           | 0.000
#
# Iteration: 08300(41.50%) of 20000 	 Time left:00:39:32
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -50.822         | -124.163        | 0.017           | 0.395           | 0.000
# test     | -52.142         | -128.381        | 0.045           | 0.427           | 0.000
#
# Iteration: 08400(42.00%) of 20000 	 Time left:00:39:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -42.799         | 66.200          | 0.017           | 0.331           | 0.000
# test     | -46.307         | 63.784          | 0.039           | 0.513           | 0.000
#
# Iteration: 08500(42.50%) of 20000 	 Time left:00:38:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -28.526         | 100.773         | 0.015           | 0.238           | 0.000
# test     | -29.326         | 98.441          | 0.019           | 0.122           | 0.000
#
# Iteration: 08600(43.00%) of 20000 	 Time left:00:38:31
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.711         | 129.470         | 0.023           | 0.433           | 0.000
# test     | -20.884         | 128.233         | 0.020           | 0.450           | 0.000
#
# Iteration: 08700(43.50%) of 20000 	 Time left:00:41:07
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.763         | 58.594          | 0.008           | 0.301           | 0.000
# test     | -19.519         | 57.489          | 0.052           | 0.262           | 0.000
#
# Iteration: 08800(44.00%) of 20000 	 Time left:00:37:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.709          | 67.944          | 0.011           | 0.186           | 0.000
# test     | -2.007          | 65.714          | 0.037           | 0.390           | 0.000
#
# Iteration: 08900(44.50%) of 20000 	 Time left:00:40:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.870          | 193.006         | 0.007           | 0.229           | 0.000
# test     | -11.202         | 192.399         | 0.046           | 0.222           | 0.000
#
# Iteration: 09000(45.00%) of 20000 	 Time left:00:37:10
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.649         | -254.954        | 0.013           | 0.349           | 0.000
# test     | -23.450         | -252.672        | 0.023           | 0.276           | 0.000
#
# Iteration: 09100(45.50%) of 20000 	 Time left:00:36:50
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.317          | -247.879        | 0.012           | 0.522           | 0.000
# test     | -7.230          | -250.607        | 0.033           | 0.473           | 0.000
#
# Iteration: 09200(46.00%) of 20000 	 Time left:00:39:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -101.148        | 34.533          | 0.016           | 0.292           | 0.000
# test     | -115.208        | 30.885          | 0.031           | 0.391           | 0.000
#
# Iteration: 09300(46.50%) of 20000 	 Time left:00:36:09
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.119           | 152.828         | 0.016           | 0.515           | 0.000
# test     | 4.996           | 150.270         | 0.028           | 0.598           | 0.000
#
# Iteration: 09400(47.00%) of 20000 	 Time left:00:38:34
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -16.982         | -290.023        | 0.014           | 0.499           | 0.000
# test     | -18.034         | -291.407        | 0.025           | 0.492           | 0.000
#
# Iteration: 09500(47.50%) of 20000 	 Time left:00:38:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.432          | -72.225         | 0.023           | 0.245           | 0.000
# test     | -17.785         | -73.567         | 0.024           | 0.235           | 0.000
#
# Iteration: 09600(48.00%) of 20000 	 Time left:00:35:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -28.754         | 20.568          | 0.009           | 0.166           | 0.000
# test     | -24.056         | 20.977          | 0.025           | 0.172           | 0.000
#
# Iteration: 09700(48.50%) of 20000 	 Time left:00:34:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -20.590         | -83.378         | 0.028           | 0.216           | 0.000
# test     | -22.975         | -84.942         | 0.031           | 0.242           | 0.000
#
# Iteration: 09800(49.00%) of 20000 	 Time left:00:37:07
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -48.601         | 102.508         | 0.013           | 0.451           | 0.000
# test     | -53.941         | 101.364         | 0.033           | 0.404           | 0.000
#
# Iteration: 09900(49.50%) of 20000 	 Time left:00:36:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -50.106         | 217.190         | 0.010           | 0.386           | 0.000
# test     | -45.371         | 207.613         | 0.026           | 0.337           | 0.000
#
# Iteration: 10000(50.00%) of 20000 	 Time left:00:33:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -46.356         | -224.012        | 0.010           | 0.340           | 0.000
# test     | -35.212         | -227.493        | 0.022           | 0.438           | 0.000
#
# Iteration: 10100(50.50%) of 20000 	 Time left:00:33:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 19.138          | -239.720        | 0.009           | 0.274           | 0.000
# test     | 20.529          | -239.326        | 0.028           | 0.252           | 0.000
#
# Iteration: 10200(51.00%) of 20000 	 Time left:00:35:40
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -71.694         | 156.814         | 0.015           | 0.178           | 0.000
# test     | -78.009         | 156.290         | 0.043           | 0.239           | 0.000
#
# Iteration: 10300(51.50%) of 20000 	 Time left:00:37:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.854           | 24.244          | 0.018           | 0.299           | 0.000
# test     | 7.250           | 24.273          | 0.052           | 0.257           | 0.000
#
# Iteration: 10400(52.00%) of 20000 	 Time left:00:32:26
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.041         | 9.132           | 0.019           | 0.304           | 0.000
# test     | -20.062         | 8.924           | 0.026           | 0.284           | 0.000
#
# Iteration: 10500(52.50%) of 20000 	 Time left:00:32:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.633          | -59.591         | 0.018           | 0.220           | 0.000
# test     | -8.862          | -61.489         | 0.033           | 0.256           | 0.000
#
# Iteration: 10600(53.00%) of 20000 	 Time left:00:31:46
# ...
# test     | -30.137         | 27.470          | 0.031           | 0.271           | 0.000
#
# Iteration: 16500(82.50%) of 20000 	 Time left:00:11:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.874         | 113.303         | 0.012           | 0.320           | 0.000
# test     | -17.628         | 112.257         | 0.018           | 0.490           | 0.000
#
# Iteration: 16600(83.00%) of 20000 	 Time left:00:11:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.688         | 87.619          | 0.007           | 0.378           | 0.000
# test     | -15.006         | 85.872          | 0.040           | 0.441           | 0.000
#
# Iteration: 16700(83.50%) of 20000 	 Time left:00:11:09
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.917           | 108.534         | 0.005           | 0.343           | 0.000
# test     | 1.944           | 107.753         | 0.038           | 0.285           | 0.000
#
# Iteration: 16800(84.00%) of 20000 	 Time left:00:10:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.087          | 122.029         | 0.005           | 0.167           | 0.000
# test     | 0.890           | 121.643         | 0.034           | 0.213           | 0.000
#
# Iteration: 16900(84.50%) of 20000 	 Time left:00:12:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.153          | 150.853         | 0.007           | 0.126           | 0.000
# test     | -3.091          | 149.253         | 0.035           | 0.298           | 0.000
#
# Iteration: 17000(85.00%) of 20000 	 Time left:00:10:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.404          | 78.083          | 0.008           | 0.286           | 0.000
# test     | -5.912          | 77.355          | 0.041           | 0.243           | 0.000
#
# Iteration: 17100(85.50%) of 20000 	 Time left:00:10:33
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -22.367         | 22.243          | 0.012           | 0.253           | 0.000
# test     | -26.838         | 23.221          | 0.016           | 0.208           | 0.000
#
# Iteration: 17200(86.00%) of 20000 	 Time left:00:09:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.464          | 35.061          | 0.018           | 0.307           | 0.000
# test     | -14.094         | 27.667          | 0.014           | 0.274           | 0.000
#
# Iteration: 17300(86.50%) of 20000 	 Time left:00:09:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.471         | -25.359         | 0.011           | 0.133           | 0.000
# test     | -7.506          | -28.851         | 0.022           | 0.263           | 0.000
#
# Iteration: 17400(87.00%) of 20000 	 Time left:00:09:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.207          | 114.150         | 0.006           | 0.257           | 0.000
# test     | -8.776          | 112.667         | 0.030           | 0.234           | 0.000
#
# Iteration: 17500(87.50%) of 20000 	 Time left:00:08:26
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.635          | 19.400          | 0.004           | 0.319           | 0.000
# test     | -13.959         | 19.849          | 0.036           | 0.237           | 0.000
#
# Iteration: 17600(88.00%) of 20000 	 Time left:00:08:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.979         | -13.786         | 0.020           | 0.251           | 0.000
# test     | -20.335         | -14.967         | 0.018           | 0.211           | 0.000
#
# Iteration: 17700(88.50%) of 20000 	 Time left:00:07:46
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.820          | 46.179          | 0.004           | 0.378           | 0.000
# test     | -3.567          | 47.192          | 0.024           | 0.388           | 0.000
#
# Iteration: 17800(89.00%) of 20000 	 Time left:00:07:25
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.104         | 36.660          | 0.009           | 0.229           | 0.000
# test     | -14.632         | 36.657          | 0.022           | 0.242           | 0.000
#
# Iteration: 17900(89.50%) of 20000 	 Time left:00:07:38
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.436         | 45.397          | 0.019           | 0.267           | 0.000
# test     | -24.822         | 41.940          | 0.024           | 0.230           | 0.000
#
# Iteration: 18000(90.00%) of 20000 	 Time left:00:07:16
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.515           | 65.401          | 0.019           | 0.237           | 0.000
# test     | 5.841           | 64.533          | 0.018           | 0.265           | 0.000
#
# Iteration: 18100(90.50%) of 20000 	 Time left:00:06:25
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -27.453         | -41.300         | 0.008           | 0.152           | 0.000
# test     | -38.646         | -45.254         | 0.018           | 0.190           | 0.000
#
# Iteration: 18200(91.00%) of 20000 	 Time left:00:06:04
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.200          | -90.810         | 0.014           | 0.223           | 0.000
# test     | 4.891           | -91.982         | 0.028           | 0.249           | 0.000
#
# Iteration: 18300(91.50%) of 20000 	 Time left:00:05:44
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.039         | 216.339         | 0.017           | 0.299           | 0.000
# test     | -20.490         | 215.532         | 0.020           | 0.213           | 0.000
#
# Iteration: 18400(92.00%) of 20000 	 Time left:00:05:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 13.472          | 106.272         | 0.013           | 0.274           | 0.000
# test     | 12.175          | 105.900         | 0.020           | 0.201           | 0.000
#
# Iteration: 18500(92.50%) of 20000 	 Time left:00:05:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.460           | 11.935          | 0.014           | 0.206           | 0.000
# test     | 5.250           | 10.950          | 0.027           | 0.238           | 0.000
#
# Iteration: 18600(93.00%) of 20000 	 Time left:00:05:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.295          | 9.038           | 0.006           | 0.204           | 0.000
# test     | -4.678          | 8.256           | 0.043           | 0.239           | 0.000
#
# Iteration: 18700(93.50%) of 20000 	 Time left:00:05:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.041          | 2.645           | 0.015           | 0.217           | 0.000
# test     | -0.153          | 2.785           | 0.025           | 0.241           | 0.000
#
# Iteration: 18800(94.00%) of 20000 	 Time left:00:04:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.022           | 106.109         | 0.012           | 0.172           | 0.000
# test     | 2.117           | 106.013         | 0.023           | 0.168           | 0.000
#
# Iteration: 18900(94.50%) of 20000 	 Time left:00:04:17
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.271          | -117.644        | 0.013           | 0.158           | 0.000
# test     | 0.224           | -122.163        | 0.024           | 0.235           | 0.000
#
# Iteration: 19000(95.00%) of 20000 	 Time left:00:03:22
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -55.973         | -28.245         | 0.007           | 0.288           | 0.000
# test     | -61.659         | -29.878         | 0.024           | 0.357           | 0.000
#
# Iteration: 19100(95.50%) of 20000 	 Time left:00:03:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.410          | -5.004          | 0.012           | 0.203           | 0.000
# test     | -4.424          | -5.288          | 0.022           | 0.252           | 0.000
#
# Iteration: 19200(96.00%) of 20000 	 Time left:00:02:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -41.898         | -60.731         | 0.010           | 0.243           | 0.000
# test     | -56.407         | -67.539         | 0.027           | 0.203           | 0.000
#
# Iteration: 19300(96.50%) of 20000 	 Time left:00:02:32
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -37.720         | -44.947         | 0.022           | 0.273           | 0.000
# test     | -66.741         | -55.195         | 0.031           | 0.216           | 0.000
#
# Iteration: 19400(97.00%) of 20000 	 Time left:00:02:01
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.437          | -45.752         | 0.004           | 0.271           | 0.000
# test     | -2.682          | -51.593         | 0.022           | 0.128           | 0.000
#
# Iteration: 19500(97.50%) of 20000 	 Time left:00:01:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 4.844           | -61.802         | 0.007           | 0.171           | 0.000
# test     | 7.393           | -64.269         | 0.039           | 0.205           | 0.000
#
# Iteration: 19600(98.00%) of 20000 	 Time left:00:01:20
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -54.318         | 73.321          | 0.011           | 0.162           | 0.000
# test     | -59.779         | 73.749          | 0.019           | 0.184           | 0.000
#
# Iteration: 19700(98.50%) of 20000 	 Time left:00:01:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -79.005         | 74.649          | 0.010           | 0.256           | 0.000
# test     | -82.068         | 63.923          | 0.014           | 0.272           | 0.000
#
# Iteration: 19800(99.00%) of 20000 	 Time left:00:00:43
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.708         | 114.566         | 0.012           | 0.169           | 0.000
# test     | -9.417          | 113.356         | 0.014           | 0.160           | 0.000
#
# Iteration: 19900(99.50%) of 20000 	 Time left:00:00:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -43.048         | 194.466         | 0.018           | 0.248           | 0.000
# test     | -44.590         | 188.517         | 0.030           | 0.264           | 0.000

# %% [markdown]
# ### Show the result

# %%
hist = pickle.load(open(rgan_dir+'/rgan_pickle.pkl','rb'))

# %%
losses = ['generator','discriminator','Q network','Q_continous','Q_categorical']

# %% [markdown]
# Use pandas to realize the two demensional dict-like tabular.

# %%
def iter_to_epoch( p,input,max_iters = max_iters):
    num_iters = int(input.shape[0]/batch_size)+1
    num_eopch = int(max_iters / num_iters)
    epoch_loss = np.zeros([num_eopch,1])
    for i in num_eopch:
        epoch_loss[i] = np.mean(p[i*num_iters:(i+1)*num_iters])
    return epoch_loss

# %%
for p in hist.keys():
    hist[p] = pd.DataFrame(hist[p],columns=losses)

# %%
for p in hist.keys():
    plt.plot(hist[p]['discriminator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Discriminator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['generator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Generator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['Q network'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Q network loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %% [markdown]
# ### For test

# %%
def test(ckpt_dir=ckpt_dir):
    
    with tf.Session(config = tf.ConfigProto(allow_soft_placement=True,log_device_placement=True)) as sess:
        # build graph
        with tf.device(device):
            gen,z_rand,z_cont,z_cat,cont_real,cont_loss_r,real_data,real_label = build_graph(is_test=True)
        
        # use saver to reload the parametes
        saver = tf.train.Saver()
        #saver.restore(sess, './Inproved_rgan/cgan_2d/Experient_1/ckpt_rgan\\model_checkpoint-17000')
        saver.restore(sess,ckpt_dir+'\\model_checkpoint-17000')
        
        ###########################################  Experiment : Generator #################
        # Gererate random labels as conditions , [0,1] gausson distribution
        z_rand_sample = np.random.normal(0,0.3,[batch_size,z_dim])
        # To construct grid sample 
        #z_cat_sample = np.reshape(np.array([int(e/batch_size*10) for e in range(batch_size)]),[batch_size,len(cat_list)])                
        z_cat_sample = np.random.normal(0,0.3,[batch_size,10])
        #z_cont_sample = np.zeros((batch_size,cont_num))
        z_cont_order = np.linspace(-1,1,batch_size)
        if cont_num>0:
            z_cont_temp = np.zeros((batch_size,cont_num-1))
            z_cont_sample = np.insert(z_cont_temp,0,z_cont_order,axis=1)
        else:
            z_cont_sample = z_cont_oder

        samples = sess.run(gen,{z_rand:z_rand_sample,z_cat:z_cat_sample,z_cont:z_cont_sample})

        save_spectrum(samples, 0,is_show=True)
        
        ############################################  Experiment : Predict ##################
        def cv_proc(y):
            y = ymid + y*(ymax-ymin)/2
            return y
        
        Hist_predict = defaultdict(list)
        # Prediction & R2 score 
        y_train_predict,y_test_predict = cv_proc(sess.run(cont_real,{real_data:x_train,real_label:y_train})),\
                                         cv_proc(sess.run(cont_real,{real_data:x_test,real_label:y_train}))
        r_train,r_test = r2_score(cv_proc(y_train),y_train_predict),r2_score(cv_proc(y_test),y_test_predict)
        # Restore
        Hist_predict['Training'] = [y_train_predict,cv_proc(y_train)]
        Hist_predict['Testing'] =  [y_test_predict ,cv_proc(y_test)]
        Hist_predict['r2_score'] = [r_train, r_test]
        
        pickle.dump(Hist_predict,open(rgan_dir+'/predict_rgan_pickle.pkl','wb'))
        
    return Hist_predict

# %%
tf.reset_default_graph()
Hist_predict = test()
# Out:
# INFO:tensorflow:Restoring parameters from ./Inproved_rgan/RGAN/Experient_10/ckpt_rgan\model_checkpoint-17000

# %%
print('r -> {:.3f} | {:.3f}'.format(*Hist_predict['r2_score']))
# Out:
# r -> 0.898 | 0.702

# %%
y_train_ = Hist_predict['Training']
x_limit = np.arange(len(y_train_[1]))
plt.figure(figsize=[10,8])
plt.plot(x_limit,y_train_[0],'b-o',x_limit,y_train_[1],'--r*',ms=4)
plt.legend(['Predict','Under Truth'])
plt.show()

# %%
y_test_ = Hist_predict['Testing']
x_limit = np.arange(len(y_test_[1]))
plt.figure(figsize=[10,8])
plt.plot(x_limit,y_test_[0],'b-o',x_limit,y_test_[1],'--r*',ms=4)
plt.legend(['Predict','Under Truth'])
plt.show()
