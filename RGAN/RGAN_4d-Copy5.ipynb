# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly

import os
import shutil
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from collections import defaultdict
import _pickle as pickle

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110

# Define salient variable
cat_list = [] # Each entry in this list defines a categorical variable for specific size
cont_num = 1 # the number of continous variables

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1

# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/RGAN/Experient_11'

log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
xmid,ymid = (xmin+xmax)/2,(ymin+ymax)/2
x,y = (x - xmid)*2/( xmax - xmin ),(y - ymid)*2/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)
y= y.reshape(-1,cont_num)

## split the dataset
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.20,random_state=0)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 1024, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = ly.fully_connected(train, 256*172, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = tf.reshape(train,(-1,256,172,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[1,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv( x ,c ,cat_list =cat_list ,cont_num =cont_num,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img_out = ly.conv2d(x,num_outputs=size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
        
        
        img = ly.conv2d(img_out,num_outputs= size*8 ,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        c = tf.tile(c,[1,int(img_dim/4)])
        c = tf.reshape(c,(batch_size,1,int(img_dim/4),1))
        img = tf.concat((c,img),axis=1)
        
        img = ly.conv2d(img ,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        
        # fully_connected
        disc_img = ly.flatten(img)
        disc_img = ly.fully_connected(disc_img,1024,activation_fn=lrelu)
        disc = ly.fully_connected(disc_img,1,activation_fn=None)
        
        # Here we difine the unique layers used for the q_network, the number of outputs 
        q_img = ly.conv2d(img_out,num_outputs= size*8,kernel_size=[10,1],stride=[1,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        q_img = ly.flatten(q_img)
        q_img = ly.fully_connected(q_img,1024,activation_fn=lrelu,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format})
        
        q_cat_outs = []
        if len(cat_list)>0:
            for idx,var in enumerate(cat_list):
                q_outA = ly.fully_connected(q_img,var, activation_fn=tf.nn.softmax)
                q_cat_outs.append(q_outA)
        
        q_cont_outs = []
        if cont_num>0:
            q_cont_outs = ly.fully_connected(q_img,cont_num,activation_fn = tf.nn.tanh)
    
    return disc, q_cat_outs, q_cont_outs

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # Real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[None,channel,img_dim,1])
    real_label = tf.placeholder(dtype = tf.float32,shape = [None,cont_num])
    # Noise ;Continous variable, and rand variable to provide some variance
    z_cont = tf.placeholder(dtype = tf.float32,shape =[None,cont_num])
    z_rand = tf.placeholder(dtype =tf.float32,shape =[None,z_dim])
    # Categorical variable
    if len(cat_list)>0:
        z_cat = tf.placeholder(dtype = tf.int32, shape=[None,len(cat_list)])
        cat_var = tf.split(z_cat , len(cat_list),axis=1)

        cat_z =[]
        for idx ,depth in enumerate(cat_list):
            cat_temp = tf.one_hot(tf.reshape(cat_var[idx],[-1]), depth)
            cat_z.append(cat_temp)
    else:
        z_cat = tf.placeholder(dtype =tf.float32,shape =[None,10])
        cat_z = [z_cat]
    # Conbine all of the variable
    z = cat_z[:]
    z.append(z_cont)
    z.append(z_rand)
    z = tf.concat( z,axis=1)
    
    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    disc_real,cat_real,cont_real = discriminator(real_data,real_label)
    disc_fake,cat_fake,cont_fake = discriminator(gen,cont_real, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
    
    # Combine losses for each of categorical variables
    if len(cat_list)>0:
        cat_losses_f =[]
        tiny = 1e-10
        for idx,var in enumerate(cat_z):
            cat_loss_f = -tf.reduce_sum(var *tf.log(cat_fake[idx]+tiny),reduction_indices=1)
            cat_losses_f.append(cat_loss_f)
            # cat_losses_r 
    else:
        cat_losses_f=cat_losses_r = tf.constant(0.0)
    # Combine losses for each of continous variables
    # MSE
    if cont_num>0:
        cont_loss_f = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_fake-z_cont),reduction_indices=1))
        cont_loss_r = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_real- real_label),reduction_indices=1))
    else:
        cont_loss_f = cont_loss_r = tf.constant(0.0)
    
    # Loss balance parameter
    alpha = 1
    q_cont_loss = cont_loss_r + alpha* cont_loss_f
    q_cat_loss = tf.constant(0.0)
    q_loss = tf.add(q_cont_loss,q_cat_loss)
    
    # Total variation loss
    tv_loss = tf.nn.l2_loss(gen[:,:,1:,:]-gen[:,:,:img_dim-1,:])/batch_size
    
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss + 1 *cont_loss_f + 0.000 * tv_loss
    loss_dis = d_loss
    loss_qnt = cont_loss_r
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    if is_test:
        return gen,z_rand,z_cont,z_cat,cont_real,cont_loss_r,real_data,real_label
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')
    theta_c = theta_d[10:]
    theta_d = theta_d[:10]

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    counter_q = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_q = optimize(loss =loss_qnt ,variables=theta_c ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_image(specs ,size,i =100,image_path = rgan_dir):
    _,ax = plt.subplots(size[0],size[1],sharex = True,sharey = True)
    for i in range(size[0]):
        for j in range(size[1]):
            ax[i][j].plot(np.arange(specs.shape[1]),specs[i*10+j] ,'-*')
    
    plt.savefig(image_path+'/'+str(i).zfill(4)+'.png')
    plt.close()

# %%
def save_spectrum(gen, i,spec_size = 10,is_show=False):
    if gen.shape[0]<spec_size:
        spec_size = gen.shape[0]

    gen = gen[:spec_size]
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,spec_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, spec_size))
    # convert data to ideal format 
    def cv_proc(x):
        x = xmid + x*(xmax-xmin)/2
        return x
        
    spec = cv_proc(gen.reshape(spec_size,img_dim))
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')    
    plt.legend([np.array_str(var) for var in np.arange(spec_size)])
    if intv ==0:
        plt.ylim([-0.5,scale])
    else:
        plt.ylim([-0.5,scale*spec_size*intv])
    
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_rgan(max_iters = 1000):
    # build graph
    with tf.device(device):
        opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,\
        loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss = build_graph()
        
    saver = tf.train.Saver()

    def next_feed_dict(iter, shuffled = True,is_test =False):
        
        # feed image and label,train set if is_test=False
        # otherwise test set
        def generate_index(input,iter,shuffled =shuffled):
            input_number = input.shape[0]
            if shuffled:
                idx = np.random.randint(input_number,size=(batch_size,))
            else:
                bat_num = int(input_number/batch_size)
                par = int(iter % bat_num)
                idx = np.arange(input_number)[par * batch_size:(par+1)*batch_size]
            return idx
        
        if is_test:
            idx = generate_index(x_test,iter)
            feed_img,feed_label = x_test[idx],y_test[idx]
        else:
            idx = generate_index(x_train,iter)
            feed_img,feed_label = x_train[idx],y_train[idx]
        
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
        if len(cat_list)>0:
            batch_z_cat  = np.random.randint(0,10,[batch_size,len(cat_list)])
        else:
            batch_z_cat = np.random.normal(0,0.3,[batch_size,10]).astype(np.float32)
        
        batch_z_cont = np.random.uniform(-1,1,[batch_size,cont_num])     
        
        feed_dict = {real_data:feed_img, 
                     z_rand : batch_z_rand,
                     z_cat  : batch_z_cat,
                     z_cont : batch_z_cont,
                     real_label:feed_label }
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        
        # use two dict-like container to record of history data
        # for analysising the result
        history = defaultdict(list)
        test_for_best = 1000
        
        for i in range(max_iters):
            
            start_time = time.time()
            ## Training Phase
            feed_dict = next_feed_dict(i)
            
            _,dLoss = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,gLoss,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            _,qLoss,qCont,qCat = sess.run([opt_q, loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['train_loss'].append([dLoss,gLoss,qLoss,qCont,qCat])
            
            ## Testing Phase
            feed_dict = next_feed_dict(i,is_test=True)
        
            dLoss_ = sess.run(loss_dis,feed_dict = feed_dict)
            gLoss_ = sess.run(loss_gen,feed_dict = feed_dict)
            qLoss_ ,qCont_ ,qCat_ = sess.run([loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['test_loss'].append([dLoss_ ,gLoss_ ,qLoss_ ,qCont_ ,qCat_])
            
            if qLoss_< test_for_best:
                test_for_best = qLoss_
                saver.save(sess, os.path.join(ckpt_dir,'model_checkpoint_for_test'),global_step=i)
             
            if i % 100 == 0:
                elapse = time.time() - start_time
                time_left = (max_iters-i-1)* elapse
                print('\nIteration: {:0>5d}({:0.2%}) of {} \t Time left:{:02d}:{:02d}:{:02d}'.format(i,i/max_iters,max_iters,\
                     int(time_left/3600),int(time_left%3600/60),int(time_left%60)))
                
                print('{0:<8s} | {1:<15s} | {2:<15s} | {3:<15s} | {4:<15s} | {5:<15s}'\
                    .format('Loss','generator','discriminator','Q network','Q_continous','Q_categorical'))
                print('-' * 98)
                row_fmt = '{0:<8s} | {1:<15.3f} | {2:<15.3f} | {3:<15.3f} | {4:<15.3f} | {5:<15.3f}'
                print(row_fmt.format('train',*history['train_loss'][-1]))
                print(row_fmt.format('test' ,*history['test_loss'][-1]))
                save_spectrum(spec, i)
                
        

            if i %1000 ==0:
                saver.save(sess, os.path.join(ckpt_dir,'model_checkpoint'),global_step=i)
            
        pickle.dump(history,open(rgan_dir+'/rgan_pickle.pkl','wb'))

# %%
tf.reset_default_graph()
max_iters = 20000
train_rgan(max_iters =max_iters)
# Out:
# Iteration: 00000(0.00%) of 20000 	 Time left:51:41:14
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.092          | 0.403           | 0.071           | 0.361           | 0.000
# test     | -1.014          | -0.789          | 0.313           | 0.532           | 0.000
#
# Iteration: 00100(0.50%) of 20000 	 Time left:01:17:36
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -100.704        | -269.980        | 0.073           | 0.286           | 0.000
# test     | -108.717        | -272.786        | 0.095           | 0.279           | 0.000
#
# Iteration: 00200(1.00%) of 20000 	 Time left:01:17:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -317.110        | 88.082          | 0.030           | 0.388           | 0.000
# test     | -317.827        | 71.871          | 0.041           | 0.424           | 0.000
#
# Iteration: 00300(1.50%) of 20000 	 Time left:01:16:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -161.657        | -69.047         | 0.043           | 0.239           | 0.000
# test     | -157.766        | -95.938         | 0.091           | 0.337           | 0.000
#
# Iteration: 00400(2.00%) of 20000 	 Time left:01:16:26
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -123.368        | 129.767         | 0.053           | 0.114           | 0.000
# test     | -91.352         | 116.806         | 0.043           | 0.131           | 0.000
#
# Iteration: 00500(2.50%) of 20000 	 Time left:01:16:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -29.600         | 95.546          | 0.035           | 0.150           | 0.000
# test     | -27.188         | 88.907          | 0.049           | 0.199           | 0.000
#
# Iteration: 00600(3.00%) of 20000 	 Time left:01:15:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.513           | 31.506          | 0.024           | 0.068           | 0.000
# test     | 4.773           | 31.104          | 0.035           | 0.104           | 0.000
#
# Iteration: 00700(3.50%) of 20000 	 Time left:01:15:15
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -16.575         | 11.148          | 0.018           | 0.082           | 0.000
# test     | -21.813         | 9.769           | 0.034           | 0.080           | 0.000
#
# Iteration: 00800(4.00%) of 20000 	 Time left:01:14:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -110.149        | -52.950         | 0.033           | 0.134           | 0.000
# test     | -128.360        | -73.515         | 0.051           | 0.163           | 0.000
#
# Iteration: 00900(4.50%) of 20000 	 Time left:01:14:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.507          | 35.081          | 0.024           | 0.034           | 0.000
# test     | -8.689          | 34.195          | 0.017           | 0.040           | 0.000
#
# Iteration: 01000(5.00%) of 20000 	 Time left:01:19:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.567          | 100.676         | 0.042           | 0.110           | 0.000
# test     | -8.077          | 97.266          | 0.037           | 0.052           | 0.000
#
# Iteration: 01100(5.50%) of 20000 	 Time left:01:13:42
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -57.598         | -2.050          | 0.028           | 0.157           | 0.000
# test     | -64.300         | -8.815          | 0.023           | 0.139           | 0.000
#
# Iteration: 01200(6.00%) of 20000 	 Time left:01:18:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.390          | 121.775         | 0.022           | 0.036           | 0.000
# test     | -0.369          | 121.734         | 0.023           | 0.033           | 0.000
#
# Iteration: 01300(6.50%) of 20000 	 Time left:01:17:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.465          | 84.862          | 0.013           | 0.027           | 0.000
# test     | -7.592          | 83.655          | 0.047           | 0.068           | 0.000
#
# Iteration: 01400(7.00%) of 20000 	 Time left:01:12:32
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.621           | 63.293          | 0.017           | 0.030           | 0.000
# test     | 0.663           | 62.828          | 0.030           | 0.042           | 0.000
#
# Iteration: 01500(7.50%) of 20000 	 Time left:01:12:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.019          | 96.212          | 0.009           | 0.021           | 0.000
# test     | -6.862          | 95.778          | 0.031           | 0.057           | 0.000
#
# Iteration: 01600(8.00%) of 20000 	 Time left:01:11:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -62.552         | 24.059          | 0.010           | 0.044           | 0.000
# test     | -68.688         | 22.563          | 0.029           | 0.062           | 0.000
#
# Iteration: 01700(8.50%) of 20000 	 Time left:01:16:07
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.025         | 105.573         | 0.012           | 0.032           | 0.000
# test     | -19.066         | 104.852         | 0.036           | 0.084           | 0.000
#
# Iteration: 01800(9.00%) of 20000 	 Time left:01:10:58
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -39.778         | -45.321         | 0.006           | 0.015           | 0.000
# test     | -32.889         | -51.690         | 0.032           | 0.042           | 0.000
#
# Iteration: 01900(9.50%) of 20000 	 Time left:01:10:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -26.062         | 145.836         | 0.010           | 0.030           | 0.000
# test     | -27.345         | 143.997         | 0.021           | 0.035           | 0.000
#
# Iteration: 02000(10.00%) of 20000 	 Time left:01:10:11
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -21.425         | 12.013          | 0.011           | 0.033           | 0.000
# test     | -43.148         | 8.711           | 0.022           | 0.052           | 0.000
#
# Iteration: 02100(10.50%) of 20000 	 Time left:01:09:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -38.328         | 32.948          | 0.015           | 0.035           | 0.000
# test     | -48.868         | 32.017          | 0.034           | 0.065           | 0.000
#
# Iteration: 02200(11.00%) of 20000 	 Time left:01:09:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.430         | 80.810          | 0.008           | 0.043           | 0.000
# test     | -14.164         | 80.080          | 0.015           | 0.061           | 0.000
#
# Iteration: 02300(11.50%) of 20000 	 Time left:01:09:01
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -42.496         | -34.615         | 0.006           | 0.142           | 0.000
# test     | -48.026         | -37.460         | 0.027           | 0.107           | 0.000
#
# Iteration: 02400(12.00%) of 20000 	 Time left:01:08:38
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -67.892         | -18.731         | 0.009           | 0.059           | 0.000
# test     | -72.141         | -28.678         | 0.024           | 0.062           | 0.000
#
# Iteration: 02500(12.50%) of 20000 	 Time left:01:08:14
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -200.840        | 131.883         | 0.005           | 0.060           | 0.000
# test     | -228.966        | 123.168         | 0.027           | 0.124           | 0.000
#
# Iteration: 02600(13.00%) of 20000 	 Time left:01:12:22
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 32.215          | -177.250        | 0.006           | 0.050           | 0.000
# test     | 32.755          | -192.175        | 0.027           | 0.062           | 0.000
#
# Iteration: 02700(13.50%) of 20000 	 Time left:01:07:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 29.883          | -59.349         | 0.010           | 0.244           | 0.000
# test     | 35.035          | -63.661         | 0.022           | 0.320           | 0.000
#
# Iteration: 02800(14.00%) of 20000 	 Time left:01:11:32
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -36.909         | 6.878           | 0.011           | 0.205           | 0.000
# test     | -45.533         | 3.179           | 0.018           | 0.173           | 0.000
#
# Iteration: 02900(14.50%) of 20000 	 Time left:01:06:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -44.535         | -15.281         | 0.031           | 0.137           | 0.000
# test     | -19.224         | -32.728         | 0.022           | 0.111           | 0.000
#
# Iteration: 03000(15.00%) of 20000 	 Time left:01:06:17
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -60.953         | -18.365         | 0.005           | 0.039           | 0.000
# test     | -67.841         | -19.659         | 0.028           | 0.175           | 0.000
#
# Iteration: 03100(15.50%) of 20000 	 Time left:01:05:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 4.896           | -212.509        | 0.003           | 0.037           | 0.000
# test     | 4.872           | -215.664        | 0.039           | 0.072           | 0.000
#
# Iteration: 03200(16.00%) of 20000 	 Time left:01:09:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -27.034         | -104.623        | 0.004           | 0.046           | 0.000
# test     | -30.846         | -106.339        | 0.032           | 0.079           | 0.000
#
# Iteration: 03300(16.50%) of 20000 	 Time left:01:09:28
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -46.886         | -25.810         | 0.007           | 0.038           | 0.000
# test     | -45.465         | -30.550         | 0.037           | 0.067           | 0.000
#
# Iteration: 03400(17.00%) of 20000 	 Time left:01:04:44
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -28.511         | 169.062         | 0.004           | 0.011           | 0.000
# test     | -28.625         | 166.750         | 0.031           | 0.038           | 0.000
#
# Iteration: 03500(17.50%) of 20000 	 Time left:01:04:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -78.501         | 292.931         | 0.009           | 0.088           | 0.000
# test     | -85.065         | 291.251         | 0.023           | 0.070           | 0.000
#
# Iteration: 03600(18.00%) of 20000 	 Time left:01:08:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.037         | 67.488          | 0.006           | 0.034           | 0.000
# test     | -21.890         | 67.052          | 0.020           | 0.042           | 0.000
#
# Iteration: 03700(18.50%) of 20000 	 Time left:01:03:33
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.494           | -64.955         | 0.012           | 0.040           | 0.000
# test     | 2.893           | -65.364         | 0.022           | 0.061           | 0.000
#
# Iteration: 03800(19.00%) of 20000 	 Time left:01:07:23
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -47.511         | -79.512         | 0.007           | 0.019           | 0.000
# test     | -41.868         | -91.077         | 0.054           | 0.065           | 0.000
#
# Iteration: 03900(19.50%) of 20000 	 Time left:01:02:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.482         | -49.510         | 0.008           | 0.022           | 0.000
# test     | -13.503         | -51.798         | 0.028           | 0.035           | 0.000
#
# Iteration: 04000(20.00%) of 20000 	 Time left:01:06:33
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.158           | -17.746         | 0.005           | 0.093           | 0.000
# test     | 3.437           | -19.267         | 0.028           | 0.084           | 0.000
#
# Iteration: 04100(20.50%) of 20000 	 Time left:01:02:00
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -40.302         | 107.832         | 0.007           | 0.038           | 0.000
# test     | -43.178         | 105.655         | 0.044           | 0.083           | 0.000
#
# Iteration: 04200(21.00%) of 20000 	 Time left:01:01:36
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.920           | 27.388          | 0.007           | 0.028           | 0.000
# test     | -2.364          | 26.974          | 0.017           | 0.042           | 0.000
#
# Iteration: 04300(21.50%) of 20000 	 Time left:01:01:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 7.596           | 177.860         | 0.006           | 0.049           | 0.000
# test     | 8.527           | 177.469         | 0.018           | 0.045           | 0.000
#
# Iteration: 04400(22.00%) of 20000 	 Time left:01:00:50
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.595          | 98.780          | 0.004           | 0.017           | 0.000
# test     | -9.041          | 98.445          | 0.028           | 0.060           | 0.000
#
# Iteration: 04500(22.50%) of 20000 	 Time left:01:04:28
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.859          | 109.562         | 0.004           | 0.039           | 0.000
# test     | -10.024         | 108.589         | 0.027           | 0.045           | 0.000
#
# Iteration: 04600(23.00%) of 20000 	 Time left:01:00:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.385          | 94.688          | 0.005           | 0.084           | 0.000
# test     | -2.443          | 93.997          | 0.031           | 0.084           | 0.000
#
# Iteration: 04700(23.50%) of 20000 	 Time left:00:59:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.312          | 106.604         | 0.016           | 0.050           | 0.000
# test     | -7.176          | 106.233         | 0.024           | 0.038           | 0.000
#
# Iteration: 04800(24.00%) of 20000 	 Time left:00:59:16
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.021          | 120.433         | 0.007           | 0.019           | 0.000
# test     | -2.741          | 120.370         | 0.035           | 0.075           | 0.000
#
# Iteration: 04900(24.50%) of 20000 	 Time left:00:58:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.373          | 145.861         | 0.006           | 0.014           | 0.000
# test     | -1.675          | 145.720         | 0.018           | 0.027           | 0.000
#
# Iteration: 05000(25.00%) of 20000 	 Time left:00:58:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.925          | 139.129         | 0.006           | 0.023           | 0.000
# test     | -2.490          | 139.156         | 0.030           | 0.052           | 0.000
#
# Iteration: 05100(25.50%) of 20000 	 Time left:00:58:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.018           | 99.244          | 0.006           | 0.032           | 0.000
# test     | 1.785           | 98.654          | 0.027           | 0.049           | 0.000
#
# Iteration: 05200(26.00%) of 20000 	 Time left:00:57:42
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -16.175         | 103.853         | 0.004           | 0.034           | 0.000
# test     | -17.428         | 103.232         | 0.031           | 0.057           | 0.000
#
# Iteration: 05300(26.50%) of 20000 	 Time left:00:57:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.760          | 99.551          | 0.002           | 0.020           | 0.000
# test     | -5.885          | 99.339          | 0.020           | 0.052           | 0.000
#
# Iteration: 05400(27.00%) of 20000 	 Time left:00:56:56
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.684          | -216.514        | 0.012           | 0.041           | 0.000
# test     | -4.687          | -216.524        | 0.024           | 0.040           | 0.000
#
# Iteration: 05500(27.50%) of 20000 	 Time left:00:56:32
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -93.424         | -125.317        | 0.011           | 0.098           | 0.000
# test     | -102.992        | -139.983        | 0.023           | 0.112           | 0.000
#
# Iteration: 05600(28.00%) of 20000 	 Time left:00:56:09
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -30.717         | 142.569         | 0.008           | 0.061           | 0.000
# test     | -35.486         | 141.776         | 0.024           | 0.080           | 0.000
#
# Iteration: 05700(28.50%) of 20000 	 Time left:00:55:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -269.867        | 198.686         | 0.004           | 0.248           | 0.000
# test     | -356.618        | 165.606         | 0.034           | 0.384           | 0.000
#
# Iteration: 05800(29.00%) of 20000 	 Time left:00:55:22
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -68.204         | 91.726          | 0.005           | 0.056           | 0.000
# test     | -75.201         | 89.833          | 0.041           | 0.142           | 0.000
#
# Iteration: 05900(29.50%) of 20000 	 Time left:00:54:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -64.699         | 95.272          | 0.011           | 0.079           | 0.000
# test     | -72.579         | 89.026          | 0.026           | 0.157           | 0.000
#
# Iteration: 06000(30.00%) of 20000 	 Time left:00:54:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.870          | -6.822          | 0.009           | 0.018           | 0.000
# test     | -8.348          | -9.305          | 0.024           | 0.060           | 0.000
#
# Iteration: 06100(30.50%) of 20000 	 Time left:00:54:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -27.897         | -3.674          | 0.003           | 0.068           | 0.000
# test     | -33.836         | -4.159          | 0.016           | 0.047           | 0.000
#
# Iteration: 06200(31.00%) of 20000 	 Time left:00:53:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -77.463         | 31.598          | 0.003           | 0.074           | 0.000
# test     | -76.710         | 8.684           | 0.024           | 0.069           | 0.000
#
# Iteration: 06300(31.50%) of 20000 	 Time left:00:56:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -80.910         | 113.336         | 0.005           | 0.080           | 0.000
# test     | -71.288         | 52.215          | 0.039           | 0.125           | 0.000
#
# Iteration: 06400(32.00%) of 20000 	 Time left:00:53:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -118.198        | 164.983         | 0.007           | 0.021           | 0.000
# test     | -118.886        | 161.106         | 0.028           | 0.052           | 0.000
#
# Iteration: 06500(32.50%) of 20000 	 Time left:00:52:38
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -66.348         | -138.497        | 0.007           | 0.087           | 0.000
# test     | -78.804         | -143.144        | 0.033           | 0.075           | 0.000
#
# Iteration: 06600(33.00%) of 20000 	 Time left:00:52:15
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.504          | -100.898        | 0.003           | 0.045           | 0.000
# test     | 0.626           | -105.065        | 0.039           | 0.073           | 0.000
#
# Iteration: 06700(33.50%) of 20000 	 Time left:00:51:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 10.450          | -14.175         | 0.006           | 0.038           | 0.000
# test     | 11.625          | -18.257         | 0.034           | 0.060           | 0.000
#
# Iteration: 06800(34.00%) of 20000 	 Time left:00:51:28
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -96.381         | 27.519          | 0.005           | 0.041           | 0.000
# test     | -118.212        | 19.949          | 0.033           | 0.062           | 0.000
#
# Iteration: 06900(34.50%) of 20000 	 Time left:00:54:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -94.671         | 24.685          | 0.010           | 0.021           | 0.000
# test     | -99.129         | 19.300          | 0.024           | 0.039           | 0.000
#
# Iteration: 07000(35.00%) of 20000 	 Time left:00:50:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.920         | -92.666         | 0.013           | 0.034           | 0.000
# test     | -26.648         | -93.537         | 0.047           | 0.075           | 0.000
#
# Iteration: 07100(35.50%) of 20000 	 Time left:00:50:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.041           | -38.533         | 0.008           | 0.017           | 0.000
# test     | -0.294          | -39.853         | 0.019           | 0.031           | 0.000
#
# Iteration: 07200(36.00%) of 20000 	 Time left:00:49:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.223          | 88.197          | 0.004           | 0.049           | 0.000
# test     | -9.094          | 87.659          | 0.030           | 0.057           | 0.000
#
# Iteration: 07300(36.50%) of 20000 	 Time left:00:49:31
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -43.762         | -12.335         | 0.008           | 0.044           | 0.000
# test     | -48.994         | -16.249         | 0.022           | 0.050           | 0.000
#
# Iteration: 07400(37.00%) of 20000 	 Time left:00:52:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -67.587         | -16.431         | 0.003           | 0.023           | 0.000
# test     | -75.990         | -21.296         | 0.028           | 0.055           | 0.000
#
# Iteration: 07500(37.50%) of 20000 	 Time left:00:48:44
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -81.379         | 125.069         | 0.007           | 0.032           | 0.000
# test     | -90.725         | 124.691         | 0.031           | 0.063           | 0.000
#
# Iteration: 07600(38.00%) of 20000 	 Time left:00:51:34
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.354           | -11.655         | 0.013           | 0.094           | 0.000
# test     | 5.034           | -11.694         | 0.048           | 0.154           | 0.000
#
# Iteration: 07700(38.50%) of 20000 	 Time left:00:47:57
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -27.249         | -147.503        | 0.006           | 0.039           | 0.000
# test     | -28.518         | -148.855        | 0.029           | 0.046           | 0.000
#
# Iteration: 07800(39.00%) of 20000 	 Time left:00:50:44
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -53.253         | 51.279          | 0.001           | 0.046           | 0.000
# test     | -53.266         | 31.761          | 0.033           | 0.042           | 0.000
#
# Iteration: 07900(39.50%) of 20000 	 Time left:00:47:11
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 10.114          | -188.473        | 0.006           | 0.062           | 0.000
# test     | 9.673           | -189.461        | 0.019           | 0.044           | 0.000
#
# Iteration: 08000(40.00%) of 20000 	 Time left:00:46:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -28.048         | -62.529         | 0.006           | 0.087           | 0.000
# test     | -30.991         | -64.740         | 0.032           | 0.072           | 0.000
#
# Iteration: 08100(40.50%) of 20000 	 Time left:00:46:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.162           | 13.374          | 0.003           | 0.053           | 0.000
# test     | -1.017          | 13.157          | 0.024           | 0.147           | 0.000
#
# Iteration: 08200(41.00%) of 20000 	 Time left:00:46:00
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -33.594         | -7.468          | 0.010           | 0.034           | 0.000
# test     | -16.166         | -18.221         | 0.022           | 0.049           | 0.000
#
# Iteration: 08300(41.50%) of 20000 	 Time left:00:45:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 11.250          | 58.496          | 0.003           | 0.030           | 0.000
# test     | 5.119           | 58.521          | 0.019           | 0.064           | 0.000
#
# Iteration: 08400(42.00%) of 20000 	 Time left:00:48:15
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -63.268         | 96.233          | 0.002           | 0.043           | 0.000
# test     | -71.788         | 94.246          | 0.027           | 0.074           | 0.000
#
# Iteration: 08500(42.50%) of 20000 	 Time left:00:44:50
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 10.958          | 131.223         | 0.003           | 0.090           | 0.000
# test     | 11.829          | 130.514         | 0.050           | 0.151           | 0.000
#
# Iteration: 08600(43.00%) of 20000 	 Time left:00:47:25
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -39.718         | 132.878         | 0.007           | 0.060           | 0.000
# test     | -44.832         | 130.021         | 0.033           | 0.066           | 0.000
#
# Iteration: 08700(43.50%) of 20000 	 Time left:00:47:00
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -88.137         | 107.660         | 0.002           | 0.042           | 0.000
# test     | -89.056         | 99.503          | 0.024           | 0.061           | 0.000
#
# Iteration: 08800(44.00%) of 20000 	 Time left:00:46:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -27.555         | -140.289        | 0.005           | 0.068           | 0.000
# test     | -15.323         | -163.780        | 0.023           | 0.058           | 0.000
#
# Iteration: 08900(44.50%) of 20000 	 Time left:00:46:10
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 10.514          | 32.530          | 0.002           | 0.042           | 0.000
# test     | 9.379           | 32.324          | 0.021           | 0.071           | 0.000
#
# Iteration: 09000(45.00%) of 20000 	 Time left:00:42:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.964          | 18.069          | 0.003           | 0.037           | 0.000
# test     | -2.888          | 17.613          | 0.040           | 0.054           | 0.000
#
# Iteration: 09100(45.50%) of 20000 	 Time left:00:42:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.589         | -32.751         | 0.006           | 0.020           | 0.000
# test     | -8.574          | -34.767         | 0.032           | 0.045           | 0.000
#
# Iteration: 09200(46.00%) of 20000 	 Time left:00:42:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -41.352         | 191.708         | 0.002           | 0.022           | 0.000
# test     | -40.894         | 188.644         | 0.023           | 0.040           | 0.000
#
# Iteration: 09300(46.50%) of 20000 	 Time left:00:41:43
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 4.087           | -84.399         | 0.003           | 0.041           | 0.000
# test     | 2.034           | -84.547         | 0.020           | 0.036           | 0.000
#
# Iteration: 09400(47.00%) of 20000 	 Time left:00:41:20
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -87.500         | 23.180          | 0.001           | 0.024           | 0.000
# test     | -106.911        | 18.977          | 0.026           | 0.058           | 0.000
#
# Iteration: 09500(47.50%) of 20000 	 Time left:00:40:56
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.028          | -203.364        | 0.004           | 0.072           | 0.000
# test     | -6.309          | -208.752        | 0.026           | 0.049           | 0.000
#
# Iteration: 09600(48.00%) of 20000 	 Time left:00:43:15
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.772         | 190.014         | 0.005           | 0.067           | 0.000
# test     | -19.231         | 189.343         | 0.027           | 0.136           | 0.000
#
# Iteration: 09700(48.50%) of 20000 	 Time left:00:40:09
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.892         | 68.337          | 0.002           | 0.058           | 0.000
# test     | -26.706         | 66.324          | 0.022           | 0.089           | 0.000
#
# Iteration: 09800(49.00%) of 20000 	 Time left:00:39:46
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.513         | 17.495          | 0.007           | 0.073           | 0.000
# test     | -15.760         | 16.869          | 0.029           | 0.065           | 0.000
#
# Iteration: 09900(49.50%) of 20000 	 Time left:00:39:23
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.268          | 151.689         | 0.011           | 0.083           | 0.000
# test     | -1.811          | 151.590         | 0.030           | 0.063           | 0.000
#
# Iteration: 10000(50.00%) of 20000 	 Time left:00:38:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.352         | 246.716         | 0.003           | 0.047           | 0.000
# test     | -20.787         | 246.823         | 0.028           | 0.063           | 0.000
#
# Iteration: 10100(50.50%) of 20000 	 Time left:00:38:36
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -32.525         | 48.503          | 0.004           | 0.022           | 0.000
# test     | -32.110         | 45.162          | 0.026           | 0.039           | 0.000
#
# Iteration: 10200(51.00%) of 20000 	 Time left:00:40:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -33.054         | 60.149          | 0.004           | 0.039           | 0.000
# test     | -37.855         | 60.884          | 0.030           | 0.056           | 0.000
#
# Iteration: 10300(51.50%) of 20000 	 Time left:00:37:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.255         | -135.896        | 0.002           | 0.110           | 0.000
# test     | -21.054         | -135.865        | 0.032           | 0.150           | 0.000
#
# Iteration: 10400(52.00%) of 20000 	 Time left:00:37:26
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -37.618         | -171.247        | 0.010           | 0.045           | 0.000
# test     | -29.058         | -176.331        | 0.025           | 0.042           | 0.000
#
# Iteration: 10500(52.50%) of 20000 	 Time left:00:37:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -54.297         | -127.450        | 0.005           | 0.030           | 0.000
# test     | -57.925         | -131.613        | 0.018           | 0.046           | 0.000
#
# Iteration: 10600(53.00%) of 20000 	 Time left:00:36:39
# ...
# test     | 35.783          | -259.949        | 0.020           | 0.081           | 0.000
#
# Iteration: 16500(82.50%) of 20000 	 Time left:00:13:38
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.977         | 103.775         | 0.005           | 0.019           | 0.000
# test     | -12.027         | 103.939         | 0.018           | 0.056           | 0.000
#
# Iteration: 16600(83.00%) of 20000 	 Time left:00:13:15
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.848         | -50.386         | 0.001           | 0.006           | 0.000
# test     | -27.074         | -55.072         | 0.023           | 0.046           | 0.000
#
# Iteration: 16700(83.50%) of 20000 	 Time left:00:12:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -48.918         | -123.193        | 0.003           | 0.047           | 0.000
# test     | -45.143         | -127.187        | 0.028           | 0.040           | 0.000
#
# Iteration: 16800(84.00%) of 20000 	 Time left:00:14:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.710          | 120.874         | 0.010           | 0.024           | 0.000
# test     | -5.888          | 121.525         | 0.025           | 0.049           | 0.000
#
# Iteration: 16900(84.50%) of 20000 	 Time left:00:12:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 4.813           | 95.884          | 0.004           | 0.035           | 0.000
# test     | 4.763           | 95.829          | 0.030           | 0.043           | 0.000
#
# Iteration: 17000(85.00%) of 20000 	 Time left:00:11:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.865           | 45.497          | 0.007           | 0.018           | 0.000
# test     | 2.419           | 47.846          | 0.035           | 0.040           | 0.000
#
# Iteration: 17100(85.50%) of 20000 	 Time left:00:11:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.131           | 27.318          | 0.009           | 0.032           | 0.000
# test     | 1.431           | 27.428          | 0.020           | 0.033           | 0.000
#
# Iteration: 17200(86.00%) of 20000 	 Time left:00:10:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.692         | -31.437         | 0.005           | 0.035           | 0.000
# test     | -5.707          | -31.261         | 0.023           | 0.037           | 0.000
#
# Iteration: 17300(86.50%) of 20000 	 Time left:00:11:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 9.503           | -210.834        | 0.004           | 0.041           | 0.000
# test     | -2.211          | -211.684        | 0.023           | 0.035           | 0.000
#
# Iteration: 17400(87.00%) of 20000 	 Time left:00:10:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.532           | -12.608         | 0.006           | 0.027           | 0.000
# test     | 5.451           | -12.809         | 0.017           | 0.056           | 0.000
#
# Iteration: 17500(87.50%) of 20000 	 Time left:00:10:23
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.902          | 11.603          | 0.004           | 0.030           | 0.000
# test     | -8.411          | 11.376          | 0.041           | 0.048           | 0.000
#
# Iteration: 17600(88.00%) of 20000 	 Time left:00:09:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.935          | 14.998          | 0.002           | 0.019           | 0.000
# test     | -3.982          | 13.273          | 0.045           | 0.060           | 0.000
#
# Iteration: 17700(88.50%) of 20000 	 Time left:00:08:57
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.934          | 6.581           | 0.004           | 0.027           | 0.000
# test     | -4.568          | 7.046           | 0.030           | 0.052           | 0.000
#
# Iteration: 17800(89.00%) of 20000 	 Time left:00:08:34
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.123          | 133.719         | 0.001           | 0.008           | 0.000
# test     | -3.994          | 133.280         | 0.017           | 0.040           | 0.000
#
# Iteration: 17900(89.50%) of 20000 	 Time left:00:08:11
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -69.755         | 220.454         | 0.004           | 0.024           | 0.000
# test     | -75.532         | 208.565         | 0.026           | 0.043           | 0.000
#
# Iteration: 18000(90.00%) of 20000 	 Time left:00:07:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -56.600         | -107.088        | 0.002           | 0.045           | 0.000
# test     | -56.506         | -112.986        | 0.018           | 0.034           | 0.000
#
# Iteration: 18100(90.50%) of 20000 	 Time left:00:07:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -82.758         | -1.725          | 0.003           | 0.043           | 0.000
# test     | -105.896        | -33.251         | 0.037           | 0.095           | 0.000
#
# Iteration: 18200(91.00%) of 20000 	 Time left:00:07:00
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.755          | 7.092           | 0.009           | 0.095           | 0.000
# test     | -8.014          | 0.331           | 0.035           | 0.137           | 0.000
#
# Iteration: 18300(91.50%) of 20000 	 Time left:00:06:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 13.111          | 145.719         | 0.015           | 0.063           | 0.000
# test     | 11.903          | 144.167         | 0.016           | 0.050           | 0.000
#
# Iteration: 18400(92.00%) of 20000 	 Time left:00:06:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.879         | -127.299        | 0.002           | 0.021           | 0.000
# test     | -30.890         | -128.689        | 0.021           | 0.044           | 0.000
#
# Iteration: 18500(92.50%) of 20000 	 Time left:00:06:14
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.815         | 22.745          | 0.002           | 0.044           | 0.000
# test     | -14.100         | 20.545          | 0.034           | 0.084           | 0.000
#
# Iteration: 18600(93.00%) of 20000 	 Time left:00:05:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 4.569           | -13.588         | 0.004           | 0.030           | 0.000
# test     | -4.544          | -14.751         | 0.032           | 0.067           | 0.000
#
# Iteration: 18700(93.50%) of 20000 	 Time left:00:05:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.614           | 3.754           | 0.002           | 0.041           | 0.000
# test     | 1.383           | 3.099           | 0.032           | 0.060           | 0.000
#
# Iteration: 18800(94.00%) of 20000 	 Time left:00:04:40
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.261          | -167.006        | 0.003           | 0.022           | 0.000
# test     | -4.243          | -166.877        | 0.021           | 0.068           | 0.000
#
# Iteration: 18900(94.50%) of 20000 	 Time left:00:04:17
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.230          | -217.033        | 0.001           | 0.031           | 0.000
# test     | 31.850          | -239.604        | 0.062           | 0.084           | 0.000
#
# Iteration: 19000(95.00%) of 20000 	 Time left:00:03:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.211           | -273.237        | 0.002           | 0.025           | 0.000
# test     | -42.188         | -278.975        | 0.031           | 0.048           | 0.000
#
# Iteration: 19100(95.50%) of 20000 	 Time left:00:03:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -54.053         | 70.250          | 0.008           | 0.047           | 0.000
# test     | -59.949         | 69.771          | 0.036           | 0.057           | 0.000
#
# Iteration: 19200(96.00%) of 20000 	 Time left:00:03:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.364           | -34.535         | 0.001           | 0.069           | 0.000
# test     | 10.075          | -39.537         | 0.024           | 0.122           | 0.000
#
# Iteration: 19300(96.50%) of 20000 	 Time left:00:02:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -83.055         | -39.873         | 0.004           | 0.091           | 0.000
# test     | -105.189        | -50.428         | 0.026           | 0.125           | 0.000
#
# Iteration: 19400(97.00%) of 20000 	 Time left:00:02:10
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.104          | -3.428          | 0.003           | 0.030           | 0.000
# test     | -0.248          | -3.475          | 0.023           | 0.052           | 0.000
#
# Iteration: 19500(97.50%) of 20000 	 Time left:00:02:04
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.088          | 0.509           | 0.003           | 0.020           | 0.000
# test     | -1.392          | 0.663           | 0.020           | 0.058           | 0.000
#
# Iteration: 19600(98.00%) of 20000 	 Time left:00:01:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.001          | -2.831          | 0.004           | 0.023           | 0.000
# test     | -0.950          | -2.806          | 0.026           | 0.053           | 0.000
#
# Iteration: 19700(98.50%) of 20000 	 Time left:00:01:09
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.703          | -5.766          | 0.002           | 0.013           | 0.000
# test     | -1.863          | -5.726          | 0.030           | 0.042           | 0.000
#
# Iteration: 19800(99.00%) of 20000 	 Time left:00:00:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.617          | -7.109          | 0.002           | 0.009           | 0.000
# test     | -2.799          | -7.035          | 0.044           | 0.055           | 0.000
#
# Iteration: 19900(99.50%) of 20000 	 Time left:00:00:23
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.526          | -8.076          | 0.002           | 0.019           | 0.000
# test     | -1.696          | -8.307          | 0.018           | 0.054           | 0.000

# %% [markdown]
# ### Show the result

# %%
hist = pickle.load(open(rgan_dir+'/rgan_pickle.pkl','rb'))

# %%
losses = ['generator','discriminator','Q network','Q_continous','Q_categorical']

# %% [markdown]
# Use pandas to realize the two demensional dict-like tabular.

# %%
def iter_to_epoch( p,input,max_iters = max_iters):
    num_iters = int(input.shape[0]/batch_size)+1
    num_eopch = int(max_iters / num_iters)
    epoch_loss = np.zeros([num_eopch,1])
    for i in num_eopch:
        epoch_loss[i] = np.mean(p[i*num_iters:(i+1)*num_iters])
    return epoch_loss

# %%
for p in hist.keys():
    hist[p] = pd.DataFrame(hist[p],columns=losses)

# %%
for p in hist.keys():
    plt.plot(hist[p]['discriminator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Discriminator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['generator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Generator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['Q network'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Q network loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %% [markdown]
# ### For test Phase

# %%
def test(ckpt_dir=ckpt_dir):
    
    with tf.Session(config = tf.ConfigProto(allow_soft_placement=True,log_device_placement=True)) as sess:
        # build graph
        with tf.device(device):
            gen,z_rand,z_cont,z_cat,cont_real,cont_loss_r,real_data,real_label = build_graph(is_test=True)
        
        # use saver to reload the parametes
        saver = tf.train.Saver()
        
        #saver.restore(sess,ckpt_dir+'\\model_checkpoint-19000')
        saver.restore(sess,tf.train.latest_checkpoint(ckpt_dir))
        
        #for testing error
        #saver.restore(sess, ckpt_dir+'\\model_checkpoint_for_test-18607')
        
        ###########################################  Experiment : Generator #################
        # Gererate random labels as conditions , [0,1] gausson distribution
        z_rand_sample = np.random.normal(0,0.3,[batch_size,z_dim])
        # To construct grid sample 
        #z_cat_sample = np.reshape(np.array([int(e/batch_size*10) for e in range(batch_size)]),[batch_size,len(cat_list)])                
        z_cat_sample = np.random.normal(0,0.3,[batch_size,10])
        #z_cont_sample = np.zeros((batch_size,cont_num))
        z_cont_order = np.linspace(-1,1,batch_size)
        if cont_num>0:
            z_cont_temp = np.zeros((batch_size,cont_num-1))
            z_cont_sample = np.insert(z_cont_temp,0,z_cont_order,axis=1)
        else:
            z_cont_sample = z_cont_oder

        samples = sess.run(gen,{z_rand:z_rand_sample,z_cat:z_cat_sample,z_cont:z_cont_sample})

        save_spectrum(samples, 0,is_show=True)
        
        ############################################  Experiment : Predict ##################
        def cv_proc(y):
            y = ymid + y*(ymax-ymin)/2
            return y
        
        Hist_predict = defaultdict(list)
        # Prediction & R2 score 
        y_train_predict,y_test_predict = cv_proc(sess.run(cont_real,{real_data:x_train,real_label:y_train})),\
                                         cv_proc(sess.run(cont_real,{real_data:x_test,real_label:y_train}))
        r_train,r_test = r2_score(cv_proc(y_train),y_train_predict),r2_score(cv_proc(y_test),y_test_predict)
        # Restore
        Hist_predict['Training'] = [y_train_predict,cv_proc(y_train)]
        Hist_predict['Testing'] =  [y_test_predict ,cv_proc(y_test)]
        Hist_predict['r2_score'] = [r_train, r_test]
        
        pickle.dump(Hist_predict,open(rgan_dir+'/predict_rgan_pickle.pkl','wb'))
        
    return Hist_predict

# %%
tf.reset_default_graph()
Hist_predict = test()
# Out:
# INFO:tensorflow:Restoring parameters from ./Inproved_rgan/RGAN/Experient_11/ckpt_rgan\model_checkpoint-19000

# %%
print('r -> {:.3f} | {:.3f}'.format(*Hist_predict['r2_score']))
# Out:
# r -> 0.974 | 0.762

# %%
y_train_ = Hist_predict['Training']
x_limit = np.arange(len(y_train_[1]))
plt.figure(figsize=[10,8])
plt.plot(x_limit,y_train_[0],'b-o',x_limit,y_train_[1],'--r*',ms=4)
plt.legend(['Predict','Under Truth'])
plt.show()

# %%
y_test_ = Hist_predict['Testing']
x_limit = np.arange(len(y_test_[1]))
plt.figure(figsize=[10,8])
plt.plot(x_limit,y_test_[0],'b-o',x_limit,y_test_[1],'--r*',ms=4)
plt.legend(['Predict','Under Truth'])
plt.show()
