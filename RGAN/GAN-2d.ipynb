# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import shutil

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110
y_dim = 1

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1
# Updata Diters times for critic in one iter(unless i<25 or i %500==0, i is the iterstep)
Riters = 10
Diters = 5
Diters = int(((Riters+1)/Riters*Diters))

# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/Experient_1'
log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
x,y = (x - xmin)/( xmax - xmin ),(y - ymin)/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 1024, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = ly.fully_connected(train,256*172,activation_fn = tf.nn.relu,normalizer_fn =None)
    train = tf.reshape(train,(-1,256,172,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[1,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv(x,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img = ly.conv2d(x,num_outputs=size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
    
        img = ly.conv2d(img,num_outputs= size*8,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
       
        img = ly.conv2d(img,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = tf.reshape(img,[batch_size,-1])
        # fully_connected
        img = ly.fully_connected(img,1024,activation_fn=lrelu)
        disc = ly.fully_connected(img,1,activation_fn=None)
    
    return disc

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[batch_size,channel,img_dim,1])

    
    # Noise
    z = tf.placeholder(dtype =tf.float32,shape =[batch_size,z_dim])

    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    disc_real = discriminator(real_data)
    disc_fake = discriminator(gen, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
     
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss
    loss_dis = d_loss
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    if is_test:
        return gen,regr_real,z_reg,z_rand,real_data
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,real_data,z ,loss_dis,loss_gen,gen

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_spectrum(gen, i,is_show=False):
    batch_size = 10
    gen = gen[:batch_size]
    
    
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,batch_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, batch_size))
    # convert data to ideal format    
    spec = gen.reshape(batch_size,img_dim)*(xmax-xmin)+ xmin
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')
    plt.ylim((-0.5,scale))
    #plt.legend([np.array_str(var) for var in np.arange(batch_size)])
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_wgan(max_iters = 1000):
    with tf.device(device):
        opt_d, opt_g ,real_data,z,loss_dis,loss_gen,gen = build_graph()
    
    def next_feed_dict(iter, shuffled = False):
        if shuffled:
            idx = np.random.randint(x.shape[0],size=(batch_size,))
        else:
            bat_num = int(x.shape[0]/batch_size)
            par = int(1 % bat_num)
            idx = np.arange(x.shape[0])[par * batch_size:(par+1)*batch_size]

        train_img,train_label = x[idx],y[idx].reshape(batch_size,y_dim)
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
            
        feed_dict = {real_data:train_img, z:batch_z_rand}
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())

        d_loss, g_loss=[], []
        for i in range(max_iters):
            feed_dict = next_feed_dict(i)
            # training discriminator
            _,loss_of_dis = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,loss_of_gen,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            
            d_loss.append(loss_of_dis)
            g_loss.append(loss_of_gen)
            if i % 100 == 0:
                print('the loss of discriminator is %0.3f'%loss_of_dis)
                save_spectrum(spec, i)
                print('the loss of generator is %0.3f'%loss_of_gen)
                
    return  d_loss,g_loss

# %%
tf.reset_default_graph()
max_iters = 20000
d_loss,g_loss = train_wgan(max_iters =max_iters )
# Out:
# the loss of discriminator is 0.005
# the loss of generator is 0.530
# the loss of discriminator is -274.544
# the loss of generator is 161.135
# the loss of discriminator is -385.666
# the loss of generator is 129.182
# the loss of discriminator is -836.872
# the loss of generator is 440.594
# the loss of discriminator is -395.964
# the loss of generator is 197.056
# the loss of discriminator is -649.820
# the loss of generator is 268.175
# the loss of discriminator is -614.204
# the loss of generator is 278.884
# the loss of discriminator is -562.613
# the loss of generator is 231.812
# the loss of discriminator is -24.932
# the loss of generator is -407.691
# the loss of discriminator is 7.102
# the loss of generator is 351.140
# the loss of discriminator is -48.293
# the loss of generator is 244.349
# the loss of discriminator is 2.131
# the loss of generator is 11.404
# the loss of discriminator is -339.232
# the loss of generator is 131.291
# the loss of discriminator is -661.952
# the loss of generator is 279.730
# the loss of discriminator is -323.109
# the loss of generator is 59.773
# the loss of discriminator is -130.827
# the loss of generator is -181.110
# the loss of discriminator is -126.347
# the loss of generator is 11.357
# the loss of discriminator is -21.151
# the loss of generator is -74.103
# the loss of discriminator is -12.470
# the loss of generator is -157.737
# the loss of discriminator is -20.546
# the loss of generator is -187.686
# the loss of discriminator is -114.447
# the loss of generator is 42.110
# the loss of discriminator is -33.281
# the loss of generator is -96.185
# the loss of discriminator is -9.355
# the loss of generator is -156.953
# the loss of discriminator is -18.226
# the loss of generator is -173.163
# the loss of discriminator is -31.086
# the loss of generator is -167.385
# the loss of discriminator is -49.773
# the loss of generator is -169.046
# the loss of discriminator is -41.947
# the loss of generator is 20.207
# the loss of discriminator is -35.263
# the loss of generator is -138.848
# the loss of discriminator is -2.323
# the loss of generator is 53.279
# the loss of discriminator is -4.895
# the loss of generator is -128.184
# the loss of discriminator is -11.262
# the loss of generator is -98.952
# the loss of discriminator is -13.635
# the loss of generator is -125.754
# the loss of discriminator is -42.293
# the loss of generator is -146.513
# the loss of discriminator is -12.555
# the loss of generator is -93.210
# the loss of discriminator is -48.155
# the loss of generator is -61.848
# the loss of discriminator is -90.342
# the loss of generator is -118.652
# the loss of discriminator is -38.734
# the loss of generator is -202.203
# the loss of discriminator is -109.711
# the loss of generator is -64.678
# the loss of discriminator is -4.786
# the loss of generator is -123.089
# the loss of discriminator is -61.133
# the loss of generator is 20.898
# the loss of discriminator is -48.885
# the loss of generator is 110.043
# the loss of discriminator is -1.849
# the loss of generator is 14.151
# the loss of discriminator is 0.471
# the loss of generator is 1.023
# the loss of discriminator is -6.340
# the loss of generator is 34.925
# the loss of discriminator is -8.529
# the loss of generator is -32.216
# the loss of discriminator is -3.638
# the loss of generator is -69.731
# the loss of discriminator is -71.000
# the loss of generator is 3.056
# the loss of discriminator is -105.045
# the loss of generator is -30.515
# the loss of discriminator is -16.508
# the loss of generator is 28.734
# the loss of discriminator is -32.261
# the loss of generator is -152.671
# the loss of discriminator is 22.841
# the loss of generator is 115.959
# the loss of discriminator is -8.901
# the loss of generator is -182.476
# the loss of discriminator is 2.377
# the loss of generator is -206.127
# the loss of discriminator is -78.509
# the loss of generator is -31.222
# the loss of discriminator is -17.336
# the loss of generator is -200.352
# the loss of discriminator is -18.369
# the loss of generator is 84.758
# the loss of discriminator is -35.498
# the loss of generator is -143.012
# the loss of discriminator is -35.790
# the loss of generator is -90.163
# the loss of discriminator is -46.304
# the loss of generator is 75.292
# the loss of discriminator is 2.475
# the loss of generator is 101.185
# the loss of discriminator is -65.939
# the loss of generator is -58.003
# the loss of discriminator is -102.973
# the loss of generator is -85.027
# the loss of discriminator is -72.254
# the loss of generator is -110.904
# the loss of discriminator is -95.142
# the loss of generator is 35.235
# the loss of discriminator is -33.406
# the loss of generator is -172.329
# the loss of discriminator is -25.048
# the loss of generator is 59.888
# the loss of discriminator is -27.442
# the loss of generator is 126.027
# the loss of discriminator is -17.216
# the loss of generator is -235.590
# the loss of discriminator is -20.834
# the loss of generator is -181.055
# the loss of discriminator is 5.261
# the loss of generator is -172.251
# the loss of discriminator is -71.997
# the loss of generator is 84.073
# the loss of discriminator is -12.016
# the loss of generator is 20.106
# the loss of discriminator is -5.626
# the loss of generator is -48.210
# the loss of discriminator is -48.128
# the loss of generator is 26.893
# the loss of discriminator is 15.489
# the loss of generator is -86.415
# the loss of discriminator is -96.811
# the loss of generator is -92.968
# the loss of discriminator is -24.938
# the loss of generator is -269.571
# the loss of discriminator is -17.309
# the loss of generator is 100.737
# the loss of discriminator is -2.501
# the loss of generator is 2.372
# the loss of discriminator is -57.446
# the loss of generator is -235.115
# the loss of discriminator is -0.799
# the loss of generator is 12.247
# the loss of discriminator is 0.160
# the loss of generator is 5.393
# the loss of discriminator is -0.897
# the loss of generator is 6.435
# the loss of discriminator is -0.133
# the loss of generator is 5.151
# the loss of discriminator is -1.253
# the loss of generator is 4.583
# the loss of discriminator is -1.173
# the loss of generator is 7.315
# the loss of discriminator is 1.101
# the loss of generator is 1.549
# the loss of discriminator is -0.423
# the loss of generator is -8.513
# the loss of discriminator is -1.023
# the loss of generator is 7.585
# the loss of discriminator is -1.733
# the loss of generator is -7.806
# the loss of discriminator is -11.900
# the loss of generator is 10.025
# the loss of discriminator is -9.341
# the loss of generator is 9.116
# the loss of discriminator is -3.567
# the loss of generator is -5.857
# the loss of discriminator is -2.034
# the loss of generator is -3.287
# the loss of discriminator is 0.038
# the loss of generator is -15.137
# the loss of discriminator is -0.426
# the loss of generator is -14.672
# the loss of discriminator is 0.077
# the loss of generator is -5.794
# the loss of discriminator is -2.086
# the loss of generator is 0.202
# the loss of discriminator is 5.183
# the loss of generator is -13.869
# the loss of discriminator is -50.007
# the loss of generator is -173.843
# the loss of discriminator is -68.774
# the loss of generator is -141.066
# the loss of discriminator is -3.746
# the loss of generator is -65.395
# the loss of discriminator is -25.042
# the loss of generator is -198.771
# the loss of discriminator is -24.147
# the loss of generator is 31.045
# the loss of discriminator is -165.477
# the loss of generator is 21.965
# the loss of discriminator is -152.416
# the loss of generator is -71.335
# the loss of discriminator is -60.724
# the loss of generator is -17.438
# the loss of discriminator is -31.585
# the loss of generator is 218.684
# the loss of discriminator is 3.815
# the loss of generator is -169.019
# the loss of discriminator is -91.237
# the loss of generator is -64.350
# the loss of discriminator is -60.882
# the loss of generator is 43.824
# the loss of discriminator is -89.306
# the loss of generator is -27.228
# the loss of discriminator is -101.658
# the loss of generator is -102.220
# the loss of discriminator is -14.575
# the loss of generator is 25.162
# the loss of discriminator is -54.556
# the loss of generator is -20.323
# the loss of discriminator is -16.135
# the loss of generator is -194.109
# the loss of discriminator is -40.949
# the loss of generator is 103.257
# the loss of discriminator is -3.444
# the loss of generator is -285.277
# the loss of discriminator is -56.756
# the loss of generator is -291.032
# the loss of discriminator is -4.427
# the loss of generator is -259.850
# the loss of discriminator is 3.407
# the loss of generator is 154.579
# the loss of discriminator is -13.718
# the loss of generator is 37.545
# the loss of discriminator is -27.432
# the loss of generator is 47.010
# the loss of discriminator is -53.478
# the loss of generator is 131.413
# the loss of discriminator is -15.863
# the loss of generator is 13.098
# the loss of discriminator is -10.035
# the loss of generator is -7.799
# the loss of discriminator is 2.280
# the loss of generator is -14.347
# the loss of discriminator is -6.114
# the loss of generator is -1.011
# the loss of discriminator is -8.940
# the loss of generator is 34.026
# the loss of discriminator is -4.749
# the loss of generator is 22.844
# the loss of discriminator is 1.618
# the loss of generator is 2.962
# the loss of discriminator is -2.687
# the loss of generator is 49.681
# the loss of discriminator is -10.957
# the loss of generator is -1.001
# the loss of discriminator is -88.500
# the loss of generator is -79.911
# the loss of discriminator is -18.747
# the loss of generator is -86.204
# the loss of discriminator is 2.627
# the loss of generator is -265.801
# the loss of discriminator is -117.348
# the loss of generator is -87.174
# the loss of discriminator is -101.378
# the loss of generator is 116.754
# the loss of discriminator is -177.103
# the loss of generator is 108.941
# the loss of discriminator is -109.769
# the loss of generator is -29.401
# the loss of discriminator is -238.444
# the loss of generator is -173.692
# the loss of discriminator is -149.077
# the loss of generator is 9.149
# the loss of discriminator is -101.360
# the loss of generator is 66.882
# the loss of discriminator is -154.389
# the loss of generator is -54.668
# the loss of discriminator is -97.540
# the loss of generator is 16.528
# the loss of discriminator is -199.398
# the loss of generator is -229.989
# the loss of discriminator is -108.150
# the loss of generator is 37.350
# the loss of discriminator is -127.596
# the loss of generator is 86.084
# the loss of discriminator is -157.755
# the loss of generator is -126.466
# the loss of discriminator is -280.702
# the loss of generator is -141.321
# the loss of discriminator is -31.504
# the loss of generator is 192.778
# the loss of discriminator is -1.753
# the loss of generator is 7.776
# the loss of discriminator is -11.712
# the loss of generator is 17.503
# the loss of discriminator is -22.073
# the loss of generator is -21.345
# the loss of discriminator is 84.835
# the loss of generator is 2.867
# the loss of discriminator is -50.816
# the loss of generator is -123.034
# the loss of discriminator is -77.932
# the loss of generator is 33.502
# the loss of discriminator is -54.192
# the loss of generator is -273.288
# the loss of discriminator is 9.808
# the loss of generator is 35.668
# the loss of discriminator is -5.872
# the loss of generator is -53.640
# the loss of discriminator is -12.137
# the loss of generator is -73.883
# the loss of discriminator is 0.267
# the loss of generator is -62.083
# the loss of discriminator is -8.166
# the loss of generator is -163.412
# the loss of discriminator is -109.431
# the loss of generator is 28.716
# the loss of discriminator is -1.605
# the loss of generator is 100.354
# the loss of discriminator is -0.731
# the loss of generator is 74.255
# the loss of discriminator is -58.109
# the loss of generator is -30.646
# the loss of discriminator is 3.506
# the loss of generator is 80.784
# the loss of discriminator is -161.300
# the loss of generator is 92.210
# the loss of discriminator is -42.633
# the loss of generator is -232.394
# the loss of discriminator is 9.865
# the loss of generator is -0.684
# the loss of discriminator is -6.512
# the loss of generator is 82.439
# the loss of discriminator is 1.995
# the loss of generator is 18.286
# the loss of discriminator is 9.093
# the loss of generator is 42.982
# the loss of discriminator is -7.573
# the loss of generator is 2.523
# the loss of discriminator is -1.406
# the loss of generator is 48.293
# the loss of discriminator is -5.899
# the loss of generator is 10.320
# the loss of discriminator is -12.888
# the loss of generator is -7.985
# the loss of discriminator is -13.980
# the loss of generator is 129.827
# the loss of discriminator is -5.969
# the loss of generator is 5.150
# the loss of discriminator is -8.002
# the loss of generator is 2.887
# the loss of discriminator is -29.042
# the loss of generator is -133.485
# the loss of discriminator is 2.358
# the loss of generator is 28.001
# the loss of discriminator is 4.709
# the loss of generator is -42.415
# the loss of discriminator is -8.576
# the loss of generator is -83.941
# the loss of discriminator is -7.474
# the loss of generator is -136.019
# the loss of discriminator is -71.056
# the loss of generator is -19.809
# the loss of discriminator is -7.911
# the loss of generator is -277.249
# the loss of discriminator is 26.765
# the loss of generator is 105.268
# the loss of discriminator is -8.137
# the loss of generator is 113.865
# the loss of discriminator is -3.324
# the loss of generator is -102.804
# the loss of discriminator is -5.549
# the loss of generator is -159.117
# the loss of discriminator is -2.097
# the loss of generator is -130.206
# the loss of discriminator is -66.974
# the loss of generator is 78.697
# the loss of discriminator is -20.888
# the loss of generator is -49.069
# the loss of discriminator is -46.417
# the loss of generator is -49.898
# the loss of discriminator is -24.037
# the loss of generator is 63.382
# the loss of discriminator is -2.161
# the loss of generator is 19.982
# the loss of discriminator is -22.987
# the loss of generator is -6.691
# the loss of discriminator is -30.502
# the loss of generator is 132.204

# %%
d_loss,g_loss = [np.array(var) for var in(d_loss,g_loss)]    
plt.plot(np.arange(max_iters),d_loss,'-r',np.arange(max_iters),g_loss,'-b')
plt.show()

# %%
plt.plot(np.arange(max_iters),g_loss,'-b')
plt.show()

# %%
plt.plot(np.arange(max_iters),d_loss,'-r')
plt.show()
