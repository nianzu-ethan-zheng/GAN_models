# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import shutil

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110
y_dim = 1

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1
# Updata Diters times for critic in one iter(unless i<25 or i %500==0, i is the iterstep)
Riters = 10
Diters = 5
Diters = int(((Riters+1)/Riters*Diters))

# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/Experient_1'
log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
x,y = (x - xmin)/( xmax - xmin ),(y - ymin)/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 256*43, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = tf.reshape(train,(-1,256,43,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 32, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv(x,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img = ly.conv2d(x,num_outputs=size*2,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = ly.conv2d(img,num_outputs= size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        img = ly.conv2d(img,num_outputs= size*8,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
       
        img = ly.conv2d(img,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = tf.reshape(img,[batch_size,-1])
        # fully_connected
        disc = ly.fully_connected(img,1,activation_fn=None)
    
    return disc

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[batch_size,channel,img_dim,1])

    
    # Noise
    z = tf.placeholder(dtype =tf.float32,shape =[batch_size,z_dim])

    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    disc_real = discriminator(real_data)
    disc_fake = discriminator(gen, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
     
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss
    loss_dis = d_loss
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    if is_test:
        return gen,regr_real,z_reg,z_rand,real_data
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,real_data,z ,loss_dis,loss_gen,gen

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_spectrum(gen, i,is_show=False):
    batch_size = 10
    gen = gen[:batch_size]
    
    
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,batch_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, batch_size))
    # convert data to ideal format    
    spec = gen.reshape(batch_size,img_dim)*(xmax-xmin)+ xmin
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')    
    #plt.legend([np.array_str(var) for var in np.arange(batch_size)])
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_wgan(max_iters = 1000):
    with tf.device(device):
        opt_d, opt_g ,real_data,z,loss_dis,loss_gen,gen = build_graph()
    
    def next_feed_dict(iter, shuffled = False):
        if shuffled:
            idx = np.random.randint(x.shape[0],size=(batch_size,))
        else:
            bat_num = int(x.shape[0]/batch_size)
            par = int(1 % bat_num)
            idx = np.arange(x.shape[0])[par * batch_size:(par+1)*batch_size]

        train_img,train_label = x[idx],y[idx].reshape(batch_size,y_dim)
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
            
        feed_dict = {real_data:train_img, z:batch_z_rand}
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())

        d_loss, g_loss=[], []
        for i in range(max_iters):
            feed_dict = next_feed_dict(i)
            # training discriminator
            _,loss_of_dis = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,loss_of_gen,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            
            d_loss.append(loss_of_dis)
            g_loss.append(loss_of_gen)
            if i % 100 == 0:
                print('the loss of discriminator is %0.3f'%loss_of_dis)
                save_spectrum(spec, i)
                print('the loss of generator is %0.3f'%loss_of_gen)
                
    return  d_loss,g_loss

# %%
tf.reset_default_graph()
max_iters = 20000
d_loss,g_loss = train_wgan(max_iters =max_iters )
# Out:
# the loss of discriminator is 0.028
# the loss of generator is 0.084
# the loss of discriminator is -13.436
# the loss of generator is -12.992
# the loss of discriminator is -47.572
# the loss of generator is 10.399
# the loss of discriminator is -69.312
# the loss of generator is 31.737
# the loss of discriminator is -46.434
# the loss of generator is 6.776
# the loss of discriminator is -74.930
# the loss of generator is 34.553
# the loss of discriminator is -37.170
# the loss of generator is -7.321
# the loss of discriminator is -76.707
# the loss of generator is 33.384
# the loss of discriminator is -80.446
# the loss of generator is 35.567
# the loss of discriminator is -79.040
# the loss of generator is 31.920
# the loss of discriminator is -85.366
# the loss of generator is 37.173
# the loss of discriminator is -81.955
# the loss of generator is 31.628
# the loss of discriminator is -83.465
# the loss of generator is 31.516
# the loss of discriminator is -85.862
# the loss of generator is 33.667
# the loss of discriminator is -77.482
# the loss of generator is 28.620
# the loss of discriminator is -84.635
# the loss of generator is 33.029
# the loss of discriminator is -85.753
# the loss of generator is 34.406
# the loss of discriminator is -86.698
# the loss of generator is 35.543
# the loss of discriminator is -59.438
# the loss of generator is 13.543
# the loss of discriminator is -89.084
# the loss of generator is 37.885
# the loss of discriminator is -46.766
# the loss of generator is 2.934
# the loss of discriminator is -89.784
# the loss of generator is 39.627
# the loss of discriminator is -91.051
# the loss of generator is 39.279
# the loss of discriminator is -90.488
# the loss of generator is 38.096
# the loss of discriminator is -90.899
# the loss of generator is 38.181
# the loss of discriminator is -90.046
# the loss of generator is 37.214
# the loss of discriminator is -89.259
# the loss of generator is 36.776
# the loss of discriminator is -87.975
# the loss of generator is 35.566
# the loss of discriminator is -73.625
# the loss of generator is 25.382
# the loss of discriminator is -87.878
# the loss of generator is 34.570
# the loss of discriminator is -90.581
# the loss of generator is 37.348
# the loss of discriminator is -90.962
# the loss of generator is 37.512
# the loss of discriminator is -90.929
# the loss of generator is 37.312
# the loss of discriminator is -67.699
# the loss of generator is 17.212
# the loss of discriminator is -86.689
# the loss of generator is 34.434
# the loss of discriminator is -86.656
# the loss of generator is 34.266
# the loss of discriminator is -89.124
# the loss of generator is 35.752
# the loss of discriminator is -88.799
# the loss of generator is 35.573
# the loss of discriminator is -72.718
# the loss of generator is 24.959
# the loss of discriminator is -89.656
# the loss of generator is 36.785
# the loss of discriminator is -67.722
# the loss of generator is 22.201
# the loss of discriminator is -70.650
# the loss of generator is 21.967
# the loss of discriminator is -65.220
# the loss of generator is 16.513
# the loss of discriminator is -91.181
# the loss of generator is 39.269
# the loss of discriminator is -85.406
# the loss of generator is 33.340
# the loss of discriminator is -90.107
# the loss of generator is 36.759
# the loss of discriminator is -90.760
# the loss of generator is 36.984
# the loss of discriminator is -88.907
# the loss of generator is 36.303
# the loss of discriminator is -83.053
# the loss of generator is 33.383
# the loss of discriminator is -84.132
# the loss of generator is 34.185
# the loss of discriminator is -65.460
# the loss of generator is 19.385
# the loss of discriminator is -64.022
# the loss of generator is 22.115
# the loss of discriminator is -62.628
# the loss of generator is 20.314
# the loss of discriminator is -63.580
# the loss of generator is 22.438
# the loss of discriminator is -22.526
# the loss of generator is -6.669
# the loss of discriminator is -8.876
# the loss of generator is -23.350
# the loss of discriminator is -85.599
# the loss of generator is 35.390
# the loss of discriminator is -92.664
# the loss of generator is 40.776
# the loss of discriminator is -97.125
# the loss of generator is 44.880
# the loss of discriminator is -78.594
# the loss of generator is 31.885
# the loss of discriminator is -84.587
# the loss of generator is 33.207
# the loss of discriminator is -85.730
# the loss of generator is 36.801
# the loss of discriminator is -68.109
# the loss of generator is 26.631
# the loss of discriminator is -68.754
# the loss of generator is 28.091
# the loss of discriminator is -47.408
# the loss of generator is 21.020
# the loss of discriminator is -53.867
# the loss of generator is 27.745
# the loss of discriminator is -36.865
# the loss of generator is 1.138
# the loss of discriminator is -56.731
# the loss of generator is 40.508
# the loss of discriminator is -27.755
# the loss of generator is -0.102
# the loss of discriminator is 5.677
# the loss of generator is 32.716
# the loss of discriminator is -16.858
# the loss of generator is -15.728
# the loss of discriminator is -81.662
# the loss of generator is 37.612
# the loss of discriminator is -29.151
# the loss of generator is -14.638
# the loss of discriminator is -24.275
# the loss of generator is -13.302
# the loss of discriminator is -20.344
# the loss of generator is -1.347
# the loss of discriminator is -51.616
# the loss of generator is 2.963
# the loss of discriminator is 2.032
# the loss of generator is 37.638
# the loss of discriminator is -10.673
# the loss of generator is -9.746
# the loss of discriminator is -0.164
# the loss of generator is 21.620
# the loss of discriminator is -2.434
# the loss of generator is -20.818
# the loss of discriminator is -6.694
# the loss of generator is -16.241
# the loss of discriminator is -1.304
# the loss of generator is -0.410
# the loss of discriminator is -1.118
# the loss of generator is -22.063
# the loss of discriminator is -27.907
# the loss of generator is -6.382
# the loss of discriminator is -2.524
# the loss of generator is 7.727
# the loss of discriminator is -0.645
# the loss of generator is 6.643
# the loss of discriminator is -2.520
# the loss of generator is 5.985
# the loss of discriminator is -3.247
# the loss of generator is 3.136
# the loss of discriminator is -0.159
# the loss of generator is 3.105
# the loss of discriminator is -18.130
# the loss of generator is 31.678
# the loss of discriminator is -9.161
# the loss of generator is -6.828
# the loss of discriminator is 1.403
# the loss of generator is -2.955
# the loss of discriminator is -0.172
# the loss of generator is 1.796
# the loss of discriminator is -2.151
# the loss of generator is -0.338
# the loss of discriminator is -0.842
# the loss of generator is 5.054
# the loss of discriminator is -4.456
# the loss of generator is 1.745
# the loss of discriminator is -0.211
# the loss of generator is -2.215
# the loss of discriminator is -4.976
# the loss of generator is 5.692
# the loss of discriminator is -7.589
# the loss of generator is 0.502
# the loss of discriminator is -0.431
# the loss of generator is 7.383
# the loss of discriminator is -1.398
# the loss of generator is 1.327
# the loss of discriminator is -0.265
# the loss of generator is -2.651
# the loss of discriminator is -2.296
# the loss of generator is -7.850
# the loss of discriminator is 0.604
# the loss of generator is 1.365
# the loss of discriminator is -0.949
# the loss of generator is 0.255
# the loss of discriminator is -6.411
# the loss of generator is -1.329
# the loss of discriminator is -20.000
# the loss of generator is 10.188
# the loss of discriminator is 0.921
# the loss of generator is 0.815
# the loss of discriminator is 0.060
# the loss of generator is -1.290
# the loss of discriminator is -4.515
# the loss of generator is -2.710
# the loss of discriminator is -2.152
# the loss of generator is -22.263
# the loss of discriminator is -3.849
# the loss of generator is -7.217
# the loss of discriminator is -3.063
# the loss of generator is -11.619
# the loss of discriminator is -10.062
# the loss of generator is -1.949
# the loss of discriminator is -6.591
# the loss of generator is 17.630
# the loss of discriminator is -14.932
# the loss of generator is -11.156
# the loss of discriminator is -1.615
# the loss of generator is 4.439
# the loss of discriminator is -6.519
# the loss of generator is 2.355
# the loss of discriminator is -0.957
# the loss of generator is -5.457
# the loss of discriminator is -18.790
# the loss of generator is -10.345
# the loss of discriminator is -0.379
# the loss of generator is 1.823
# the loss of discriminator is -0.257
# the loss of generator is -2.223
# the loss of discriminator is -0.294
# the loss of generator is -1.025
# the loss of discriminator is -0.354
# the loss of generator is -4.651
# the loss of discriminator is -0.457
# the loss of generator is -5.244
# the loss of discriminator is -0.393
# the loss of generator is -5.755
# the loss of discriminator is -0.293
# the loss of generator is -6.436
# the loss of discriminator is -0.867
# the loss of generator is -5.282
# the loss of discriminator is -0.084
# the loss of generator is -6.672
# the loss of discriminator is -0.426
# the loss of generator is -6.492
# the loss of discriminator is -0.679
# the loss of generator is -4.968
# the loss of discriminator is 0.116
# the loss of generator is -5.587
# the loss of discriminator is -0.773
# the loss of generator is -6.056
# the loss of discriminator is -0.246
# the loss of generator is -5.725
# the loss of discriminator is -0.100
# the loss of generator is -5.365
# the loss of discriminator is -0.041
# the loss of generator is -5.839
# the loss of discriminator is -0.101
# the loss of generator is -7.074
# the loss of discriminator is -0.249
# the loss of generator is -7.766
# the loss of discriminator is -0.292
# the loss of generator is -7.757
# the loss of discriminator is 0.199
# the loss of generator is -7.695
# the loss of discriminator is -0.953
# the loss of generator is -6.779
# the loss of discriminator is 0.289
# the loss of generator is -5.626
# the loss of discriminator is -0.483
# the loss of generator is -6.959
# the loss of discriminator is -0.673
# the loss of generator is -5.259
# the loss of discriminator is 0.503
# the loss of generator is -6.048
# the loss of discriminator is -0.604
# the loss of generator is -7.210
# the loss of discriminator is -0.291
# the loss of generator is -7.440
# the loss of discriminator is -0.194
# the loss of generator is -6.970
# the loss of discriminator is 0.232
# the loss of generator is -6.434
# the loss of discriminator is -1.313
# the loss of generator is -5.201
# the loss of discriminator is -0.891
# the loss of generator is -6.906
# the loss of discriminator is -1.144
# the loss of generator is 8.616
# the loss of discriminator is -1.314
# the loss of generator is -6.484
# the loss of discriminator is -0.744
# the loss of generator is -3.021
# the loss of discriminator is -0.937
# the loss of generator is -4.960
# the loss of discriminator is -1.730
# the loss of generator is -7.154
# the loss of discriminator is -1.017
# the loss of generator is -9.424
# the loss of discriminator is -2.138
# the loss of generator is -7.319
# the loss of discriminator is -0.101
# the loss of generator is 6.216
# the loss of discriminator is -3.845
# the loss of generator is -1.126
# the loss of discriminator is -0.949
# the loss of generator is -14.015
# the loss of discriminator is -22.878
# the loss of generator is 16.833
# the loss of discriminator is -26.735
# the loss of generator is -11.423
# the loss of discriminator is -1.938
# the loss of generator is -4.479
# the loss of discriminator is -0.476
# the loss of generator is -12.394
# the loss of discriminator is -1.016
# the loss of generator is -12.359
# the loss of discriminator is -1.812
# the loss of generator is -13.210
# the loss of discriminator is -1.164
# the loss of generator is -14.931
# the loss of discriminator is -0.458
# the loss of generator is 7.916
# the loss of discriminator is -0.696
# the loss of generator is 2.745
# the loss of discriminator is -2.626
# the loss of generator is -7.175
# the loss of discriminator is 0.106
# the loss of generator is 6.317
# the loss of discriminator is -4.427
# the loss of generator is -7.383
# the loss of discriminator is -4.613
# the loss of generator is 9.136
# the loss of discriminator is 0.333
# the loss of generator is 6.967
# the loss of discriminator is 0.165
# the loss of generator is 5.708
# the loss of discriminator is -1.466
# the loss of generator is -6.664
# the loss of discriminator is -2.282
# the loss of generator is -8.710
# the loss of discriminator is -0.068
# the loss of generator is -7.515
# the loss of discriminator is -0.828
# the loss of generator is -5.000
# the loss of discriminator is -0.052
# the loss of generator is -9.719
# the loss of discriminator is -4.457
# the loss of generator is -0.661
# the loss of discriminator is -3.712
# the loss of generator is -17.555
# the loss of discriminator is -1.748
# the loss of generator is 15.344
# the loss of discriminator is -4.320
# the loss of generator is -12.485
# the loss of discriminator is -2.245
# the loss of generator is -9.621
# the loss of discriminator is -1.792
# the loss of generator is -22.900
# the loss of discriminator is -0.916
# the loss of generator is 0.345
# the loss of discriminator is -1.256
# the loss of generator is -11.115
# the loss of discriminator is 7.499
# the loss of generator is -1.670
# the loss of discriminator is 0.338
# the loss of generator is 21.366
# the loss of discriminator is -0.043
# the loss of generator is 17.228
# the loss of discriminator is -0.351
# the loss of generator is 12.839
# the loss of discriminator is -0.750
# the loss of generator is 6.359
# the loss of discriminator is -1.328
# the loss of generator is -0.293
# the loss of discriminator is -0.948
# the loss of generator is 13.888
# the loss of discriminator is -0.396
# the loss of generator is -0.750
# the loss of discriminator is -0.725
# the loss of generator is -14.212
# the loss of discriminator is -0.746
# the loss of generator is -12.171
# the loss of discriminator is -0.740
# the loss of generator is -13.448

# %%
d_loss,g_loss = [np.array(var) for var in(d_loss,g_loss)]    
plt.plot(np.arange(max_iters),d_loss,'-r',np.arange(max_iters),g_loss,'-b')
plt.show()
