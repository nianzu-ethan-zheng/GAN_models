# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import shutil

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110
y_dim = 1

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1
# Updata Diters times for critic in one iter(unless i<25 or i %500==0, i is the iterstep)
Riters = 10
Diters = 5
Diters = int(((Riters+1)/Riters*Diters))

# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/cgan/Experient_2'
log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
x,y = (x - xmin)/( xmax - xmin ),(y - ymin)/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 256*43, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = tf.reshape(train,(-1,256,43,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 32, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv(x,c,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img = ly.conv2d(x,num_outputs=size*2,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
        
        c = tf.tile(c,[1,int(img_dim/2)])
        c = tf.reshape(c,(batch_size,1,int(img_dim/2),1))
        img = tf.concat((c,img),axis=1)
        
        img = ly.conv2d(img,num_outputs= size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        img = ly.conv2d(img,num_outputs= size*8,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = ly.conv2d(img,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = tf.reshape(img,[batch_size,-1])
        # fully_connected
        disc = ly.fully_connected(img,1,activation_fn=None)
    
    return disc

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[batch_size,channel,img_dim,1])
    real_label = tf.placeholder(dtype = tf.float32,shape =[batch_size,y_dim])
    
    # Noise
    z_reg = tf.placeholder(dtype = tf.float32,shape =[batch_size,y_dim])
    z_rand = tf.placeholder(dtype =tf.float32,shape =[batch_size,z_dim])
    z = tf.concat([z_reg,z_rand],axis=1)
    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    disc_real = discriminator(real_data,real_label)
    disc_fake = discriminator(gen,z_reg, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
     
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss
    loss_dis = d_loss
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    if is_test:
        return gen,regr_real,z_reg,z_rand,real_data
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,real_data,real_label,z_reg,z_rand,loss_dis,loss_gen,gen

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_spectrum(gen, i,is_show=False):
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,batch_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, batch_size))
    # convert data to ideal format    
    spec = gen.reshape(batch_size,img_dim)*(xmax-xmin)+ xmin
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')    
    #plt.legend([np.array_str(var) for var in np.arange(batch_size)])
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_wgan(max_iters = 1000):
    
    
    with tf.device(device):
        opt_d, opt_g ,real_data,real_label,z_reg,z_rand,loss_dis,loss_gen,gen = build_graph()
        
    saver = tf.train.Saver()
    
    def next_feed_dict(iter, shuffled = False):
        if shuffled:
            idx = np.random.randint(x.shape[0],size=(batch_size,))
        else:
            bat_num = int(x.shape[0]/batch_size)
            par = int(1 % bat_num)
            idx = np.arange(x.shape[0])[par * batch_size:(par+1)*batch_size]

        train_img,train_label = x[idx],y[idx].reshape(batch_size,y_dim)
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
            
        feed_dict = {real_data:train_img, real_label:train_label, z_rand:batch_z_rand,z_reg:train_label}
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())

        d_loss, g_loss=[], []
        for i in range(max_iters):
            feed_dict = next_feed_dict(i)
            # training discriminator
            _,loss_of_dis = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,loss_of_gen,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            
            d_loss.append(loss_of_dis)
            g_loss.append(loss_of_gen)
            if i % 100 == 0:
                print('the loss of discriminator is %0.3f'%loss_of_dis)
                save_spectrum(spec, i)
                print('the loss of generator is %0.3f'%loss_of_gen)
            if i %1000 ==0:
                saver.save(sess, os.path.join(ckpt_dir,'model_checkpoint'),global_step=i)
                
    return  d_loss,g_loss

# %%
tf.reset_default_graph()
max_iters = 50000
d_loss,g_loss = train_wgan(max_iters =max_iters)
# Out:
# the loss of discriminator is 0.067
# the loss of generator is -0.245
# the loss of discriminator is -44.956
# the loss of generator is 18.142
# the loss of discriminator is -44.358
# the loss of generator is 10.320
# the loss of discriminator is -53.476
# the loss of generator is 11.710
# the loss of discriminator is -61.224
# the loss of generator is 18.328
# the loss of discriminator is -71.209
# the loss of generator is 29.507
# the loss of discriminator is -62.477
# the loss of generator is 19.460
# the loss of discriminator is -69.412
# the loss of generator is 24.589
# the loss of discriminator is -62.978
# the loss of generator is 16.882
# the loss of discriminator is -73.823
# the loss of generator is 30.489
# the loss of discriminator is -79.624
# the loss of generator is 34.031
# the loss of discriminator is -84.640
# the loss of generator is 38.899
# the loss of discriminator is -85.906
# the loss of generator is 39.275
# the loss of discriminator is -87.494
# the loss of generator is 40.504
# the loss of discriminator is -82.649
# the loss of generator is 36.222
# the loss of discriminator is -82.527
# the loss of generator is 36.059
# the loss of discriminator is -63.243
# the loss of generator is 26.611
# the loss of discriminator is -76.008
# the loss of generator is 33.361
# the loss of discriminator is -67.225
# the loss of generator is 26.194
# the loss of discriminator is -60.562
# the loss of generator is 22.554
# the loss of discriminator is -62.027
# the loss of generator is 20.768
# the loss of discriminator is -80.380
# the loss of generator is 34.724
# the loss of discriminator is -42.675
# the loss of generator is 3.605
# the loss of discriminator is -55.136
# the loss of generator is 29.192
# the loss of discriminator is -70.496
# the loss of generator is 30.625
# the loss of discriminator is -62.306
# the loss of generator is 34.955
# the loss of discriminator is -88.021
# the loss of generator is 40.284
# the loss of discriminator is -56.190
# the loss of generator is 15.845
# the loss of discriminator is -88.139
# the loss of generator is 38.473
# the loss of discriminator is -84.078
# the loss of generator is 34.442
# the loss of discriminator is -88.820
# the loss of generator is 40.190
# the loss of discriminator is -83.219
# the loss of generator is 35.783
# the loss of discriminator is -89.224
# the loss of generator is 39.783
# the loss of discriminator is -87.584
# the loss of generator is 37.745
# the loss of discriminator is -88.931
# the loss of generator is 38.193
# the loss of discriminator is -88.793
# the loss of generator is 37.344
# the loss of discriminator is -91.312
# the loss of generator is 39.275
# the loss of discriminator is -92.930
# the loss of generator is 40.058
# the loss of discriminator is -92.099
# the loss of generator is 39.498
# the loss of discriminator is -92.396
# the loss of generator is 38.775
# the loss of discriminator is -92.667
# the loss of generator is 39.191
# the loss of discriminator is -85.855
# the loss of generator is 36.986
# the loss of discriminator is -90.891
# the loss of generator is 38.061
# the loss of discriminator is -94.148
# the loss of generator is 40.092
# the loss of discriminator is -91.107
# the loss of generator is 39.300
# the loss of discriminator is -81.228
# the loss of generator is 38.534
# the loss of discriminator is -75.744
# the loss of generator is 33.938
# the loss of discriminator is -98.424
# the loss of generator is 41.994
# the loss of discriminator is -97.063
# the loss of generator is 40.224
# the loss of discriminator is -97.356
# the loss of generator is 40.027
# the loss of discriminator is -97.993
# the loss of generator is 40.365
# the loss of discriminator is -97.771
# the loss of generator is 40.030
# the loss of discriminator is -95.020
# the loss of generator is 39.016
# the loss of discriminator is -93.875
# the loss of generator is 40.583
# the loss of discriminator is -93.187
# the loss of generator is 42.146
# the loss of discriminator is -89.622
# the loss of generator is 39.087
# the loss of discriminator is -81.478
# the loss of generator is 26.824
# the loss of discriminator is -92.411
# the loss of generator is 37.722
# the loss of discriminator is -65.433
# the loss of generator is 32.749
# the loss of discriminator is -90.310
# the loss of generator is 40.641
# the loss of discriminator is -97.813
# the loss of generator is 42.728
# the loss of discriminator is -89.079
# the loss of generator is 33.932
# the loss of discriminator is -85.672
# the loss of generator is 30.961
# the loss of discriminator is -86.374
# the loss of generator is 37.946
# the loss of discriminator is -93.380
# the loss of generator is 42.569
# the loss of discriminator is -62.738
# the loss of generator is 22.973
# the loss of discriminator is -92.720
# the loss of generator is 39.464
# the loss of discriminator is -90.488
# the loss of generator is 41.109
# the loss of discriminator is -82.814
# the loss of generator is 40.344
# the loss of discriminator is -59.226
# the loss of generator is 20.214
# the loss of discriminator is -91.489
# the loss of generator is 40.053
# the loss of discriminator is -84.536
# the loss of generator is 33.871
# the loss of discriminator is -60.620
# the loss of generator is 23.959
# the loss of discriminator is -72.599
# the loss of generator is 37.362
# the loss of discriminator is -74.919
# the loss of generator is 37.367
# the loss of discriminator is -67.789
# the loss of generator is 29.218
# the loss of discriminator is -84.459
# the loss of generator is 33.791
# the loss of discriminator is -87.409
# the loss of generator is 39.155
# the loss of discriminator is -79.116
# the loss of generator is 34.021
# the loss of discriminator is -78.518
# the loss of generator is 30.221
# the loss of discriminator is -89.644
# the loss of generator is 35.842
# the loss of discriminator is -73.952
# the loss of generator is 36.229
# the loss of discriminator is -87.245
# the loss of generator is 32.146
# the loss of discriminator is -94.919
# the loss of generator is 43.074
# the loss of discriminator is -28.141
# the loss of generator is -19.024
# the loss of discriminator is -33.336
# the loss of generator is -14.780
# the loss of discriminator is -28.251
# the loss of generator is 0.685
# the loss of discriminator is -55.179
# the loss of generator is 13.273
# the loss of discriminator is -24.033
# the loss of generator is -18.435
# the loss of discriminator is -70.961
# the loss of generator is 39.834
# the loss of discriminator is -85.044
# the loss of generator is 26.638
# the loss of discriminator is -24.115
# the loss of generator is 8.137
# the loss of discriminator is -53.737
# the loss of generator is 25.397
# the loss of discriminator is -77.065
# the loss of generator is 40.207
# the loss of discriminator is -88.788
# the loss of generator is 35.454
# the loss of discriminator is -35.556
# the loss of generator is -6.404
# the loss of discriminator is -40.770
# the loss of generator is 26.652
# the loss of discriminator is -69.233
# the loss of generator is 30.476
# the loss of discriminator is -39.402
# the loss of generator is -14.055
# the loss of discriminator is -64.244
# the loss of generator is 21.368
# the loss of discriminator is -23.796
# the loss of generator is -23.444
# the loss of discriminator is -86.661
# the loss of generator is 36.921
# the loss of discriminator is -44.154
# the loss of generator is 13.814
# the loss of discriminator is -84.156
# the loss of generator is 40.173
# the loss of discriminator is -60.000
# the loss of generator is 40.950
# the loss of discriminator is -50.584
# the loss of generator is 7.507
# the loss of discriminator is -19.049
# the loss of generator is -35.655
# the loss of discriminator is -64.539
# the loss of generator is 29.720
# the loss of discriminator is -68.873
# the loss of generator is 20.880
# the loss of discriminator is -42.771
# the loss of generator is 3.617
# the loss of discriminator is -70.091
# the loss of generator is 32.325
# the loss of discriminator is -28.588
# the loss of generator is -8.472
# the loss of discriminator is -50.032
# the loss of generator is 28.139
# the loss of discriminator is -83.141
# the loss of generator is 32.929
# the loss of discriminator is -17.628
# the loss of generator is -33.953
# the loss of discriminator is -50.514
# the loss of generator is 6.097
# the loss of discriminator is -64.529
# the loss of generator is 37.568
# the loss of discriminator is -52.654
# the loss of generator is 10.221
# the loss of discriminator is -73.807
# the loss of generator is 34.388
# the loss of discriminator is -59.528
# the loss of generator is 32.816
# the loss of discriminator is -88.422
# the loss of generator is 42.094
# the loss of discriminator is -52.557
# the loss of generator is 15.636
# the loss of discriminator is -19.388
# the loss of generator is -29.702
# the loss of discriminator is -48.108
# the loss of generator is 15.042
# the loss of discriminator is -19.943
# the loss of generator is -22.414
# the loss of discriminator is -19.480
# the loss of generator is -20.461
# the loss of discriminator is -29.203
# the loss of generator is -16.367
# the loss of discriminator is -23.883
# the loss of generator is -19.569
# the loss of discriminator is -48.270
# the loss of generator is 11.749
# the loss of discriminator is -48.755
# the loss of generator is 24.056
# the loss of discriminator is -24.160
# the loss of generator is -10.974
# the loss of discriminator is -32.273
# the loss of generator is -8.901
# the loss of discriminator is -1.806
# the loss of generator is 18.450
# the loss of discriminator is -5.486
# the loss of generator is -3.306
# the loss of discriminator is -23.414
# the loss of generator is -1.148
# the loss of discriminator is -3.897
# the loss of generator is -21.564
# the loss of discriminator is -36.615
# the loss of generator is 1.918
# the loss of discriminator is -37.448
# the loss of generator is -1.171
# the loss of discriminator is -14.901
# the loss of generator is -31.779
# the loss of discriminator is -59.053
# the loss of generator is 18.105
# the loss of discriminator is -60.756
# the loss of generator is 23.923
# the loss of discriminator is -18.798
# the loss of generator is -22.812
# the loss of discriminator is -19.139
# the loss of generator is 11.421
# the loss of discriminator is -11.973
# the loss of generator is -33.738
# the loss of discriminator is -39.788
# the loss of generator is 14.083
# the loss of discriminator is 11.947
# the loss of generator is 18.621
# the loss of discriminator is -18.869
# the loss of generator is -2.976
# the loss of discriminator is -8.256
# the loss of generator is -21.676
# the loss of discriminator is -44.762
# the loss of generator is 16.248
# the loss of discriminator is -32.879
# the loss of generator is 26.538
# the loss of discriminator is -47.236
# the loss of generator is 14.988
# the loss of discriminator is -8.149
# the loss of generator is -32.269
# the loss of discriminator is -28.312
# the loss of generator is -14.131
# the loss of discriminator is -32.260
# the loss of generator is 7.846
# the loss of discriminator is -6.834
# the loss of generator is -40.512
# the loss of discriminator is -4.308
# the loss of generator is -24.186
# the loss of discriminator is -22.971
# the loss of generator is 6.831
# the loss of discriminator is -53.072
# the loss of generator is 7.409
# the loss of discriminator is -57.027
# the loss of generator is 18.328
# the loss of discriminator is -9.875
# the loss of generator is -36.367
# the loss of discriminator is -32.945
# the loss of generator is -12.518
# the loss of discriminator is -28.973
# the loss of generator is 6.894
# the loss of discriminator is -57.383
# the loss of generator is 10.926
# the loss of discriminator is -6.024
# the loss of generator is -40.773
# the loss of discriminator is 1.558
# the loss of generator is 29.968
# the loss of discriminator is -7.330
# the loss of generator is 1.569
# the loss of discriminator is -12.969
# the loss of generator is -24.765
# the loss of discriminator is -22.916
# the loss of generator is -24.292
# the loss of discriminator is -33.560
# the loss of generator is -11.515
# the loss of discriminator is -32.134
# the loss of generator is -10.658
# the loss of discriminator is -26.963
# the loss of generator is 21.362
# the loss of discriminator is -4.298
# the loss of generator is 26.630
# the loss of discriminator is -16.412
# the loss of generator is -26.015
# the loss of discriminator is -23.807
# the loss of generator is -17.106
# the loss of discriminator is -10.871
# the loss of generator is -31.370
# the loss of discriminator is -6.635
# the loss of generator is -39.383
# the loss of discriminator is -40.232
# the loss of generator is 4.604
# the loss of discriminator is -26.868
# the loss of generator is -13.261
# the loss of discriminator is -44.560
# the loss of generator is 13.922
# the loss of discriminator is -24.320
# the loss of generator is -29.353
# the loss of discriminator is -4.077
# the loss of generator is -26.863
# the loss of discriminator is -4.512
# the loss of generator is -41.093
# the loss of discriminator is -0.694
# the loss of generator is 33.977
# the loss of discriminator is -1.348
# the loss of generator is 21.641
# the loss of discriminator is -2.070
# the loss of generator is 18.116
# the loss of discriminator is -7.598
# the loss of generator is -24.155
# the loss of discriminator is -7.474
# the loss of generator is -33.198
# the loss of discriminator is -46.689
# the loss of generator is 15.848
# the loss of discriminator is -40.211
# the loss of generator is -2.051
# the loss of discriminator is -52.379
# the loss of generator is 19.437
# the loss of discriminator is -51.613
# the loss of generator is 5.597
# the loss of discriminator is -50.272
# the loss of generator is 9.709
# the loss of discriminator is -46.266
# the loss of generator is 7.735
# the loss of discriminator is -8.429
# the loss of generator is -36.738
# the loss of discriminator is -14.218
# the loss of generator is -16.453
# the loss of discriminator is -58.833
# the loss of generator is 23.087
# the loss of discriminator is -80.978
# the loss of generator is 35.951
# the loss of discriminator is -59.247
# the loss of generator is 19.739
# the loss of discriminator is -36.071
# the loss of generator is -11.619
# the loss of discriminator is -11.665
# the loss of generator is -21.560
# the loss of discriminator is -7.080
# the loss of generator is 25.120
# the loss of discriminator is -32.680
# the loss of generator is 13.612
# the loss of discriminator is -12.882
# the loss of generator is -24.544
# the loss of discriminator is -16.825
# the loss of generator is -23.247
# the loss of discriminator is -5.094
# the loss of generator is 2.045
# the loss of discriminator is -22.661
# the loss of generator is -23.573
# the loss of discriminator is -23.804
# the loss of generator is -15.230
# the loss of discriminator is -0.504
# the loss of generator is 17.396
# the loss of discriminator is 0.078
# the loss of generator is 13.485
# the loss of discriminator is -13.446
# the loss of generator is -20.787
# the loss of discriminator is -26.726
# the loss of generator is -6.590
# the loss of discriminator is -69.039
# the loss of generator is 25.124
# the loss of discriminator is -81.033
# the loss of generator is 35.807
# the loss of discriminator is -91.923
# the loss of generator is 42.402
# the loss of discriminator is -22.436
# the loss of generator is -27.214
# the loss of discriminator is -3.199
# the loss of generator is -16.675
# the loss of discriminator is -55.656
# the loss of generator is 26.947
# the loss of discriminator is -46.920
# the loss of generator is 1.078
# the loss of discriminator is -45.055
# the loss of generator is 1.675
# the loss of discriminator is -50.112
# the loss of generator is 8.778
# the loss of discriminator is -31.158
# the loss of generator is 3.688
# the loss of discriminator is -25.195
# the loss of generator is -5.556
# the loss of discriminator is -49.819
# the loss of generator is 23.679
# the loss of discriminator is -88.213
# the loss of generator is 43.320
# the loss of discriminator is -80.330
# the loss of generator is 38.702
# the loss of discriminator is -75.369
# the loss of generator is 30.487
# the loss of discriminator is -72.301
# the loss of generator is 29.544
# the loss of discriminator is -89.695
# the loss of generator is 41.725
# the loss of discriminator is -81.130
# the loss of generator is 34.250
# the loss of discriminator is -12.278
# the loss of generator is -24.403
# the loss of discriminator is -83.906
# the loss of generator is 35.520
# the loss of discriminator is -93.135
# the loss of generator is 44.948
# the loss of discriminator is -63.140
# the loss of generator is 29.137
# the loss of discriminator is -94.609
# the loss of generator is 44.166
# the loss of discriminator is -93.433
# the loss of generator is 42.447
# the loss of discriminator is -82.920
# the loss of generator is 34.925
# the loss of discriminator is -91.386
# the loss of generator is 41.568
# the loss of discriminator is -92.370
# the loss of generator is 41.424
# the loss of discriminator is -94.296
# the loss of generator is 41.696
# the loss of discriminator is -93.302
# the loss of generator is 40.031
# the loss of discriminator is -87.728
# the loss of generator is 35.741
# the loss of discriminator is -92.033
# the loss of generator is 38.077
# the loss of discriminator is -91.149
# the loss of generator is 37.472
# the loss of discriminator is -91.351
# the loss of generator is 36.957
# the loss of discriminator is -91.238
# the loss of generator is 37.158
# the loss of discriminator is -92.667
# the loss of generator is 37.789
# the loss of discriminator is -92.027
# the loss of generator is 37.079
# the loss of discriminator is -90.835
# the loss of generator is 36.167
# the loss of discriminator is -93.836
# the loss of generator is 37.461
# the loss of discriminator is -92.509
# the loss of generator is 37.252
# the loss of discriminator is -92.707
# the loss of generator is 37.735
# the loss of discriminator is -93.406
# the loss of generator is 38.046
# the loss of discriminator is -92.870
# the loss of generator is 37.152
# the loss of discriminator is -93.015
# the loss of generator is 37.275
# the loss of discriminator is -89.893
# the loss of generator is 35.280
# the loss of discriminator is -93.863
# the loss of generator is 37.753
# the loss of discriminator is -94.295
# the loss of generator is 37.904
# the loss of discriminator is -93.848
# the loss of generator is 37.434
# the loss of discriminator is -94.003
# the loss of generator is 37.361
# the loss of discriminator is -94.340
# the loss of generator is 37.549
# the loss of discriminator is -93.960
# the loss of generator is 37.343
# the loss of discriminator is -93.915
# the loss of generator is 37.396
# the loss of discriminator is -92.199
# the loss of generator is 36.804
# the loss of discriminator is -95.276
# the loss of generator is 38.053
# the loss of discriminator is -92.411
# the loss of generator is 37.158
# the loss of discriminator is -91.982
# the loss of generator is 36.278
# the loss of discriminator is -95.014
# the loss of generator is 38.138
# the loss of discriminator is -95.165
# the loss of generator is 37.807
# the loss of discriminator is -94.513
# the loss of generator is 37.269
# the loss of discriminator is -95.528
# the loss of generator is 37.933
# the loss of discriminator is -96.776
# the loss of generator is 38.403
# the loss of discriminator is -96.972
# the loss of generator is 38.384
# the loss of discriminator is -97.610
# the loss of generator is 38.279
# the loss of discriminator is -98.491
# the loss of generator is 38.778
# the loss of discriminator is -99.443
# the loss of generator is 39.486
# the loss of discriminator is -99.325
# the loss of generator is 39.413
# the loss of discriminator is -99.352
# the loss of generator is 39.560
# the loss of discriminator is -99.771
# the loss of generator is 39.516
# the loss of discriminator is -99.588
# the loss of generator is 39.878
# the loss of discriminator is -97.863
# the loss of generator is 39.078
# the loss of discriminator is -99.691
# the loss of generator is 40.008
# the loss of discriminator is -100.619
# the loss of generator is 40.405
# the loss of discriminator is -98.651
# the loss of generator is 40.573
# the loss of discriminator is -100.282
# the loss of generator is 40.204
# the loss of discriminator is -96.284
# the loss of generator is 38.981
# the loss of discriminator is -97.243
# the loss of generator is 39.353
# the loss of discriminator is -101.629
# the loss of generator is 40.795
# the loss of discriminator is -103.084
# the loss of generator is 42.201
# the loss of discriminator is -102.770
# the loss of generator is 41.649
# the loss of discriminator is -102.345
# the loss of generator is 41.166
# the loss of discriminator is -102.625
# the loss of generator is 41.279
# the loss of discriminator is -103.708
# the loss of generator is 40.998
# the loss of discriminator is -102.527
# the loss of generator is 40.988
# the loss of discriminator is -102.237
# the loss of generator is 40.635
# the loss of discriminator is -102.293
# the loss of generator is 40.710
# the loss of discriminator is -102.037
# the loss of generator is 40.477
# the loss of discriminator is -101.954
# the loss of generator is 40.525
# the loss of discriminator is -101.418
# the loss of generator is 40.403
# the loss of discriminator is -100.222
# the loss of generator is 39.698
# the loss of discriminator is -100.072
# the loss of generator is 39.759
# the loss of discriminator is -98.627
# the loss of generator is 39.644
# the loss of discriminator is -97.837
# the loss of generator is 38.933
# the loss of discriminator is -97.886
# the loss of generator is 39.199
# the loss of discriminator is -102.174
# the loss of generator is 41.372
# the loss of discriminator is -102.708
# the loss of generator is 41.566
# the loss of discriminator is -102.488
# the loss of generator is 41.253
# the loss of discriminator is -102.064
# the loss of generator is 40.823
# the loss of discriminator is -101.205
# the loss of generator is 40.666
# the loss of discriminator is -98.924
# the loss of generator is 40.296
# the loss of discriminator is -87.369
# the loss of generator is 29.944
# the loss of discriminator is -98.660
# the loss of generator is 40.029
# the loss of discriminator is -93.551
# the loss of generator is 38.136
# the loss of discriminator is -92.685
# the loss of generator is 37.260
# the loss of discriminator is -101.403
# the loss of generator is 41.926
# the loss of discriminator is -101.359
# the loss of generator is 40.734
# the loss of discriminator is -101.317
# the loss of generator is 41.116
# the loss of discriminator is -103.021
# the loss of generator is 41.722
# the loss of discriminator is -103.715
# the loss of generator is 41.019
# the loss of discriminator is -102.225
# the loss of generator is 40.907
# the loss of discriminator is -102.401
# the loss of generator is 41.158
# the loss of discriminator is -102.275
# the loss of generator is 40.815
# the loss of discriminator is -102.480
# the loss of generator is 40.944
# the loss of discriminator is -102.674
# the loss of generator is 41.029
# the loss of discriminator is -102.887
# the loss of generator is 41.223
# the loss of discriminator is -102.782
# the loss of generator is 41.006
# the loss of discriminator is -102.667
# the loss of generator is 40.896
# the loss of discriminator is -102.969
# the loss of generator is 41.119
# the loss of discriminator is -103.044
# the loss of generator is 41.189
# the loss of discriminator is -102.761
# the loss of generator is 40.894
# the loss of discriminator is -102.705
# the loss of generator is 40.980
# the loss of discriminator is -103.086
# the loss of generator is 41.201
# the loss of discriminator is -103.069
# the loss of generator is 41.091
# the loss of discriminator is -103.046
# the loss of generator is 41.070
# the loss of discriminator is -103.060
# the loss of generator is 41.141
# the loss of discriminator is -103.177
# the loss of generator is 41.149
# the loss of discriminator is -103.101
# the loss of generator is 41.079
# the loss of discriminator is -103.281
# the loss of generator is 41.201
# the loss of discriminator is -103.075
# the loss of generator is 41.027
# the loss of discriminator is -102.737
# the loss of generator is 40.838
# the loss of discriminator is -102.811
# the loss of generator is 40.954
# the loss of discriminator is -103.058
# the loss of generator is 41.063
# the loss of discriminator is -103.161
# the loss of generator is 41.153
# the loss of discriminator is -103.128
# the loss of generator is 41.147
# the loss of discriminator is -103.304
# the loss of generator is 41.237
# the loss of discriminator is -103.170
# the loss of generator is 41.104
# the loss of discriminator is -103.001
# the loss of generator is 40.994
# the loss of discriminator is -103.180
# the loss of generator is 41.103
# the loss of discriminator is -103.210
# the loss of generator is 41.123
# the loss of discriminator is -103.391
# the loss of generator is 41.222
# the loss of discriminator is -103.334
# the loss of generator is 41.164
# the loss of discriminator is -103.396
# the loss of generator is 41.274
# the loss of discriminator is -103.012
# the loss of generator is 41.006
# the loss of discriminator is -102.897
# the loss of generator is 40.911
# the loss of discriminator is -103.386
# the loss of generator is 41.858
# the loss of discriminator is -102.120
# the loss of generator is 40.749
# the loss of discriminator is -88.872
# the loss of generator is 32.145
# the loss of discriminator is -98.586
# the loss of generator is 40.135
# the loss of discriminator is -87.639
# the loss of generator is 33.291
# the loss of discriminator is -102.407
# the loss of generator is 41.460
# the loss of discriminator is -103.114
# the loss of generator is 41.652
# the loss of discriminator is -99.335
# the loss of generator is 40.559
# the loss of discriminator is -102.452
# the loss of generator is 42.098
# the loss of discriminator is -100.033
# the loss of generator is 41.430
# the loss of discriminator is -102.576
# the loss of generator is 41.472
# the loss of discriminator is -102.401
# the loss of generator is 40.884
# the loss of discriminator is -102.599
# the loss of generator is 41.005
# the loss of discriminator is -103.018
# the loss of generator is 41.460
# the loss of discriminator is -102.782
# the loss of generator is 41.050
# the loss of discriminator is -102.807
# the loss of generator is 41.030
# the loss of discriminator is -102.885
# the loss of generator is 40.982
# the loss of discriminator is -102.909
# the loss of generator is 40.950
# the loss of discriminator is -102.986
# the loss of generator is 41.000
# the loss of discriminator is -102.956
# the loss of generator is 41.015
# the loss of discriminator is -103.158
# the loss of generator is 41.140
# the loss of discriminator is -102.901
# the loss of generator is 40.912
# the loss of discriminator is -104.496
# the loss of generator is 41.126
# the loss of discriminator is -103.233
# the loss of generator is 41.107
# the loss of discriminator is -103.232
# the loss of generator is 41.098
# the loss of discriminator is -103.137
# the loss of generator is 40.996
# the loss of discriminator is -103.283
# the loss of generator is 41.141
# the loss of discriminator is -103.264
# the loss of generator is 41.147
# the loss of discriminator is -103.311
# the loss of generator is 41.226
# the loss of discriminator is -103.265
# the loss of generator is 41.117
# the loss of discriminator is -103.190
# the loss of generator is 41.064
# the loss of discriminator is -102.975
# the loss of generator is 40.854
# the loss of discriminator is -104.438
# the loss of generator is 40.981
# the loss of discriminator is -103.371
# the loss of generator is 41.217
# the loss of discriminator is -103.225
# the loss of generator is 41.030
# the loss of discriminator is -103.114
# the loss of generator is 41.087
# the loss of discriminator is -102.707
# the loss of generator is 40.801
# the loss of discriminator is -102.547
# the loss of generator is 40.833
# the loss of discriminator is -101.434
# the loss of generator is 40.181
# the loss of discriminator is -94.799
# the loss of generator is 38.085
# the loss of discriminator is -101.553
# the loss of generator is 41.448
# the loss of discriminator is -102.488
# the loss of generator is 41.710
# the loss of discriminator is -101.745
# the loss of generator is 41.311
# the loss of discriminator is -101.895
# the loss of generator is 41.421
# the loss of discriminator is -103.105
# the loss of generator is 41.565
# the loss of discriminator is -101.630
# the loss of generator is 40.185
# the loss of discriminator is -99.503
# the loss of generator is 42.088
# the loss of discriminator is -104.534
# the loss of generator is 41.919
# the loss of discriminator is -103.242
# the loss of generator is 41.667
# the loss of discriminator is -100.573
# the loss of generator is 40.389
# the loss of discriminator is -36.000
# the loss of generator is -4.644
# the loss of discriminator is -102.824
# the loss of generator is 41.449
# the loss of discriminator is -103.071
# the loss of generator is 41.436
# the loss of discriminator is -101.876
# the loss of generator is 40.276
# the loss of discriminator is -101.850
# the loss of generator is 40.475
# the loss of discriminator is -102.845
# the loss of generator is 41.058
# the loss of discriminator is -102.759
# the loss of generator is 41.003
# the loss of discriminator is -102.615
# the loss of generator is 40.821
# the loss of discriminator is -103.030
# the loss of generator is 41.120
# the loss of discriminator is -103.130
# the loss of generator is 41.138
# the loss of discriminator is -103.159
# the loss of generator is 41.184
# the loss of discriminator is -103.088
# the loss of generator is 41.114
# the loss of discriminator is -103.331
# the loss of generator is 41.311
# the loss of discriminator is -103.124
# the loss of generator is 41.054
# the loss of discriminator is -103.198
# the loss of generator is 41.157
# the loss of discriminator is -103.242
# the loss of generator is 41.153
# the loss of discriminator is -103.385
# the loss of generator is 41.280
# the loss of discriminator is -103.322
# the loss of generator is 41.196
# the loss of discriminator is -103.275
# the loss of generator is 41.157
# the loss of discriminator is -103.252
# the loss of generator is 41.167
# the loss of discriminator is -103.173
# the loss of generator is 41.141
# the loss of discriminator is -103.341
# the loss of generator is 41.205
# the loss of discriminator is -103.465
# the loss of generator is 41.298
# the loss of discriminator is -103.458
# the loss of generator is 41.294
# the loss of discriminator is -101.420
# the loss of generator is 40.166
# the loss of discriminator is -102.501
# the loss of generator is 40.770
# the loss of discriminator is -102.435
# the loss of generator is 40.974
# the loss of discriminator is -81.138
# the loss of generator is 35.753
# the loss of discriminator is -18.159
# the loss of generator is -22.925
# the loss of discriminator is -17.937
# the loss of generator is -25.088
# the loss of discriminator is -47.311
# the loss of generator is 0.811
# the loss of discriminator is -93.886
# the loss of generator is 42.409
# the loss of discriminator is -104.024
# the loss of generator is 45.947
# the loss of discriminator is -102.225
# the loss of generator is 43.520
# the loss of discriminator is -99.598
# the loss of generator is 40.892
# the loss of discriminator is -101.611
# the loss of generator is 42.470
# the loss of discriminator is -100.155
# the loss of generator is 40.600
# the loss of discriminator is -100.726
# the loss of generator is 40.664
# the loss of discriminator is -101.528
# the loss of generator is 41.176
# the loss of discriminator is -100.526
# the loss of generator is 40.133
# the loss of discriminator is -101.477
# the loss of generator is 40.747
# the loss of discriminator is -101.549
# the loss of generator is 40.722
# the loss of discriminator is -101.733
# the loss of generator is 40.988
# the loss of discriminator is -101.691
# the loss of generator is 40.598
# the loss of discriminator is -101.798
# the loss of generator is 40.722
# the loss of discriminator is -101.623
# the loss of generator is 41.148
# the loss of discriminator is -101.300
# the loss of generator is 40.167
# the loss of discriminator is -101.579
# the loss of generator is 40.375
# the loss of discriminator is -101.816
# the loss of generator is 40.518
# the loss of discriminator is -101.675
# the loss of generator is 40.518
# the loss of discriminator is -101.945
# the loss of generator is 40.589
# the loss of discriminator is -101.895
# the loss of generator is 40.757
# the loss of discriminator is -101.866
# the loss of generator is 40.557
# the loss of discriminator is -101.717
# the loss of generator is 40.543
# the loss of discriminator is -102.231
# the loss of generator is 40.941
# the loss of discriminator is -101.827
# the loss of generator is 40.526
# the loss of discriminator is -101.723
# the loss of generator is 40.593
# the loss of discriminator is -102.187
# the loss of generator is 40.993
# the loss of discriminator is -101.941
# the loss of generator is 40.718
# the loss of discriminator is -101.897
# the loss of generator is 40.595
# the loss of discriminator is -99.580
# the loss of generator is 39.119
# the loss of discriminator is -101.512
# the loss of generator is 40.616
# the loss of discriminator is -101.263
# the loss of generator is 40.287
# the loss of discriminator is -101.575
# the loss of generator is 40.524
# the loss of discriminator is -98.403
# the loss of generator is 39.135
# the loss of discriminator is -99.287
# the loss of generator is 39.281
# the loss of discriminator is -98.714
# the loss of generator is 40.091
# the loss of discriminator is -97.781
# the loss of generator is 38.969
# the loss of discriminator is -100.853
# the loss of generator is 40.811
# the loss of discriminator is -102.664
# the loss of generator is 42.286
# the loss of discriminator is -100.624
# the loss of generator is 40.824
# the loss of discriminator is -100.298
# the loss of generator is 40.389
# the loss of discriminator is -99.131
# the loss of generator is 39.577
# the loss of discriminator is -95.661
# the loss of generator is 39.578
# the loss of discriminator is -78.801
# the loss of generator is 25.512
# the loss of discriminator is -98.603
# the loss of generator is 40.370
# the loss of discriminator is -95.045
# the loss of generator is 37.862
# the loss of discriminator is -101.711
# the loss of generator is 41.593
# the loss of discriminator is -96.727
# the loss of generator is 38.922
# the loss of discriminator is -100.040
# the loss of generator is 41.123
# the loss of discriminator is -97.776
# the loss of generator is 39.603
# the loss of discriminator is -95.481
# the loss of generator is 41.537
# the loss of discriminator is -97.817
# the loss of generator is 41.439
# the loss of discriminator is -103.190
# the loss of generator is 41.881
# the loss of discriminator is -101.443
# the loss of generator is 40.014
# the loss of discriminator is -103.180
# the loss of generator is 41.449
# the loss of discriminator is -102.959
# the loss of generator is 41.149
# the loss of discriminator is -102.720
# the loss of generator is 40.831
# the loss of discriminator is -102.592
# the loss of generator is 40.758
# the loss of discriminator is -102.338
# the loss of generator is 40.747
# the loss of discriminator is -103.286
# the loss of generator is 41.471
# the loss of discriminator is -103.125
# the loss of generator is 41.211
# the loss of discriminator is -103.358
# the loss of generator is 41.463
# the loss of discriminator is -103.215
# the loss of generator is 41.234
# the loss of discriminator is -103.102
# the loss of generator is 41.043
# the loss of discriminator is -103.521
# the loss of generator is 41.479
# the loss of discriminator is -102.976
# the loss of generator is 40.906

# %%
d_loss,g_loss = [np.array(var) for var in(d_loss,g_loss)]    
plt.plot(np.arange(max_iters),d_loss,'-r',np.arange(max_iters),g_loss,'-b')
plt.show()

# %%
plt.plot(np.arange(max_iters),d_loss,'-r')
plt.show()

# %%
plt.plot(np.arange(max_iters),g_loss,'-b')
plt.show()
