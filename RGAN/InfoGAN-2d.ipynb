# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import shutil

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110

# Define salient variable
cat_list = [10] # Each entry in this list defines a categorical variable for specific size
cont_num = 3 # the number of continous variables

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1
# Updata Diters times for critic in one iter(unless i<25 or i %500==0, i is the iterstep)
Riters = 10
Diters = 5
Diters = int(((Riters+1)/Riters*Diters))

# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/cgan_2d/Experient_1'
log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
x,y = (x - xmin)/( xmax - xmin ),(y - ymin)/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 1024, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = ly.fully_connected(train, 256*172, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = tf.reshape(train,(-1,256,172,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[1,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv( x ,cat_list =cat_list ,cont_num =cont_num,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img = ly.conv2d(x,num_outputs=size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = ly.conv2d(img,num_outputs= size*8 ,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = ly.conv2d(img,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = tf.reshape(img,[batch_size,-1])
        # fully_connected
        img = ly.fully_connected(img,1024,activation_fn=lrelu)
        disc = ly.fully_connected(img,1,activation_fn=None)
        
        # Here we difine the unique layers used for the q_network, the number of outputs 
        q_img = ly.fully_connected(img,128,activation_fn=lrelu)
        
        q_cat_outs = []
        if len(cat_list)>0:
            for idx,var in enumerate(cat_list):
                q_outA = ly.fully_connected(q_img,var, activation_fn=tf.nn.softmax)
                q_cat_outs.append(q_outA)
        
        q_cont_outs = []
        if cont_num>0:
            q_cont_outs = ly.fully_connected(q_img,cont_num,activation_fn = tf.nn.tanh)
    
    return disc, q_cat_outs, q_cont_outs

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # Real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[batch_size,channel,img_dim,1])
    
    # Noise ;Continous variable, and rand variable to provide some variance
    z_cont = tf.placeholder(dtype = tf.float32,shape =[batch_size,cont_num])
    z_rand = tf.placeholder(dtype =tf.float32,shape =[batch_size,z_dim])
    # Categorical variable
    if len(cat_list)>0:
        z_cat = tf.placeholder(dtype = tf.int32, shape=[batch_size,len(cat_list)])
        cat_var = tf.split(z_cat , len(cat_list),axis=1)

        cat_z =[]
        for idx ,depth in enumerate(cat_list):
            cat_temp = tf.one_hot(tf.reshape(cat_var[idx],[-1]), depth)
            cat_z.append(cat_temp)
    else:
        z_cat = tf.placeholder(dtype =tf.float32,shape =[batch_size,10])
        cat_z = [z_cat]
    # Conbine all of the variable
    z = cat_z[:]
    z.append(z_cont)
    z.append(z_rand)
    z = tf.concat( z,axis=1)
    
    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    if is_test:
        return gen,z_rand,z_cont,z_cat
    
    disc_real,_,_ = discriminator(real_data)
    disc_fake,cat_fake,cont_fake = discriminator(gen, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
    
    # Combine losses for each of categorical variables
    if len(cat_list)>0:
        cat_losses =[]
        tiny = 1e-10
        for idx,var in enumerate(cat_z):
            cat_loss = -tf.reduce_sum(var *tf.log(cat_fake[idx]+tiny),reduction_indices=1)
            cat_losses.append(cat_loss)
    else:
        cat_losses = tf.constant(0.0)
    # Combine losses for each of continous variables   
    if cont_num>0:
        cont_loss = -tf.reduce_sum(0.5*tf.square(cont_fake-z_cont),reduction_indices=1)
    else:
        cont_loss = tf.constant(0.0)
    
    q_cont_loss = tf.reduce_mean(cont_loss)
    q_cat_loss = tf.reduce_mean(cat_losses)
    q_loss = tf.add(q_cont_loss,q_cat_loss)
    
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss
    loss_dis = d_loss
    loss_qnt = q_loss
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    counter_q = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_q = optimize(loss =loss_qnt ,variables=theta_d+theta_g ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,opt_q,real_data,z_rand,z_cont,z_cat,loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_image(specs ,size,i =100,image_path = rgan_dir):
    _,ax = plt.subplots(size[0],size[1],sharex = True,sharey = True)
    for i in range(size[0]):
        for j in range(size[1]):
            ax[i][j].plot(np.arange(specs.shape[1]),specs[i*10+j] ,'-*')
    
    plt.savefig(image_path+'/'+str(i).zfill(4)+'.png')
    plt.close()

# %%
def save_spectrum(gen, i,spec_size = 10,is_show=False):
    if gen.shape[0]<spec_size:
        spec_size = gen.shape[0]

    gen = gen[:spec_size]
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,spec_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, spec_size))
    # convert data to ideal format    
    spec = gen.reshape(spec_size,img_dim)*(xmax-xmin)+ xmin
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')    
    plt.legend([np.array_str(var) for var in np.arange(spec_size)])
    if intv ==0:
        plt.ylim([-0.5,scale])
    else:
        plt.ylim([-0.5,scale*spec_size*intv])
    
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_rgan(max_iters = 1000):
    
    
    with tf.device(device):
        opt_d, opt_g ,opt_q,real_data,z_rand,z_cont,z_cat,loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss = build_graph()
        
    saver = tf.train.Saver()
    
    def next_feed_dict(iter, shuffled = False):
        if shuffled:
            idx = np.random.randint(x.shape[0],size=(batch_size,))
        else:
            bat_num = int(x.shape[0]/batch_size)
            par = int(1 % bat_num)
            idx = np.arange(x.shape[0])[par * batch_size:(par+1)*batch_size]

        train_img = x[idx]
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
        if len(cat_list)>0:
            batch_z_cat  = np.random.randint(0,10,[batch_size,len(cat_list)])
        else:
            batch_z_cat = np.random.normal(0,0.3,[batch_size,10]).astype(np.float32)
        batch_z_cont = np.random.uniform(-1,1,[batch_size,cont_num])
            
        feed_dict = {real_data:train_img, 
                     z_rand : batch_z_rand,
                     z_cat  : batch_z_cat,
                     z_cont : batch_z_cont}
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())

        d_loss, g_loss,q_loss,qcont,qcat =[], [],[],[],[]
        for i in range(max_iters):
            feed_dict = next_feed_dict(i)
            # training discriminator
            _,dLoss = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,gLoss,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            _,qLoss,qCont,qCat = sess.run([opt_q, loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            d_loss.append(dLoss)
            g_loss.append(gLoss)
            q_loss.append(qLoss)
            qcont.append(qCont)
            qcat.append(qCat)
            if i % 100 == 0:
                print('Batch:%04d,G loss:%02.3f,D Loss:%02.3f,Q Loss:%02.3f,%03.3f'%(i,dLoss, gLoss,qCont,qCat))
                save_spectrum(spec, i)

            if i %1000 ==0:
                saver.save(sess, os.path.join(ckpt_dir,'model_checkpoint'),global_step=i)
                
    return  d_loss,g_loss,q_loss,qcont,qcat

# %%
tf.reset_default_graph()
max_iters = 50000
d_loss,g_loss,q_loss,qcont,qcat = train_rgan(max_iters =max_iters)
# Out:
# Batch:0000,G loss:-0.085,D Loss:0.641,Q Loss:-0.382,2.303
# Batch:0100,G loss:-355.470,D Loss:191.603,Q Loss:-2.261,1.422
# Batch:0200,G loss:-715.654,D Loss:372.212,Q Loss:-2.009,0.803
# Batch:0300,G loss:-694.999,D Loss:303.935,Q Loss:-1.791,0.597
# Batch:0400,G loss:-720.763,D Loss:314.188,Q Loss:-1.968,0.549
# Batch:0500,G loss:-805.666,D Loss:378.304,Q Loss:-2.082,0.532
# Batch:0600,G loss:-769.717,D Loss:348.896,Q Loss:-1.655,0.389
# Batch:0700,G loss:-785.469,D Loss:342.627,Q Loss:-1.868,0.189
# Batch:0800,G loss:-823.920,D Loss:354.102,Q Loss:-1.813,0.136
# Batch:0900,G loss:-854.436,D Loss:365.889,Q Loss:-1.975,0.066
# Batch:1000,G loss:-846.855,D Loss:347.454,Q Loss:-2.110,0.057
# Batch:1100,G loss:-873.303,D Loss:378.512,Q Loss:-1.983,0.096
# Batch:1200,G loss:-868.786,D Loss:366.049,Q Loss:-2.207,0.060
# Batch:1300,G loss:-895.045,D Loss:353.462,Q Loss:-1.841,0.047
# Batch:1400,G loss:-875.956,D Loss:352.957,Q Loss:-1.737,0.051
# Batch:1500,G loss:-904.032,D Loss:372.163,Q Loss:-1.855,0.037
# Batch:1600,G loss:-897.314,D Loss:368.021,Q Loss:-2.039,0.038
# Batch:1700,G loss:-887.436,D Loss:352.260,Q Loss:-2.261,0.038
# Batch:1800,G loss:-890.049,D Loss:351.517,Q Loss:-2.137,0.034
# Batch:1900,G loss:-919.860,D Loss:355.539,Q Loss:-2.033,0.037
# Batch:2000,G loss:-909.273,D Loss:372.231,Q Loss:-2.168,0.051
# Batch:2100,G loss:-883.980,D Loss:340.060,Q Loss:-2.268,0.033
# Batch:2200,G loss:-911.757,D Loss:334.518,Q Loss:-1.838,0.042
# Batch:2300,G loss:-912.477,D Loss:357.473,Q Loss:-2.005,0.037
# Batch:2400,G loss:-900.328,D Loss:349.501,Q Loss:-2.060,0.039
# Batch:2500,G loss:-932.990,D Loss:348.347,Q Loss:-1.956,0.020
# Batch:2600,G loss:-945.239,D Loss:383.183,Q Loss:-1.773,0.026
# Batch:2700,G loss:-956.347,D Loss:387.677,Q Loss:-1.933,0.032
# Batch:2800,G loss:-927.176,D Loss:425.513,Q Loss:-2.440,0.019
# Batch:2900,G loss:-929.119,D Loss:382.179,Q Loss:-2.246,0.018
# Batch:3000,G loss:-911.708,D Loss:331.713,Q Loss:-1.899,0.040
# Batch:3100,G loss:-918.913,D Loss:343.291,Q Loss:-2.077,0.073
# Batch:3200,G loss:-901.154,D Loss:341.841,Q Loss:-2.012,0.040
# Batch:3300,G loss:-901.013,D Loss:347.442,Q Loss:-1.872,0.031
# Batch:3400,G loss:-918.684,D Loss:363.849,Q Loss:-1.965,0.041
# Batch:3500,G loss:-935.408,D Loss:341.178,Q Loss:-2.180,0.040
# Batch:3600,G loss:-935.082,D Loss:343.465,Q Loss:-1.959,0.032
# Batch:3700,G loss:-942.428,D Loss:360.244,Q Loss:-2.007,0.028
# Batch:3800,G loss:-950.418,D Loss:355.432,Q Loss:-1.808,0.032
# Batch:3900,G loss:-924.872,D Loss:368.583,Q Loss:-2.121,0.025
# Batch:4000,G loss:-926.997,D Loss:366.443,Q Loss:-1.924,0.053
# Batch:4100,G loss:-936.899,D Loss:357.037,Q Loss:-1.971,0.030
# Batch:4200,G loss:-935.298,D Loss:354.762,Q Loss:-1.846,0.027
# Batch:4300,G loss:-954.099,D Loss:373.397,Q Loss:-2.074,0.025
# Batch:4400,G loss:-931.156,D Loss:364.493,Q Loss:-2.179,0.043
# Batch:4500,G loss:-949.117,D Loss:362.632,Q Loss:-1.900,0.038
# Batch:4600,G loss:-949.328,D Loss:345.186,Q Loss:-1.764,0.034
# Batch:4700,G loss:-943.335,D Loss:334.847,Q Loss:-2.296,0.028
# Batch:4800,G loss:-951.145,D Loss:367.308,Q Loss:-1.951,0.018
# Batch:4900,G loss:-921.223,D Loss:349.755,Q Loss:-1.707,0.046
# Batch:5000,G loss:-891.085,D Loss:356.079,Q Loss:-1.810,0.030
# Batch:5100,G loss:-982.532,D Loss:396.245,Q Loss:-1.967,0.045
# Batch:5200,G loss:-940.584,D Loss:369.524,Q Loss:-1.814,0.025
# Batch:5300,G loss:-921.847,D Loss:365.580,Q Loss:-2.152,0.050
# Batch:5400,G loss:-910.651,D Loss:335.390,Q Loss:-1.584,0.023
# Batch:5500,G loss:-940.981,D Loss:365.687,Q Loss:-1.944,0.022
# Batch:5600,G loss:-957.873,D Loss:368.680,Q Loss:-1.935,0.044
# Batch:5700,G loss:-895.180,D Loss:303.335,Q Loss:-2.300,0.014
# Batch:5800,G loss:-954.683,D Loss:368.605,Q Loss:-1.957,0.015
# Batch:5900,G loss:-948.228,D Loss:338.274,Q Loss:-1.833,0.030
# Batch:6000,G loss:-922.143,D Loss:350.647,Q Loss:-1.785,0.017
# Batch:6100,G loss:-927.817,D Loss:341.447,Q Loss:-2.019,0.021
# Batch:6200,G loss:-901.107,D Loss:340.169,Q Loss:-2.171,0.016
# Batch:6300,G loss:-940.773,D Loss:366.882,Q Loss:-1.956,0.019
# Batch:6400,G loss:-923.794,D Loss:355.943,Q Loss:-2.020,0.011
# Batch:6500,G loss:-940.536,D Loss:368.022,Q Loss:-1.737,0.019
# Batch:6600,G loss:-946.676,D Loss:376.362,Q Loss:-1.850,0.023
# Batch:6700,G loss:-964.422,D Loss:367.697,Q Loss:-1.946,0.014
# Batch:6800,G loss:-904.403,D Loss:349.588,Q Loss:-2.019,0.014
# Batch:6900,G loss:-929.714,D Loss:344.831,Q Loss:-2.024,0.031
# Batch:7000,G loss:-561.629,D Loss:176.892,Q Loss:-1.813,0.078
# Batch:7100,G loss:-363.713,D Loss:98.130,Q Loss:-2.100,0.217
# Batch:7200,G loss:-351.182,D Loss:71.002,Q Loss:-2.047,0.068
# Batch:7300,G loss:-268.552,D Loss:4.364,Q Loss:-1.818,0.152
# Batch:7400,G loss:-126.148,D Loss:-25.176,Q Loss:-1.991,0.139
# Batch:7500,G loss:-158.689,D Loss:-73.886,Q Loss:-2.149,0.017
# Batch:7600,G loss:-149.233,D Loss:-96.327,Q Loss:-1.825,0.044
# Batch:7700,G loss:-108.115,D Loss:-98.869,Q Loss:-2.069,0.061
# Batch:7800,G loss:-96.226,D Loss:-151.228,Q Loss:-2.061,0.126
# Batch:7900,G loss:-111.444,D Loss:-92.951,Q Loss:-2.108,0.062
# Batch:8000,G loss:-152.743,D Loss:14.955,Q Loss:-2.087,0.057
# Batch:8100,G loss:-248.957,D Loss:-17.954,Q Loss:-2.127,0.015
# Batch:8200,G loss:-161.287,D Loss:-97.364,Q Loss:-1.835,0.074
# Batch:8300,G loss:-130.360,D Loss:-127.153,Q Loss:-2.154,0.024
# Batch:8400,G loss:-116.168,D Loss:-60.820,Q Loss:-1.764,0.041
# Batch:8500,G loss:-99.769,D Loss:-167.690,Q Loss:-2.116,0.058
# Batch:8600,G loss:-213.691,D Loss:-67.129,Q Loss:-2.042,0.038
# Batch:8700,G loss:-204.732,D Loss:-132.920,Q Loss:-2.368,0.038
# Batch:8800,G loss:-156.542,D Loss:-83.860,Q Loss:-1.722,0.035
# Batch:8900,G loss:-184.519,D Loss:-54.096,Q Loss:-2.018,0.039
# Batch:9000,G loss:-212.846,D Loss:-99.896,Q Loss:-2.283,0.396
# Batch:9100,G loss:-185.506,D Loss:-98.220,Q Loss:-2.320,0.025
# Batch:9200,G loss:-244.096,D Loss:8.427,Q Loss:-2.166,0.028
# Batch:9300,G loss:-140.078,D Loss:-89.708,Q Loss:-1.986,0.143
# Batch:9400,G loss:-89.671,D Loss:-105.765,Q Loss:-2.308,0.109
# Batch:9500,G loss:-138.622,D Loss:-35.232,Q Loss:-1.876,0.365
# Batch:9600,G loss:-106.465,D Loss:-74.445,Q Loss:-2.000,0.031
# Batch:9700,G loss:-79.344,D Loss:-95.475,Q Loss:-1.808,0.084
# Batch:9800,G loss:-71.339,D Loss:-145.420,Q Loss:-1.701,0.534
# Batch:9900,G loss:-134.368,D Loss:-122.006,Q Loss:-2.063,0.061
# Batch:10000,G loss:-89.977,D Loss:-137.317,Q Loss:-2.110,0.054
# Batch:10100,G loss:-341.903,D Loss:86.465,Q Loss:-1.962,0.148
# Batch:10200,G loss:-218.800,D Loss:168.347,Q Loss:-1.852,0.040
# Batch:10300,G loss:-151.330,D Loss:-152.499,Q Loss:-1.930,0.129
# Batch:10400,G loss:-47.171,D Loss:-20.381,Q Loss:-2.080,0.139
# Batch:10500,G loss:-113.805,D Loss:25.170,Q Loss:-1.875,0.048
# Batch:10600,G loss:-84.259,D Loss:-35.416,Q Loss:-1.991,0.129
# Batch:10700,G loss:-91.235,D Loss:-38.493,Q Loss:-2.099,0.089
# Batch:10800,G loss:43.386,D Loss:20.994,Q Loss:-2.086,0.051
# Batch:10900,G loss:0.020,D Loss:-15.718,Q Loss:-1.995,0.156
# Batch:11000,G loss:-44.804,D Loss:-22.850,Q Loss:-1.870,0.037
# Batch:11100,G loss:-123.478,D Loss:1.329,Q Loss:-2.368,0.049
# Batch:11200,G loss:-69.494,D Loss:71.345,Q Loss:-2.066,1.030
# Batch:11300,G loss:-90.451,D Loss:-6.748,Q Loss:-1.856,0.101
# Batch:11400,G loss:-106.696,D Loss:22.719,Q Loss:-2.129,0.078
# Batch:11500,G loss:-34.402,D Loss:-121.277,Q Loss:-1.805,0.274
# Batch:11600,G loss:-45.057,D Loss:-90.681,Q Loss:-2.073,0.508
# Batch:11700,G loss:-66.650,D Loss:-12.937,Q Loss:-2.272,0.075
# Batch:11800,G loss:-43.186,D Loss:-77.297,Q Loss:-2.062,0.150
# Batch:11900,G loss:-22.330,D Loss:27.639,Q Loss:-1.844,0.126
# Batch:12000,G loss:-97.181,D Loss:-37.140,Q Loss:-2.216,0.053
# Batch:12100,G loss:-129.317,D Loss:-24.200,Q Loss:-1.626,0.027
# Batch:12200,G loss:-38.139,D Loss:-108.648,Q Loss:-2.221,0.026
# Batch:12300,G loss:-11.502,D Loss:17.326,Q Loss:-2.061,0.054
# Batch:12400,G loss:-38.501,D Loss:-88.416,Q Loss:-2.029,0.709
# Batch:12500,G loss:-57.075,D Loss:2.624,Q Loss:-2.019,0.368
# Batch:12600,G loss:-85.920,D Loss:85.358,Q Loss:-2.022,0.154
# Batch:12700,G loss:-42.460,D Loss:-41.907,Q Loss:-1.955,0.044
# Batch:12800,G loss:-14.612,D Loss:-75.417,Q Loss:-1.872,0.090
# Batch:12900,G loss:-58.134,D Loss:-59.351,Q Loss:-1.930,0.025
# Batch:13000,G loss:-11.445,D Loss:-69.365,Q Loss:-1.875,0.053
# Batch:13100,G loss:-90.592,D Loss:-34.130,Q Loss:-2.053,0.061
# Batch:13200,G loss:-73.517,D Loss:23.894,Q Loss:-1.861,0.083
# Batch:13300,G loss:-97.717,D Loss:59.411,Q Loss:-2.207,0.059
# Batch:13400,G loss:-56.953,D Loss:-27.227,Q Loss:-1.871,0.033
# Batch:13500,G loss:-55.737,D Loss:-110.475,Q Loss:-1.905,0.069
# Batch:13600,G loss:-59.276,D Loss:-77.913,Q Loss:-1.945,0.041
# Batch:13700,G loss:-45.849,D Loss:-43.193,Q Loss:-2.129,1.008
# Batch:13800,G loss:-41.018,D Loss:-121.703,Q Loss:-1.692,0.013
# Batch:13900,G loss:-46.687,D Loss:-105.072,Q Loss:-1.841,0.155
# Batch:14000,G loss:-45.643,D Loss:-46.426,Q Loss:-2.321,0.209
# Batch:14100,G loss:-33.360,D Loss:-134.292,Q Loss:-2.281,0.169
# Batch:14200,G loss:-64.108,D Loss:-106.156,Q Loss:-2.111,0.840
# Batch:14300,G loss:-53.471,D Loss:-68.268,Q Loss:-2.041,0.159
# Batch:14400,G loss:-45.966,D Loss:-61.631,Q Loss:-1.909,0.051
# Batch:14500,G loss:-57.044,D Loss:9.414,Q Loss:-1.831,0.054
# Batch:14600,G loss:-143.997,D Loss:112.700,Q Loss:-2.128,0.385
# Batch:14700,G loss:-88.722,D Loss:-49.842,Q Loss:-1.954,0.044
# Batch:14800,G loss:-51.093,D Loss:-92.277,Q Loss:-2.608,0.052
# Batch:14900,G loss:-65.214,D Loss:-54.956,Q Loss:-1.851,0.070
# Batch:15000,G loss:-60.332,D Loss:-105.565,Q Loss:-1.841,0.283
# Batch:15100,G loss:-445.157,D Loss:335.716,Q Loss:-1.997,0.329
# Batch:15200,G loss:-318.988,D Loss:16.366,Q Loss:-1.715,0.619
# Batch:15300,G loss:-101.991,D Loss:-157.508,Q Loss:-2.191,0.103
# Batch:15400,G loss:-35.575,D Loss:-131.273,Q Loss:-1.771,0.113
# Batch:15500,G loss:-51.517,D Loss:-104.494,Q Loss:-1.907,0.045
# Batch:15600,G loss:-55.199,D Loss:-108.270,Q Loss:-2.152,0.066
# Batch:15700,G loss:-18.839,D Loss:25.297,Q Loss:-1.915,0.100
# Batch:15800,G loss:-84.551,D Loss:-45.466,Q Loss:-1.656,0.176
# Batch:15900,G loss:-67.975,D Loss:-69.598,Q Loss:-1.981,0.269
# Batch:16000,G loss:-23.702,D Loss:-50.225,Q Loss:-1.838,0.152
# Batch:16100,G loss:-61.540,D Loss:38.173,Q Loss:-2.134,0.152
# Batch:16200,G loss:-16.605,D Loss:-20.243,Q Loss:-2.154,0.136
# Batch:16300,G loss:-46.339,D Loss:-44.708,Q Loss:-1.976,0.033
# Batch:16400,G loss:-38.430,D Loss:-64.995,Q Loss:-1.873,0.027
# Batch:16500,G loss:-40.000,D Loss:-123.244,Q Loss:-1.964,0.022
# Batch:16600,G loss:-69.129,D Loss:-12.316,Q Loss:-1.897,0.164
# Batch:16700,G loss:-38.810,D Loss:-1.967,Q Loss:-2.106,0.052
# Batch:16800,G loss:-30.426,D Loss:-36.797,Q Loss:-2.089,0.014
# Batch:16900,G loss:-50.328,D Loss:-6.689,Q Loss:-1.797,0.195
# Batch:17000,G loss:-55.658,D Loss:-57.046,Q Loss:-2.213,0.212
# Batch:17100,G loss:12.850,D Loss:-8.023,Q Loss:-1.901,0.039
# Batch:17200,G loss:-31.669,D Loss:-21.309,Q Loss:-2.135,0.057
# Batch:17300,G loss:-19.960,D Loss:-78.197,Q Loss:-1.858,0.071
# Batch:17400,G loss:-35.514,D Loss:35.144,Q Loss:-2.137,0.343
# Batch:17500,G loss:-79.058,D Loss:-71.412,Q Loss:-1.717,0.029
# Batch:17600,G loss:49.825,D Loss:52.737,Q Loss:-2.094,0.051
# Batch:17700,G loss:-38.089,D Loss:-89.725,Q Loss:-2.181,0.051
# Batch:17800,G loss:-37.062,D Loss:-52.982,Q Loss:-1.493,0.107
# Batch:17900,G loss:18.431,D Loss:108.739,Q Loss:-1.706,0.237
# Batch:18000,G loss:-40.619,D Loss:-122.812,Q Loss:-2.007,0.043
# Batch:18100,G loss:-39.903,D Loss:-82.853,Q Loss:-2.049,0.072
# Batch:18200,G loss:-29.713,D Loss:-79.292,Q Loss:-2.113,0.035
# Batch:18300,G loss:-37.566,D Loss:-0.306,Q Loss:-2.253,0.011
# Batch:18400,G loss:-22.563,D Loss:-112.614,Q Loss:-2.054,0.058
# Batch:18500,G loss:-57.587,D Loss:40.853,Q Loss:-2.069,0.052
# Batch:18600,G loss:-40.777,D Loss:-5.036,Q Loss:-2.157,0.036
# Batch:18700,G loss:-29.119,D Loss:-19.301,Q Loss:-1.925,0.057
# Batch:18800,G loss:-70.135,D Loss:-78.285,Q Loss:-2.072,0.034
# Batch:18900,G loss:-18.416,D Loss:-81.300,Q Loss:-2.297,0.048
# Batch:19000,G loss:-34.857,D Loss:-45.746,Q Loss:-1.879,0.229
# Batch:19100,G loss:-21.407,D Loss:-141.499,Q Loss:-2.063,0.284
# Batch:19200,G loss:-5.828,D Loss:-88.667,Q Loss:-1.812,0.171
# Batch:19300,G loss:-59.603,D Loss:-67.841,Q Loss:-2.143,0.105
# Batch:19400,G loss:-44.245,D Loss:-87.114,Q Loss:-1.956,0.030
# Batch:19500,G loss:-33.334,D Loss:-64.679,Q Loss:-1.772,0.085
# Batch:19600,G loss:-57.061,D Loss:-85.950,Q Loss:-1.821,0.080
# Batch:19700,G loss:-53.662,D Loss:-52.900,Q Loss:-2.300,0.237
# Batch:19800,G loss:-45.802,D Loss:-49.006,Q Loss:-1.769,0.031
# Batch:19900,G loss:-99.837,D Loss:-68.533,Q Loss:-2.375,0.060
# Batch:20000,G loss:-19.945,D Loss:-58.668,Q Loss:-2.114,0.064
# Batch:20100,G loss:-70.501,D Loss:-28.417,Q Loss:-2.282,0.046
# Batch:20200,G loss:-24.236,D Loss:-72.445,Q Loss:-1.908,0.038
# Batch:20300,G loss:-41.148,D Loss:-65.270,Q Loss:-2.199,0.026
# Batch:20400,G loss:-11.227,D Loss:36.112,Q Loss:-1.976,0.035
# Batch:20500,G loss:-51.282,D Loss:-54.235,Q Loss:-2.029,0.014
# Batch:20600,G loss:-23.144,D Loss:-93.671,Q Loss:-2.165,0.088
# Batch:20700,G loss:-85.149,D Loss:-28.921,Q Loss:-1.899,0.026
# Batch:20800,G loss:-17.367,D Loss:-8.937,Q Loss:-1.636,0.053
# Batch:20900,G loss:-35.939,D Loss:-88.228,Q Loss:-2.144,0.027
# Batch:21000,G loss:-61.126,D Loss:-56.646,Q Loss:-1.979,0.019
# Batch:21100,G loss:-41.490,D Loss:-136.679,Q Loss:-1.999,0.123
# Batch:21200,G loss:-55.442,D Loss:47.188,Q Loss:-1.981,0.146
# Batch:21300,G loss:-16.914,D Loss:-115.451,Q Loss:-1.950,0.080
# Batch:21400,G loss:-40.768,D Loss:-67.717,Q Loss:-2.408,0.032
# Batch:21500,G loss:-44.002,D Loss:-103.588,Q Loss:-2.279,0.016
# Batch:21600,G loss:-58.316,D Loss:-95.664,Q Loss:-2.229,0.074
# Batch:21700,G loss:-26.578,D Loss:41.240,Q Loss:-1.926,0.078
# Batch:21800,G loss:-22.894,D Loss:-85.601,Q Loss:-1.990,0.031
# Batch:21900,G loss:-19.907,D Loss:-61.103,Q Loss:-2.043,0.067
# Batch:22000,G loss:-10.738,D Loss:-32.776,Q Loss:-2.067,0.004
# Batch:22100,G loss:-62.150,D Loss:-30.631,Q Loss:-2.132,0.059
# Batch:22200,G loss:-20.305,D Loss:-109.103,Q Loss:-2.070,0.133
# Batch:22300,G loss:-21.921,D Loss:-88.905,Q Loss:-1.786,0.127
# Batch:22400,G loss:-17.045,D Loss:-20.485,Q Loss:-1.701,0.048
# Batch:22500,G loss:-61.906,D Loss:-29.498,Q Loss:-1.928,0.123
# Batch:22600,G loss:-72.172,D Loss:-84.340,Q Loss:-1.879,0.007
# Batch:22700,G loss:-30.290,D Loss:-106.125,Q Loss:-2.324,0.019
# Batch:22800,G loss:40.919,D Loss:-13.660,Q Loss:-2.124,0.014
# Batch:22900,G loss:-56.305,D Loss:-86.288,Q Loss:-1.983,0.023
# Batch:23000,G loss:-72.374,D Loss:-24.831,Q Loss:-2.232,0.062
# Batch:23100,G loss:-15.328,D Loss:-104.106,Q Loss:-1.742,0.068
# Batch:23200,G loss:-203.010,D Loss:230.395,Q Loss:-1.610,0.333
# Batch:23300,G loss:-197.096,D Loss:-57.652,Q Loss:-2.161,0.013
# Batch:23400,G loss:-23.406,D Loss:-52.665,Q Loss:-2.132,0.041
# Batch:23500,G loss:9.851,D Loss:58.631,Q Loss:-2.086,2.354
# Batch:23600,G loss:-60.701,D Loss:-23.501,Q Loss:-2.190,0.074
# Batch:23700,G loss:-77.474,D Loss:-92.994,Q Loss:-2.081,0.010
# Batch:23800,G loss:-14.009,D Loss:-20.834,Q Loss:-2.077,0.115
# Batch:23900,G loss:-65.015,D Loss:7.177,Q Loss:-2.018,0.089
# Batch:24000,G loss:-140.456,D Loss:-0.200,Q Loss:-1.798,0.062
# Batch:24100,G loss:27.229,D Loss:61.980,Q Loss:-2.023,0.076
# Batch:24200,G loss:46.043,D Loss:171.092,Q Loss:-2.180,0.084
# Batch:24300,G loss:-120.508,D Loss:-107.267,Q Loss:-2.106,0.185
# Batch:24400,G loss:-41.563,D Loss:-65.851,Q Loss:-1.928,0.069
# Batch:24500,G loss:-39.574,D Loss:-127.734,Q Loss:-2.117,0.059
# Batch:24600,G loss:-25.108,D Loss:103.443,Q Loss:-1.821,0.186
# Batch:24700,G loss:-57.057,D Loss:-22.984,Q Loss:-2.334,0.105
# Batch:24800,G loss:-41.875,D Loss:50.107,Q Loss:-1.695,0.091
# Batch:24900,G loss:-21.004,D Loss:-26.073,Q Loss:-2.034,0.016
# Batch:25000,G loss:-26.418,D Loss:-66.526,Q Loss:-2.009,0.442
# Batch:25100,G loss:53.591,D Loss:-12.442,Q Loss:-1.995,0.073
# Batch:25200,G loss:-48.076,D Loss:-91.280,Q Loss:-2.055,0.008
# Batch:25300,G loss:-40.316,D Loss:-94.493,Q Loss:-1.669,0.030
# Batch:25400,G loss:-38.345,D Loss:-74.452,Q Loss:-1.940,0.034
# Batch:25500,G loss:-48.465,D Loss:-48.904,Q Loss:-1.713,0.045
# Batch:25600,G loss:-15.526,D Loss:7.009,Q Loss:-1.999,0.035
# Batch:25700,G loss:-22.740,D Loss:-86.418,Q Loss:-2.097,0.040
# Batch:25800,G loss:-39.419,D Loss:-6.174,Q Loss:-2.002,0.023
# Batch:25900,G loss:-1.697,D Loss:-60.434,Q Loss:-1.916,0.115
# Batch:26000,G loss:-53.007,D Loss:10.801,Q Loss:-1.871,0.152
# Batch:26100,G loss:-59.026,D Loss:-74.829,Q Loss:-2.261,0.008
# Batch:26200,G loss:-10.569,D Loss:-84.051,Q Loss:-2.148,0.048
# Batch:26300,G loss:-36.845,D Loss:-91.260,Q Loss:-2.034,0.065
# Batch:26400,G loss:-69.027,D Loss:-34.093,Q Loss:-1.904,0.044
# Batch:26500,G loss:-60.724,D Loss:-82.009,Q Loss:-2.072,0.174
# Batch:26600,G loss:-49.420,D Loss:-87.255,Q Loss:-2.093,0.061
# Batch:26700,G loss:-64.590,D Loss:-80.926,Q Loss:-2.383,0.012
# Batch:26800,G loss:-52.126,D Loss:-58.204,Q Loss:-2.043,0.534
# Batch:26900,G loss:-64.658,D Loss:-40.528,Q Loss:-1.995,0.058
# Batch:27000,G loss:-50.414,D Loss:-78.624,Q Loss:-2.253,0.019
# Batch:27100,G loss:-35.800,D Loss:-65.570,Q Loss:-1.957,0.047
# Batch:27200,G loss:-33.078,D Loss:-57.997,Q Loss:-1.978,0.036
# Batch:27300,G loss:-51.019,D Loss:-64.008,Q Loss:-2.051,0.084
# Batch:27400,G loss:-169.370,D Loss:-30.433,Q Loss:-2.003,0.076
# Batch:27500,G loss:-70.697,D Loss:-34.018,Q Loss:-1.730,0.012
# Batch:27600,G loss:9.279,D Loss:-68.100,Q Loss:-2.321,0.074
# Batch:27700,G loss:-42.387,D Loss:-86.116,Q Loss:-2.075,0.276
# Batch:27800,G loss:-41.599,D Loss:-83.916,Q Loss:-1.971,0.027
# Batch:27900,G loss:-43.810,D Loss:-99.559,Q Loss:-1.909,0.043
# Batch:28000,G loss:-50.146,D Loss:-89.209,Q Loss:-1.739,0.045
# Batch:28100,G loss:-39.130,D Loss:-104.989,Q Loss:-2.255,0.091
# Batch:28200,G loss:-26.092,D Loss:-78.304,Q Loss:-1.841,0.120
# Batch:28300,G loss:-77.346,D Loss:-7.202,Q Loss:-2.172,0.167
# Batch:28400,G loss:-16.336,D Loss:-45.792,Q Loss:-2.393,0.063
# Batch:28500,G loss:-25.481,D Loss:-120.169,Q Loss:-1.777,0.029
# Batch:28600,G loss:8.911,D Loss:-8.343,Q Loss:-2.106,0.086
# Batch:28700,G loss:-38.541,D Loss:-40.712,Q Loss:-2.185,0.061
# Batch:28800,G loss:-48.150,D Loss:-52.822,Q Loss:-1.911,0.028
# Batch:28900,G loss:-40.016,D Loss:-76.492,Q Loss:-1.920,0.170
# Batch:29000,G loss:-69.668,D Loss:-83.609,Q Loss:-1.990,0.041
# Batch:29100,G loss:-143.967,D Loss:26.689,Q Loss:-1.950,0.175
# Batch:29200,G loss:-2.754,D Loss:-65.912,Q Loss:-2.160,0.108
# Batch:29300,G loss:-47.803,D Loss:20.121,Q Loss:-2.041,0.057
# Batch:29400,G loss:-45.586,D Loss:-56.254,Q Loss:-2.165,0.039
# Batch:29500,G loss:-22.431,D Loss:-24.077,Q Loss:-1.764,0.090
# Batch:29600,G loss:-66.562,D Loss:12.443,Q Loss:-2.422,0.257
# Batch:29700,G loss:-16.915,D Loss:-124.178,Q Loss:-1.903,0.080
# Batch:29800,G loss:-52.836,D Loss:-39.184,Q Loss:-2.026,0.023
# Batch:29900,G loss:-75.318,D Loss:-54.424,Q Loss:-2.278,0.029
# Batch:30000,G loss:-63.278,D Loss:-53.552,Q Loss:-1.813,0.071
# Batch:30100,G loss:-70.718,D Loss:-75.933,Q Loss:-1.851,0.065
# Batch:30200,G loss:-47.566,D Loss:-78.410,Q Loss:-2.004,0.044
# Batch:30300,G loss:-57.834,D Loss:-43.538,Q Loss:-2.078,0.058
# Batch:30400,G loss:-39.794,D Loss:-18.039,Q Loss:-2.087,0.186
# Batch:30500,G loss:-70.275,D Loss:-4.899,Q Loss:-2.033,0.067
# Batch:30600,G loss:-43.583,D Loss:-64.017,Q Loss:-1.917,0.020
# Batch:30700,G loss:-52.612,D Loss:-47.326,Q Loss:-1.769,0.224
# Batch:30800,G loss:10.989,D Loss:21.435,Q Loss:-2.038,0.059
# Batch:30900,G loss:-40.642,D Loss:-91.765,Q Loss:-2.263,0.871
# Batch:31000,G loss:-26.243,D Loss:-54.442,Q Loss:-2.524,0.051
# Batch:31100,G loss:-24.719,D Loss:-58.098,Q Loss:-1.873,0.065
# Batch:31200,G loss:-36.850,D Loss:-75.998,Q Loss:-2.532,0.028
# Batch:31300,G loss:-62.897,D Loss:-59.618,Q Loss:-1.908,0.125
# Batch:31400,G loss:-64.269,D Loss:-40.872,Q Loss:-2.177,0.066
# Batch:31500,G loss:-47.755,D Loss:-75.077,Q Loss:-1.827,0.057
# Batch:31600,G loss:-59.336,D Loss:39.728,Q Loss:-1.698,0.080
# Batch:31700,G loss:-14.104,D Loss:-21.642,Q Loss:-1.750,0.047
# Batch:31800,G loss:-79.880,D Loss:-107.807,Q Loss:-2.383,0.035
# Batch:31900,G loss:-51.936,D Loss:-95.495,Q Loss:-1.984,0.048
# Batch:32000,G loss:-13.361,D Loss:-111.240,Q Loss:-1.936,0.020
# Batch:32100,G loss:-33.346,D Loss:-96.048,Q Loss:-2.384,0.016
# Batch:32200,G loss:-32.413,D Loss:-113.243,Q Loss:-1.870,0.041
# Batch:32300,G loss:-54.138,D Loss:-102.198,Q Loss:-2.249,0.023
# Batch:32400,G loss:-53.350,D Loss:45.835,Q Loss:-2.121,0.085
# Batch:32500,G loss:-59.006,D Loss:-10.933,Q Loss:-2.104,0.080
# Batch:32600,G loss:-45.942,D Loss:-80.723,Q Loss:-2.046,0.032
# Batch:32700,G loss:-47.260,D Loss:-71.317,Q Loss:-2.228,0.020
# Batch:32800,G loss:-70.795,D Loss:-22.414,Q Loss:-2.164,0.056
# Batch:32900,G loss:-36.962,D Loss:-81.250,Q Loss:-1.935,0.022
# Batch:33000,G loss:-62.989,D Loss:-71.452,Q Loss:-1.667,0.072
# Batch:33100,G loss:-39.895,D Loss:-78.763,Q Loss:-2.181,0.044
# Batch:33200,G loss:-52.071,D Loss:-46.543,Q Loss:-1.653,0.026
# Batch:33300,G loss:-74.294,D Loss:-41.409,Q Loss:-1.677,0.018
# Batch:33400,G loss:-27.062,D Loss:-75.687,Q Loss:-2.124,0.017
# Batch:33500,G loss:-25.955,D Loss:-66.859,Q Loss:-2.229,0.053
# Batch:33600,G loss:-15.766,D Loss:-88.033,Q Loss:-1.661,0.188
# Batch:33700,G loss:-26.109,D Loss:-71.298,Q Loss:-2.195,0.047
# Batch:33800,G loss:-44.314,D Loss:5.810,Q Loss:-2.029,0.040
# Batch:33900,G loss:-26.524,D Loss:-76.441,Q Loss:-1.919,0.211
# Batch:34000,G loss:-42.496,D Loss:46.748,Q Loss:-1.780,0.158
# Batch:34100,G loss:-22.289,D Loss:25.436,Q Loss:-1.824,0.085
# Batch:34200,G loss:-22.350,D Loss:-83.702,Q Loss:-1.878,0.043
# Batch:34300,G loss:-68.581,D Loss:-34.596,Q Loss:-2.188,0.087
# Batch:34400,G loss:-26.179,D Loss:-48.121,Q Loss:-1.999,0.068
# Batch:34500,G loss:-39.313,D Loss:-52.246,Q Loss:-1.836,0.036
# Batch:34600,G loss:-19.779,D Loss:-91.600,Q Loss:-1.849,0.181
# Batch:34700,G loss:-36.196,D Loss:-83.049,Q Loss:-2.327,0.086
# Batch:34800,G loss:-29.983,D Loss:-41.446,Q Loss:-2.023,0.058
# Batch:34900,G loss:-18.228,D Loss:-57.707,Q Loss:-2.077,0.048
# Batch:35000,G loss:-29.481,D Loss:-85.910,Q Loss:-2.014,0.031
# Batch:35100,G loss:-31.494,D Loss:16.658,Q Loss:-1.968,0.106
# Batch:35200,G loss:-54.569,D Loss:-49.635,Q Loss:-1.897,0.049
# Batch:35300,G loss:-36.370,D Loss:-62.475,Q Loss:-1.857,0.033
# Batch:35400,G loss:-21.417,D Loss:-87.053,Q Loss:-2.285,0.034
# Batch:35500,G loss:-16.757,D Loss:-86.471,Q Loss:-1.857,0.033
# Batch:35600,G loss:-15.434,D Loss:-29.162,Q Loss:-2.093,0.017
# Batch:35700,G loss:-33.207,D Loss:-61.594,Q Loss:-1.973,0.072
# Batch:35800,G loss:-24.258,D Loss:-68.407,Q Loss:-1.929,0.094
# Batch:35900,G loss:-44.819,D Loss:-70.217,Q Loss:-1.773,0.095
# Batch:36000,G loss:-24.387,D Loss:-39.798,Q Loss:-2.060,0.140
# Batch:36100,G loss:-22.752,D Loss:-95.158,Q Loss:-2.398,0.042
# Batch:36200,G loss:-38.945,D Loss:-50.786,Q Loss:-1.797,0.036
# Batch:36300,G loss:-46.220,D Loss:-63.030,Q Loss:-2.107,0.047
# Batch:36400,G loss:-47.500,D Loss:-55.540,Q Loss:-1.672,0.080
# Batch:36500,G loss:-30.801,D Loss:-46.704,Q Loss:-2.076,0.069
# Batch:36600,G loss:-47.990,D Loss:-58.139,Q Loss:-2.030,0.034
# Batch:36700,G loss:-46.932,D Loss:-88.183,Q Loss:-2.143,0.025
# Batch:36800,G loss:-66.871,D Loss:-102.512,Q Loss:-2.196,1.193
# Batch:36900,G loss:-27.122,D Loss:2.856,Q Loss:-2.176,0.226
# Batch:37000,G loss:-38.678,D Loss:-71.495,Q Loss:-1.960,0.011
# Batch:37100,G loss:-18.843,D Loss:-87.817,Q Loss:-2.414,0.052
# Batch:37200,G loss:-32.538,D Loss:-74.729,Q Loss:-1.891,0.045
# Batch:37300,G loss:-53.973,D Loss:-59.892,Q Loss:-1.917,0.057
# Batch:37400,G loss:-49.377,D Loss:-95.085,Q Loss:-1.731,0.008
# Batch:37500,G loss:-23.248,D Loss:-95.031,Q Loss:-2.154,0.018
# Batch:37600,G loss:-48.915,D Loss:-6.155,Q Loss:-1.695,0.034
# Batch:37700,G loss:-46.368,D Loss:-85.128,Q Loss:-2.106,0.060
# Batch:37800,G loss:-35.303,D Loss:-92.432,Q Loss:-2.174,0.022
# Batch:37900,G loss:-75.131,D Loss:-15.438,Q Loss:-1.637,0.028
# Batch:38000,G loss:-35.948,D Loss:-50.700,Q Loss:-2.260,0.023
# Batch:38100,G loss:-32.224,D Loss:-42.752,Q Loss:-2.183,0.060
# Batch:38200,G loss:-9.226,D Loss:-68.694,Q Loss:-2.034,0.048
# Batch:38300,G loss:-90.253,D Loss:9.137,Q Loss:-2.277,0.014
# Batch:38400,G loss:-31.916,D Loss:63.897,Q Loss:-2.152,0.125
# Batch:38500,G loss:-33.107,D Loss:-87.115,Q Loss:-2.202,0.103
# Batch:38600,G loss:-13.021,D Loss:-110.805,Q Loss:-1.867,0.106
# Batch:38700,G loss:-6.833,D Loss:-40.161,Q Loss:-1.959,0.223
# Batch:38800,G loss:-20.031,D Loss:68.784,Q Loss:-2.217,0.453
# Batch:38900,G loss:-10.151,D Loss:-75.037,Q Loss:-1.909,0.122
# Batch:39000,G loss:-23.130,D Loss:-120.251,Q Loss:-2.173,0.056
# Batch:39100,G loss:-69.500,D Loss:-78.391,Q Loss:-1.977,0.025
# Batch:39200,G loss:-25.603,D Loss:-109.140,Q Loss:-2.194,0.065
# Batch:39300,G loss:-60.102,D Loss:41.140,Q Loss:-2.049,0.201
# Batch:39400,G loss:-29.938,D Loss:23.193,Q Loss:-2.121,0.125
# Batch:39500,G loss:-34.144,D Loss:-6.331,Q Loss:-1.934,3.779
# Batch:39600,G loss:11.082,D Loss:-35.938,Q Loss:-1.913,0.067
# Batch:39700,G loss:-79.263,D Loss:-88.134,Q Loss:-2.034,0.202
# Batch:39800,G loss:-49.276,D Loss:-75.168,Q Loss:-1.791,0.057
# Batch:39900,G loss:-53.631,D Loss:-7.188,Q Loss:-2.145,0.440
# Batch:40000,G loss:-29.323,D Loss:-31.518,Q Loss:-1.785,0.118
# Batch:40100,G loss:-31.014,D Loss:-67.942,Q Loss:-1.806,0.060
# Batch:40200,G loss:-15.524,D Loss:-83.962,Q Loss:-2.001,0.072
# Batch:40300,G loss:-25.163,D Loss:-72.236,Q Loss:-2.007,0.035
# Batch:40400,G loss:-21.606,D Loss:-119.032,Q Loss:-1.772,0.042
# Batch:40500,G loss:-15.608,D Loss:-74.432,Q Loss:-2.001,0.036
# Batch:40600,G loss:-33.449,D Loss:-40.199,Q Loss:-1.513,0.040
# Batch:40700,G loss:-19.416,D Loss:-77.217,Q Loss:-2.334,0.110
# Batch:40800,G loss:-38.011,D Loss:-30.623,Q Loss:-2.037,0.085
# Batch:40900,G loss:-39.498,D Loss:-43.257,Q Loss:-2.004,0.023
# Batch:41000,G loss:-59.496,D Loss:138.785,Q Loss:-2.084,0.684
# Batch:41100,G loss:14.172,D Loss:21.647,Q Loss:-2.103,0.171
# Batch:41200,G loss:-27.816,D Loss:-57.456,Q Loss:-1.591,0.059
# Batch:41300,G loss:-29.950,D Loss:-70.767,Q Loss:-1.755,0.066
# Batch:41400,G loss:-45.395,D Loss:-44.140,Q Loss:-1.973,0.207
# Batch:41500,G loss:-36.970,D Loss:-70.163,Q Loss:-1.683,0.050
# Batch:41600,G loss:-23.562,D Loss:-98.964,Q Loss:-1.949,0.047
# Batch:41700,G loss:-12.998,D Loss:-56.570,Q Loss:-1.662,0.056
# Batch:41800,G loss:-20.283,D Loss:-67.776,Q Loss:-1.706,0.174
# Batch:41900,G loss:-13.987,D Loss:-63.114,Q Loss:-1.463,0.052
# Batch:42000,G loss:-25.438,D Loss:10.349,Q Loss:-1.935,0.060
# Batch:42100,G loss:-43.644,D Loss:-57.923,Q Loss:-1.868,0.020
# Batch:42200,G loss:-34.996,D Loss:-71.930,Q Loss:-2.118,0.034
# Batch:42300,G loss:-105.053,D Loss:25.066,Q Loss:-2.152,0.024
# Batch:42400,G loss:-3.668,D Loss:-63.733,Q Loss:-2.313,0.115
# Batch:42500,G loss:-17.304,D Loss:-74.264,Q Loss:-1.881,0.037
# Batch:42600,G loss:-66.197,D Loss:-1.994,Q Loss:-2.000,0.023
# Batch:42700,G loss:-21.445,D Loss:-68.371,Q Loss:-2.501,0.095
# Batch:42800,G loss:-36.778,D Loss:-83.136,Q Loss:-1.766,0.108
# Batch:42900,G loss:-9.979,D Loss:-55.822,Q Loss:-1.882,0.050
# Batch:43000,G loss:3.172,D Loss:74.414,Q Loss:-2.083,1.210
# Batch:43100,G loss:-121.567,D Loss:204.178,Q Loss:-2.355,0.136
# Batch:43200,G loss:-67.819,D Loss:-32.517,Q Loss:-1.740,0.021
# Batch:43300,G loss:-39.055,D Loss:-47.233,Q Loss:-1.940,0.046
# Batch:43400,G loss:-16.936,D Loss:-28.222,Q Loss:-2.134,0.019
# Batch:43500,G loss:-12.833,D Loss:-60.171,Q Loss:-2.328,0.061
# Batch:43600,G loss:-32.185,D Loss:-51.426,Q Loss:-1.689,0.035
# Batch:43700,G loss:-28.969,D Loss:-30.083,Q Loss:-2.045,0.038
# Batch:43800,G loss:-21.624,D Loss:-26.627,Q Loss:-1.993,0.098
# Batch:43900,G loss:-34.189,D Loss:-50.276,Q Loss:-1.865,0.014
# Batch:44000,G loss:-21.073,D Loss:-26.723,Q Loss:-2.055,0.018
# Batch:44100,G loss:0.847,D Loss:18.467,Q Loss:-1.912,0.687
# Batch:44200,G loss:-27.481,D Loss:-51.018,Q Loss:-1.897,0.037
# Batch:44300,G loss:-31.604,D Loss:-37.167,Q Loss:-2.103,0.015
# Batch:44400,G loss:-30.939,D Loss:-42.320,Q Loss:-1.874,0.017
# Batch:44500,G loss:-26.285,D Loss:-56.929,Q Loss:-2.041,0.052
# Batch:44600,G loss:-36.510,D Loss:-21.356,Q Loss:-2.112,0.050
# Batch:44700,G loss:-11.663,D Loss:-13.805,Q Loss:-1.934,0.496
# Batch:44800,G loss:-26.025,D Loss:-28.806,Q Loss:-2.150,0.055
# Batch:44900,G loss:-38.094,D Loss:-60.288,Q Loss:-2.190,0.071
# Batch:45000,G loss:-18.231,D Loss:-60.147,Q Loss:-2.068,0.030
# Batch:45100,G loss:-22.016,D Loss:-23.560,Q Loss:-2.121,0.043
# Batch:45200,G loss:-28.981,D Loss:-27.578,Q Loss:-1.979,0.048
# Batch:45300,G loss:-30.240,D Loss:-32.403,Q Loss:-2.121,0.061
# Batch:45400,G loss:-20.885,D Loss:-41.764,Q Loss:-2.347,0.035
# Batch:45500,G loss:-53.817,D Loss:-62.925,Q Loss:-1.817,0.100
# Batch:45600,G loss:-26.639,D Loss:-17.151,Q Loss:-2.043,0.070
# Batch:45700,G loss:-28.365,D Loss:-69.013,Q Loss:-2.076,0.053
# Batch:45800,G loss:-35.382,D Loss:-63.489,Q Loss:-1.842,0.070
# Batch:45900,G loss:-32.176,D Loss:-68.878,Q Loss:-1.986,0.032
# Batch:46000,G loss:-33.209,D Loss:-76.057,Q Loss:-2.092,0.036
# Batch:46100,G loss:-68.216,D Loss:15.104,Q Loss:-2.000,0.533
# Batch:46200,G loss:-17.212,D Loss:-52.276,Q Loss:-2.130,0.070
# Batch:46300,G loss:-37.440,D Loss:-62.893,Q Loss:-1.892,0.010
# Batch:46400,G loss:-18.613,D Loss:-12.679,Q Loss:-1.952,0.110
# Batch:46500,G loss:-30.050,D Loss:140.365,Q Loss:-2.035,0.102
# Batch:46600,G loss:-22.039,D Loss:-6.982,Q Loss:-2.220,0.089
# Batch:46700,G loss:-8.163,D Loss:-69.676,Q Loss:-1.989,0.108
# Batch:46800,G loss:-18.904,D Loss:-72.446,Q Loss:-2.022,0.030
# Batch:46900,G loss:-23.041,D Loss:-20.926,Q Loss:-1.801,0.060
# Batch:47000,G loss:8.060,D Loss:39.989,Q Loss:-1.772,3.185
# Batch:47100,G loss:-26.495,D Loss:-52.686,Q Loss:-2.132,0.019
# Batch:47200,G loss:-18.117,D Loss:-31.366,Q Loss:-2.231,0.558
# Batch:47300,G loss:-26.450,D Loss:-57.977,Q Loss:-2.149,0.031
# Batch:47400,G loss:-8.895,D Loss:-13.521,Q Loss:-2.024,0.040
# Batch:47500,G loss:-38.013,D Loss:-0.472,Q Loss:-2.146,0.028
# Batch:47600,G loss:-40.777,D Loss:-33.775,Q Loss:-2.242,0.050
# Batch:47700,G loss:-15.704,D Loss:-37.371,Q Loss:-2.244,0.033
# Batch:47800,G loss:-37.042,D Loss:-26.044,Q Loss:-2.057,0.048
# Batch:47900,G loss:-16.435,D Loss:-47.459,Q Loss:-1.984,0.059
# Batch:48000,G loss:-5.258,D Loss:-30.850,Q Loss:-1.748,0.042
# Batch:48100,G loss:-35.544,D Loss:-37.813,Q Loss:-1.874,0.038
# Batch:48200,G loss:-17.250,D Loss:-4.453,Q Loss:-1.841,0.021
# Batch:48300,G loss:-11.333,D Loss:-54.225,Q Loss:-1.899,0.112
# Batch:48400,G loss:-28.808,D Loss:-48.866,Q Loss:-1.968,0.023
# Batch:48500,G loss:-34.172,D Loss:-8.336,Q Loss:-1.702,0.045
# Batch:48600,G loss:-29.555,D Loss:-45.947,Q Loss:-2.049,0.040
# Batch:48700,G loss:-26.554,D Loss:-36.775,Q Loss:-2.511,0.041
# Batch:48800,G loss:-40.459,D Loss:-24.743,Q Loss:-1.916,0.046
# Batch:48900,G loss:-15.280,D Loss:42.031,Q Loss:-2.287,0.084
# Batch:49000,G loss:-4.858,D Loss:-27.473,Q Loss:-1.733,0.024
# Batch:49100,G loss:-29.322,D Loss:-75.199,Q Loss:-2.253,0.011
# Batch:49200,G loss:-31.938,D Loss:15.285,Q Loss:-1.981,0.628
# Batch:49300,G loss:-18.324,D Loss:33.153,Q Loss:-1.978,0.142
# Batch:49400,G loss:-36.069,D Loss:-74.056,Q Loss:-1.949,0.026
# Batch:49500,G loss:-25.577,D Loss:-74.748,Q Loss:-1.783,0.045
# Batch:49600,G loss:-56.459,D Loss:11.883,Q Loss:-1.846,0.211
# Batch:49700,G loss:-42.627,D Loss:-58.534,Q Loss:-2.258,0.040
# Batch:49800,G loss:-55.540,D Loss:48.971,Q Loss:-2.320,0.478
# Batch:49900,G loss:-5.258,D Loss:73.103,Q Loss:-1.799,0.253

# %%
d_loss,g_loss = [np.array(var) for var in(d_loss,g_loss)]    
plt.plot(np.arange(max_iters),d_loss,'-r',np.arange(max_iters),g_loss,'-b')
plt.show()

# %%
plt.plot(np.arange(max_iters),d_loss,'-r')
plt.show()

# %%
plt.plot(np.arange(max_iters),g_loss,'-b')
plt.show()

# %%
plt.plot(np.arange(max_iters),q_loss,'-b')
plt.show()

# %%
plt.plot(np.arange(max_iters),qcont,'-b')
plt.show()

# %%
plt.plot(np.arange(max_iters),qcat,'-b')
plt.show()

# %%
def test(ckpt_dir=ckpt_dir):
    
    with tf.Session(config = tf.ConfigProto(allow_soft_placement=True,log_device_placement=True)) as sess:
        # build graph
        with tf.device(device):
            gen,z_rand,z_cont,z_cat = build_graph(is_test=True)
        
        # use saver to reload the parametes
        saver = tf.train.Saver()
        #saver.restore(sess, './Inproved_rgan/cgan_2d/Experient_1/ckpt_rgan\\model_checkpoint-17000')
        saver.restore(sess,tf.train.latest_checkpoint(ckpt_dir))
        
        ###########################################  Experiment : Generator #################
        # Gererate random labels as conditions , [0,1] gausson distribution
        z_rand_sample = np.random.normal(0,0.3,[batch_size,z_dim])
        # To construct grid sample 
        z_cat_sample = np.reshape(np.array([int(e/batch_size*10) for e in range(batch_size)]),[batch_size,len(cat_list)])                
        #z_cat_sample = np.tile(np.random.normal(1),[batch_size,1])
        z_cont_sample = np.zeros((batch_size,cont_num))
#         z_cont_sample = np.linspace(0,1,batch_size).reshape(batch_size,1)
#         z_cont_sample = np.hstack((z_cont_sample,np.zeros_like(z_cont_sample)))

        samples = sess.run(gen,{z_rand:z_rand_sample,z_cat:z_cat_sample,z_cont:z_cont_sample})

        save_spectrum(samples, 0,is_show=True)

# %%
tf.reset_default_graph()
test()
# Out:
# INFO:tensorflow:Restoring parameters from ./Inproved_rgan/cgan_2d/Experient_1/ckpt_rgan\model_checkpoint-49000
