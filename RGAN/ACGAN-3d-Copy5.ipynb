# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly

import os
import shutil
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from collections import defaultdict
import _pickle as pickle

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110

# Define salient variable
cat_list = [] # Each entry in this list defines a categorical variable for specific size
cont_num = 1 # the number of continous variables

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1
# Updata Diters times for critic in one iter(unless i<25 or i %500==0, i is the iterstep)
Riters = 10
Diters = 5
Diters = int(((Riters+1)/Riters*Diters))


# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/RGAN/Experient_5'
log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
x,y = (x - xmin)/( xmax - xmin ),(y - ymin)/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)
y= y.reshape(-1,cont_num)

## split the dataset
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.10,random_state=0)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 1024, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = ly.fully_connected(train, 256*172, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = tf.reshape(train,(-1,256,172,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[1,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv( x ,cat_list =cat_list ,cont_num =cont_num,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img = ly.conv2d(x,num_outputs=size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img_out = ly.conv2d(img ,num_outputs= size*8 ,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        img = ly.conv2d(img_out ,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        
        # fully_connected
        disc_img = tf.reshape(img,[batch_size,-1])
        disc_img = ly.fully_connected(disc_img,1024,activation_fn=lrelu)
        disc = ly.fully_connected(disc_img,1,activation_fn=None)
        
        # Here we difine the unique layers used for the q_network, the number of outputs 
        q_img = ly.conv2d(img_out,num_outputs= size*8,kernel_size=[10,1],stride=[1,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        q_img = tf.reshape(q_img,[batch_size,-1])
        q_img = ly.fully_connected(q_img,1024,activation_fn=lrelu)
        
        q_cat_outs = []
        if len(cat_list)>0:
            for idx,var in enumerate(cat_list):
                q_outA = ly.fully_connected(q_img,var, activation_fn=tf.nn.softmax)
                q_cat_outs.append(q_outA)
        
        q_cont_outs = []
        if cont_num>0:
            q_cont_outs = ly.fully_connected(q_img,cont_num,activation_fn = tf.nn.tanh)
    
    return disc, q_cat_outs, q_cont_outs

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # Real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[batch_size,channel,img_dim,1])
    real_label = tf.placeholder(dtype = tf.float32,shape = [batch_size,cont_num])
    # Noise ;Continous variable, and rand variable to provide some variance
    z_cont = tf.placeholder(dtype = tf.float32,shape =[batch_size,cont_num])
    z_rand = tf.placeholder(dtype =tf.float32,shape =[batch_size,z_dim])
    # Categorical variable
    if len(cat_list)>0:
        z_cat = tf.placeholder(dtype = tf.int32, shape=[batch_size,len(cat_list)])
        cat_var = tf.split(z_cat , len(cat_list),axis=1)

        cat_z =[]
        for idx ,depth in enumerate(cat_list):
            cat_temp = tf.one_hot(tf.reshape(cat_var[idx],[-1]), depth)
            cat_z.append(cat_temp)
    else:
        z_cat = tf.placeholder(dtype =tf.float32,shape =[batch_size,10])
        cat_z = [z_cat]
    # Conbine all of the variable
    z = cat_z[:]
    z.append(z_cont)
    z.append(z_rand)
    z = tf.concat( z,axis=1)
    
    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    if is_test:
        return gen,z_rand,z_cont,z_cat
    
    disc_real,cat_real,cont_real = discriminator(real_data)
    disc_fake,cat_fake,cont_fake = discriminator(gen, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
    
    # Combine losses for each of categorical variables
    if len(cat_list)>0:
        cat_losses_f =[]
        tiny = 1e-10
        for idx,var in enumerate(cat_z):
            cat_loss_f = -tf.reduce_sum(var *tf.log(cat_fake[idx]+tiny),reduction_indices=1)
            cat_losses_f.append(cat_loss_f)
            # cat_losses_r 
    else:
        cat_losses_f=cat_losses_r = tf.constant(0.0)
    # Combine losses for each of continous variables
    # MSE
    if cont_num>0:
        cont_loss_f = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_fake-z_cont),reduction_indices=1))
        cont_loss_r = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_real- real_label),reduction_indices=1))
    else:
        cont_loss_f = cont_loss_r = tf.constant(0.0)
    
    # Loss balance parameter
    alpha = 1
    q_cont_loss = cont_loss_r + alpha* cont_loss_f
    q_cat_loss = tf.constant(0.0)
    q_loss = tf.add(q_cont_loss,q_cat_loss)
    
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss + 0.0 *cont_loss_f
    loss_dis = d_loss
    loss_qnt = cont_loss_r
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')
    theta_c = theta_d[10:]

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    counter_q = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_q = optimize(loss =loss_qnt ,variables=theta_c ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_image(specs ,size,i =100,image_path = rgan_dir):
    _,ax = plt.subplots(size[0],size[1],sharex = True,sharey = True)
    for i in range(size[0]):
        for j in range(size[1]):
            ax[i][j].plot(np.arange(specs.shape[1]),specs[i*10+j] ,'-*')
    
    plt.savefig(image_path+'/'+str(i).zfill(4)+'.png')
    plt.close()

# %%
def save_spectrum(gen, i,spec_size = 10,is_show=False):
    if gen.shape[0]<spec_size:
        spec_size = gen.shape[0]

    gen = gen[:spec_size]
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,spec_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, spec_size))
    # convert data to ideal format    
    spec = gen.reshape(spec_size,img_dim)*(xmax-xmin)+ xmin
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')    
    plt.legend([np.array_str(var) for var in np.arange(spec_size)])
    if intv ==0:
        plt.ylim([-0.5,scale])
    else:
        plt.ylim([-0.5,scale*spec_size*intv])
    
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_rgan(max_iters = 1000):
    # build graph
    with tf.device(device):
        opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,\
        loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss = build_graph()
        
    saver = tf.train.Saver()

    def next_feed_dict(iter, shuffled = True,is_test =False):
        
        # feed image and label,train set if is_test=False
        # otherwise test set
        def generate_index(input,iter,shuffled =shuffled):
            input_number = input.shape[0]
            if shuffled:
                idx = np.random.randint(input_number,size=(batch_size,))
            else:
                bat_num = int(input_number/batch_size)
                par = int(iter % bat_num)
                idx = np.arange(input_number)[par * batch_size:(par+1)*batch_size]
            return idx
        
        if is_test:
            idx = generate_index(x_train,iter)
            feed_img,feed_label = x_train[idx],y_train[idx]
        else:
            idx = generate_index(x_test,iter)
            feed_img,feed_label = x_test[idx],y_test[idx]
        
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
        if len(cat_list)>0:
            batch_z_cat  = np.random.randint(0,10,[batch_size,len(cat_list)])
        else:
            batch_z_cat = np.random.normal(0,0.3,[batch_size,10]).astype(np.float32)
        
        batch_z_cont = np.random.uniform(-1,1,[batch_size,cont_num])     
        
        feed_dict = {real_data:feed_img, 
                     z_rand : batch_z_rand,
                     z_cat  : batch_z_cat,
                     z_cont : batch_z_cont,
                     real_label:feed_label }
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        
        # use two dict-like container to record of history data
        # for analysising the result
        history = defaultdict(list)
        
        for i in range(max_iters):
            
            start_time = time.time()
            ## Training Phase
            feed_dict = next_feed_dict(i)
            
            _,dLoss = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,gLoss,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            _,qLoss,qCont,qCat = sess.run([opt_q, loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['train_loss'].append([dLoss,gLoss,qLoss,qCont,qCat])
            
            ## Testing Phase
            feed_dict = next_feed_dict(i,is_test=True)
        
            dLoss_ = sess.run(loss_dis,feed_dict = feed_dict)
            gLoss_ = sess.run(loss_gen,feed_dict = feed_dict)
            qLoss_ ,qCont_ ,qCat_ = sess.run([loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['test_loss'].append([dLoss_ ,gLoss_ ,qLoss_ ,qCont_ ,qCat_])
            if i % 100 == 0:
                elapse = time.time() - start_time
                time_left = (max_iters-i-1)* elapse
                print('\nIteration: {:0>5d}({:0.2%}) of {} \t Time left:{:02d}:{:02d}:{:02d}'.format(i,i/max_iters,max_iters,\
                     int(time_left/3600),int(time_left%3600/60),int(time_left%60)))
                
                print('{0:<8s} | {1:<15s} | {2:<15s} | {3:<15s} | {4:<15s} | {5:<15s}'\
                    .format('Loss','generator','discriminator','Q network','Q_continous','Q_categorical'))
                print('-' * 98)
                row_fmt = '{0:<8s} | {1:<15.3f} | {2:<15.3f} | {3:<15.3f} | {4:<15.3f} | {5:<15.3f}'
                print(row_fmt.format('train',*history['train_loss'][-1]))
                print(row_fmt.format('test' ,*history['test_loss'][-1]))
                save_spectrum(spec, i)
                
        

            if i %1000 ==0:
                saver.save(sess, os.path.join(ckpt_dir,'model_checkpoint'),global_step=i)
            
        pickle.dump(history,open(rgan_dir+'/rgan_pickle.pkl','wb'))

# %%
tf.reset_default_graph()
max_iters = 20000
train_rgan(max_iters =max_iters)
# Out:
# Iteration: 00000(0.00%) of 20000 	 Time left:05:11:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.028          | 0.512           | 0.151           | 0.367           | 0.000
# test     | -0.251          | -0.512          | 0.133           | 0.271           | 0.000
#
# Iteration: 00100(0.50%) of 20000 	 Time left:01:22:46
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -388.928        | 142.220         | 0.027           | 0.520           | 0.000
# test     | -422.842        | 137.323         | 0.023           | 0.397           | 0.000
#
# Iteration: 00200(1.00%) of 20000 	 Time left:01:22:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -533.947        | 188.961         | 0.026           | 0.173           | 0.000
# test     | -226.178        | -221.923        | 0.018           | 0.238           | 0.000
#
# Iteration: 00300(1.50%) of 20000 	 Time left:01:21:56
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -912.883        | 496.535         | 0.023           | 0.510           | 0.000
# test     | -957.202        | 493.720         | 0.028           | 0.499           | 0.000
#
# Iteration: 00400(2.00%) of 20000 	 Time left:01:21:31
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1045.606       | 564.712         | 0.025           | 0.273           | 0.000
# test     | -1106.617       | 562.840         | 0.020           | 0.400           | 0.000
#
# Iteration: 00500(2.50%) of 20000 	 Time left:01:21:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -185.083        | -287.073        | 0.014           | 0.399           | 0.000
# test     | -205.271        | -288.463        | 0.030           | 0.289           | 0.000
#
# Iteration: 00600(3.00%) of 20000 	 Time left:01:20:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -247.650        | -191.733        | 0.022           | 0.759           | 0.000
# test     | -261.923        | -200.081        | 0.022           | 0.448           | 0.000
#
# Iteration: 00700(3.50%) of 20000 	 Time left:01:20:17
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -352.277        | 44.356          | 0.036           | 0.762           | 0.000
# test     | -181.844        | -53.261         | 0.022           | 0.644           | 0.000
#
# Iteration: 00800(4.00%) of 20000 	 Time left:01:19:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -452.992        | 201.039         | 0.019           | 0.253           | 0.000
# test     | -477.197        | 192.915         | 0.025           | 0.205           | 0.000
#
# Iteration: 00900(4.50%) of 20000 	 Time left:01:19:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -427.383        | 104.174         | 0.032           | 0.257           | 0.000
# test     | -444.570        | 91.177          | 0.029           | 0.341           | 0.000
#
# Iteration: 01000(5.00%) of 20000 	 Time left:01:19:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -569.782        | 240.181         | 0.022           | 0.204           | 0.000
# test     | -596.663        | 237.187         | 0.020           | 0.189           | 0.000
#
# Iteration: 01100(5.50%) of 20000 	 Time left:01:18:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -669.991        | 315.950         | 0.019           | 0.476           | 0.000
# test     | -704.548        | 315.145         | 0.016           | 0.664           | 0.000
#
# Iteration: 01200(6.00%) of 20000 	 Time left:01:18:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -64.569         | 268.254         | 0.020           | 0.264           | 0.000
# test     | -427.727        | 255.238         | 0.018           | 0.304           | 0.000
#
# Iteration: 01300(6.50%) of 20000 	 Time left:01:22:38
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -459.924        | 229.000         | 0.016           | 0.402           | 0.000
# test     | -499.002        | 222.407         | 0.020           | 0.604           | 0.000
#
# Iteration: 01400(7.00%) of 20000 	 Time left:01:17:22
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -729.796        | 367.428         | 0.021           | 0.234           | 0.000
# test     | -748.857        | 363.815         | 0.016           | 0.344           | 0.000
#
# Iteration: 01500(7.50%) of 20000 	 Time left:01:19:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -699.558        | 357.333         | 0.016           | 0.332           | 0.000
# test     | -735.535        | 356.424         | 0.016           | 0.457           | 0.000
#
# Iteration: 01600(8.00%) of 20000 	 Time left:01:15:04
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -103.355        | 241.872         | 0.024           | 0.532           | 0.000
# test     | -355.969        | 240.091         | 0.011           | 0.541           | 0.000
#
# Iteration: 01700(8.50%) of 20000 	 Time left:01:16:07
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -402.646        | 30.871          | 0.021           | 0.689           | 0.000
# test     | -338.181        | 6.876           | 0.021           | 0.476           | 0.000
#
# Iteration: 01800(9.00%) of 20000 	 Time left:01:20:26
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -166.766        | 158.450         | 0.020           | 0.226           | 0.000
# test     | -189.696        | 154.804         | 0.013           | 0.260           | 0.000
#
# Iteration: 01900(9.50%) of 20000 	 Time left:01:15:17
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -30.535         | -165.413        | 0.014           | 0.271           | 0.000
# test     | -31.085         | -168.532        | 0.016           | 0.170           | 0.000
#
# Iteration: 02000(10.00%) of 20000 	 Time left:01:14:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -30.310         | -110.188        | 0.019           | 0.237           | 0.000
# test     | -36.129         | -125.274        | 0.016           | 0.259           | 0.000
#
# Iteration: 02100(10.50%) of 20000 	 Time left:01:14:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -24.065         | 205.392         | 0.017           | 0.524           | 0.000
# test     | -25.022         | 202.739         | 0.022           | 0.687           | 0.000
#
# Iteration: 02200(11.00%) of 20000 	 Time left:01:14:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.719         | 120.410         | 0.018           | 0.257           | 0.000
# test     | -18.738         | 118.453         | 0.018           | 0.265           | 0.000
#
# Iteration: 02300(11.50%) of 20000 	 Time left:01:13:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.480          | 106.124         | 0.019           | 0.360           | 0.000
# test     | -4.449          | 105.509         | 0.029           | 0.412           | 0.000
#
# Iteration: 02400(12.00%) of 20000 	 Time left:01:17:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.453          | 135.724         | 0.017           | 0.557           | 0.000
# test     | -8.069          | 135.245         | 0.009           | 0.489           | 0.000
#
# Iteration: 02500(12.50%) of 20000 	 Time left:01:13:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.724          | 161.854         | 0.019           | 0.179           | 0.000
# test     | -4.273          | 161.215         | 0.024           | 0.194           | 0.000
#
# Iteration: 02600(13.00%) of 20000 	 Time left:01:13:32
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.080          | 106.568         | 0.015           | 0.309           | 0.000
# test     | -0.740          | 106.271         | 0.027           | 0.452           | 0.000
#
# Iteration: 02700(13.50%) of 20000 	 Time left:01:12:56
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.777          | 117.201         | 0.018           | 0.179           | 0.000
# test     | -1.995          | 117.083         | 0.019           | 0.193           | 0.000
#
# Iteration: 02800(14.00%) of 20000 	 Time left:01:12:14
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.745          | 120.167         | 0.021           | 0.305           | 0.000
# test     | -0.644          | 120.075         | 0.014           | 0.231           | 0.000
#
# Iteration: 02900(14.50%) of 20000 	 Time left:01:12:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.175          | 125.472         | 0.015           | 0.621           | 0.000
# test     | -1.198          | 125.386         | 0.019           | 0.414           | 0.000
#
# Iteration: 03000(15.00%) of 20000 	 Time left:01:07:12
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.255          | 117.662         | 0.018           | 0.474           | 0.000
# test     | -2.268          | 117.479         | 0.022           | 0.363           | 0.000
#
# Iteration: 03100(15.50%) of 20000 	 Time left:01:10:17
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.932          | 121.841         | 0.020           | 0.304           | 0.000
# test     | -1.795          | 121.691         | 0.009           | 0.435           | 0.000
#
# Iteration: 03200(16.00%) of 20000 	 Time left:01:09:53
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.208          | 114.188         | 0.014           | 0.253           | 0.000
# test     | -0.934          | 114.069         | 0.009           | 0.310           | 0.000
#
# Iteration: 03300(16.50%) of 20000 	 Time left:01:10:34
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.269          | 115.212         | 0.011           | 0.257           | 0.000
# test     | -0.077          | 115.126         | 0.014           | 0.252           | 0.000
#
# Iteration: 03400(17.00%) of 20000 	 Time left:01:09:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.101          | 108.582         | 0.016           | 0.259           | 0.000
# test     | -0.004          | 108.485         | 0.023           | 0.218           | 0.000
#
# Iteration: 03500(17.50%) of 20000 	 Time left:01:08:38
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.653          | 102.520         | 0.025           | 0.419           | 0.000
# test     | -0.811          | 102.363         | 0.008           | 0.296           | 0.000
#
# Iteration: 03600(18.00%) of 20000 	 Time left:01:08:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.409           | 107.137         | 0.011           | 0.200           | 0.000
# test     | 0.359           | 106.913         | 0.024           | 0.231           | 0.000
#
# Iteration: 03700(18.50%) of 20000 	 Time left:01:09:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -2.194          | 115.281         | 0.010           | 0.528           | 0.000
# test     | -2.137          | 115.044         | 0.017           | 0.561           | 0.000
#
# Iteration: 03800(19.00%) of 20000 	 Time left:01:08:28
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.775          | 114.280         | 0.015           | 0.187           | 0.000
# test     | -0.992          | 114.005         | 0.044           | 0.293           | 0.000
#
# Iteration: 03900(19.50%) of 20000 	 Time left:01:11:09
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.426          | 108.793         | 0.015           | 0.635           | 0.000
# test     | -3.573          | 108.388         | 0.047           | 0.521           | 0.000
#
# Iteration: 04000(20.00%) of 20000 	 Time left:01:11:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.026         | 83.930          | 0.011           | 0.170           | 0.000
# test     | -14.862         | 82.897          | 0.012           | 0.227           | 0.000
#
# Iteration: 04100(20.50%) of 20000 	 Time left:01:06:40
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -117.919        | 9.460           | 0.021           | 0.229           | 0.000
# test     | -124.214        | 2.658           | 0.024           | 0.328           | 0.000
#
# Iteration: 04200(21.00%) of 20000 	 Time left:01:05:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.055         | -243.138        | 0.018           | 0.220           | 0.000
# test     | -17.235         | -242.728        | 0.021           | 0.191           | 0.000
#
# Iteration: 04300(21.50%) of 20000 	 Time left:01:10:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.725         | -244.693        | 0.010           | 0.330           | 0.000
# test     | -14.597         | -245.168        | 0.019           | 0.297           | 0.000
#
# Iteration: 04400(22.00%) of 20000 	 Time left:01:01:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.626          | -194.068        | 0.035           | 0.143           | 0.000
# test     | -6.265          | -195.867        | 0.012           | 0.186           | 0.000
#
# Iteration: 04500(22.50%) of 20000 	 Time left:01:09:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.969           | -15.277         | 0.014           | 0.787           | 0.000
# test     | 6.159           | -15.525         | 0.024           | 0.726           | 0.000
#
# Iteration: 04600(23.00%) of 20000 	 Time left:01:04:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 8.296           | -113.320        | 0.024           | 0.274           | 0.000
# test     | 10.020          | -117.237        | 0.010           | 0.207           | 0.000
#
# Iteration: 04700(23.50%) of 20000 	 Time left:01:04:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.434          | -194.378        | 0.015           | 0.203           | 0.000
# test     | -1.387          | -196.727        | 0.019           | 0.376           | 0.000
#
# Iteration: 04800(24.00%) of 20000 	 Time left:01:02:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.836         | 267.187         | 0.014           | 0.474           | 0.000
# test     | -12.349         | 267.694         | 0.025           | 0.340           | 0.000
#
# Iteration: 04900(24.50%) of 20000 	 Time left:01:06:32
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.032         | 168.861         | 0.018           | 0.242           | 0.000
# test     | -22.122         | 165.912         | 0.022           | 0.329           | 0.000
#
# Iteration: 05000(25.00%) of 20000 	 Time left:01:01:41
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -69.472         | 139.578         | 0.014           | 0.354           | 0.000
# test     | -76.836         | 133.382         | 0.013           | 0.269           | 0.000
#
# Iteration: 05100(25.50%) of 20000 	 Time left:01:10:16
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.968           | -414.489        | 0.013           | 0.528           | 0.000
# test     | 1.982           | -415.958        | 0.017           | 0.378           | 0.000
#
# Iteration: 05200(26.00%) of 20000 	 Time left:01:01:33
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.482         | -298.324        | 0.016           | 0.244           | 0.000
# test     | -16.164         | -300.931        | 0.021           | 0.247           | 0.000
#
# Iteration: 05300(26.50%) of 20000 	 Time left:01:07:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.460         | -194.959        | 0.014           | 0.263           | 0.000
# test     | -20.452         | -203.500        | 0.011           | 0.268           | 0.000
#
# Iteration: 05400(27.00%) of 20000 	 Time left:01:04:31
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.152         | 282.661         | 0.017           | 0.144           | 0.000
# test     | -18.499         | 282.904         | 0.016           | 0.158           | 0.000
#
# Iteration: 05500(27.50%) of 20000 	 Time left:00:57:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -194.666        | 27.972          | 0.035           | 0.577           | 0.000
# test     | -254.891        | 16.959          | 0.024           | 0.664           | 0.000
#
# Iteration: 05600(28.00%) of 20000 	 Time left:01:01:17
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -394.604        | 237.324         | 0.025           | 0.682           | 0.000
# test     | -489.860        | 232.426         | 0.019           | 0.692           | 0.000
#
# Iteration: 05700(28.50%) of 20000 	 Time left:01:04:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.850         | 267.147         | 0.015           | 0.557           | 0.000
# test     | -26.883         | 265.514         | 0.016           | 0.525           | 0.000
#
# Iteration: 05800(29.00%) of 20000 	 Time left:00:59:58
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -39.843         | 108.619         | 0.016           | 0.769           | 0.000
# test     | -35.340         | 103.055         | 0.017           | 0.518           | 0.000
#
# Iteration: 05900(29.50%) of 20000 	 Time left:01:03:46
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.620          | 15.966          | 0.018           | 0.372           | 0.000
# test     | -3.294          | 15.285          | 0.049           | 0.414           | 0.000
#
# Iteration: 06000(30.00%) of 20000 	 Time left:01:01:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.381          | 16.762          | 0.013           | 0.489           | 0.000
# test     | -11.643         | 17.766          | 0.019           | 0.632           | 0.000
#
# Iteration: 06100(30.50%) of 20000 	 Time left:00:57:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.553         | -76.311         | 0.015           | 0.329           | 0.000
# test     | -16.861         | -75.823         | 0.016           | 0.311           | 0.000
#
# Iteration: 06200(31.00%) of 20000 	 Time left:00:58:33
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 7.887           | -14.220         | 0.015           | 0.785           | 0.000
# test     | -2.695          | -19.872         | 0.026           | 0.539           | 0.000
#
# Iteration: 06300(31.50%) of 20000 	 Time left:00:57:43
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -55.350         | -76.045         | 0.013           | 0.208           | 0.000
# test     | -55.737         | -86.438         | 0.014           | 0.174           | 0.000
#
# Iteration: 06400(32.00%) of 20000 	 Time left:01:00:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -21.761         | -9.914          | 0.014           | 0.247           | 0.000
# test     | -26.895         | -15.078         | 0.021           | 0.287           | 0.000
#
# Iteration: 06500(32.50%) of 20000 	 Time left:00:56:09
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.040           | -154.568        | 0.018           | 0.365           | 0.000
# test     | 5.890           | -159.588        | 0.023           | 0.350           | 0.000
#
# Iteration: 06600(33.00%) of 20000 	 Time left:01:07:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.243         | -188.531        | 0.016           | 0.330           | 0.000
# test     | -13.438         | -190.825        | 0.016           | 0.344           | 0.000
#
# Iteration: 06700(33.50%) of 20000 	 Time left:00:59:42
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -35.739         | -165.220        | 0.023           | 0.267           | 0.000
# test     | -35.768         | -166.324        | 0.011           | 0.208           | 0.000
#
# Iteration: 06800(34.00%) of 20000 	 Time left:00:54:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.354          | 7.651           | 0.014           | 0.225           | 0.000
# test     | -23.084         | 5.834           | 0.020           | 0.210           | 0.000
#
# Iteration: 06900(34.50%) of 20000 	 Time left:00:57:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.800         | -103.329        | 0.025           | 0.270           | 0.000
# test     | -33.837         | -101.184        | 0.025           | 0.339           | 0.000
#
# Iteration: 07000(35.00%) of 20000 	 Time left:00:54:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -41.758         | -130.129        | 0.022           | 0.198           | 0.000
# test     | -26.703         | -148.361        | 0.026           | 0.294           | 0.000
#
# Iteration: 07100(35.50%) of 20000 	 Time left:00:56:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.705          | -159.118        | 0.020           | 0.179           | 0.000
# test     | -8.421          | -160.518        | 0.038           | 0.252           | 0.000
#
# Iteration: 07200(36.00%) of 20000 	 Time left:00:53:27
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.651           | -189.596        | 0.018           | 0.447           | 0.000
# test     | 2.688           | -191.120        | 0.019           | 0.417           | 0.000
#
# Iteration: 07300(36.50%) of 20000 	 Time left:00:52:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.427          | -150.022        | 0.016           | 0.474           | 0.000
# test     | -5.508          | -154.167        | 0.021           | 0.502           | 0.000
#
# Iteration: 07400(37.00%) of 20000 	 Time left:01:07:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -45.657         | -65.196         | 0.019           | 0.342           | 0.000
# test     | -28.996         | -95.042         | 0.025           | 0.680           | 0.000
#
# Iteration: 07500(37.50%) of 20000 	 Time left:00:55:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.191           | 112.015         | 0.021           | 0.303           | 0.000
# test     | 6.080           | 110.902         | 0.017           | 0.244           | 0.000
#
# Iteration: 07600(38.00%) of 20000 	 Time left:00:51:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.278         | 16.806          | 0.013           | 0.605           | 0.000
# test     | -17.711         | 18.920          | 0.013           | 0.484           | 0.000
#
# Iteration: 07700(38.50%) of 20000 	 Time left:00:48:47
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.840         | -14.243         | 0.015           | 0.530           | 0.000
# test     | -12.276         | -14.695         | 0.010           | 0.456           | 0.000
#
# Iteration: 07800(39.00%) of 20000 	 Time left:00:55:23
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.716         | -28.127         | 0.014           | 0.213           | 0.000
# test     | -14.222         | -31.315         | 0.012           | 0.229           | 0.000
#
# Iteration: 07900(39.50%) of 20000 	 Time left:00:51:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -15.676         | -190.281        | 0.024           | 0.199           | 0.000
# test     | -45.281         | -174.211        | 0.012           | 0.219           | 0.000
#
# Iteration: 08000(40.00%) of 20000 	 Time left:00:51:11
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.925          | -153.143        | 0.022           | 0.173           | 0.000
# test     | 22.879          | -182.676        | 0.021           | 0.196           | 0.000
#
# Iteration: 08100(40.50%) of 20000 	 Time left:00:50:15
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -112.609        | -46.253         | 0.021           | 0.254           | 0.000
# test     | -229.985        | 53.338          | 0.023           | 0.407           | 0.000
#
# Iteration: 08200(41.00%) of 20000 	 Time left:00:49:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -53.812         | -121.221        | 0.016           | 0.358           | 0.000
# test     | -131.283        | -57.684         | 0.015           | 0.491           | 0.000
#
# Iteration: 08300(41.50%) of 20000 	 Time left:00:48:40
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -26.605         | -247.798        | 0.012           | 0.367           | 0.000
# test     | -14.022         | -248.150        | 0.036           | 0.429           | 0.000
#
# Iteration: 08400(42.00%) of 20000 	 Time left:00:55:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.292          | -268.120        | 0.024           | 0.280           | 0.000
# test     | -10.387         | -268.889        | 0.040           | 0.316           | 0.000
#
# Iteration: 08500(42.50%) of 20000 	 Time left:00:47:50
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -116.987        | -164.738        | 0.023           | 0.389           | 0.000
# test     | -33.065         | -239.986        | 0.020           | 0.340           | 0.000
#
# Iteration: 08600(43.00%) of 20000 	 Time left:00:52:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 44.234          | -26.109         | 0.017           | 0.417           | 0.000
# test     | -2.493          | -19.284         | 0.011           | 0.594           | 0.000
#
# Iteration: 08700(43.50%) of 20000 	 Time left:00:47:00
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -139.348        | -5.401          | 0.023           | 0.233           | 0.000
# test     | -143.580        | -15.079         | 0.022           | 0.242           | 0.000
#
# Iteration: 08800(44.00%) of 20000 	 Time left:00:49:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -130.670        | -95.918         | 0.020           | 0.341           | 0.000
# test     | -82.040         | -131.240        | 0.014           | 0.454           | 0.000
#
# Iteration: 08900(44.50%) of 20000 	 Time left:00:49:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -115.986        | 110.760         | 0.032           | 0.413           | 0.000
# test     | -195.131        | 84.162          | 0.010           | 0.413           | 0.000
#
# Iteration: 09000(45.00%) of 20000 	 Time left:00:43:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.537          | -138.532        | 0.023           | 0.391           | 0.000
# test     | -55.845         | -95.405         | 0.018           | 0.419           | 0.000
#
# Iteration: 09100(45.50%) of 20000 	 Time left:00:45:20
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -116.064        | -123.162        | 0.020           | 0.269           | 0.000
# test     | -149.253        | -114.033        | 0.017           | 0.349           | 0.000
#
# Iteration: 09200(46.00%) of 20000 	 Time left:00:48:46
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -37.567         | 248.053         | 0.021           | 0.500           | 0.000
# test     | -39.966         | 247.092         | 0.021           | 0.358           | 0.000
#
# Iteration: 09300(46.50%) of 20000 	 Time left:00:47:58
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -87.652         | -78.794         | 0.025           | 0.406           | 0.000
# test     | -55.966         | -117.376        | 0.008           | 0.257           | 0.000
#
# Iteration: 09400(47.00%) of 20000 	 Time left:00:46:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -153.333        | 15.557          | 0.014           | 0.426           | 0.000
# test     | -116.417        | -22.790         | 0.019           | 0.446           | 0.000
#
# Iteration: 09500(47.50%) of 20000 	 Time left:00:45:55
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -34.391         | -266.663        | 0.023           | 0.338           | 0.000
# test     | -30.461         | -279.779        | 0.016           | 0.278           | 0.000
#
# Iteration: 09600(48.00%) of 20000 	 Time left:00:44:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -38.747         | -83.790         | 0.014           | 0.316           | 0.000
# test     | -34.760         | -94.114         | 0.020           | 0.310           | 0.000
#
# Iteration: 09700(48.50%) of 20000 	 Time left:00:45:03
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 18.321          | -336.371        | 0.021           | 0.409           | 0.000
# test     | 14.075          | -337.376        | 0.019           | 0.284           | 0.000
#
# Iteration: 09800(49.00%) of 20000 	 Time left:00:44:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -33.320         | -259.752        | 0.017           | 0.251           | 0.000
# test     | -64.350         | -249.367        | 0.021           | 0.221           | 0.000
#
# Iteration: 09900(49.50%) of 20000 	 Time left:00:43:45
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -116.344        | 81.596          | 0.020           | 0.432           | 0.000
# test     | -84.531         | 60.185          | 0.018           | 0.542           | 0.000
#
# Iteration: 10000(50.00%) of 20000 	 Time left:00:43:19
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -49.058         | 193.665         | 0.023           | 0.333           | 0.000
# test     | -52.298         | 192.181         | 0.013           | 0.457           | 0.000
#
# Iteration: 10100(50.50%) of 20000 	 Time left:00:41:14
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.567          | 16.785          | 0.014           | 0.273           | 0.000
# test     | -7.619          | 16.926          | 0.017           | 0.482           | 0.000
#
# Iteration: 10200(51.00%) of 20000 	 Time left:00:40:49
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.006         | -69.503         | 0.010           | 0.390           | 0.000
# test     | -9.969          | -68.509         | 0.034           | 0.388           | 0.000
#
# Iteration: 10300(51.50%) of 20000 	 Time left:00:42:01
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.599          | 123.377         | 0.014           | 0.435           | 0.000
# test     | -27.304         | 128.248         | 0.008           | 0.403           | 0.000
#
# Iteration: 10400(52.00%) of 20000 	 Time left:00:41:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.906           | 31.888          | 0.016           | 0.184           | 0.000
# test     | 4.859           | 27.975          | 0.019           | 0.256           | 0.000
#
# Iteration: 10500(52.50%) of 20000 	 Time left:00:40:22
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.787         | -157.375        | 0.015           | 0.318           | 0.000
# test     | -25.621         | -155.932        | 0.024           | 0.217           | 0.000
#
# Iteration: 10600(53.00%) of 20000 	 Time left:00:39:56
# ...
# test     | -7.176          | 11.833          | 0.019           | 0.229           | 0.000
#
# Iteration: 16500(82.50%) of 20000 	 Time left:00:14:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.292         | -55.161         | 0.016           | 0.314           | 0.000
# test     | -14.256         | -53.587         | 0.015           | 0.429           | 0.000
#
# Iteration: 16600(83.00%) of 20000 	 Time left:00:14:48
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.646          | -78.080         | 0.025           | 0.333           | 0.000
# test     | -3.801          | -81.025         | 0.018           | 0.168           | 0.000
#
# Iteration: 16700(83.50%) of 20000 	 Time left:00:14:04
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.011         | 22.161          | 0.022           | 0.216           | 0.000
# test     | -17.790         | 21.390          | 0.025           | 0.322           | 0.000
#
# Iteration: 16800(84.00%) of 20000 	 Time left:00:13:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -31.012         | 136.284         | 0.022           | 0.268           | 0.000
# test     | -38.265         | 132.622         | 0.016           | 0.306           | 0.000
#
# Iteration: 16900(84.50%) of 20000 	 Time left:00:13:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -192.282        | 121.166         | 0.020           | 0.279           | 0.000
# test     | -266.743        | 121.529         | 0.020           | 0.225           | 0.000
#
# Iteration: 17000(85.00%) of 20000 	 Time left:00:13:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -30.191         | 112.391         | 0.025           | 0.369           | 0.000
# test     | -48.271         | 120.601         | 0.030           | 0.282           | 0.000
#
# Iteration: 17100(85.50%) of 20000 	 Time left:00:12:39
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -68.766         | -62.744         | 0.021           | 0.393           | 0.000
# test     | -44.493         | -95.958         | 0.017           | 0.313           | 0.000
#
# Iteration: 17200(86.00%) of 20000 	 Time left:00:12:13
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.729           | 157.864         | 0.021           | 0.329           | 0.000
# test     | 2.557           | 156.753         | 0.022           | 0.515           | 0.000
#
# Iteration: 17300(86.50%) of 20000 	 Time left:00:11:30
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.029           | 78.284          | 0.017           | 0.364           | 0.000
# test     | 9.736           | 72.583          | 0.015           | 0.447           | 0.000
#
# Iteration: 17400(87.00%) of 20000 	 Time left:00:11:01
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.274          | 28.190          | 0.019           | 0.394           | 0.000
# test     | -11.794         | 25.000          | 0.013           | 0.444           | 0.000
#
# Iteration: 17500(87.50%) of 20000 	 Time left:00:10:29
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.432         | -34.965         | 0.014           | 0.147           | 0.000
# test     | -30.551         | -29.614         | 0.020           | 0.212           | 0.000
#
# Iteration: 17600(88.00%) of 20000 	 Time left:00:10:05
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.057         | 73.673          | 0.020           | 0.318           | 0.000
# test     | -28.539         | 84.806          | 0.011           | 0.231           | 0.000
#
# Iteration: 17700(88.50%) of 20000 	 Time left:00:09:43
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -29.569         | 147.496         | 0.021           | 0.225           | 0.000
# test     | -31.624         | 142.321         | 0.017           | 0.328           | 0.000
#
# Iteration: 17800(89.00%) of 20000 	 Time left:00:09:06
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -111.056        | -12.191         | 0.017           | 0.355           | 0.000
# test     | -106.014        | -26.264         | 0.013           | 0.237           | 0.000
#
# Iteration: 17900(89.50%) of 20000 	 Time left:00:08:52
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -55.436         | -86.349         | 0.016           | 0.402           | 0.000
# test     | -50.028         | -100.334        | 0.021           | 0.335           | 0.000
#
# Iteration: 18000(90.00%) of 20000 	 Time left:00:08:21
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 10.045          | 194.772         | 0.027           | 0.314           | 0.000
# test     | 7.795           | 196.439         | 0.034           | 0.294           | 0.000
#
# Iteration: 18100(90.50%) of 20000 	 Time left:00:08:02
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.801           | 13.603          | 0.019           | 0.276           | 0.000
# test     | 0.545           | 13.806          | 0.019           | 0.149           | 0.000
#
# Iteration: 18200(91.00%) of 20000 	 Time left:00:07:36
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.013          | -0.764          | 0.024           | 0.302           | 0.000
# test     | -0.588          | -1.195          | 0.040           | 0.268           | 0.000
#
# Iteration: 18300(91.50%) of 20000 	 Time left:00:07:07
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.647          | -59.552         | 0.017           | 0.262           | 0.000
# test     | -6.829          | -58.277         | 0.014           | 0.238           | 0.000
#
# Iteration: 18400(92.00%) of 20000 	 Time left:00:06:54
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.629         | -147.026        | 0.021           | 0.276           | 0.000
# test     | -14.060         | -146.765        | 0.019           | 0.305           | 0.000
#
# Iteration: 18500(92.50%) of 20000 	 Time left:00:06:18
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.841          | -218.923        | 0.022           | 0.363           | 0.000
# test     | 0.477           | -219.846        | 0.017           | 0.433           | 0.000
#
# Iteration: 18600(93.00%) of 20000 	 Time left:00:05:51
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.555           | -187.900        | 0.021           | 0.335           | 0.000
# test     | 1.897           | -188.802        | 0.009           | 0.253           | 0.000
#
# Iteration: 18700(93.50%) of 20000 	 Time left:00:05:22
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.372          | -144.760        | 0.026           | 0.298           | 0.000
# test     | -1.122          | -145.132        | 0.026           | 0.386           | 0.000
#
# Iteration: 18800(94.00%) of 20000 	 Time left:00:04:59
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.677          | -148.411        | 0.014           | 0.174           | 0.000
# test     | -5.775          | -147.851        | 0.016           | 0.255           | 0.000
#
# Iteration: 18900(94.50%) of 20000 	 Time left:00:04:37
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.569          | -141.018        | 0.018           | 0.288           | 0.000
# test     | 2.287           | -149.038        | 0.021           | 0.381           | 0.000
#
# Iteration: 19000(95.00%) of 20000 	 Time left:00:04:14
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.857          | -109.283        | 0.021           | 0.390           | 0.000
# test     | -6.717          | -109.046        | 0.014           | 0.392           | 0.000
#
# Iteration: 19100(95.50%) of 20000 	 Time left:00:03:44
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.559         | -93.313         | 0.015           | 0.277           | 0.000
# test     | -14.006         | -93.711         | 0.013           | 0.159           | 0.000
#
# Iteration: 19200(96.00%) of 20000 	 Time left:00:03:26
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.543          | -73.363         | 0.010           | 0.427           | 0.000
# test     | -3.651          | -73.452         | 0.025           | 0.480           | 0.000
#
# Iteration: 19300(96.50%) of 20000 	 Time left:00:02:58
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.879           | -82.214         | 0.007           | 0.260           | 0.000
# test     | 2.673           | -82.746         | 0.018           | 0.409           | 0.000
#
# Iteration: 19400(97.00%) of 20000 	 Time left:00:02:35
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.793          | -54.401         | 0.015           | 0.365           | 0.000
# test     | -5.303          | -55.772         | 0.014           | 0.281           | 0.000
#
# Iteration: 19500(97.50%) of 20000 	 Time left:00:02:08
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.575           | -83.712         | 0.012           | 0.491           | 0.000
# test     | 1.809           | -84.035         | 0.017           | 0.418           | 0.000
#
# Iteration: 19600(98.00%) of 20000 	 Time left:00:01:40
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.536          | -63.985         | 0.015           | 0.250           | 0.000
# test     | -1.254          | -64.979         | 0.022           | 0.300           | 0.000
#
# Iteration: 19700(98.50%) of 20000 	 Time left:00:01:16
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.326          | -88.003         | 0.012           | 0.300           | 0.000
# test     | -5.075          | -87.937         | 0.009           | 0.346           | 0.000
#
# Iteration: 19800(99.00%) of 20000 	 Time left:00:00:50
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.367          | -98.544         | 0.012           | 0.352           | 0.000
# test     | -0.057          | -99.468         | 0.009           | 0.304           | 0.000
#
# Iteration: 19900(99.50%) of 20000 	 Time left:00:00:24
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.038          | -104.162        | 0.013           | 0.308           | 0.000
# test     | 0.045           | -103.889        | 0.026           | 0.267           | 0.000

# %% [markdown]
# ### Show the result

# %%
hist = pickle.load(open(rgan_dir+'/rgan_pickle.pkl','rb'))

# %%
losses = ['generator','discriminator','Q network','Q_continous','Q_categorical']

# %% [markdown]
# Use pandas to realize the two demensional dict-like tabular.

# %%
for p in hist.keys():
    hist[p] = pd.DataFrame(hist[p],columns=losses)

# %%
for p in hist.keys():
    plt.plot(hist[p]['discriminator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Discriminator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['generator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Generator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['Q network'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Q network loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %% [markdown]
# ### For test

# %%
def test(ckpt_dir=ckpt_dir):
    
    with tf.Session(config = tf.ConfigProto(allow_soft_placement=True,log_device_placement=True)) as sess:
        # build graph
        with tf.device(device):
            gen,z_rand,z_cont,z_cat = build_graph(is_test=True)
        
        # use saver to reload the parametes
        saver = tf.train.Saver()
        #saver.restore(sess, './Inproved_rgan/cgan_2d/Experient_1/ckpt_rgan\\model_checkpoint-17000')
        saver.restore(sess,tf.train.latest_checkpoint(ckpt_dir))
        
        ###########################################  Experiment : Generator #################
        # Gererate random labels as conditions , [0,1] gausson distribution
        z_rand_sample = np.random.normal(0,0.3,[batch_size,z_dim])
        # To construct grid sample 
        #z_cat_sample = np.reshape(np.array([int(e/batch_size*10) for e in range(batch_size)]),[batch_size,len(cat_list)])                
        z_cat_sample = np.random.normal(0,0.3,[batch_size,10])
        #z_cont_sample = np.zeros((batch_size,cont_num))
        z_cont_order = np.linspace(1,1,batch_size)
        if cont_num>0:
            z_cont_temp = np.zeros((batch_size,cont_num-1))
            z_cont_sample = np.insert(z_cont_temp,0,z_cont_order,axis=1)
        else:
            z_cont_sample = z_cont_oder

        samples = sess.run(gen,{z_rand:z_rand_sample,z_cat:z_cat_sample,z_cont:z_cont_sample})

        save_spectrum(samples, 0,is_show=True)

# %%
tf.reset_default_graph()
test()
# Out:
# INFO:tensorflow:Restoring parameters from ./Inproved_rgan/RGAN/Experient_5/ckpt_rgan\model_checkpoint-19000
