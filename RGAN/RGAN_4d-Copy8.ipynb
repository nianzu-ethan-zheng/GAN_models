# %% [markdown]
# ## Load Module

# %%
import tensorflow as tf
import tensorflow.contrib.layers as ly

import os
import shutil
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.io as scio
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from collections import defaultdict
import _pickle as pickle

# %% [markdown]
# ## Parameters

# %%
# Inputs:Global parameters 
batch_size = 32
img_dim = 688
z_dim = 110

# Define salient variable
cat_list = [] # Each entry in this list defines a categorical variable for specific size
cont_num = 1 # the number of continous variables

# Optimizer: whether use adam for parameters update , if flag is set false use tf.train.RMEPropOptimzer
is_adam = True
learning_rate_gen = 2e-4
learning_rate_dis = 2e-4
# the upper bound and lower bound in critic
clamp_lower =-0.01
clamp_upper = 0.01


# Train : Prameters
max_iter_step = 10000
device = '/gpu:0'
data_format = 'NCHW'
channel = 1

# directory to store log ,include loss  and grad_norm of generator and critic
rgan_dir = './Inproved_rgan/RGAN/Experient_14'

log_dir = rgan_dir + '/log_rgan'
ckpt_dir = rgan_dir + '/ckpt_rgan'
spec_dir = rgan_dir + '/spec_rgan'

if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)
else:
    shutil.rmtree(ckpt_dir)
    os.makedirs(ckpt_dir)
    
if not os.path.exists(spec_dir):
    os.makedirs(spec_dir)
else:
    shutil.rmtree(spec_dir)
    os.makedirs(spec_dir)

# %% [markdown]
# ## Load dataset

# %%
# from database load the data and label,clip the length network required
spect = scio.loadmat('NMR_Index.mat')
x,y = spect['NMR'],spect['Index'][:,3]
if x.shape[1]>img_dim:
    x = x[:,:img_dim]
# plot raw data    
plt.plot(x.transpose())
plt.show()

# pre_processing by minmaxmap
xmin, xmax, ymin, ymax = x.min(),x.max(), y.min(),y.max()
xmid,ymid = (xmin+xmax)/2,(ymin+ymax)/2
x,y = (x - xmid)*2/( xmax - xmin ),(y - ymid)*2/( ymax - ymin )

# reshape the data to the format that look like image
x= x.reshape(-1,1,img_dim,1)
y= y.reshape(-1,cont_num)

## split the dataset
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.20,random_state=0)

# %% [markdown]
# ## Generator

# %%
def generator_conv(z):
    train = ly.fully_connected(z, 1024, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = ly.fully_connected(train, 256*172, activation_fn = tf.nn.relu, normalizer_fn=None)
    train = tf.reshape(train,(-1,256,172,1))
    train = ly.conv2d_transpose(train, 128, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, 64, kernel_size=[5,1],stride=[2,1],data_format=data_format,
                                activation_fn = tf.nn.relu, normalizer_fn = ly.batch_norm, padding='SAME',
                                normalizer_params={'fused':True,'data_format':data_format,},
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    train = ly.conv2d_transpose(train, channel , kernel_size=[5,1],stride=[1,1],data_format=data_format,
                                activation_fn = tf.nn.tanh, padding='SAME',
                                weights_initializer = tf.random_normal_initializer(0,0.02))
    return train

# %% [markdown]
# ## Discriminator

# %%
def lrelu(x,leak=0.2,name='lrelu'):
    with tf.variable_scope('lrelu'):
        f1 = 0.5*(1+leak)
        f2 = 0.5*(1-leak)
        return f1*x + f2*abs(x)

# %%
def critic_conv( x ,c ,cat_list =cat_list ,cont_num =cont_num,reuse=False):
    with tf.variable_scope('discriminator') as scope:
        if reuse:
            scope.reuse_variables()
        size = 16
        
        img_out = ly.conv2d(x,num_outputs=size*4,kernel_size=[10,1],stride=[2,1],padding='SAME',
                       activation_fn = lrelu,data_format=data_format,
                       weights_initializer = tf.random_normal_initializer(0,0.02))
        
        
        img = ly.conv2d(img_out,num_outputs= size*8 ,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        c = tf.tile(c,[1,int(img_dim/4)])
        c = tf.reshape(c,(batch_size,1,int(img_dim/4),1))
        img = tf.concat((c,img),axis=1)
        
        img = ly.conv2d(img ,num_outputs= size*16,kernel_size=[10,1],stride=[2,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        
        # fully_connected
        disc_img = ly.flatten(img)
        disc_img = ly.fully_connected(disc_img,1024,activation_fn=lrelu)
        disc = ly.fully_connected(disc_img,1,activation_fn=None)
        
        # Here we difine the unique layers used for the q_network, the number of outputs 
        q_img = ly.conv2d(img_out,num_outputs= size*8,kernel_size=[10,1],stride=[1,1],padding='SAME',
                        activation_fn = lrelu,data_format=data_format,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format},
                        weights_initializer = tf.random_normal_initializer(0,0.02))
        
        q_img = ly.flatten(q_img)
        q_img = ly.fully_connected(q_img,1024,activation_fn=lrelu,normalizer_fn = ly.batch_norm,
                        normalizer_params ={'fused':True,'data_format':data_format})
        
        q_cat_outs = []
        if len(cat_list)>0:
            for idx,var in enumerate(cat_list):
                q_outA = ly.fully_connected(q_img,var, activation_fn=tf.nn.softmax)
                q_cat_outs.append(q_outA)
        
        q_cont_outs = []
        if cont_num>0:
            q_cont_outs = ly.fully_connected(q_img,cont_num,activation_fn = tf.nn.tanh)
    
    return disc, q_cat_outs, q_cont_outs

# %% [markdown]
# ## Build Graph & Loss Function

# %%
def build_graph(is_test=False):
    ##########################  Inputs ######################################
    # Real data 
    real_data = tf.placeholder(dtype = tf.float32,shape=[None,channel,img_dim,1])
    real_label = tf.placeholder(dtype = tf.float32,shape = [None,cont_num])
    # Noise ;Continous variable, and rand variable to provide some variance
    z_cont = tf.placeholder(dtype = tf.float32,shape =[None,cont_num])
    z_rand = tf.placeholder(dtype =tf.float32,shape =[None,z_dim])
    # Categorical variable
    if len(cat_list)>0:
        z_cat = tf.placeholder(dtype = tf.int32, shape=[None,len(cat_list)])
        cat_var = tf.split(z_cat , len(cat_list),axis=1)

        cat_z =[]
        for idx ,depth in enumerate(cat_list):
            cat_temp = tf.one_hot(tf.reshape(cat_var[idx],[-1]), depth)
            cat_z.append(cat_temp)
    else:
        z_cat = tf.placeholder(dtype =tf.float32,shape =[None,10])
        cat_z = [z_cat]
    # Conbine all of the variable
    z = cat_z[:]
    z.append(z_cont)
    z.append(z_rand)
    z = tf.concat( z,axis=1)
    
    #########################  End Inputs #####################################
    
    ##########################  Graph   ######################################
    generator = generator_conv
    discriminator = critic_conv
    
    with tf.variable_scope('generator'):
        gen = generator(z)
    
    disc_real,cat_real,cont_real = discriminator(real_data,real_label)
    disc_fake,cat_fake,cont_fake = discriminator(gen,cont_real, reuse=True)

    # Wasserstein distance
    d_loss = tf.reduce_mean(disc_fake - disc_real)
    g_loss = tf.reduce_mean( - disc_fake)
    g_loss_summ = tf.summary.scalar('wasserstein_loss_g' , g_loss)
    d_loss_summ = tf.summary.scalar('wasserstein_loss_d' , -d_loss)
    
    # Combine losses for each of categorical variables
    if len(cat_list)>0:
        cat_losses_f =[]
        tiny = 1e-10
        for idx,var in enumerate(cat_z):
            cat_loss_f = -tf.reduce_sum(var *tf.log(cat_fake[idx]+tiny),reduction_indices=1)
            cat_losses_f.append(cat_loss_f)
            # cat_losses_r 
    else:
        cat_losses_f=cat_losses_r = tf.constant(0.0)
    # Combine losses for each of continous variables
    # MSE
    if cont_num>0:
        cont_loss_f = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_fake-z_cont),reduction_indices=1))
        cont_loss_r = tf.reduce_mean(tf.reduce_sum(0.5*tf.square(cont_real- real_label),reduction_indices=1))
    else:
        cont_loss_f = cont_loss_r = tf.constant(0.0)
    
    # Loss balance parameter
    alpha = 1
    q_cont_loss = cont_loss_r + alpha* cont_loss_f
    q_cat_loss = tf.constant(0.0)
    q_loss = tf.add(q_cont_loss,q_cat_loss)
    
    # Total variation loss
    tv_loss = tf.nn.l2_loss(gen[:,:,1:,:]-gen[:,:,:img_dim-1,:])/batch_size
    
    # Loss of Discriminator and Generator, Discriminator train on True and False data
    loss_gen = g_loss + 1e-3 *cont_loss_f + 0.000 * tv_loss
    loss_dis = d_loss
    loss_qnt = cont_loss_r
    
    loss_gen_summ = tf.summary.scalar('generator_loss',loss_gen)
    loss_dis_summ = tf.summary.scalar('discriminator_loss',loss_dis)
    ########################### End Graph   ######################################
    if is_test:
        return gen,z_rand,z_cont,z_cat,cont_real,cont_loss_r,real_data,real_label
    
    ##################### Optimization ########################################
    # Variable Collection
    theta_g = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='generator')
    theta_d = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,scope='discriminator')
    theta_c = theta_d[10:]
    theta_d = theta_d[:10]

    # Optimizers
    counter_g = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_g = optimize(loss = loss_gen,variables=theta_g, learning_rate = learning_rate_gen,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_g,summaries=['gradient_norm','gradients'])
    
    counter_d = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_d = optimize(loss =loss_dis,variables=theta_d ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    
    counter_q = tf.Variable(trainable=False , initial_value=0,dtype=tf.int32)
    opt_q = optimize(loss =loss_qnt ,variables=theta_c ,learning_rate = learning_rate_dis,
                    optimizer=tf.train.AdamOptimizer if is_adam is True else tf.train.RMSPropOptimizer,
                    global_step=counter_d,summaries=['gradient_norm','gradients'])
    # Clip weights
    clipped_var_d = [tf.assign(var,tf.clip_by_value(var,clamp_lower,clamp_upper)) for var in theta_d]
    with tf.control_dependencies([opt_d]):
        opt_d = tf.tuple(clipped_var_d)
    ################################# End Optimization ################################################
    return opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss

# %% [markdown]
# ####  Optimizer

# %%
def optimize(loss,learning_rate, optimizer,variables,global_step,summaries):
    optim = optimizer(learning_rate=learning_rate)
    
    # Caculate gradients
    gradients = optim.compute_gradients(loss,var_list = variables)
    
    # Add summary
    if summaries is None:
        summaries = ['loss','learning_rate']
    if 'gradient_norm'  in summaries:
        tf.summary.scalar('global_norm/gradient_norm',tf.global_norm(list(zip(*gradients))[0]))
        
    if 'loss' in summaries:
        tf.summary.scalar('loss',loss)
    
    for gradient,variable in gradients:
        if isinstance(gradient,tf.IndexedSlices):
            grad_values = gradient.values
        else:
            grad_values = gradient
        
        if grad_values is not None:
            var_name = variable.name.replace(':','_')
            if 'gradients' in summaries:
                tf.summary.histogram('gradients/%s'%var_name, grad_values)
            
            if 'gradient_norm' in summaries:
                tf.summary.scalar('gradient_norm/%s'%var_name,tf.global_norm([grad_values]))
    return optim.apply_gradients(gradients,global_step=global_step)

# %% [markdown]
# ## Plot

# %%
def save_image(specs ,size,i =100,image_path = rgan_dir):
    _,ax = plt.subplots(size[0],size[1],sharex = True,sharey = True)
    for i in range(size[0]):
        for j in range(size[1]):
            ax[i][j].plot(np.arange(specs.shape[1]),specs[i*10+j] ,'-*')
    
    plt.savefig(image_path+'/'+str(i).zfill(4)+'.png')
    plt.close()

# %%
def save_spectrum(gen, i,spec_size = 10,is_show=False):
    if gen.shape[0]<spec_size:
        spec_size = gen.shape[0]

    gen = gen[:spec_size]
    # control the spect limitation and intv determine the the distance of spectrums
    intv = 0
    scale = 3.9
    # extend along y axis to visulize the difference between spetrum
    if is_show:
        extd = np.matlib.repmat(np.arange(0,spec_size),img_dim,1) 
        extd = extd * scale*intv
    else:
        extd = np.zeros((img_dim, spec_size))
    # convert data to ideal format 
    def cv_proc(x):
        x = xmid + x*(xmax-xmin)/2
        return x
        
    spec = cv_proc(gen.reshape(spec_size,img_dim))
    spec = spec.transpose() + extd
    
    # plot the spectrum with ylimit legend and other thing
    plt.figure(figsize=(10,8))
    plt.plot(np.arange(spec.shape[0]),spec ,'-*')    
    plt.legend([np.array_str(var) for var in np.arange(spec_size)])
    if intv ==0:
        plt.ylim([-0.5,scale])
    else:
        plt.ylim([-0.5,scale*spec_size*intv])
    
    
    if is_show:
        return plt.show()
    # savefig
    plt.savefig(spec_dir+'/'+str(i).zfill(4)+'.png')
    plt.close('all')

# %% [markdown]
# ## Condictional WGAN Subphase

# %%
def train_rgan(max_iters = 1000):
    # build graph
    with tf.device(device):
        opt_d, opt_g ,opt_q,real_data,real_label,z_rand,z_cont,z_cat,\
        loss_dis,loss_gen,loss_qnt,gen,q_cont_loss,q_cat_loss = build_graph()
        
    saver = tf.train.Saver()

    def next_feed_dict(iter, shuffled = True,is_test =False):
        
        # feed image and label,train set if is_test=False
        # otherwise test set
        def generate_index(input,iter,shuffled =shuffled):
            input_number = input.shape[0]
            if shuffled:
                idx = np.random.randint(input_number,size=(batch_size,))
            else:
                bat_num = int(input_number/batch_size)
                par = int(iter % bat_num)
                idx = np.arange(input_number)[par * batch_size:(par+1)*batch_size]
            return idx
        
        if is_test:
            idx = generate_index(x_test,iter)
            feed_img,feed_label = x_test[idx],y_test[idx]
        else:
            idx = generate_index(x_train,iter)
            feed_img,feed_label = x_train[idx],y_train[idx]
        
        # False data which sigma = 0.3 mean most of point located in the [-1,1].
        batch_z_rand = np.random.normal(0,0.3,[batch_size,z_dim]).astype(np.float32)
        if len(cat_list)>0:
            batch_z_cat  = np.random.randint(0,10,[batch_size,len(cat_list)])
        else:
            batch_z_cat = np.random.normal(0,0.3,[batch_size,10]).astype(np.float32)
        
        batch_z_cont = np.random.uniform(-1,1,[batch_size,cont_num])     
        
        feed_dict = {real_data:feed_img, 
                     z_rand : batch_z_rand,
                     z_cat  : batch_z_cat,
                     z_cont : batch_z_cont,
                     real_label:feed_label }
        return feed_dict
    
    config = tf.ConfigProto(allow_soft_placement = True,log_device_placement=True)
    config.gpu_options.allow_growth =True
    config.gpu_options.per_process_gpu_memory_fraction=0.9
    
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        
        # use two dict-like container to record of history data
        # for analysising the result
        history = defaultdict(list)
        test_for_best = 1000
        
        for i in range(max_iters):
            
            start_time = time.time()
            ## Training Phase
            feed_dict = next_feed_dict(i)
            
            _,dLoss = sess.run([opt_d,loss_dis],feed_dict = feed_dict)
            _,gLoss,spec = sess.run([opt_g,loss_gen,gen],feed_dict = feed_dict)
            _,qLoss,qCont,qCat = sess.run([opt_q, loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['train_loss'].append([dLoss,gLoss,qLoss,qCont,qCat])
            
            ## Testing Phase
            feed_dict = next_feed_dict(i,is_test=True)
        
            dLoss_ = sess.run(loss_dis,feed_dict = feed_dict)
            gLoss_ = sess.run(loss_gen,feed_dict = feed_dict)
            qLoss_ ,qCont_ ,qCat_ = sess.run([loss_qnt,q_cont_loss,q_cat_loss],feed_dict = feed_dict)
            
            history['test_loss'].append([dLoss_ ,gLoss_ ,qLoss_ ,qCont_ ,qCat_])
            
            if qLoss_< test_for_best:
                test_for_best = qLoss_
                saver.save(sess, os.path.join(log_dir,'model_checkpoint_for_test'),global_step=i)
                test_for_iter = i
    
             
            if i % 100 == 0:
                elapse = time.time() - start_time
                time_left = (max_iters-i-1)* elapse
                print('\nIteration: {:0>5d}({:0.2%}) of {} \t Time left:{:02d}:{:02d}:{:02d}\t{}\n'.format(i,i/max_iters,max_iters,\
                     int(time_left/3600),int(time_left%3600/60),int(time_left%60),test_for_iter))
                
                print('{0:<8s} | {1:<15s} | {2:<15s} | {3:<15s} | {4:<15s} | {5:<15s}'\
                    .format('Loss','generator','discriminator','Q network','Q_continous','Q_categorical'))
                print('-' * 98)
                row_fmt = '{0:<8s} | {1:<15.3f} | {2:<15.3f} | {3:<15.3f} | {4:<15.3f} | {5:<15.3f}'
                print(row_fmt.format('train',*history['train_loss'][-1]))
                print(row_fmt.format('test' ,*history['test_loss'][-1]))
                save_spectrum(spec, i)
                
        

            if i %1000 ==0:
                saver.save(sess, os.path.join(ckpt_dir,'model_checkpoint'),global_step=i)
            
        pickle.dump(history,open(rgan_dir+'/rgan_pickle.pkl','wb'))

# %%
tf.reset_default_graph()
max_iters = 20000
train_rgan(max_iters =max_iters)
# Out:
# Iteration: 00000(0.00%) of 20000 	 Time left:40:38:40	0
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.060           | 0.264           | 0.136           | 0.440           | 0.000
# test     | -0.574          | -0.780          | 0.141           | 0.523           | 0.000
#
# Iteration: 00100(0.50%) of 20000 	 Time left:01:17:36	78
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.184         | -101.278        | 0.142           | 0.547           | 0.000
# test     | -9.738          | -108.460        | 0.125           | 0.815           | 0.000
#
# Iteration: 00200(1.00%) of 20000 	 Time left:01:17:12	125
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.742         | -183.930        | 0.028           | 0.365           | 0.000
# test     | 4.016           | -192.045        | 0.068           | 0.419           | 0.000
#
# Iteration: 00300(1.50%) of 20000 	 Time left:01:16:49	125
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -16.772         | -159.356        | 0.021           | 0.358           | 0.000
# test     | -13.333         | -163.885        | 0.038           | 0.436           | 0.000
#
# Iteration: 00400(2.00%) of 20000 	 Time left:01:16:26	392
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 18.369          | -176.765        | 0.037           | 0.260           | 0.000
# test     | 11.573          | -195.032        | 0.063           | 0.287           | 0.000
#
# Iteration: 00500(2.50%) of 20000 	 Time left:01:16:02	469
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -26.004         | 141.622         | 0.027           | 0.226           | 0.000
# test     | -26.677         | 133.752         | 0.023           | 0.227           | 0.000
#
# Iteration: 00600(3.00%) of 20000 	 Time left:01:20:41	469
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 5.175           | 35.219          | 0.019           | 0.339           | 0.000
# test     | 3.718           | 32.633          | 0.031           | 0.309           | 0.000
#
# Iteration: 00700(3.50%) of 20000 	 Time left:01:15:15	663
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -44.129         | 101.291         | 0.015           | 0.267           | 0.000
# test     | -50.482         | 97.177          | 0.034           | 0.310           | 0.000
#
# Iteration: 00800(4.00%) of 20000 	 Time left:01:14:52	663
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -126.025        | 131.100         | 0.016           | 0.231           | 0.000
# test     | -143.982        | 98.303          | 0.030           | 0.320           | 0.000
#
# Iteration: 00900(4.50%) of 20000 	 Time left:01:09:31	663
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.935         | -58.637         | 0.014           | 0.364           | 0.000
# test     | -8.716          | -75.802         | 0.051           | 0.341           | 0.000
#
# Iteration: 01000(5.00%) of 20000 	 Time left:01:14:05	663
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -56.983         | 168.153         | 0.024           | 0.409           | 0.000
# test     | -55.523         | 163.514         | 0.026           | 0.401           | 0.000
#
# Iteration: 01100(5.50%) of 20000 	 Time left:01:13:42	663
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.455          | -107.734        | 0.010           | 0.264           | 0.000
# test     | -4.092          | -122.205        | 0.038           | 0.240           | 0.000
#
# Iteration: 01200(6.00%) of 20000 	 Time left:01:18:12	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.043         | 84.069          | 0.016           | 0.209           | 0.000
# test     | -24.418         | 83.717          | 0.045           | 0.318           | 0.000
#
# Iteration: 01300(6.50%) of 20000 	 Time left:01:12:55	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -20.614         | 40.782          | 0.007           | 0.240           | 0.000
# test     | -26.267         | 38.785          | 0.032           | 0.339           | 0.000
#
# Iteration: 01400(7.00%) of 20000 	 Time left:01:12:32	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 10.262          | -133.537        | 0.025           | 0.324           | 0.000
# test     | 5.276           | -136.247        | 0.020           | 0.333           | 0.000
#
# Iteration: 01500(7.50%) of 20000 	 Time left:01:12:08	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -47.854         | -221.713        | 0.020           | 0.321           | 0.000
# test     | -59.749         | -223.393        | 0.037           | 0.210           | 0.000
#
# Iteration: 01600(8.00%) of 20000 	 Time left:01:11:45	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -23.807         | -198.339        | 0.017           | 0.205           | 0.000
# test     | -42.576         | -201.321        | 0.038           | 0.247           | 0.000
#
# Iteration: 01700(8.50%) of 20000 	 Time left:01:16:07	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -33.388         | -199.452        | 0.009           | 0.296           | 0.000
# test     | -40.749         | -200.816        | 0.029           | 0.455           | 0.000
#
# Iteration: 01800(9.00%) of 20000 	 Time left:01:10:58	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -213.368        | 137.152         | 0.016           | 0.184           | 0.000
# test     | -254.743        | 95.952          | 0.025           | 0.173           | 0.000
#
# Iteration: 01900(9.50%) of 20000 	 Time left:01:10:35	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -352.946        | 183.809         | 0.011           | 0.134           | 0.000
# test     | -395.991        | 172.242         | 0.022           | 0.232           | 0.000
#
# Iteration: 02000(10.00%) of 20000 	 Time left:01:10:11	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 17.031          | 205.729         | 0.013           | 0.183           | 0.000
# test     | 16.223          | 204.887         | 0.032           | 0.274           | 0.000
#
# Iteration: 02100(10.50%) of 20000 	 Time left:01:09:48	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -31.466         | -197.348        | 0.005           | 0.241           | 0.000
# test     | -46.165         | -203.574        | 0.024           | 0.336           | 0.000
#
# Iteration: 02200(11.00%) of 20000 	 Time left:01:14:02	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -31.976         | 225.465         | 0.018           | 0.327           | 0.000
# test     | -30.947         | 223.474         | 0.025           | 0.403           | 0.000
#
# Iteration: 02300(11.50%) of 20000 	 Time left:01:09:01	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.938         | -29.854         | 0.009           | 0.357           | 0.000
# test     | -8.066          | -37.962         | 0.024           | 0.301           | 0.000
#
# Iteration: 02400(12.00%) of 20000 	 Time left:01:08:38	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -90.029         | -6.182          | 0.011           | 0.440           | 0.000
# test     | -89.061         | -13.842         | 0.035           | 0.653           | 0.000
#
# Iteration: 02500(12.50%) of 20000 	 Time left:01:09:59	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -38.942         | 82.370          | 0.008           | 0.332           | 0.000
# test     | -37.259         | 78.495          | 0.026           | 0.402           | 0.000
#
# Iteration: 02600(13.00%) of 20000 	 Time left:01:07:51	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.671           | 4.529           | 0.010           | 0.359           | 0.000
# test     | -0.995          | 5.021           | 0.032           | 0.459           | 0.000
#
# Iteration: 02700(13.50%) of 20000 	 Time left:01:11:57	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.683           | -55.210         | 0.010           | 0.229           | 0.000
# test     | 6.479           | -59.182         | 0.047           | 0.433           | 0.000
#
# Iteration: 02800(14.00%) of 20000 	 Time left:01:07:04	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -24.674         | -23.641         | 0.013           | 0.204           | 0.000
# test     | -12.425         | -28.956         | 0.051           | 0.258           | 0.000
#
# Iteration: 02900(14.50%) of 20000 	 Time left:01:06:41	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -54.407         | 35.743          | 0.004           | 0.208           | 0.000
# test     | -47.082         | 21.174          | 0.030           | 0.202           | 0.000
#
# Iteration: 03000(15.00%) of 20000 	 Time left:01:10:42	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -103.045        | 114.628         | 0.020           | 0.221           | 0.000
# test     | -104.718        | 104.398         | 0.039           | 0.373           | 0.000
#
# Iteration: 03100(15.50%) of 20000 	 Time left:01:05:54	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -79.045         | -8.375          | 0.005           | 0.246           | 0.000
# test     | -93.300         | -14.016         | 0.019           | 0.326           | 0.000
#
# Iteration: 03200(16.00%) of 20000 	 Time left:01:09:53	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -65.635         | -23.379         | 0.015           | 0.428           | 0.000
# test     | -51.213         | -29.010         | 0.037           | 0.515           | 0.000
#
# Iteration: 03300(16.50%) of 20000 	 Time left:01:05:07	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -39.368         | 42.628          | 0.011           | 0.278           | 0.000
# test     | -35.661         | 23.154          | 0.026           | 0.349           | 0.000
#
# Iteration: 03400(17.00%) of 20000 	 Time left:01:04:44	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -23.480         | 49.864          | 0.012           | 0.283           | 0.000
# test     | -30.482         | 48.762          | 0.017           | 0.397           | 0.000
#
# Iteration: 03500(17.50%) of 20000 	 Time left:01:00:36	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -11.354         | 75.907          | 0.016           | 0.338           | 0.000
# test     | -11.574         | 75.183          | 0.031           | 0.383           | 0.000
#
# Iteration: 03600(18.00%) of 20000 	 Time left:01:03:57	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.478           | 46.470          | 0.005           | 0.213           | 0.000
# test     | 5.623           | 45.687          | 0.036           | 0.216           | 0.000
#
# Iteration: 03700(18.50%) of 20000 	 Time left:01:07:48	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -34.498         | 100.053         | 0.011           | 0.281           | 0.000
# test     | -36.121         | 99.013          | 0.025           | 0.211           | 0.000
#
# Iteration: 03800(19.00%) of 20000 	 Time left:01:07:23	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -36.608         | 75.536          | 0.009           | 0.200           | 0.000
# test     | -45.042         | 74.819          | 0.043           | 0.255           | 0.000
#
# Iteration: 03900(19.50%) of 20000 	 Time left:01:02:47	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.904          | 116.832         | 0.007           | 0.180           | 0.000
# test     | 2.100           | 113.087         | 0.026           | 0.189           | 0.000
#
# Iteration: 04000(20.00%) of 20000 	 Time left:01:02:23	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 8.199           | 21.068          | 0.008           | 0.286           | 0.000
# test     | -0.237          | 20.457          | 0.039           | 0.287           | 0.000
#
# Iteration: 04100(20.50%) of 20000 	 Time left:01:02:00	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -10.077         | 101.218         | 0.016           | 0.168           | 0.000
# test     | -17.599         | 101.295         | 0.036           | 0.316           | 0.000
#
# Iteration: 04200(21.00%) of 20000 	 Time left:01:01:36	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -86.307         | 29.454          | 0.003           | 0.268           | 0.000
# test     | -105.757        | 30.272          | 0.035           | 0.224           | 0.000
#
# Iteration: 04300(21.50%) of 20000 	 Time left:01:01:13	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -41.603         | -31.630         | 0.006           | 0.322           | 0.000
# test     | -39.661         | -56.415         | 0.022           | 0.341           | 0.000
#
# Iteration: 04400(22.00%) of 20000 	 Time left:01:00:50	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -143.204        | -12.487         | 0.023           | 0.133           | 0.000
# test     | -153.427        | -26.633         | 0.028           | 0.180           | 0.000
#
# Iteration: 04500(22.50%) of 20000 	 Time left:01:04:28	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -39.402         | 18.877          | 0.018           | 0.372           | 0.000
# test     | -54.422         | 14.673          | 0.029           | 0.260           | 0.000
#
# Iteration: 04600(23.00%) of 20000 	 Time left:01:04:03	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -45.142         | -121.250        | 0.009           | 0.431           | 0.000
# test     | -40.770         | -129.741        | 0.026           | 0.403           | 0.000
#
# Iteration: 04700(23.50%) of 20000 	 Time left:01:03:38	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -36.468         | 54.249          | 0.011           | 0.238           | 0.000
# test     | -39.136         | 51.859          | 0.033           | 0.392           | 0.000
#
# Iteration: 04800(24.00%) of 20000 	 Time left:00:59:16	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.905          | 91.205          | 0.013           | 0.403           | 0.000
# test     | -9.845          | 89.067          | 0.032           | 0.340           | 0.000
#
# Iteration: 04900(24.50%) of 20000 	 Time left:00:58:53	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.676           | -109.047        | 0.004           | 0.242           | 0.000
# test     | 0.933           | -113.860        | 0.025           | 0.298           | 0.000
#
# Iteration: 05000(25.00%) of 20000 	 Time left:01:02:23	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.848         | -88.789         | 0.013           | 0.181           | 0.000
# test     | -18.183         | -92.768         | 0.026           | 0.297           | 0.000
#
# Iteration: 05100(25.50%) of 20000 	 Time left:01:01:58	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.829         | 43.010          | 0.005           | 0.189           | 0.000
# test     | -29.160         | 40.395          | 0.034           | 0.276           | 0.000
#
# Iteration: 05200(26.00%) of 20000 	 Time left:00:57:42	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -33.492         | -193.575        | 0.010           | 0.228           | 0.000
# test     | -35.486         | -195.728        | 0.016           | 0.316           | 0.000
#
# Iteration: 05300(26.50%) of 20000 	 Time left:00:57:19	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.049          | 127.350         | 0.010           | 0.265           | 0.000
# test     | -4.734          | 126.283         | 0.036           | 0.145           | 0.000
#
# Iteration: 05400(27.00%) of 20000 	 Time left:01:04:31	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.499          | -103.164        | 0.017           | 0.279           | 0.000
# test     | -6.737          | -104.726        | 0.025           | 0.179           | 0.000
#
# Iteration: 05500(27.50%) of 20000 	 Time left:01:00:18	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.471          | 82.489          | 0.010           | 0.265           | 0.000
# test     | -27.142         | 78.591          | 0.025           | 0.258           | 0.000
#
# Iteration: 05600(28.00%) of 20000 	 Time left:00:56:09	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.432         | -41.732         | 0.010           | 0.203           | 0.000
# test     | -33.398         | -40.855         | 0.024           | 0.280           | 0.000
#
# Iteration: 05700(28.50%) of 20000 	 Time left:00:55:45	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -92.426         | 33.761          | 0.009           | 0.322           | 0.000
# test     | -167.359        | 31.511          | 0.023           | 0.377           | 0.000
#
# Iteration: 05800(29.00%) of 20000 	 Time left:00:55:22	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 8.170           | 115.870         | 0.008           | 0.370           | 0.000
# test     | 9.236           | 115.208         | 0.036           | 0.348           | 0.000
#
# Iteration: 05900(29.50%) of 20000 	 Time left:00:58:39	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.093         | 134.951         | 0.007           | 0.318           | 0.000
# test     | -8.925          | 127.931         | 0.028           | 0.334           | 0.000
#
# Iteration: 06000(30.00%) of 20000 	 Time left:00:54:35	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -28.214         | -58.994         | 0.007           | 0.271           | 0.000
# test     | -34.402         | -59.168         | 0.042           | 0.284           | 0.000
#
# Iteration: 06100(30.50%) of 20000 	 Time left:00:54:12	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 27.790          | -200.728        | 0.006           | 0.212           | 0.000
# test     | 28.681          | -202.497        | 0.037           | 0.343           | 0.000
#
# Iteration: 06200(31.00%) of 20000 	 Time left:00:53:48	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -50.154         | -0.764          | 0.007           | 0.246           | 0.000
# test     | -47.886         | -6.742          | 0.019           | 0.288           | 0.000
#
# Iteration: 06300(31.50%) of 20000 	 Time left:00:53:25	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 4.985           | -71.662         | 0.016           | 0.298           | 0.000
# test     | 5.483           | -75.182         | 0.075           | 0.349           | 0.000
#
# Iteration: 06400(32.00%) of 20000 	 Time left:00:53:02	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 3.131           | -58.698         | 0.006           | 0.163           | 0.000
# test     | -2.823          | -58.168         | 0.025           | 0.262           | 0.000
#
# Iteration: 06500(32.50%) of 20000 	 Time left:00:52:38	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.878           | 6.792           | 0.012           | 0.121           | 0.000
# test     | 10.724          | 3.307           | 0.021           | 0.222           | 0.000
#
# Iteration: 06600(33.00%) of 20000 	 Time left:00:52:15	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.839           | 55.050          | 0.003           | 0.313           | 0.000
# test     | 5.372           | 54.100          | 0.014           | 0.208           | 0.000
#
# Iteration: 06700(33.50%) of 20000 	 Time left:00:51:51	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -18.391         | 78.305          | 0.018           | 0.193           | 0.000
# test     | -16.379         | 78.562          | 0.042           | 0.392           | 0.000
#
# Iteration: 06800(34.00%) of 20000 	 Time left:00:51:28	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -33.279         | -56.860         | 0.002           | 0.166           | 0.000
# test     | -35.194         | -61.515         | 0.027           | 0.163           | 0.000
#
# Iteration: 06900(34.50%) of 20000 	 Time left:00:54:29	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 1.752           | 104.093         | 0.004           | 0.244           | 0.000
# test     | 0.658           | 104.152         | 0.020           | 0.214           | 0.000
#
# Iteration: 07000(35.00%) of 20000 	 Time left:00:50:41	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.864           | 189.421         | 0.008           | 0.311           | 0.000
# test     | -0.828          | 190.228         | 0.032           | 0.133           | 0.000
#
# Iteration: 07100(35.50%) of 20000 	 Time left:00:50:18	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.289         | 234.879         | 0.010           | 0.214           | 0.000
# test     | -16.019         | 235.349         | 0.039           | 0.347           | 0.000
#
# Iteration: 07200(36.00%) of 20000 	 Time left:00:53:14	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.737          | 46.995          | 0.006           | 0.153           | 0.000
# test     | -1.923          | 47.645          | 0.023           | 0.335           | 0.000
#
# Iteration: 07300(36.50%) of 20000 	 Time left:00:49:31	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -47.789         | -226.423        | 0.006           | 0.346           | 0.000
# test     | -56.545         | -237.862        | 0.015           | 0.315           | 0.000
#
# Iteration: 07400(37.00%) of 20000 	 Time left:00:49:08	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 6.085           | 26.551          | 0.008           | 0.237           | 0.000
# test     | 4.299           | 19.825          | 0.030           | 0.306           | 0.000
#
# Iteration: 07500(37.50%) of 20000 	 Time left:00:48:44	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.188         | -170.217        | 0.007           | 0.268           | 0.000
# test     | -21.903         | -168.246        | 0.038           | 0.335           | 0.000
#
# Iteration: 07600(38.00%) of 20000 	 Time left:00:48:21	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -34.142         | 10.896          | 0.012           | 0.164           | 0.000
# test     | -35.191         | 8.422           | 0.031           | 0.208           | 0.000
#
# Iteration: 07700(38.50%) of 20000 	 Time left:00:51:09	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.222          | -19.593         | 0.003           | 0.315           | 0.000
# test     | -7.065          | -20.365         | 0.027           | 0.340           | 0.000
#
# Iteration: 07800(39.00%) of 20000 	 Time left:00:47:34	1104
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -34.815         | -122.893        | 0.009           | 0.351           | 0.000
# test     | -43.137         | -126.926        | 0.017           | 0.389           | 0.000
#
# Iteration: 07900(39.50%) of 20000 	 Time left:00:47:11	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -37.551         | 118.807         | 0.003           | 0.307           | 0.000
# test     | -43.099         | 117.200         | 0.025           | 0.311           | 0.000
#
# Iteration: 08000(40.00%) of 20000 	 Time left:00:53:02	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -29.327         | 23.853          | 0.004           | 0.298           | 0.000
# test     | -31.521         | 19.719          | 0.029           | 0.332           | 0.000
#
# Iteration: 08100(40.50%) of 20000 	 Time left:00:49:29	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 7.207           | -95.500         | 0.012           | 0.231           | 0.000
# test     | 3.578           | -95.684         | 0.018           | 0.276           | 0.000
#
# Iteration: 08200(41.00%) of 20000 	 Time left:00:46:00	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 7.498           | -74.438         | 0.005           | 0.240           | 0.000
# test     | 8.103           | -79.505         | 0.030           | 0.246           | 0.000
#
# Iteration: 08300(41.50%) of 20000 	 Time left:00:45:37	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -17.962         | 44.498          | 0.005           | 0.212           | 0.000
# test     | -29.628         | 39.530          | 0.026           | 0.246           | 0.000
#
# Iteration: 08400(42.00%) of 20000 	 Time left:00:45:14	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -109.935        | 65.679          | 0.003           | 0.161           | 0.000
# test     | -118.248        | 56.013          | 0.028           | 0.393           | 0.000
#
# Iteration: 08500(42.50%) of 20000 	 Time left:00:44:50	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 19.781          | -199.815        | 0.011           | 0.391           | 0.000
# test     | 15.201          | -202.489        | 0.030           | 0.327           | 0.000
#
# Iteration: 08600(43.00%) of 20000 	 Time left:00:47:25	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -82.026         | 91.121          | 0.003           | 0.219           | 0.000
# test     | -67.376         | 80.487          | 0.027           | 0.313           | 0.000
#
# Iteration: 08700(43.50%) of 20000 	 Time left:00:47:00	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.187         | -3.894          | 0.004           | 0.243           | 0.000
# test     | -18.064         | -3.556          | 0.023           | 0.248           | 0.000
#
# Iteration: 08800(44.00%) of 20000 	 Time left:00:46:35	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.102           | 137.198         | 0.005           | 0.177           | 0.000
# test     | 3.228           | 134.808         | 0.051           | 0.291           | 0.000
#
# Iteration: 08900(44.50%) of 20000 	 Time left:00:46:10	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -78.597         | -29.942         | 0.012           | 0.364           | 0.000
# test     | -41.331         | -38.465         | 0.030           | 0.257           | 0.000
#
# Iteration: 09000(45.00%) of 20000 	 Time left:00:42:53	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -57.837         | -87.160         | 0.010           | 0.424           | 0.000
# test     | -42.643         | -122.178        | 0.021           | 0.628           | 0.000
#
# Iteration: 09100(45.50%) of 20000 	 Time left:00:42:30	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -36.119         | -113.420        | 0.002           | 0.254           | 0.000
# test     | -43.020         | -119.622        | 0.027           | 0.363           | 0.000
#
# Iteration: 09200(46.00%) of 20000 	 Time left:00:42:06	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -65.725         | -24.397         | 0.010           | 0.217           | 0.000
# test     | -67.965         | -33.906         | 0.023           | 0.263           | 0.000
#
# Iteration: 09300(46.50%) of 20000 	 Time left:00:44:30	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -70.570         | 56.554          | 0.007           | 0.209           | 0.000
# test     | -82.734         | 55.054          | 0.041           | 0.250           | 0.000
#
# Iteration: 09400(47.00%) of 20000 	 Time left:00:41:20	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -159.843        | 12.446          | 0.011           | 0.499           | 0.000
# test     | -166.727        | -45.068         | 0.032           | 0.383           | 0.000
#
# Iteration: 09500(47.50%) of 20000 	 Time left:00:40:56	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.447         | 52.968          | 0.012           | 0.401           | 0.000
# test     | -15.470         | 53.339          | 0.023           | 0.413           | 0.000
#
# Iteration: 09600(48.00%) of 20000 	 Time left:00:40:33	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -25.079         | -292.360        | 0.004           | 0.252           | 0.000
# test     | -28.305         | -291.341        | 0.033           | 0.288           | 0.000
#
# Iteration: 09700(48.50%) of 20000 	 Time left:00:40:09	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.310          | 225.795         | 0.008           | 0.247           | 0.000
# test     | -8.189          | 223.378         | 0.027           | 0.358           | 0.000
#
# Iteration: 09800(49.00%) of 20000 	 Time left:00:39:46	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -12.356         | -124.249        | 0.011           | 0.309           | 0.000
# test     | 10.621          | -150.676        | 0.023           | 0.278           | 0.000
#
# Iteration: 09900(49.50%) of 20000 	 Time left:00:39:23	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -144.116        | 151.201         | 0.005           | 0.299           | 0.000
# test     | -142.258        | 131.011         | 0.023           | 0.312           | 0.000
#
# Iteration: 10000(50.00%) of 20000 	 Time left:00:41:35	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 49.978          | -64.949         | 0.005           | 0.196           | 0.000
# test     | 38.063          | -92.896         | 0.024           | 0.224           | 0.000
#
# Iteration: 10100(50.50%) of 20000 	 Time left:00:41:10	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -16.558         | 53.142          | 0.005           | 0.335           | 0.000
# test     | -22.205         | 45.099          | 0.043           | 0.268           | 0.000
#
# Iteration: 10200(51.00%) of 20000 	 Time left:00:40:45	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -74.728         | -87.612         | 0.005           | 0.309           | 0.000
# test     | -77.136         | -89.879         | 0.021           | 0.344           | 0.000
#
# Iteration: 10300(51.50%) of 20000 	 Time left:00:37:49	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.782          | -19.100         | 0.028           | 0.245           | 0.000
# test     | -30.720         | -26.916         | 0.020           | 0.247           | 0.000
#
# Iteration: 10400(52.00%) of 20000 	 Time left:00:37:26	7849
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -84.718         | 121.657         | 0.003           | 0.223           | 0.000
# ...
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.410         | -55.210         | 0.007           | 0.251           | 0.000
# test     | -10.871         | -53.308         | 0.021           | 0.255           | 0.000
#
# Iteration: 16600(83.00%) of 20000 	 Time left:00:12:22	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.415           | -93.211         | 0.006           | 0.393           | 0.000
# test     | -2.751          | -93.937         | 0.030           | 0.319           | 0.000
#
# Iteration: 16700(83.50%) of 20000 	 Time left:00:12:51	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.539          | -157.686        | 0.001           | 0.291           | 0.000
# test     | -7.892          | -157.653        | 0.037           | 0.391           | 0.000
#
# Iteration: 16800(84.00%) of 20000 	 Time left:00:12:28	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.893          | -72.951         | 0.023           | 0.252           | 0.000
# test     | -6.005          | -74.757         | 0.024           | 0.237           | 0.000
#
# Iteration: 16900(84.50%) of 20000 	 Time left:00:12:05	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -6.339          | -74.638         | 0.010           | 0.352           | 0.000
# test     | -9.137          | -74.170         | 0.029           | 0.272           | 0.000
#
# Iteration: 17000(85.00%) of 20000 	 Time left:00:12:28	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -5.080          | -71.128         | 0.006           | 0.313           | 0.000
# test     | -5.200          | -71.003         | 0.029           | 0.293           | 0.000
#
# Iteration: 17100(85.50%) of 20000 	 Time left:00:12:03	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.984          | -94.261         | 0.001           | 0.321           | 0.000
# test     | -6.130          | -95.097         | 0.022           | 0.254           | 0.000
#
# Iteration: 17200(86.00%) of 20000 	 Time left:00:10:54	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -19.761         | -164.789        | 0.004           | 0.256           | 0.000
# test     | -26.301         | -163.316        | 0.021           | 0.243           | 0.000
#
# Iteration: 17300(86.50%) of 20000 	 Time left:00:10:31	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -34.708         | -146.676        | 0.007           | 0.271           | 0.000
# test     | -37.815         | -147.927        | 0.042           | 0.230           | 0.000
#
# Iteration: 17400(87.00%) of 20000 	 Time left:00:10:08	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -51.357         | 160.972         | 0.003           | 0.325           | 0.000
# test     | -7.689          | 107.836         | 0.017           | 0.257           | 0.000
#
# Iteration: 17500(87.50%) of 20000 	 Time left:00:09:44	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -169.766        | 35.292          | 0.005           | 0.310           | 0.000
# test     | -223.890        | 25.238          | 0.016           | 0.221           | 0.000
#
# Iteration: 17600(88.00%) of 20000 	 Time left:00:09:21	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -9.063          | -271.092        | 0.004           | 0.248           | 0.000
# test     | -14.891         | -268.271        | 0.032           | 0.314           | 0.000
#
# Iteration: 17700(88.50%) of 20000 	 Time left:00:08:57	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 65.358          | -298.633        | 0.002           | 0.284           | 0.000
# test     | 65.200          | -302.421        | 0.025           | 0.225           | 0.000
#
# Iteration: 17800(89.00%) of 20000 	 Time left:00:09:08	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -49.922         | -36.868         | 0.002           | 0.181           | 0.000
# test     | -58.455         | -37.557         | 0.009           | 0.210           | 0.000
#
# Iteration: 17900(89.50%) of 20000 	 Time left:00:08:11	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -69.695         | -24.805         | 0.005           | 0.278           | 0.000
# test     | -86.892         | -19.142         | 0.032           | 0.301           | 0.000
#
# Iteration: 18000(90.00%) of 20000 	 Time left:00:08:18	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.285          | -2.208          | 0.004           | 0.201           | 0.000
# test     | -0.121          | -2.270          | 0.031           | 0.290           | 0.000
#
# Iteration: 18100(90.50%) of 20000 	 Time left:00:07:24	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -7.241          | 29.254          | 0.003           | 0.268           | 0.000
# test     | -11.728         | 30.533          | 0.028           | 0.206           | 0.000
#
# Iteration: 18200(91.00%) of 20000 	 Time left:00:07:00	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -3.484          | 98.068          | 0.004           | 0.237           | 0.000
# test     | -1.762          | 97.093          | 0.018           | 0.297           | 0.000
#
# Iteration: 18300(91.50%) of 20000 	 Time left:00:06:37	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 8.378           | 89.101          | 0.005           | 0.276           | 0.000
# test     | 4.312           | 89.086          | 0.022           | 0.265           | 0.000
#
# Iteration: 18400(92.00%) of 20000 	 Time left:00:06:14	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -0.662          | -6.497          | 0.003           | 0.298           | 0.000
# test     | -0.892          | -6.458          | 0.030           | 0.253           | 0.000
#
# Iteration: 18500(92.50%) of 20000 	 Time left:00:05:50	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.792          | -3.850          | 0.001           | 0.212           | 0.000
# test     | -3.892          | -3.894          | 0.024           | 0.255           | 0.000
#
# Iteration: 18600(93.00%) of 20000 	 Time left:00:05:27	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 8.631           | -42.290         | 0.001           | 0.221           | 0.000
# test     | 9.714           | -44.834         | 0.051           | 0.300           | 0.000
#
# Iteration: 18700(93.50%) of 20000 	 Time left:00:05:03	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.834           | 7.168           | 0.001           | 0.302           | 0.000
# test     | 0.315           | 7.153           | 0.016           | 0.297           | 0.000
#
# Iteration: 18800(94.00%) of 20000 	 Time left:00:04:59	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -4.704          | 11.782          | 0.009           | 0.279           | 0.000
# test     | -3.757          | 11.754          | 0.031           | 0.282           | 0.000
#
# Iteration: 18900(94.50%) of 20000 	 Time left:00:04:34	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 0.065           | -12.755         | 0.004           | 0.218           | 0.000
# test     | -0.136          | -12.716         | 0.034           | 0.315           | 0.000
#
# Iteration: 19000(95.00%) of 20000 	 Time left:00:03:53	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | 2.965           | -59.261         | 0.006           | 0.334           | 0.000
# test     | 1.718           | -59.443         | 0.042           | 0.357           | 0.000
#
# Iteration: 19100(95.50%) of 20000 	 Time left:00:03:30	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.710          | -0.108          | 0.005           | 0.273           | 0.000
# test     | -1.848          | -0.103          | 0.031           | 0.275           | 0.000
#
# Iteration: 19200(96.00%) of 20000 	 Time left:00:03:19	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -1.117          | -97.081         | 0.003           | 0.175           | 0.000
# test     | -6.410          | -99.116         | 0.023           | 0.311           | 0.000
#
# Iteration: 19300(96.50%) of 20000 	 Time left:00:02:43	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -14.778         | -17.237         | 0.006           | 0.281           | 0.000
# test     | -12.180         | -18.462         | 0.013           | 0.313           | 0.000
#
# Iteration: 19400(97.00%) of 20000 	 Time left:00:02:20	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -8.813          | 33.924          | 0.003           | 0.256           | 0.000
# test     | -9.742          | 32.397          | 0.014           | 0.358           | 0.000
#
# Iteration: 19500(97.50%) of 20000 	 Time left:00:01:56	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -21.640         | 29.304          | 0.002           | 0.232           | 0.000
# test     | -24.255         | 29.282          | 0.045           | 0.199           | 0.000
#
# Iteration: 19600(98.00%) of 20000 	 Time left:00:01:33	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -70.869         | -105.512        | 0.011           | 0.332           | 0.000
# test     | -76.347         | -119.833        | 0.023           | 0.282           | 0.000
#
# Iteration: 19700(98.50%) of 20000 	 Time left:00:01:09	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -71.065         | -39.075         | 0.002           | 0.471           | 0.000
# test     | -83.497         | -47.823         | 0.030           | 0.564           | 0.000
#
# Iteration: 19800(99.00%) of 20000 	 Time left:00:00:49	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -13.693         | 171.155         | 0.004           | 0.423           | 0.000
# test     | -16.600         | 170.412         | 0.031           | 0.337           | 0.000
#
# Iteration: 19900(99.50%) of 20000 	 Time left:00:00:23	15676
#
# Loss     | generator       | discriminator   | Q network       | Q_continous     | Q_categorical
# --------------------------------------------------------------------------------------------------
# train    | -39.778         | -3.919          | 0.004           | 0.357           | 0.000
# test     | -42.273         | -4.597          | 0.023           | 0.308           | 0.000

# %% [markdown]
# ### Show the result

# %%
hist = pickle.load(open(rgan_dir+'/rgan_pickle.pkl','rb'))

# %%
losses = ['generator','discriminator','Q network','Q_continous','Q_categorical']

# %% [markdown]
# Use pandas to realize the two demensional dict-like tabular.

# %%
def iter_to_epoch( p,input,max_iters):
    num_iters = int(input.shape[0]/batch_size)+1
    num_eopch = int(max_iters / num_iters)
    epoch_loss = np.zeros([num_eopch,1])
    for i in num_eopch:
        epoch_loss[i] = np.mean(p[i*num_iters:(i+1)*num_iters])
    return epoch_loss

# %%
for p in hist.keys():
    hist[p] = pd.DataFrame(hist[p],columns=losses)

# %%
for p in hist.keys():
    plt.plot(hist[p]['discriminator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Discriminator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['generator'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Generator loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %%
for p in hist.keys():
    plt.plot(hist[p]['Q network'],label = '{}'.format(p))
plt.legend(['train loss','test loss'])
plt.title('Q network loss per iteration')
plt.xlabel('iteration')
plt.ylabel(r'Loss $L_Q$ ')
plt.show()

# %% [markdown]
# ### For test Phase

# %%
def test(ckpt_dir=ckpt_dir):
    
    with tf.Session(config = tf.ConfigProto(allow_soft_placement=True,log_device_placement=True)) as sess:
        # build graph
        with tf.device(device):
            gen,z_rand,z_cont,z_cat,cont_real,cont_loss_r,real_data,real_label = build_graph(is_test=True)
        
        # use saver to reload the parametes
        saver = tf.train.Saver()
        
        #saver.restore(sess,ckpt_dir+'\\model_checkpoint-19000')
        #saver.restore(sess,tf.train.latest_checkpoint(ckpt_dir))
        
        ############################## For testing error  ##########################
        saver.restore(sess, ckpt_dir+'\\model_checkpoint_for_test-15676')
        
        ###########################################  Experiment : Generator #################
        # Gererate random labels as conditions , [0,1] gausson distribution
        z_rand_sample = np.random.normal(0,0.3,[batch_size,z_dim])
        # To construct grid sample 
        #z_cat_sample = np.reshape(np.array([int(e/batch_size*10) for e in range(batch_size)]),[batch_size,len(cat_list)])                
        z_cat_sample = np.random.normal(0,0.3,[batch_size,10])
        #z_cont_sample = np.zeros((batch_size,cont_num))
        z_cont_order = np.linspace(-1,1,batch_size)
        if cont_num>0:
            z_cont_temp = np.zeros((batch_size,cont_num-1))
            z_cont_sample = np.insert(z_cont_temp,0,z_cont_order,axis=1)
        else:
            z_cont_sample = z_cont_oder

        samples = sess.run(gen,{z_rand:z_rand_sample,z_cat:z_cat_sample,z_cont:z_cont_sample})

        save_spectrum(samples, 0,is_show=True)
        
        ############################################  Experiment : Predict ##################
        def cv_proc(y):
            y = ymid + y*(ymax-ymin)/2
            return y
        
        Hist_predict = defaultdict(list)
        # Prediction & R2 score 
        y_train_predict,y_test_predict = cv_proc(sess.run(cont_real,{real_data:x_train,real_label:y_train})),\
                                         cv_proc(sess.run(cont_real,{real_data:x_test,real_label:y_train}))
        r_train,r_test = r2_score(cv_proc(y_train),y_train_predict),r2_score(cv_proc(y_test),y_test_predict)
        # Restore
        Hist_predict['Training'] = [y_train_predict,cv_proc(y_train)]
        Hist_predict['Testing'] =  [y_test_predict ,cv_proc(y_test)]
        Hist_predict['r2_score'] = [r_train, r_test]
        
        pickle.dump(Hist_predict,open(rgan_dir+'/predict_rgan_pickle.pkl','wb'))
        
    return Hist_predict

# %%
tf.reset_default_graph()
Hist_predict = test()
# Out:
# INFO:tensorflow:Restoring parameters from ./Inproved_rgan/RGAN/Experient_14/ckpt_rgan\model_checkpoint_for_test-15676
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#
# C:\Program Files\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ./Inproved_rgan/RGAN/Experient_14/ckpt_rgan\model_checkpoint_for_test-15676
# 	 [[Node: save/RestoreV2_20 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/RestoreV2_20/tensor_names, save/RestoreV2_20/shape_and_slices)]]
# 	 [[Node: save/RestoreV2_26/_1 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/gpu:0", send_device="/job:localhost/replica:0/task:0/cpu:0", send_device_incarnation=1, tensor_name="edge_146_save/RestoreV2_26", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/gpu:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-27-2bdcd46f2889> in <module>()
#       1 tf.reset_default_graph()
# ----> 2 Hist_predict = test()
#
# <ipython-input-26-a226ba0dc215> in test(ckpt_dir)
#      13
#      14         ############################## For testing error  ##########################
# ---> 15         saver.restore(sess, ckpt_dir+'\\model_checkpoint_for_test-15676')
#      16
#      17         ###########################################  Experiment : Generator #################
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1455     logging.info("Restoring parameters from %s", save_path)
#    1456     sess.run(self.saver_def.restore_op_name,
# -> 1457              {self.saver_def.filename_tensor_name: save_path})
#    1458
#    1459   @staticmethod
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1050         except KeyError:
#    1051           pass
# -> 1052       raise type(e)(node_def, op, message)
#    1053
#    1054   def _extend_graph(self):
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ./Inproved_rgan/RGAN/Experient_14/ckpt_rgan\model_checkpoint_for_test-15676
# 	 [[Node: save/RestoreV2_20 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/RestoreV2_20/tensor_names, save/RestoreV2_20/shape_and_slices)]]
# 	 [[Node: save/RestoreV2_26/_1 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/gpu:0", send_device="/job:localhost/replica:0/task:0/cpu:0", send_device_incarnation=1, tensor_name="edge_146_save/RestoreV2_26", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/gpu:0"]()]]
#
# Caused by op 'save/RestoreV2_20', defined at:
#   File "C:\Program Files\Anaconda3\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Program Files\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "C:\Program Files\Anaconda3\lib\site-packages\traitlets\config\application.py", line 653, in launch_instance
#     app.start()
#   File "C:\Program Files\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Program Files\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Program Files\Anaconda3\lib\site-packages\tornado\ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Program Files\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Program Files\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Program Files\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Program Files\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Program Files\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Program Files\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Program Files\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Program Files\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-27-2bdcd46f2889>", line 2, in <module>
#     Hist_predict = test()
#   File "<ipython-input-26-a226ba0dc215>", line 9, in test
#     saver = tf.train.Saver()
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1056, in __init__
#     self.build()
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1086, in build
#     restore_sequentially=self._restore_sequentially)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 691, in build
#     restore_sequentially, reshape)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 407, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 247, in restore_op
#     [spec.tensor.dtype])[0])
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 669, in restore_v2
#     dtypes=dtypes, name=name)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 768, in apply_op
#     op_def=op_def)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 2336, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "C:\Program Files\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1228, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Unsuccessful TensorSliceReader constructor: Failed to find any matching files for ./Inproved_rgan/RGAN/Experient_14/ckpt_rgan\model_checkpoint_for_test-15676
# 	 [[Node: save/RestoreV2_20 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save/Const_0, save/RestoreV2_20/tensor_names, save/RestoreV2_20/shape_and_slices)]]
# 	 [[Node: save/RestoreV2_26/_1 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/gpu:0", send_device="/job:localhost/replica:0/task:0/cpu:0", send_device_incarnation=1, tensor_name="edge_146_save/RestoreV2_26", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/gpu:0"]()]]

# %%
print('r -> {:.3f} | {:.3f}'.format(*Hist_predict['r2_score']))
# Out:
# r -> 0.964 | 0.733

# %%
y_train_ = Hist_predict['Training']
x_limit = np.arange(len(y_train_[1]))
plt.figure(figsize=[10,8])
plt.plot(x_limit,y_train_[0],'b-o',x_limit,y_train_[1],'--r*',ms=4)
plt.legend(['Predict','Under Truth'])
plt.show()

# %%
y_test_ = Hist_predict['Testing']
x_limit = np.arange(len(y_test_[1]))
plt.figure(figsize=[10,8])
plt.plot(x_limit,y_test_[0],'b-o',x_limit,y_test_[1],'--r*',ms=4)
plt.legend(['Predict','Under Truth'])
plt.show()
